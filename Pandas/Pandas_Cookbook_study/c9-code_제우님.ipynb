# %% [markdown]
# # Grouping for Aggregation, Filtration, and Transformation

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 15, 'display.max_rows', 10, 'display.max_colwidth', 12)

# %% [markdown]
# ## Introduction

# %% [markdown]
# * 데이터분석의 기본 : Split - Apply - Combine (분할 - 적용 - 병합)
# * Pandas에서 제공하는 .groupby 메서드를 활용하면 데이터를 다양한 방식으로 그룹화하고 각 그룹에 독립적인 함수를 적용한 다음 단일 데이터셋을 반환할 수 있음
# ---
# df.groupby(['list', 'of', 'grouping', 'columns'])
# df.groupby('single_column')

# %%
# .groupby 메서드 호출 결과는 groupby 객체, 다른 메서드 처럼 직관적이지는 않으며
# 메서드를 체인시켜야 그룹화 결과를 확인할 수 있다.
flights = pd.read_csv('data/flights.csv')
flights.groupby('MONTH')

# %% [markdown]
# ### Defining an Aggregation

# %% [markdown]
# * .groupby 메서드의 가장 일반적인 용도는 집계(aggregation)을 수행하는 것
# * 집계 : 많은 입력 시퀀스를 요약하거나 결합해 단일값으로 출력하는것
# * ex) 열 전체 합산, 최대값 찾기, 분산 및 평균 구하기 등등

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
# .agg 메서드 : groupby 객체로 집계를 수행하기 위한 메서드 
# 집계 열과 집계 함수 쌍의 딕셔너리 형태 사용 예시
(flights
     .groupby('AIRLINE')
     .agg({'ARR_DELAY':'mean'})
)
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# ...            ...
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353
#
# [14 rows x 1 columns]

# %%
# 집계 열을 인덱스 연산자에, 집계 함수를 .agg내에 str 형태로 전달하는 형태 예시 
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .agg('mean')
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
# 집계 열을 인덱스 연산자에, 집계 함수를 .agg에 집계함수를 직접 전달하는 형태 예시 
(flights
    .groupby('AIRLINE')
    ['ARR_DELAY']
    .agg(np.mean)
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
# 집계 열을 인덱스 연산자에 넣고, .agg를 생략하고 집계함수를 직접 사용 가능
# 대부분의 집계함수를 이렇게 사용 가능하다
(flights
    .groupby('AIRLINE')
    ['ARR_DELAY']
    .mean()
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %% [markdown]
# ### There's more...

# %%
# .agg에 집계함수가 아닌 함수는 사용이 불가능한 예시
(flights
   .groupby('AIRLINE')
   ['ARR_DELAY']
   .agg(np.sqrt)
)
# Out:
# C:\Users\ZeusRyu\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3262384b5a20> in <module>
#       1 # .agg에 집계함수가 아닌 함수는 사용이 불가능한 예시
# ----> 2 (flights
#       3    .groupby('AIRLINE')
#       4    ['ARR_DELAY']
#       5    .agg(np.sqrt)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     285
#     286             try:
# --> 287                 return self._python_agg_general(func, *args, **kwargs)
#     288             except KeyError:
#     289                 # TODO: KeyError is raised in _python_agg_general,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1479             try:
#    1480                 # if this function is invalid for this dtype, we will ignore it.
# -> 1481                 result = self.grouper.agg_series(obj, f)
#    1482             except TypeError:
#    1483                 warn_dropping_nuisance_columns_deprecated(type(self), "agg")
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func, preserve_dtype)
#     979
#     980         else:
# --> 981             result = self._aggregate_series_pure_python(obj, func)
#     982
#     983         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#    1008             if not initialized:
#    1009                 # We only do this validation on the first iteration
# -> 1010                 libreduction.check_result_array(res, group.dtype)
#    1011                 initialized = True
#    1012
#
# ~\anaconda3\lib\site-packages\pandas\_libs\reduction.pyx in pandas._libs.reduction.check_result_array()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\reduction.pyx in pandas._libs.reduction.check_result_array()
#
# ValueError: Must produce aggregated value

# %% [markdown]
# ## Grouping and aggregating with multiple columns and functions

# %% [markdown]
# #1 요일별 모든 항공사의 취소된 항공편 수

# %%
flights['CANCELLED'].unique() # 취소된거는 1인가 보다
# Out:
# array([0, 1], dtype=int64)

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY']) # '요일별' '항공사' 그룹화 
    ['CANCELLED']  # 취소 항공편을 집계할 열로 지정
    .agg('sum') # 취소 항공편이 1 의 값을 가지니 그 값들의 합을 모으면 원하는 결과 도출
)
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#                     ..
# WN       3          18
#          4          10
#          5           7
#          6          10
#          7           7
# Name: CANCELLED, Length: 98, dtype: int64

# %% [markdown]
# #2 요일별 모든 항공사의 취소 또는 우회한 항공편의 수와 비율

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY']) # 요일별 모든 항공사 그룹화
    ['CANCELLED', 'DIVERTED'] # 취소와 우회여부를 대해 집계할 열로 지정 
    .agg(['sum', 'mean']) # sum으로 취소, 우회 횟수를 구하고, mean으로 비율 구하여 결과 도출 
)
# Out:
# <ipython-input-11-6c86afd2dd2f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (flights
#                 CANCELLED           DIVERTED
#                       sum      mean      sum      mean
# AIRLINE WEEKDAY
# AA      1              41  0.032106        6  0.004699
#         2               9  0.007341        2  0.001631
#         3              16  0.011949        2  0.001494
#         4              20  0.015004        5  0.003751
#         5              18  0.014151        1  0.000786
# ...                   ...       ...      ...       ...
# WN      3              18  0.014118        2  0.001569
#         4              10  0.007911        4  0.003165
#         5               7  0.005828        0  0.000000
#         6              10  0.010132        3  0.003040
#         7               7  0.006066        3  0.002600
#
# [98 rows x 4 columns]

# %% [markdown]
# #3 각 출발지와 도착지에 대해 총 항공편 수, 취소된 항공편의 수와 비율, 비행시간의 평균과 분산

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR']) # 출발지, 도착지 기준 그룹화
    .agg({'CANCELLED':['sum', 'mean', 'size'], # 그룹의 취소 열에 대한 합계, 평균, 크기(몇개의 행이 있는지)
          'AIR_TIME':['mean', 'var']}) # 비행시간 열에 대해 평균과 분산 계산
)
# Out:
#                  CANCELLED                   AIR_TIME
#                        sum      mean size        mean         var
# ORG_AIR DEST_AIR
# ATL     ABE              0  0.000000   31   96.387097   45.778495
#         ABQ              0  0.000000   16  170.500000   87.866667
#         ABY              0  0.000000   19   28.578947    6.590643
#         ACY              0  0.000000    6   91.333333   11.466667
#         AEX              0  0.000000   40   78.725000   47.332692
# ...                    ...       ...  ...         ...         ...
# SFO     SNA              4  0.032787  122   64.059322   11.338331
#         STL              0  0.000000   20  198.900000  101.042105
#         SUN              0  0.000000   10   78.000000   25.777778
#         TUS              0  0.000000   20  100.200000   35.221053
#         XNA              0  0.000000    2  173.500000    0.500000
#
# [1130 rows x 5 columns]

# %%
# 앞선 방법으로 다중 집계를 시도하면 결과 컬럼이 계층 구조로 만들어짐
# 이를 피하려면 다음과 같이 NamedAgg를 사용하는 방법도 가능
# '새로운 집계 열 정의' = pd.NamedAgg(column='집계 열', aggfunc='집계 함수')  
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg(sum_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='sum'),
         mean_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='mean'),
         size_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='size'),
         mean_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='mean'),
         var_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='var'))
)
# Out:
#                   sum_cancelled  mean_cancelled  size_cancelled  \
# ORG_AIR DEST_AIR
# ATL     ABE                 0       0.000000              31
#         ABQ                 0       0.000000              16
#         ABY                 0       0.000000              19
#         ACY                 0       0.000000               6
#         AEX                 0       0.000000              40
# ...                       ...            ...             ...
# SFO     SNA                 4       0.032787             122
#         STL                 0       0.000000              20
#         SUN                 0       0.000000              10
#         TUS                 0       0.000000              20
#         XNA                 0       0.000000               2
#
#                   mean_air_time  var_air_time
# ORG_AIR DEST_AIR
# ATL     ABE         96.387097      45.778495
#         ABQ        170.500000      87.866667
#         ABY         28.578947       6.590643
#         ACY         91.333333      11.466667
#         AEX         78.725000      47.332692
# ...                       ...            ...
# SFO     SNA         64.059322      11.338331
#         STL        198.900000     101.042105
#         SUN         78.000000      25.777778
#         TUS        100.200000      35.221053
#         XNA        173.500000       0.500000
#
# [1130 rows x 5 columns]

# %%
# 혹은 계층 구조로 만들어진 컬럼을 .to_flat_index 메서드를 사용해 펼칠수 도 있음
res = (flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
print(res.columns.to_flat_index()) 
res.columns = ['_'.join(x) for x in
    res.columns.to_flat_index()]
res
# Out:
# Index([ ('CANCELLED', 'sum'), ('CANCELLED', 'mean'), ('CANCELLED', 'size'),
#         ('AIR_TIME', 'mean'),   ('AIR_TIME', 'var')],
#       dtype='object')
#                   CANCELLED_sum  CANCELLED_mean  CANCELLED_size  \
# ORG_AIR DEST_AIR
# ATL     ABE                 0       0.000000              31
#         ABQ                 0       0.000000              16
#         ABY                 0       0.000000              19
#         ACY                 0       0.000000               6
#         AEX                 0       0.000000              40
# ...                       ...            ...             ...
# SFO     SNA                 4       0.032787             122
#         STL                 0       0.000000              20
#         SUN                 0       0.000000              10
#         TUS                 0       0.000000              20
#         XNA                 0       0.000000               2
#
#                   AIR_TIME_mean  AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE         96.387097      45.778495
#         ABQ        170.500000      87.866667
#         ABY         28.578947       6.590643
#         ACY         91.333333      11.466667
#         AEX         78.725000      47.332692
# ...                       ...            ...
# SFO     SNA         64.059322      11.338331
#         STL        198.900000     101.042105
#         SUN         78.000000      25.777778
#         TUS        100.200000      35.221053
#         XNA        173.500000       0.500000
#
# [1130 rows x 5 columns]

# %%
# 이것도 따로 처리하지 않고 한번에 체인 메서드로 묶어주고 싶다면
# pipe 메서드 사용가능
# pipe 메서드 -> DataFrame이나 Series를 넣으면 DataFrame이나 Series를 리턴하는 function을 적용시키는 메서드
def flatten_cols(df):
    df.columns = ['_'.join(x) for x in
        df.columns.to_flat_index()]
    return df

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
    .pipe(flatten_cols)
)
# Out:
#                   CANCELLED_sum  CANCELLED_mean  CANCELLED_size  \
# ORG_AIR DEST_AIR
# ATL     ABE                 0       0.000000              31
#         ABQ                 0       0.000000              16
#         ABY                 0       0.000000              19
#         ACY                 0       0.000000               6
#         AEX                 0       0.000000              40
# ...                       ...            ...             ...
# SFO     SNA                 4       0.032787             122
#         STL                 0       0.000000              20
#         SUN                 0       0.000000              10
#         TUS                 0       0.000000              20
#         XNA                 0       0.000000               2
#
#                   AIR_TIME_mean  AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE         96.387097      45.778495
#         ABQ        170.500000      87.866667
#         ABY         28.578947       6.590643
#         ACY         91.333333      11.466667
#         AEX         78.725000      47.332692
# ...                       ...            ...
# SFO     SNA         64.059322      11.338331
#         STL        198.900000     101.042105
#         SUN         78.000000      25.777778
#         TUS        100.200000      35.221053
#         XNA        173.500000       0.500000
#
# [1130 rows x 5 columns]

# %%
# 그룹화 하는 컬럼이 category 타입이라면 그룹화 하는 과정에서 모든 조합을 다 출력함
# ex) 아래 예시에선 ATL에서 출발한 비행기가 ABI에 도착하는 노선이 없지만 
# 출발 노선을 카테고리 타입으로 바꿔서 모든 조합을 확인하는 인덱스를 가지는 것을 볼수 있음
# 이는 카디널리티가 높은(unique 수가 많은) 카테고리 타입일수록 양이 폭발적으로 늘어남
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED              AIR_TIME
#                        sum mean size        mean        var
# ORG_AIR DEST_AIR
# ATL     ABE              0  0.0   31   96.387097  45.778495
#         ABI              0  NaN    0         NaN        NaN
#         ABQ              0  0.0   16  170.500000  87.866667
#         ABR              0  NaN    0         NaN        NaN
#         ABY              0  0.0   19   28.578947   6.590643
# ...                    ...  ...  ...         ...        ...
# SFO     TYS              0  NaN    0         NaN        NaN
#         VLD              0  NaN    0         NaN        NaN
#         VPS              0  NaN    0         NaN        NaN
#         XNA              0  0.0    2  173.500000   0.500000
#         YUM              0  NaN    0         NaN        NaN
#
# [2710 rows x 5 columns]

# %%
# 이를 막기 위해 observe=True 매개변수를 사용하면 
# 일반적인 문자열 형태에 대한 그룹화처럼 작동하여 실제로 관측이 가능한 값만 표시된다.
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'], observed=True)
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED                   AIR_TIME
#                        sum      mean size        mean         var
# ORG_AIR DEST_AIR
# LAX     ABQ              1  0.018182   55   89.259259   29.403215
#         ANC              0  0.000000    7  307.428571   78.952381
#         ASE              1  0.038462   26  102.920000  102.243333
#         ATL              0  0.000000  174  224.201149  127.155837
#         AUS              0  0.000000   80  150.537500   57.897310
# ...                    ...       ...  ...         ...         ...
# MSP     TTN              1  0.125000    8  124.428571   57.952381
#         TUL              0  0.000000   18   91.611111   63.075163
#         TUS              0  0.000000    2  176.000000   32.000000
#         TVC              0  0.000000    5   56.600000   10.300000
#         XNA              0  0.000000   14   90.642857  115.939560
#
# [1130 rows x 5 columns]

# %% [markdown]
# ## Removing the MultiIndex after grouping

# %%
# 요렇게 다중 인덱스가 발생하면 처리하기 어려움
# Descriptive한 인덱스를 만들어야한다
flights = pd.read_csv('data/flights.csv')
airline_info = (flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg({'DIST':['sum', 'mean'],
          'ARR_DELAY':['min', 'max']}) 
    .astype(int)
)
airline_info
# Out:
#                     DIST       ARR_DELAY
#                      sum  mean       min  max
# AIRLINE WEEKDAY
# AA      1        1455386  1139       -60  551
#         2        1358256  1107       -52  725
#         3        1496665  1117       -45  473
#         4        1452394  1089       -46  349
#         5        1427749  1122       -41  732
# ...                  ...   ...       ...  ...
# WN      3         997213   782       -38  262
#         4        1024854   810       -52  284
#         5         981036   816       -44  244
#         6         823946   834       -41  290
#         7         945679   819       -45  261
#
# [98 rows x 4 columns]

# %%
# get_level_values 메서드로 한 레벨씩 읽어낼수 있음
airline_info.columns.get_level_values(0)
# Out:
# Index(['DIST', 'DIST', 'ARR_DELAY', 'ARR_DELAY'], dtype='object')

# %%
airline_info.columns.get_level_values(1)
# Out:
# Index(['sum', 'mean', 'min', 'max'], dtype='object')

# %%
# 앞에서 했던 내용 반복
# 다층 구조로 된 열을 풀 떄는 to_flat_index() 쓰면 좋다
airline_info.columns.to_flat_index()
# Out:
# Index([('DIST', 'sum'), ('DIST', 'mean'), ('ARR_DELAY', 'min'),
#        ('ARR_DELAY', 'max')],
#       dtype='object')

# %%
airline_info.columns = ['_'.join(x) for x in
    airline_info.columns.to_flat_index()]
airline_info
# Out:
#                  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# AIRLINE WEEKDAY
# AA      1         1455386       1139          -60            551
#         2         1358256       1107          -52            725
#         3         1496665       1117          -45            473
#         4         1452394       1089          -46            349
#         5         1427749       1122          -41            732
# ...                   ...        ...          ...            ...
# WN      3          997213        782          -38            262
#         4         1024854        810          -52            284
#         5          981036        816          -44            244
#         6          823946        834          -41            290
#         7          945679        819          -45            261
#
# [98 rows x 4 columns]

# %%
# 다층 구조의 인덱스를 풀어버리는 제일 쉬운 방법은 reset_index() 메서드를 사용하는 것
airline_info.reset_index()
# Out:
#    AIRLINE  WEEKDAY  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# 0       AA        1   1455386       1139          -60            551
# 1       AA        2   1358256       1107          -52            725
# 2       AA        3   1496665       1117          -45            473
# 3       AA        4   1452394       1089          -46            349
# 4       AA        5   1427749       1122          -41            732
# ..     ...      ...       ...        ...          ...            ...
# 93      WN        3    997213        782          -38            262
# 94      WN        4   1024854        810          -52            284
# 95      WN        5    981036        816          -44            244
# 96      WN        6    823946        834          -41            290
# 97      WN        7    945679        819          -45            261
#
# [98 rows x 6 columns]

# %%
# .NamedAgg를 사용할 수 도 있다. 열은 이걸로 풀고 인덱스는 reset_index로 풀어준것에 주목
(flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg(dist_sum=pd.NamedAgg(column='DIST', aggfunc='sum'),
         dist_mean=pd.NamedAgg(column='DIST', aggfunc='mean'),
         arr_delay_min=pd.NamedAgg(column='ARR_DELAY', aggfunc='min'),
         arr_delay_max=pd.NamedAgg(column='ARR_DELAY', aggfunc='max'))
    .astype(int)
    .reset_index()
)
# Out:
#    AIRLINE  WEEKDAY  dist_sum  dist_mean  arr_delay_min  arr_delay_max
# 0       AA        1   1455386       1139          -60            551
# 1       AA        2   1358256       1107          -52            725
# 2       AA        3   1496665       1117          -45            473
# 3       AA        4   1452394       1089          -46            349
# 4       AA        5   1427749       1122          -41            732
# ..     ...      ...       ...        ...          ...            ...
# 93      WN        3    997213        782          -38            262
# 94      WN        4   1024854        810          -52            284
# 95      WN        5    981036        816          -44            244
# 96      WN        6    823946        834          -41            290
# 97      WN        7    945679        819          -45            261
#
# [98 rows x 6 columns]

# %%
# 멀티 인덱스를 처음부터 안 만드는 방법은 as_index 매개변수를 False로 설정하면된다.
(flights
    .groupby(['AIRLINE'], as_index=False)
    ['DIST']
    .agg('mean')
    .round(0) # 정수레벨로 반올림
)
# Out:
#    AIRLINE    DIST
# 0       AA  1114.0
# 1       AS  1066.0
# 2       B6  1772.0
# 3       DL   866.0
# 4       EV   460.0
# ..     ...     ...
# 9       OO   511.0
# 10      UA  1231.0
# 11      US  1181.0
# 12      VX  1240.0
# 13      WN   810.0
#
# [14 rows x 2 columns]

# %% [markdown]
# ## Grouping with a custom aggregation function

# %% [markdown]
# * 이미 만들어진 집계함수 외에 다른 집계를 수행해야 하는 경우가 발생할 수 있다.
# * college 데이터셋 에서 주(state)당 학부생 수의 평균과 표준편차를 계산하고자 하고, 이 정보를 사용해 각 주별 평균들에서의 최대표준편차를 찾는 예시

# %%
# 각 주 별로 학부생 수의 평균과 표준편차를 찾음
college = pd.read_csv('data/college.csv')

# %%
(college
    .groupby('STABBR') # 아마도 주 
    ['UGDS'] # 아마도 Undergraduated students? 학부생 수
    .agg(['mean', 'std'])
    .round(0) 
)
# 요건 주 별 전체기관들의 학부생 수 평균과 표준편차
# 찾고자 하는건 각 기관들의 편차를 해당 주의 표준편차와 비교했을때 최고 비율을 구하고자 하는것
# 각각의 주를 표준화 시켜서 어떤 주가 최대 편차값을 가지고 있는지 비교하고자한다는것
# Out:
#           mean      std
# STABBR
# AK      2493.0   4052.0
# AL      2790.0   4658.0
# AR      1644.0   3143.0
# AS      1276.0      NaN
# AZ      4130.0  14894.0
# ...        ...      ...
# VT      1513.0   2194.0
# WA      2271.0   4124.0
# WI      2655.0   4615.0
# WV      1758.0   5957.0
# WY      2244.0   2745.0
#
# [59 rows x 2 columns]

# %%
# 그래서 각 주별로 평균에서의 최대 표준 편차를 구하는 집계 함수 정의
def max_deviation(s):
    std_score = (s - s.mean()) / s.std()
    return std_score.abs().max()

# %%
# 요렇게 정의한 집계함수를 써먹을 수 있다는 것
(college
    .groupby('STABBR')
    ['UGDS']
    .agg(max_deviation)
    .round(1)
)
# Out:
# STABBR
# AK    2.6
# AL    5.8
# AR    6.3
# AS    NaN
# AZ    9.9
#      ...
# VT    3.8
# WA    6.6
# WI    5.8
# WV    7.2
# WY    2.8
# Name: UGDS, Length: 59, dtype: float64

# %%
# 여러개의 열에다가 적용시켜도 잘 작동한다. 
# 다만 AK 주의 UGDS 처럼 수치적으로 의미가 있어야 잘동작하고 아니면 NaN
(college
    .groupby('STABBR')
    ['UGDS', 'SATVRMID', 'SATMTMID']
    .agg(max_deviation)
    .round(1)
)
# Out:
# <ipython-input-31-f4534dc6879b>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#         UGDS  SATVRMID  SATMTMID
# STABBR
# AK       2.6       NaN       NaN
# AL       5.8       1.6       1.8
# AR       6.3       2.2       2.3
# AS       NaN       NaN       NaN
# AZ       9.9       1.9       1.4
# ...      ...       ...       ...
# VT       3.8       1.9       1.9
# WA       6.6       2.2       2.0
# WI       5.8       2.4       2.2
# WV       7.2       1.7       2.1
# WY       2.8       NaN       NaN
#
# [59 rows x 3 columns]

# %%
college[college['STABBR'] == 'AK'].loc[:,['UGDS','SATVRMID','SATMTMID']]
# Out:
#          UGDS  SATVRMID  SATMTMID
# 60    12865.0       NaN       NaN
# 61       27.0       NaN       NaN
# 62     5536.0       NaN       NaN
# 63     1428.0       NaN       NaN
# 64      275.0     555.0     503.0
# 65      889.0       NaN       NaN
# 66     3256.0       NaN       NaN
# 67      479.0       NaN       NaN
# 5171    109.0       NaN       NaN
# 5417     68.0       NaN       NaN

# %%
# 기존의 집계 함수들과도 같이 쓸수 있다.
(college
    .groupby(['STABBR', 'RELAFFIL']) 
    ['UGDS', 'SATVRMID', 'SATMTMID'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
# <ipython-input-33-490e0f49200c>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#                          UGDS                      SATVRMID               \
#                 max_deviation    mean     std max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                 2.1   3508.9  4539.5          NaN     NaN   NaN
#        1                 1.1    123.3   132.9          NaN   555.0   NaN
# AL     0                 5.2   3248.8  5102.4          1.6   514.9  56.5
#        1                 2.4    979.7   870.8          1.5   498.0  53.0
# AR     0                 5.8   1793.7  3401.6          1.9   481.1  37.9
# ...                      ...      ...     ...          ...     ...   ...
# WI     0                 5.3   2879.1  5031.5          1.3   558.8  47.5
#        1                 3.4   1716.2  1934.6          2.1   500.1  66.0
# WV     0                 6.9   1873.9  6271.7          1.6   466.7  27.9
#        1                 1.3    716.4   503.6          1.9   485.7  14.6
# WY     0                 2.8   2244.4  2744.7          NaN   535.0   NaN
#
#                      SATMTMID
#                 max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                 NaN     NaN   NaN
#        1                 NaN   503.0   NaN
# AL     0                 1.7   515.8  56.7
#        1                 1.4   485.6  61.4
# AR     0                 2.0   503.6  39.0
# ...                      ...     ...   ...
# WI     0                 1.3   591.2  85.7
#        1                 1.8   526.6  42.5
# WV     0                 1.8   480.0  27.7
#        1                 1.7   484.8  17.7
# WY     0                 NaN   540.0   NaN
#
# [112 rows x 9 columns]

# %%
# 함수 이름을 열의 이름으로 사용하게 되는데
max_deviation.__name__
# Out:
# 'max_deviation'

# %%
# 그래서 rename메서드나 내부메서드를 통해 함수 이름을 바꿔주면 
# 출력 열의 이름도 바뀌는 것을 확인할 수 있다.
max_deviation.__name__ = 'Max Deviation!!!!'
(college
    .groupby(['STABBR', 'RELAFFIL']) 
    ['UGDS', 'SATVRMID', 'SATMTMID'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
# <ipython-input-35-121fb2474e63>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#                              UGDS                          SATVRMID         \
#                 Max Deviation!!!!    mean     std Max Deviation!!!!   mean
# STABBR RELAFFIL
# AK     0                 2.1       3508.9  4539.5          NaN         NaN
#        1                 1.1        123.3   132.9          NaN       555.0
# AL     0                 5.2       3248.8  5102.4          1.6       514.9
#        1                 2.4        979.7   870.8          1.5       498.0
# AR     0                 5.8       1793.7  3401.6          1.9       481.1
# ...                      ...          ...     ...          ...         ...
# WI     0                 5.3       2879.1  5031.5          1.3       558.8
#        1                 3.4       1716.2  1934.6          2.1       500.1
# WV     0                 6.9       1873.9  6271.7          1.6       466.7
#        1                 1.3        716.4   503.6          1.9       485.7
# WY     0                 2.8       2244.4  2744.7          NaN       535.0
#
#                                SATMTMID
#                   std Max Deviation!!!!   mean   std
# STABBR RELAFFIL
# AK     0          NaN          NaN         NaN   NaN
#        1          NaN          NaN       503.0   NaN
# AL     0         56.5          1.7       515.8  56.7
#        1         53.0          1.4       485.6  61.4
# AR     0         37.9          2.0       503.6  39.0
# ...               ...          ...         ...   ...
# WI     0         47.5          1.3       591.2  85.7
#        1         66.0          1.8       526.6  42.5
# WV     0         27.9          1.8       480.0  27.7
#        1         14.6          1.7       484.8  17.7
# WY     0          NaN          NaN       540.0   NaN
#
# [112 rows x 9 columns]

# %% [markdown]
# ## Customizing aggregating functions with *args and **kwargs

# %%
# 직접 커스텀한 집계함수에 매개변수를 필요로 할 수 도 있음
# 아래 함수는 학부생 비율이 1000~3000사이인 학교의 비율을 반환하는 함수
def pct_between_1_3k(s):
    return (s
        .between(1_000, 3_000)
        .mean()
        * 100
    )

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between_1_3k)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           14.3
#         1            0.0
# AL      0           23.6
#         1           33.3
# AR      0           27.9
#                     ...
# WI      0           13.8
#         1           36.0
# WV      0           24.6
#         1           37.5
# WY      0           54.5
# Name: UGDS, Length: 112, dtype: float64

# %%
# 학부생 비율의 하한과 상한을 사용자가 지정할 수 있게 만든 함수
def pct_between(s, low, high):
    return s.between(low, high).mean() * 100

# %%
# .agg 메서드의 구조는 agg(func, *arg, **karg)
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between, 1_000, 10_000)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           42.9
#         1            0.0
# AL      0           45.8
#         1           37.5
# AR      0           39.7
#                     ...
# WI      0           31.0
#         1           44.0
# WV      0           29.2
#         1           37.5
# WY      0           72.7
# Name: UGDS, Length: 112, dtype: float64

# %%
# 매개변수를 직접 열에 출력하고 싶다면 다음과 같이 파이썬의 클로져 기능을 사용할 수 있음
def between_n_m(n, m): 
    def wrapper(ser): # pct_between을 커버하는 wrapper 함수 정의
        return pct_between(ser, n, m)
    # 함수의 name 속성을 함수 이름을 매개변수를 포함하도록 지정
    wrapper.__name__ = f'between_{n}_{m}'
    # wrapper를 리턴 -> wrapper는 pct_between을 return 하므로 사실상 pct_between을 return하는것이다.
    return wrapper

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg([between_n_m(1_000, 10_000), 'max', 'mean'])
    .round(1)
)
# Out:
#                  between_1000_10000      max    mean
# STABBR RELAFFIL
# AK     0                42.9         12865.0  3508.9
#        1                 0.0           275.0   123.3
# AL     0                45.8         29851.0  3248.8
#        1                37.5          3033.0   979.7
# AR     0                39.7         21405.0  1793.7
# ...                      ...             ...     ...
# WI     0                31.0         29302.0  2879.1
#        1                44.0          8212.0  1716.2
# WV     0                29.2         44924.0  1873.9
#        1                37.5          1375.0   716.4
# WY     0                72.7          9910.0  2244.4
#
# [112 rows x 3 columns]

# %% [markdown]
# ## Examining the groupby object

# %% [markdown]
# ### How to do it...

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# groupby 객체의 속성 종류
print([attr for attr in dir(grouped) if not
    attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'ewm', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sample', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'value_counts', 'var']

# %%
# groupby로 만들어진 그룹 개수
grouped.ngroups
# Out:
# 112

# %%
# .groups를 통해서 각 group들을 딕셔너리 형태로 추출할 수 있다.
groups = list(grouped.groups)
len(groups[:]) # 요건 키 값들 나온거임
# Out:
# 112

# %%
grouped.groups[('IL', 1)]
# Out:
# Int64Index([ 986,  992, 1004, 1009, 1019, 1024, 1030, 1031, 1034, 1038, 1043,
#             1047, 1052, 1064, 1077, 1078, 1082, 1083, 1085, 1088, 1089, 1091,
#             1092, 1095, 1096, 1097, 1105, 1106, 1107, 1114, 1119, 1129, 1131,
#             1132, 1133, 1134, 1140, 1145, 1150, 1153, 1154, 1159, 1161, 1828,
#             4321, 4369, 5427, 5482, 5606, 5684, 6624, 6650, 7278, 7349, 7477,
#             7478, 7479],
#            dtype='int64')

# %%
grouped.get_group(('AK', 0)) # get_group 메서드는 단일 그룹을 데이터프레임 형태로 추출
# Out:
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 60    Universi...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 62    Universi...  Fairbanks     AK   0.0      0.0        0.0         0  ...
# 63    Universi...     Juneau     AK   0.0      0.0        0.0         0  ...
# 65    AVTEC-Al...     Seward     AK   0.0      0.0        0.0         0  ...
# 66    Charter ...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 67    Alaska C...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 5171  Ilisagvi...     Barrow     AK   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 60      0.4539         1   0.2385    0.2647   0.4386        42500
# 62      0.3887         1   0.2263    0.2550   0.4519        36200
# 63      0.5112         1   0.1769    0.1996   0.5550        37400
# 65      0.6817         1   0.0737    0.0664   0.7127        33500
# 66      0.0000         1   0.8307    0.7503   0.5472        39200
# 67      0.0000         1   0.7078    0.7860   0.5612        28700
# 5171    0.6239         1   0.1323    0.0000   0.6498        24900
#
#       GRAD_DEBT_MDN_SUPP
# 60        19449.5
# 62          19355
# 63          16875
# 65    PrivacyS...
# 66          13875
# 67           8994
# 5171  PrivacyS...
#
# [7 rows x 27 columns]

# %%
# 꿀팁? 하나의 셀에서 dataframe 테이블을 여러개 출력하고 싶다면 display를 활용
from IPython.display import display
for name, group in grouped:
    print(name)
    display(group.head(3))
# Out:
# ('AK', 0)
#          INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 60  Universi...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 62  Universi...  Fairbanks     AK   0.0      0.0        0.0         0  ...
# 63  Universi...     Juneau     AK   0.0      0.0        0.0         0  ...
#
#     PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 60    0.4539         1   0.2385    0.2647   0.4386        42500
# 62    0.3887         1   0.2263    0.2550   0.4519        36200
# 63    0.5112         1   0.1769    0.1996   0.5550        37400
#
#     GRAD_DEBT_MDN_SUPP
# 60      19449.5
# 62        19355
# 63        16875
#
# [3 rows x 27 columns]
# ('AK', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 61    Alaska B...     Palmer     AK   0.0      0.0        0.0         1  ...
# 64    Alaska P...  Anchorage     AK   0.0      0.0        0.0         1  ...
# 5417  Alaska C...   Soldotna     AK   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 61      0.1481         1   0.3571    0.2857   0.4286          NaN
# 64      0.3745         1   0.3152    0.5297   0.4910        47000
# 5417    0.0735         1   0.8868    0.6792   0.2264          NaN
#
#       GRAD_DEBT_MDN_SUPP
# 61    PrivacyS...
# 64          23250
# 5417  PrivacyS...
#
# [3 rows x 27 columns]
# ('AL', 0)
#         INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 0  Alabama ...      Normal     AL   1.0      0.0        0.0         0  ...
# 1  Universi...  Birmingham     AL   0.0      0.0        0.0         0  ...
# 3  Universi...  Huntsville     AL   0.0      0.0        0.0         0  ...
#
#    PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 0    0.0656         1   0.7356    0.8284   0.1049        30300
# 1    0.2607         1   0.3460    0.5214   0.2422        39700
# 3    0.2146         1   0.3072    0.4596   0.2640        45500
#
#    GRAD_DEBT_MDN_SUPP
# 0        33888
# 1      21941.5
# 3        24097
#
# [3 rows x 27 columns]
# ('AL', 1)
#          INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2   Amridge ...  Montgomery     AL   0.0      0.0        0.0         1  ...
# 10  Birmingh...  Birmingham     AL   0.0      0.0        0.0         1  ...
# 12  Concordi...       Selma     AL   1.0      0.0        0.0         1  ...
#
#     PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2     0.4536         1   0.6801    0.7795   0.8540        40100
# 10    0.0017         1   0.1920    0.4809   0.0152        44200
# 12    0.1056         1   0.8667    0.9333   0.2367        19900
#
#     GRAD_DEBT_MDN_SUPP
# 2         23370
# 10        27000
# 12  PrivacyS...
#
# [3 rows x 27 columns]
# ('AR', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 128  Universi...  Little Rock     AR   0.0      0.0        0.0         0  ...
# 129  Universi...  Little Rock     AR   0.0      0.0        0.0         0  ...
# 130  ABC Beau...  Arkadelphia     AR   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 128    0.4126         1   0.3941    0.4775   0.4062        33900
# 129    0.2433         1   0.3944    0.6144   0.5133        61400
# 130    0.2105         1   0.9815    1.0000   0.4688  PrivacyS...
#
#      GRAD_DEBT_MDN_SUPP
# 128        21736
# 129        12500
# 130        16500
#
# [3 rows x 27 columns]
# ('AR', 1)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 131  Arkansas...  Little Rock     AR   1.0      0.0        0.0         1  ...
# 134  Lyon Col...   Batesville     AR   0.0      0.0        0.0         1  ...
# 144  Baptist ...  Little Rock     AR   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 131    0.1127         1   0.8306    0.8695   0.2833        22000
# 134    0.0101         1   0.4578    0.6740   0.0524        38600
# 144    0.0848         1   0.5033    0.7266   0.3791        43200
#
#      GRAD_DEBT_MDN_SUPP
# 131        38000
# 134        25000
# 144      13393.5
#
# [3 rows x 27 columns]
# ('AS', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4138  American...  Pago Pago     AS   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4138    0.4389         1   0.7245       0.0   0.1774        19800
#
#       GRAD_DEBT_MDN_SUPP
# 4138  PrivacyS...
#
# [1 rows x 27 columns]
# ('AZ', 0)
#          INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 69  Collins ...   Phoenix     AZ   0.0      0.0        0.0         0  ...
# 71  Empire B...    Tucson     AZ   0.0      0.0        0.0         0  ...
# 72  Thunderb...  Glendale     AZ   0.0      0.0        0.0         0  ...
#
#     PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 69    0.3373         0   0.7205    0.8228   0.4764        25700
# 71    0.2222         1   0.7962    0.6615   0.4229        18200
# 72    1.0000         0   0.0000    0.0000   0.0000       118900
#
#     GRAD_DEBT_MDN_SUPP
# 69        47000
# 71         9833
# 72  PrivacyS...
#
# [3 rows x 27 columns]
# ('AZ', 1)
#          INSTNM     CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 68  Everest ...  Phoenix     AZ   0.0      0.0        0.0         1  ...
# 70  Empire B...  Phoenix     AZ   0.0      0.0        0.0         1  ...
# 73  American...  Phoenix     AZ   0.0      0.0        0.0         1  ...
#
#     PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 68    0.4749         0   0.8291    0.7151   0.6700        28600
# 70    0.1600         0   0.6349    0.5873   0.4651        17800
# 73    0.0787         0   0.7500    0.5375   0.4684  PrivacyS...
#
#     GRAD_DEBT_MDN_SUPP
# 68         9500
# 70         9588
# 73  PrivacyS...
#
# [3 rows x 27 columns]
# ('CA', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 192  Academy ...  San Fran...     CA   0.0      0.0        0.0         0  ...
# 193  ITT Tech...  Rancho C...     CA   0.0      0.0        0.0         0  ...
# 194  Academy ...      Oakland     CA   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 192    0.4334         1   0.4008    0.5524   0.4043        36000
# 193    0.2540         0   0.7137    0.7667   0.7235        38800
# 194       NaN         1      NaN       NaN      NaN          NaN
#
#      GRAD_DEBT_MDN_SUPP
# 192        35093
# 193      25827.5
# 194  PrivacyS...
#
# [3 rows x 27 columns]
# ('CA', 1)
#           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 200  American...  Berkeley     CA   0.0      0.0        0.0         1  ...
# 210  Azusa Pa...     Azusa     CA   0.0      0.0        0.0         1  ...
# 214  Bethesda...   Anaheim     CA   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 200       NaN         1      NaN       NaN      NaN          NaN
# 210    0.0875         1   0.2898    0.5172   0.1467        50000
# 214    0.1609         1   0.3686    0.2078   0.4672  PrivacyS...
#
#      GRAD_DEBT_MDN_SUPP
# 200  PrivacyS...
# 210        22500
# 214  PrivacyS...
#
# [3 rows x 27 columns]
# ('CO', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 565  The Salo...  Grand Ju...     CO   0.0      0.0        0.0         0  ...
# 566  Adams St...      Alamosa     CO   0.0      0.0        0.0         0  ...
# 567  Aims Com...      Greeley     CO   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 565    0.0000         1   0.3806    0.4925   0.2778  PrivacyS...
# 566    0.1474         1   0.5175    0.6305   0.2106        32800
# 567    0.5246         1   0.4105    0.3197   0.3941        31400
#
#      GRAD_DEBT_MDN_SUPP
# 565         9570
# 566        16255
# 567         8773
#
# [3 rows x 27 columns]
# ('CO', 1)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 575  Colorado...     Lakewood     CO   0.0      0.0        0.0         1  ...
# 589  Prince I...  Westminster     CO   0.0      0.0        0.0         1  ...
# 592  Denver S...    Littleton     CO   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 575    0.5835         1   0.3087    0.5214   0.4500        36900
# 589       NaN         0   0.6923    0.9487   0.8824        33400
# 592       NaN         1      NaN       NaN      NaN          NaN
#
#      GRAD_DEBT_MDN_SUPP
# 575        25808
# 589        20992
# 592  PrivacyS...
#
# [3 rows x 27 columns]
# ('CT', 0)
#           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 629  Paul Mit...   Danbury     CT   0.0      0.0        0.0         0  ...
# 630  Asnuntuc...   Enfield     CT   0.0      0.0        0.0         0  ...
# 631  Branford...  Branford     CT   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 629    0.2774         1   0.4078    0.5475   0.2913        19000
# 630    0.4795         1   0.3790    0.0950   0.3959        30900
# 631    0.3002         1   0.7103    0.7351   0.5725        27900
#
#      GRAD_DEBT_MDN_SUPP
# 629        10486
# 630         5500
# 631         9800
#
# [3 rows x 27 columns]
# ('CT', 1)
#           INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 628  Albertus...  New Haven     CT   0.0      0.0        0.0         1  ...
# 645  Fairfiel...  Fairfield     CT   0.0      0.0        0.0         1  ...
# 652  Holy Apo...   Cromwell     CT   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 628    0.0825         1   0.4420    0.8002   0.5133        52100
# 645    0.0406         1   0.1322    0.5092   0.0604        68500
# 652    0.3621         1   0.1379    0.2241   0.7241          NaN
#
#      GRAD_DEBT_MDN_SUPP
# 628      27763.5
# 645      26852.5
# 652  PrivacyS...
#
# [3 rows x 27 columns]
# ('DC', 0)
#           INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 698  Universi...  Washington     DC   1.0      0.0        0.0         0  ...
# 700  Gallaude...  Washington     DC   0.0      0.0        0.0         0  ...
# 701  George W...  Washington     DC   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 698    0.5554         1   0.5401    0.4832   0.5662        34800
# 700    0.0500         1   0.5278    0.3880   0.2451        26000
# 701    0.0666         1   0.1420    0.4003   0.0783        65400
#
#      GRAD_DEBT_MDN_SUPP
# 698      22393.5
# 700        17750
# 701        25350
#
# [3 rows x 27 columns]
# ('DC', 1)
#           INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 696  American...  Washington     DC   0.0      0.0        0.0         1  ...
# 697  Catholic...  Washington     DC   0.0      0.0        0.0         1  ...
# 699  Pontific...  Washington     DC   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 696    0.0293         1   0.1666    0.5213   0.0252        55900
# 697    0.0530         1   0.1252    0.5615   0.0940        53900
# 699       NaN         1      NaN       NaN      NaN          NaN
#
#      GRAD_DEBT_MDN_SUPP
# 696        24589
# 697        26000
# 699  PrivacyS...
#
# [3 rows x 27 columns]
# ('DE', 0)
#           INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 685  Margaret...       Lewes     DE   0.0      0.0        0.0         0  ...
# 686  Dawn Car...  Wilmington     DE   0.0      0.0        0.0         0  ...
# 688  Delaware...       Dover     DE   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 685    0.0000         1   0.4545    0.4727   0.4909  PrivacyS...
# 686    0.0000         1   0.6677    0.7505   0.6003        22400
# 688    0.5365         1   0.4606    0.2013   0.4075        30700
#
#      GRAD_DEBT_MDN_SUPP
# 685  PrivacyS...
# 686         9500
# 688         8000
#
# [3 rows x 27 columns]
# ('DE', 1)
#           INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 687  Delaware...  Georgetown     DE   0.0      0.0        0.0         1  ...
# 689  Delaware...  Wilmington     DE   0.0      0.0        0.0         1  ...
# 694  Wesley C...       Dover     DE   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 687    0.5327         1   0.4674    0.1411   0.3561        28800
# 689    0.6461         1   0.3511    0.1504   0.3842        34000
# 694    0.0342         1   0.5010    0.8632   0.1319        41600
#
#      GRAD_DEBT_MDN_SUPP
# 687         6750
# 689         7508
# 694        31000
#
# [3 rows x 27 columns]
# ('FL', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 709  Wyotech-...  Ormond B...     FL   0.0      0.0        0.0         0  ...
# 710  The Art ...  Fort Lau...     FL   0.0      0.0        0.0         0  ...
# 711  Atlantic...  Coconut ...     FL   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 709    0.0000         1   0.6402    0.6978   0.5980        31800
# 710    0.3692         1   0.6263    0.7942   0.4132        28800
# 711    0.0000         1   0.1363    0.0000   0.5044        31900
#
#      GRAD_DEBT_MDN_SUPP
# 709        11600
# 710        29983
# 711  PrivacyS...
#
# [3 rows x 27 columns]
# ('FL', 1)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 712  The Bapt...   Graceville     FL   0.0      0.0        0.0         1  ...
# 713  Barry Un...        Miami     FL   0.0      0.0        0.0         1  ...
# 714  Gooding ...  Panama City     FL   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 712    0.2291         1   0.5878    0.5602   0.3531        30800
# 713    0.1518         1   0.5045    0.6733   0.4361        44100
# 714       NaN         0      NaN       NaN      NaN          NaN
#
#      GRAD_DEBT_MDN_SUPP
# 712        20052
# 713        28250
# 714  PrivacyS...
#
# [3 rows x 27 columns]
# ('FM', 0)
#            INSTNM     CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4214  College ...  Pohnpei     FM   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4214    0.3157         1   0.8778       0.0   0.1631        15700
#
#       GRAD_DEBT_MDN_SUPP
# 4214  PrivacyS...
#
# [1 rows x 27 columns]
# ('GA', 0)
#           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 860  Abraham ...    Tifton     GA   0.0      0.0        0.0         0  ...
# 862  Interact...  Chamblee     GA   0.0      0.0        0.0         0  ...
# 863  Interact...    Morrow     GA   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 860    0.2441         1   0.4629    0.4493   0.1523        32000
# 862    0.0174         1   0.5620    0.4236   0.7937        21100
# 863    0.0000         1   0.6129    0.6452   0.7778        21100
#
#      GRAD_DEBT_MDN_SUPP
# 860      15085.5
# 862         7376
# 863         7376
#
# [3 rows x 27 columns]
# ('GA', 1)
#           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 785  Luther R...  Lithonia     GA   0.0      0.0        0.0         1  ...
# 861  Agnes Sc...   Decatur     GA   0.0      0.0        1.0         1  ...
# 867  Andrew C...  Cuthbert     GA   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 785    0.8224         1   0.5832    0.5362   0.8748        39400
# 861    0.0050         1   0.4404    0.6470   0.0459        38800
# 867    0.0034         1   0.6139    0.8544   0.0095        27500
#
#      GRAD_DEBT_MDN_SUPP
# 785        29500
# 861        27000
# 867        12875
#
# [3 rows x 27 columns]
# ('GU', 0)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4139  Guam Com...  Mangilao     GU   0.0      0.0        0.0         0  ...
# 4140  Universi...  Mangilao     GU   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4139    0.5453         1   0.6354     0.000   0.3058        22000
# 4140    0.2265         1   0.5269     0.276   0.2064        29900
#
#       GRAD_DEBT_MDN_SUPP
# 4139  PrivacyS...
# 4140  PrivacyS...
#
# [2 rows x 27 columns]
# ('GU', 1)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 5289  Pacific ...  Mangilao     GU   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 5289    0.1846         1    0.973       0.0   0.2533  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 5289  PrivacyS...
#
# [1 rows x 27 columns]
# ('HI', 0)
#           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 951  Universi...      Hilo     HI   0.0      0.0        0.0         0  ...
# 952  Universi...  Honolulu     HI   0.0      0.0        0.0         0  ...
# 953  Hawaii I...  Honolulu     HI   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 951    0.1733         1   0.4706    0.4515   0.2690        33500
# 952    0.1601         1   0.3015    0.3746   0.1755        43000
# 953    0.0000         1   0.8112    0.3776   0.5529        17300
#
#      GRAD_DEBT_MDN_SUPP
# 951        19197
# 952        19000
# 953         5868
#
# [3 rows x 27 columns]
# ('HI', 1)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 949   Heald Co...  Honolulu     HI   0.0      0.0        0.0         1  ...
# 950   Chaminad...  Honolulu     HI   0.0      0.0        0.0         1  ...
# 3805  Brigham ...      Laie     HI   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 949     0.2198         0   0.7283    0.6920   0.5262        35000
# 950     0.1765         1   0.4641    0.4425   0.3237        38400
# 3805    0.0523         1   0.2415    0.1749   0.2224        41500
#
#       GRAD_DEBT_MDN_SUPP
# 949         11676
# 950         22000
# 3805         8291
#
# [3 rows x 27 columns]
# ('IA', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1247  Allen Co...    Waterloo     IA   0.0      0.0        0.0         0  ...
# 1248  AIB Coll...  Des Moines     IA   0.0      0.0        0.0         0  ...
# 1251  Capri Co...     Dubuque     IA   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1247    0.3588         1   0.3317    0.8065   0.3945        49100
# 1248    0.2490         1   0.4132    0.7125   0.3209        37000
# 1251    0.0000         1   0.4845    0.5103   0.2295        19400
#
#       GRAD_DEBT_MDN_SUPP
# 1247      17090.5
# 1248      19732.5
# 1251         8477
#
# [3 rows x 27 columns]
# ('IA', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1249  Briar Cl...   Sioux City     IA   0.0      0.0        0.0         1
# 1250  Buena Vi...   Storm Lake     IA   0.0      0.0        0.0         1
# 1253  American...  Cedar Ra...     IA   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1249  ...    0.1971         1   0.4549    0.7975   0.2380        38100
# 1250  ...    0.1147         1   0.4911    0.8195   0.3999        38300
# 1253  ...    0.0000         0   0.8889    0.8889   0.4545  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 1249        24000
# 1250      23877.5
# 1253  PrivacyS...
#
# [3 rows x 27 columns]
# ('ID', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 965  Carringt...        Boise     ID   0.0      0.0        0.0         0  ...
# 967  Boise St...        Boise     ID   0.0      0.0        0.0         0  ...
# 968  Eastern ...  Idaho Falls     ID   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 965    0.0789         1   0.6654    0.5804   0.5580        25000
# 967    0.2519         1   0.3464    0.4669   0.3182        35600
# 968    0.5037         1   0.5421    0.5393   0.6041        26600
#
#      GRAD_DEBT_MDN_SUPP
# 965         9500
# 967        23500
# 968        11375
#
# [3 rows x 27 columns]
# ('ID', 1)
#           INSTNM     CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 966  Boise Bi...    Boise     ID   0.0      0.0        0.0         1  ...
# 977  Northwes...    Nampa     ID   0.0      0.0        0.0         1  ...
# 979  Brigham ...  Rexburg     ID   0.0      0.0        0.0         1  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 966    0.0930         1   0.6793    0.6576   0.1613        25500
# 977    0.1085         1   0.3382    0.6081   0.2991        35900
# 979    0.3462         1   0.4733    0.2138   0.3710        38800
#
#      GRAD_DEBT_MDN_SUPP
# 966        19596
# 977        25500
# 979        11000
#
# [3 rows x 27 columns]
# ('IL', 0)
#           INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 43   Prince I...     Elmhurst     IL   0.0      0.0        0.0         0  ...
# 981  Adler Un...      Chicago     IL   0.0      0.0        0.0         0  ...
# 982  Alvareit...  Edwardsv...     IL   0.0      0.0        0.0         0  ...
#
#      PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 43     0.0000         1   0.7857    0.9375   0.6569  PrivacyS...
# 981       NaN         1      NaN       NaN      NaN          NaN
# 982    0.3404         0   0.6364    0.7792   0.3111  PrivacyS...
#
#      GRAD_DEBT_MDN_SUPP
# 43         20992
# 981  PrivacyS...
# 982         9911
#
# [3 rows x 27 columns]
# ('IL', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 986   Augustan...  Rock Island     IL   0.0      0.0        0.0         1
# 992   Blackbur...  Carlinville     IL   0.0      0.0        0.0         1
# 1004  Catholic...      Chicago     IL   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 986   ...    0.0061         1   0.2310    0.6985   0.0115        47900
# 992   ...    0.0433         1   0.5064    0.7937   0.0534        37100
# 1004  ...       NaN         1      NaN       NaN      NaN          NaN
#
#       GRAD_DEBT_MDN_SUPP
# 986         27000
# 992         26000
# 1004  PrivacyS...
#
# [3 rows x 27 columns]
# ('IN', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1165  Apex Aca...     Anderson     IN   0.0      0.0        0.0         0
# 1166  Ball Sta...       Muncie     IN   0.0      0.0        0.0         0
# 1168  Butler U...  Indianap...     IN   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1165  ...    0.0000         1   0.5000    0.3333   0.3333  PrivacyS...
# 1166  ...    0.0618         1   0.3399    0.5917   0.0715        38800
# 1168  ...    0.0135         1   0.1649    0.5742   0.0185        55000
#
#       GRAD_DEBT_MDN_SUPP
# 1165  PrivacyS...
# 1166        25000
# 1168        27000
#
# [3 rows x 27 columns]
# ('IN', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 990   Bethany ...   Richmond     IN   0.0      0.0        0.0         1  ...
# 1163  Ancilla ...  Donaldson     IN   0.0      0.0        0.0         1  ...
# 1164  Anderson...   Anderson     IN   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 990        NaN         1      NaN       NaN      NaN          NaN
# 1163    0.1878         1   0.6900    0.7400   0.2925        29400
# 1164    0.0863         1   0.2118    0.4688   0.1215        35600
#
#       GRAD_DEBT_MDN_SUPP
# 990   PrivacyS...
# 1163        17000
# 1164        27000
#
# [3 rows x 27 columns]
# ('KS', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1326  Allen Co...        Iola     KS   0.0      0.0        0.0         0  ...
# 1328  Barton C...  Great Bend     KS   0.0      0.0        0.0         0  ...
# 1332  Brown Ma...      Lenexa     KS   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1326    0.5441         1   0.4001    0.2703   0.2886        29100
# 1328    0.3534         1   0.1424    0.0922   0.4148        32200
# 1332    0.0000         1   0.6440    0.6975   0.6296        25200
#
#       GRAD_DEBT_MDN_SUPP
# 1326         6900
# 1328         8976
# 1332        16000
#
# [3 rows x 27 columns]
# ('KS', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1327  Baker Un...  Baldwin ...     KS   0.0      0.0        0.0         1
# 1329  Benedict...     Atchison     KS   0.0      0.0        0.0         1
# 1330  Bethany ...    Lindsborg     KS   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1327  ...    0.3511         1   0.3774    0.7296   0.4418        48800
# 1329  ...    0.0060         1   0.2073    0.5367   0.0208        39600
# 1330  ...    0.0126         1   0.3988    0.1533   0.0316        38100
#
#       GRAD_DEBT_MDN_SUPP
# 1327        25250
# 1329        26000
# 1330        27000
#
# [3 rows x 27 columns]
# ('KY', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1389  Alice Ll...  Pippa Pa...     KY   0.0      0.0        0.0         0
# 1390  Asbury U...      Wilmore     KY   0.0      0.0        0.0         0
# 1392  Ashland ...      Ashland     KY   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1389  ...    0.0457         1   0.5737    0.6815   0.0460        33500
# 1390  ...    0.1741         1   0.3316    0.7001   0.1448        33600
# 1392  ...    0.3288         1   0.5259    0.4076   0.3974        23700
#
#       GRAD_DEBT_MDN_SUPP
# 1389        16495
# 1390        25250
# 1392        11780
#
# [3 rows x 27 columns]
# ('KY', 1)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1391  Asbury T...     Wilmore     KY   0.0      0.0        0.0         1  ...
# 1394  Bellarmi...  Louisville     KY   0.0      0.0        0.0         1  ...
# 1398  Brescia ...   Owensboro     KY   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1391       NaN         1      NaN       NaN      NaN        42500
# 1394    0.0536         1   0.2364    0.6213   0.0941        46600
# 1398    0.2403         1   0.4989    0.8219   0.4903        37500
#
#       GRAD_DEBT_MDN_SUPP
# 1391  PrivacyS...
# 1394        25000
# 1398        30500
#
# [3 rows x 27 columns]
# ('LA', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1461  Central ...  Alexandria     LA   0.0      0.0        0.0         0  ...
# 1462  American...  Shreveport     LA   0.0      0.0        0.0         0  ...
# 1463  Ayers Ca...  Shreveport     LA   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1461    0.3929         1   0.3466    0.0000   0.4799  PrivacyS...
# 1462    0.2951         0   0.6032    0.5159   0.8353        19400
# 1463    0.0000         1   0.9108    0.8410   0.6816        25100
#
#       GRAD_DEBT_MDN_SUPP
# 1461  PrivacyS...
# 1462         9500
# 1463         9500
#
# [3 rows x 27 columns]
# ('LA', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1470  Centenar...   Shreveport     LA   0.0      0.0        0.0         1
# 1478  Dillard ...  New Orleans     LA   1.0      0.0        0.0         1
# 1492  Louisian...    Pineville     LA   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1470  ...    0.0091         1   0.3515    0.6092   0.0307        40400
# 1478  ...    0.0517         1   0.7422    0.8833   0.0904        32800
# 1492  ...    0.0408         1   0.4319    0.5896   0.1487        39100
#
#       GRAD_DEBT_MDN_SUPP
# 1470        25000
# 1478        35000
# 1492      23743.5
#
# [3 rows x 27 columns]
# ('MA', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1619  Hult Int...    Cambridge     MA   0.0      0.0        0.0         0
# 1620  New Engl...       Boston     MA   0.0      0.0        0.0         0
# 1621  American...  Springfield     MA   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1619  ...       NaN         1      NaN       NaN      NaN          NaN
# 1620  ...    0.7696         1   0.2574    0.4426   0.8543          NaN
# 1621  ...    0.0659         1   0.5063    0.8480   0.2102        38900
#
#       GRAD_DEBT_MDN_SUPP
# 1619  PrivacyS...
# 1620        18450
# 1621        27000
#
# [3 rows x 27 columns]
# ('MA', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1623  Andover ...  Newton C...     MA   0.0      0.0        0.0         1
# 1624  Anna Mar...       Paxton     MA   0.0      0.0        0.0         1
# 1626  Assumpti...    Worcester     MA   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1623  ...       NaN         1      NaN       NaN      NaN          NaN
# 1624  ...    0.3060         1   0.3500    0.7725   0.2948        41900
# 1626  ...    0.0812         1   0.2295    0.7268   0.0781        53600
#
#       GRAD_DEBT_MDN_SUPP
# 1623  PrivacyS...
# 1624        25361
# 1626        27000
#
# [3 rows x 27 columns]
# ('MD', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1556  Aaron's ...      Waldorf     MD   0.0      0.0        0.0         0
# 1557  Aestheti...  Gaithers...     MD   0.0      0.0        0.0         0
# 1558  Allegany...   Cumberland     MD   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1556  ...    0.1786         1   0.7222    0.6481   0.4359  PrivacyS...
# 1557  ...    0.5581         1   0.5833    0.4583   0.6500  PrivacyS...
# 1558  ...    0.3590         1   0.4782    0.4525   0.2946        29300
#
#       GRAD_DEBT_MDN_SUPP
# 1556  PrivacyS...
# 1557         6333
# 1558        14072
#
# [3 rows x 27 columns]
# ('MD', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1570  Washingt...  Takoma Park     MD   0.0      0.0        0.0         1
# 1587  Loyola U...    Baltimore     MD   0.0      0.0        0.0         1
# 1599  Mount St...   Emmitsburg     MD   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1570  ...    0.1443         1   0.5727    0.7854   0.3225        44500
# 1587  ...    0.0086         1   0.1426    0.5335   0.0072        63000
# 1599  ...    0.0460         1   0.2252    0.6215   0.0781        49900
#
#       GRAD_DEBT_MDN_SUPP
# 1570        27000
# 1587        27000
# 1599        25995
#
# [3 rows x 27 columns]
# ('ME', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1526  Kaplan U...  S Portland     ME   0.0      0.0        0.0         0  ...
# 1527  College ...  Bar Harbor     ME   0.0      0.0        0.0         0  ...
# 1528  Bates Co...    Lewiston     ME   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1526    0.6448         1   0.7368    0.6812   0.7520        33400
# 1527    0.0219         1   0.3876    0.6152   0.0387        26400
# 1528    0.0000         1   0.1167    0.2859   0.0034        51600
#
#       GRAD_DEBT_MDN_SUPP
# 1526        29493
# 1527        19000
# 1528        16297
#
# [3 rows x 27 columns]
# ('ME', 1)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1535  Husson U...    Bangor     ME   0.0      0.0        0.0         1  ...
# 1549  Saint Jo...  Standish     ME   0.0      0.0        0.0         1  ...
# 4515  New Engl...    Bangor     ME   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1535    0.1501         1   0.4340    0.7447   0.2332        36900
# 1549    0.4766         1   0.2452    0.6548   0.4171        39100
# 4515    0.1347         1      NaN       NaN   0.1007        27400
#
#       GRAD_DEBT_MDN_SUPP
# 1535        26250
# 1549        27000
# 4515        27000
#
# [3 rows x 27 columns]
# ('MH', 0)
#            INSTNM    CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4561  College ...  Majuro     MH   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4561    0.2727         1   0.8923       0.0    0.231  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 4561  PrivacyS...
#
# [1 rows x 27 columns]
# ('MI', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1224  West Mic...   Kalamazoo     MI   0.0      0.0        0.0         0  ...
# 1755  Hillsdal...   Hillsdale     MI   0.0      0.0        0.0         0  ...
# 1756  Northwes...  Southfield     MI   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1224    0.8085         1   0.7807    0.0000   0.4368        14800
# 1755    0.0270         1   0.7442    0.7326   0.2000  PrivacyS...
# 1756    0.0000         1   0.8547    0.8659   0.6478        30200
#
#       GRAD_DEBT_MDN_SUPP
# 1224  PrivacyS...
# 1755  PrivacyS...
# 1756         9500
#
# [3 rows x 27 columns]
# ('MI', 1)
#            INSTNM    CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1753  Adrian C...  Adrian     MI   0.0      0.0        0.0         1  ...
# 1754  Albion C...  Albion     MI   0.0      0.0        0.0         1  ...
# 1757  Alma Col...    Alma     MI   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1753    0.0153         1   0.4142    0.7884   0.0231        37100
# 1754    0.0080         1   0.2502    0.6129   0.0130        44900
# 1757    0.0081         1   0.2882    0.9070   0.0113        43200
#
#       GRAD_DEBT_MDN_SUPP
# 1753        27000
# 1754        27000
# 1757        27000
#
# [3 rows x 27 columns]
# ('MN', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 550   Walden U...  Minneapolis     MN   0.0      0.0        0.0         0
# 1863  Academy ...  Bloomington     MN   0.0      0.0        0.0         0
# 1864  Alexandr...   Alexandria     MN   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 550   ...    0.9061         1   0.4650    0.6614   0.8741        59700
# 1863  ...    0.4034         1   0.5369    0.6913   0.6779        38500
# 1864  ...    0.2249         1   0.2773    0.4067   0.2576        35100
#
#       GRAD_DEBT_MDN_SUPP
# 550         29125
# 1863        29069
# 1864        12000
#
# [3 rows x 27 columns]
# ('MN', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1868  Augsburg...  Minneapolis     MN   0.0      0.0        0.0         1
# 1872  Bethany ...      Mankato     MN   0.0      0.0        0.0         1
# 1873  Bethel U...   Saint Paul     MN   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1868  ...    0.2230         1   0.4330    0.7043   0.3108        45700
# 1872  ...    0.0318         1   0.3972    0.7599   0.0311        34200
# 1873  ...    0.1522         1   0.2725    0.6636   0.1991        45000
#
#       GRAD_DEBT_MDN_SUPP
# 1868        27000
# 1872        25000
# 1873        24069
#
# [3 rows x 27 columns]
# ('MO', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1357  Concorde...  Kansas City     MO   0.0      0.0        0.0         0
# 1999  ITT Tech...   Earth City     MO   0.0      0.0        0.0         0
# 2001  House of...  Blue Spr...     MO   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1357  ...    0.0000         1   0.4003    0.4502   0.6181        22100
# 1999  ...    0.2456         0   0.8007    0.8339   0.7010        38800
# 2001  ...    0.1765         1   0.4966    0.5510   0.3556        11600
#
#       GRAD_DEBT_MDN_SUPP
# 1357         9500
# 1999      25827.5
# 2001       9088.5
#
# [3 rows x 27 columns]
# ('MO', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1996  Aquinas ...  Saint Louis     MO   0.0      0.0        0.0         1
# 1997  Assembli...  Springfield     MO   0.0      0.0        0.0         1
# 1998  Avila Un...  Kansas City     MO   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1996  ...       NaN         1      NaN       NaN      NaN          NaN
# 1997  ...       NaN         1      NaN       NaN      NaN  PrivacyS...
# 1998  ...    0.1794         1   0.4226    0.7059   0.3298        41100
#
#       GRAD_DEBT_MDN_SUPP
# 1996  PrivacyS...
# 1997        22062
# 1998        26625
#
# [3 rows x 27 columns]
# ('MP', 0)
#            INSTNM    CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4141  Northern...  Saipan     MP   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4141    0.1509         1   0.9125       0.0   0.2002        19600
#
#       GRAD_DEBT_MDN_SUPP
# 4141  PrivacyS...
#
# [1 rows x 27 columns]
# ('MS', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1956  Alcorn S...  Alcorn S...     MS   1.0      0.0        0.0         0
# 1959  Chris Be...     Gulfport     MS   0.0      0.0        0.0         0
# 1960  Coahoma ...   Clarksdale     MS   1.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1956  ...    0.1450         1   0.7646    0.8423    0.254        30400
# 1959  ...    0.0000         1   0.5649    0.0000    0.299        15300
# 1960  ...    0.0443         1   0.8843    0.0000    0.302        21100
#
#       GRAD_DEBT_MDN_SUPP
# 1956        28000
# 1959  PrivacyS...
# 1960  PrivacyS...
#
# [3 rows x 27 columns]
# ('MS', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 1957  Belhaven...      Jackson     MS   0.0      0.0        0.0         1
# 1958  Blue Mou...  Blue Mou...     MS   0.0      0.0        0.0         1
# 1963  Creation...       Tupelo     MS   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1957  ...    0.4965         1   0.4860    0.6792   0.5435        36800
# 1958  ...    0.0743         1   0.5551    0.5691   0.1692        29200
# 1963  ...    0.0000         0   0.8113    0.0000   0.4902        17900
#
#       GRAD_DEBT_MDN_SUPP
# 1957        29656
# 1958  PrivacyS...
# 1963  PrivacyS...
#
# [3 rows x 27 columns]
# ('MT', 0)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2108  Academy ...   Bozeman     MT   0.0      0.0        0.0         0  ...
# 2109  Blackfee...  Browning     MT   0.0      0.0        0.0         0  ...
# 2110  Butte Ac...     Butte     MT   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2108    0.0000         1   0.4490    0.4286   0.2619  PrivacyS...
# 2109    0.1452         1   0.7279    0.0000   0.4800        15600
# 2110    0.0000         1   0.7455    0.6364   0.4054  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 2108  PrivacyS...
# 2109  PrivacyS...
# 2110         9500
#
# [3 rows x 27 columns]
# ('MT', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 2113  Carroll ...       Helena     MT   0.0      0.0        0.0         1
# 2121  Universi...  Great Falls     MT   0.0      0.0        0.0         1
# 2130  Rocky Mo...     Billings     MT   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2113  ...    0.0199         1   0.2103    0.5759   0.0741        45500
# 2121  ...    0.3971         1   0.3834    0.5315   0.4283        30700
# 2130  ...    0.0266         1   0.3381    0.7996   0.1053        38900
#
#       GRAD_DEBT_MDN_SUPP
# 2113        27000
# 2121        24000
# 2130        25626
#
# [3 rows x 27 columns]
# ('NC', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 2642  College ...  Elizabet...     NC   0.0      0.0        0.0         0
# 2643  The Art ...    Charlotte     NC   0.0      0.0        0.0         0
# 2644  South Pi...      Polkton     NC   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2642  ...    0.5136         1   0.4029     0.000   0.3617        22300
# 2643  ...    0.4588         1   0.7099     0.822   0.2754        28800
# 2644  ...    0.6648         1   0.4150     0.000   0.3595        21700
#
#       GRAD_DEBT_MDN_SUPP
# 2642  PrivacyS...
# 2643        25167
# 2644  PrivacyS...
#
# [3 rows x 27 columns]
# ('NC', 1)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2647  Barton C...      Wilson     NC   0.0      0.0        0.0         1  ...
# 2649  Belmont ...     Belmont     NC   0.0      0.0        0.0         1  ...
# 2650  Bennett ...  Greensboro     NC   1.0      0.0        1.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2647    0.1082         1   0.4664    0.7843   0.2271        36000
# 2649    0.0634         1   0.5086    0.7485   0.4347        36000
# 2650    0.0145         1   0.7265    0.8574   0.0235        26900
#
#       GRAD_DEBT_MDN_SUPP
# 2647        27000
# 2649        27000
# 2650        37000
#
# [3 rows x 27 columns]
# ('ND', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2772  Rasmusse...      Fargo     ND   0.0      0.0        0.0         0  ...
# 2773  Bismarck...   Bismarck     ND   0.0      0.0        0.0         0  ...
# 2774  Dickinso...  Dickinson     ND   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2772    0.4453         1   0.5516    0.6948   0.6286        30900
# 2773    0.2874         1   0.2029    0.3516   0.3351        38400
# 2774    0.2063         1   0.2519    0.4479   0.2436        38800
#
#       GRAD_DEBT_MDN_SUPP
# 2772        21163
# 2773        11588
# 2774        19500
#
# [3 rows x 27 columns]
# ('ND', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2778  Universi...  Jamestown     ND   0.0      0.0        0.0         1  ...
# 2782  Universi...   Bismarck     ND   0.0      0.0        0.0         1  ...
# 2792  Trinity ...  Ellendale     ND   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2778    0.0323         1   0.2681    0.6408   0.0806        39600
# 2782    0.1043         1   0.2402    0.6492   0.1698        45100
# 2792    0.0943         1   0.6768    0.9091   0.1515        25500
#
#       GRAD_DEBT_MDN_SUPP
# 2778        27000
# 2782        22722
# 2792        27592
#
# [3 rows x 27 columns]
# ('NE', 0)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2133  La'James...   Fremont     NE   0.0      0.0        0.0         0  ...
# 2134  Bellevue...  Bellevue     NE   0.0      0.0        0.0         0  ...
# 2136  Bryan Co...   Lincoln     NE   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2133    0.0000         1   0.6863    0.7451   0.2424        15900
# 2134    0.1185         1   0.2914    0.4368   0.8125        52600
# 2136    0.4745         1   0.3477    0.7049   0.3174        50900
#
#       GRAD_DEBT_MDN_SUPP
# 2133  PrivacyS...
# 2134        17188
# 2136      24280.5
#
# [3 rows x 27 columns]
# ('NE', 1)
#            INSTNM    CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2135  Clarkson...   Omaha     NE   0.0      0.0        0.0         1  ...
# 2140  Concordi...  Seward     NE   0.0      0.0        0.0         1  ...
# 2141  Creighto...   Omaha     NE   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2135    0.4628         1   0.3564    0.7205   0.4744        47000
# 2140    0.0373         1   0.2129    0.5046   0.0405        36100
# 2141    0.0357         1   0.1757    0.6830   0.0775        57100
#
#       GRAD_DEBT_MDN_SUPP
# 2135        26000
# 2140        26000
# 2141        23250
#
# [3 rows x 27 columns]
# ('NH', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2183  Colby-Sa...  New London     NH   0.0      0.0        0.0         0  ...
# 2184  Continen...      Hudson     NH   0.0      0.0        0.0         0  ...
# 2185  Daniel W...      Nashua     NH   0.0      0.0        0.0         0  ...
#
# ...
#
# [3 rows x 27 columns]
# ('SC', 1)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3418  Allen Un...    Columbia     SC   1.0      0.0        0.0         1  ...
# 3419  Charlest...  Charleston     SC   0.0      0.0        0.0         1  ...
# 3421  Benedict...    Columbia     SC   1.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3418    0.0273         1   0.8955    0.9831   0.0783        21100
# 3419    0.1055         1   0.4718    0.7246   0.2198        35700
# 3421    0.0160         1   0.8288    0.9013   0.0784        21400
#
#       GRAD_DEBT_MDN_SUPP
# 3418        37676
# 3419        27741
# 3421        44000
#
# [3 rows x 27 columns]
# ('SD', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 3479  Black Hi...   Rapid City     SD   0.0      0.0        0.0         0
# 3480  Black Hi...    Spearfish     SD   0.0      0.0        0.0         0
# 3481  Kilian C...  Sioux Falls     SD   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3479  ...    0.0000         1   0.3931    0.4162   0.1339        16200
# 3480  ...    0.2416         1   0.3443    0.5587   0.2841        34400
# 3481  ...    0.8429         0   0.6838    0.7510   0.5455        23100
#
#       GRAD_DEBT_MDN_SUPP
# 3479        11790
# 3480        25625
# 3481        17125
#
# [3 rows x 27 columns]
# ('SD', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 3478  Augustan...  Sioux Falls     SD   0.0      0.0        0.0         1
# 3483  Dakota W...     Mitchell     SD   0.0      0.0        0.0         1
# 3486  Avera Mc...  Sioux Falls     SD   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3478  ...    0.0315         1   0.2062    0.6158   0.0424        41800
# 3483  ...    0.1176         1   0.3877    0.7815   0.1309        34500
# 3486  ...    0.0000         1   0.0500    0.3000   0.0500  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 3478        27000
# 3483        27000
# 3486  PrivacyS...
#
# [3 rows x 27 columns]
# ('TN', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 1205  ITT Tech...  Nashville     TN   0.0      0.0        0.0         0  ...
# 3507  Arnolds ...      Milan     TN   0.0      0.0        0.0         0  ...
# 3508  Tennesse...     Athens     TN   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 1205    0.2047         0   0.7352    0.7219   0.8019        38800
# 3507    0.0000         1   0.6311    0.2913   0.4444        16000
# 3508    0.0000         1   0.4252    0.0000   0.3960        26600
#
#       GRAD_DEBT_MDN_SUPP
# 1205      25827.5
# 3507  PrivacyS...
# 3508  PrivacyS...
#
# [3 rows x 27 columns]
# ('TN', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3506  American...  Nashville     TN   1.0      0.0        0.0         1  ...
# 3510  Baptist ...    Memphis     TN   0.0      0.0        0.0         1  ...
# 3511  Belmont ...  Nashville     TN   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3506    0.2994         1   0.6014    0.8252   0.7305  PrivacyS...
# 3510    0.5500         1   0.5653    0.8339   0.5059        54100
# 3511    0.0620         1   0.1729    0.6090   0.0848        41800
#
#       GRAD_DEBT_MDN_SUPP
# 3506        25000
# 3510        30000
# 3511        22707
#
# [3 rows x 27 columns]
# ('TX', 0)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3611  Alvin Co...     Alvin     TX   0.0      0.0        0.0         0  ...
# 3612  Amarillo...  Amarillo     TX   0.0      0.0        0.0         0  ...
# 3613  Angelina...    Lufkin     TX   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3611    0.7123         1   0.1549    0.0625   0.2841        34500
# 3612    0.6922         1   0.3786    0.1573   0.3431        31700
# 3613    0.5600         1   0.5308    0.0000   0.2603        26900
#
#       GRAD_DEBT_MDN_SUPP
# 3611         6750
# 3612        10950
# 3613  PrivacyS...
#
# [3 rows x 27 columns]
# ('TX', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3610  Abilene ...    Abilene     TX   0.0      0.0        0.0         1  ...
# 3615  Arlingto...  Arlington     TX   0.0      0.0        0.0         1  ...
# 3618  Austin C...    Sherman     TX   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3610    0.0468         1   0.2595    0.5527   0.0381        40200
# 3615    0.1682         1   0.4978    0.4892   0.2251        34200
# 3618    0.0016         1   0.2867    0.7581   0.0124        47800
#
#       GRAD_DEBT_MDN_SUPP
# 3610        25985
# 3615        22905
# 3618        26000
#
# [3 rows x 27 columns]
# ('UT', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 3802  AmeriTec...        Provo     UT   0.0      0.0        0.0         0
# 3803  Bridgerl...        Logan     UT   0.0      0.0        0.0         0
# 3806  Broadvie...  West Jordan     UT   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3802  ...    0.0000         1   0.7295    0.8074   0.3526        24700
# 3803  ...    0.6525         1   0.2017    0.0000   0.4148        24300
# 3806  ...    0.3452         1   0.6943    0.8035   0.5590        25500
#
#       GRAD_DEBT_MDN_SUPP
# 3802        24370
# 3803  PrivacyS...
# 3806        28458
#
# [3 rows x 27 columns]
# ('UT', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 3804  Brigham ...        Provo     UT   0.0      0.0        0.0         1
# 3817  Latter-d...  Salt Lak...     UT   0.0      0.0        0.0         1
# 3818  Everest ...  West Val...     UT   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3804  ...    0.0981         1   0.3702    0.1921   0.1220        57200
# 3817  ...    0.3365         1   0.3319    0.2144   0.2235        35100
# 3818  ...    0.2811         0   0.7030    0.5619   0.5371        24400
#
#       GRAD_DEBT_MDN_SUPP
# 3804        11000
# 3817         5799
# 3818      10632.5
#
# [3 rows x 27 columns]
# ('VA', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 704   Medtech ...  Falls Ch...     VA   0.0      0.0        0.0         0
# 3850  Bar Palm...      Roanoke     VA   0.0      0.0        0.0         0
# 3851  Advanced...  Virginia...     VA   0.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 704   ...    0.0000         1   0.7097    0.4198   0.2039        26300
# 3850  ...    0.1831         1   0.4367    0.4177   0.6944        16900
# 3851  ...    0.0000         1   0.3374    0.3010   0.5364        38000
#
#       GRAD_DEBT_MDN_SUPP
# 704          9236
# 3850         9731
# 3851        16279
#
# [3 rows x 27 columns]
# ('VA', 1)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 3852  Averett ...     Danville     VA   0.0      0.0        0.0         1
# 3853  Bluefiel...    Bluefield     VA   0.0      0.0        0.0         1
# 3854  Bridgewa...  Bridgewater     VA   0.0      0.0        0.0         1
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3852  ...    0.0227         1   0.5120    0.7879   0.0992        42400
# 3853  ...    0.1193         1   0.4540    0.6989   0.4241        40000
# 3854  ...    0.0051         1   0.2754    0.7348   0.0114        40800
#
#       GRAD_DEBT_MDN_SUPP
# 3852        25000
# 3853        18873
# 3854        27000
#
# [3 rows x 27 columns]
# ('VI', 0)
#            INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# 4216  Universi...  Charlott...     VI   1.0      0.0        0.0         0
#
#       ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4216  ...    0.3059         1   0.5161    0.3224   0.3196        31800
#
#       GRAD_DEBT_MDN_SUPP
# 4216        15150
#
# [1 rows x 27 columns]
# ('VI', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 7404  Universi...  St. Croix     VI   NaN      NaN        NaN         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 7404       NaN         1      NaN       NaN      NaN        31800
#
#       GRAD_DEBT_MDN_SUPP
# 7404        15150
#
# [1 rows x 27 columns]
# ('VT', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3829  Benningt...  Bennington     VT   0.0      0.0        0.0         0  ...
# 3830  Burlingt...  Burlington     VT   0.0      0.0        0.0         0  ...
# 3831  Castleto...   Castleton     VT   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3829    0.0048         1   0.2342    0.5703   0.0097        24600
# 3830    0.0843         0   0.4670    0.7123   0.2545        26000
# 3831    0.0910         1   0.2938    0.6399   0.0938        34900
#
#       GRAD_DEBT_MDN_SUPP
# 3829        27000
# 3830        25000
# 3831        25000
#
# [3 rows x 27 columns]
# ('VT', 1)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3835  Green Mo...    Poultney     VT   0.0      0.0        0.0         1  ...
# 3843  Saint Mi...  Colchester     VT   0.0      0.0        0.0         1  ...
# 3845  College ...     Rutland     VT   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3835    0.0197         1   0.3847    0.7051   0.0407        30100
# 3843    0.0108         1   0.1682    0.6456   0.0220        46600
# 3845    0.1000         1   0.6193    0.7216   0.2557        34700
#
#       GRAD_DEBT_MDN_SUPP
# 3835        25449
# 3843        27400
# 3845        24127
#
# [3 rows x 27 columns]
# ('WA', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3943  Beauty A...  Wenatchee     WA   0.0      0.0        0.0         0  ...
# 3944  The Art ...    Seattle     WA   0.0      0.0        0.0         0  ...
# 3945  Evergree...   Bellevue     WA   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3943    0.0000         1   0.6385    0.6154   0.3896  PrivacyS...
# 3944    0.3128         1   0.4272    0.6662   0.3795        34100
# 3945    0.0000         1   0.3314    0.3314   0.4400  PrivacyS...
#
#       GRAD_DEBT_MDN_SUPP
# 3943       8718.5
# 3944      25937.5
# 3945         7917
#
# [3 rows x 27 columns]
# ('WA', 1)
#            INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 3967  Gonzaga ...   Spokane     WA   0.0      0.0        0.0         1  ...
# 3981  Trinity ...   Everett     WA   0.0      0.0        0.0         1  ...
# 3985  Northwes...  Kirkland     WA   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 3967    0.0128         1   0.1832    0.5155   0.0298        53000
# 3981    0.0478         0   0.4948    0.7010   0.2165        37100
# 3985    0.1239         1   0.3790    0.6787   0.3067        37700
#
#       GRAD_DEBT_MDN_SUPP
# 3967        25500
# 3981        25000
# 3985      23724.5
#
# [3 rows x 27 columns]
# ('WI', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4063  Advanced...    Glendale     WI   0.0      0.0        0.0         0  ...
# 4064  VICI Ave...  Greenfield     WI   0.0      0.0        0.0         0  ...
# 4066  Madison ...     Madison     WI   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4063    0.0000         1   0.5089    0.5325   0.1736        24000
# 4064    0.0000         1   0.5069    0.6406   0.2059        24000
# 4066    0.6223         1   0.3259    0.3565   0.5080        35000
#
#       GRAD_DEBT_MDN_SUPP
# 4063        10314
# 4064        10314
# 4066        14250
#
# [3 rows x 27 columns]
# ('WI', 1)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4065  Alverno ...  Milwaukee     WI   0.0      0.0        1.0         1  ...
# 4070  Cardinal...  Milwaukee     WI   0.0      0.0        0.0         1  ...
# 4071  Carroll ...   Waukesha     WI   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4065    0.2481         1   0.6096    0.8743   0.3464        37100
# 4070    0.0638         1   0.4278    0.7356   0.6632        48500
# 4071    0.0838         1   0.2709    0.7137   0.1119        41300
#
#       GRAD_DEBT_MDN_SUPP
# 4065      32606.5
# 4070        27000
# 4071        27000
#
# [3 rows x 27 columns]
# ('WV', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 2842  Scott Co...   Wheeling     WV   0.0      0.0        0.0         0  ...
# 4019  B M Spur...  Glen Dale     WV   0.0      0.0        0.0         0  ...
# 4020  Ben Fran...     Dunbar     WV   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 2842    0.0000         1   0.5276    0.4961   0.1111        14800
# 4019    0.0000         1   0.4722    0.0000   0.4444  PrivacyS...
# 4020    0.7885         1   0.1761    0.0000   0.7568        20800
#
#       GRAD_DEBT_MDN_SUPP
# 2842         9250
# 4019  PrivacyS...
# 4020  PrivacyS...
#
# [3 rows x 27 columns]
# ('WV', 1)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4016  Alderson...    Philippi     WV   0.0      0.0        0.0         1  ...
# 4018  Appalach...  Mount Hope     WV   0.0      0.0        0.0         1  ...
# 4027  Davis & ...      Elkins     WV   0.0      0.0        0.0         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4016    0.0342         1   0.4800    0.8945   0.0722        46000
# 4018    0.0612         1   0.4388    0.2770   0.0899        28700
# 4027    0.0167         1   0.4188    0.6579   0.1133        35000
#
#       GRAD_DEBT_MDN_SUPP
# 4016        27000
# 4018         9300
# 4027      23840.5
#
# [3 rows x 27 columns]
# ('WY', 0)
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 4128  Casper C...      Casper     WY   0.0      0.0        0.0         0  ...
# 4129  Central ...    Riverton     WY   0.0      0.0        0.0         0  ...
# 4130  Eastern ...  Torrington     WY   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4128    0.3250         1   0.2188    0.1455   0.3447        34800
# 4129    0.4377         1   0.1700    0.0967   0.3992        25200
# 4130    0.3275         1   0.1729    0.1166   0.2371        25900
#
#       GRAD_DEBT_MDN_SUPP
# 4128        10764
# 4129         8757
# 4130        10000
#
# [3 rows x 27 columns]

# %%
# 요렇게만 봐도 충분하긴하다
for name, group in grouped:
    print(name)
    print(group)
    break
# Out:
# ('AK', 0)
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 60    Universi...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 62    Universi...  Fairbanks     AK   0.0      0.0        0.0         0  ...
# 63    Universi...     Juneau     AK   0.0      0.0        0.0         0  ...
# 65    AVTEC-Al...     Seward     AK   0.0      0.0        0.0         0  ...
# 66    Charter ...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 67    Alaska C...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 5171  Ilisagvi...     Barrow     AK   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 60      0.4539         1   0.2385    0.2647   0.4386        42500
# 62      0.3887         1   0.2263    0.2550   0.4519        36200
# 63      0.5112         1   0.1769    0.1996   0.5550        37400
# 65      0.6817         1   0.0737    0.0664   0.7127        33500
# 66      0.0000         1   0.8307    0.7503   0.5472        39200
# 67      0.0000         1   0.7078    0.7860   0.5612        28700
# 5171    0.6239         1   0.1323    0.0000   0.6498        24900
#
#       GRAD_DEBT_MDN_SUPP
# 60        19449.5
# 62          19355
# 63          16875
# 65    PrivacyS...
# 66          13875
# 67           8994
# 5171  PrivacyS...
#
# [7 rows x 27 columns]

# %%
group
# Out:
#            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 60    Universi...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 62    Universi...  Fairbanks     AK   0.0      0.0        0.0         0  ...
# 63    Universi...     Juneau     AK   0.0      0.0        0.0         0  ...
# 65    AVTEC-Al...     Seward     AK   0.0      0.0        0.0         0  ...
# 66    Charter ...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 67    Alaska C...  Anchorage     AK   0.0      0.0        0.0         0  ...
# 5171  Ilisagvi...     Barrow     AK   0.0      0.0        0.0         0  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 60      0.4539         1   0.2385    0.2647   0.4386        42500
# 62      0.3887         1   0.2263    0.2550   0.4519        36200
# 63      0.5112         1   0.1769    0.1996   0.5550        37400
# 65      0.6817         1   0.0737    0.0664   0.7127        33500
# 66      0.0000         1   0.8307    0.7503   0.5472        39200
# 67      0.0000         1   0.7078    0.7860   0.5612        28700
# 5171    0.6239         1   0.1323    0.0000   0.6498        24900
#
#       GRAD_DEBT_MDN_SUPP
# 60        19449.5
# 62          19355
# 63          16875
# 65    PrivacyS...
# 66          13875
# 67           8994
# 5171  PrivacyS...
#
# [7 rows x 27 columns]

# %%
# 각 그룹별 하나씩 추출해서 볼수도 있음 
grouped.head(1)
# Out:
#            INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  ...  \
# 0     Alabama ...      Normal     AL   1.0      0.0        0.0         0  ...
# 2     Amridge ...  Montgomery     AL   0.0      0.0        0.0         1  ...
# 43    Prince I...    Elmhurst     IL   0.0      0.0        0.0         0  ...
# 60    Universi...   Anchorage     AK   0.0      0.0        0.0         0  ...
# 61    Alaska B...      Palmer     AK   0.0      0.0        0.0         1  ...
# ...           ...         ...    ...   ...      ...        ...       ...  ...
# 4561  College ...      Majuro     MH   0.0      0.0        0.0         0  ...
# 5289  Pacific ...    Mangilao     GU   0.0      0.0        0.0         1  ...
# 6439  Touro Un...   Henderson     NV   0.0      0.0        0.0         1  ...
# 7404  Universi...   St. Croix     VI   NaN      NaN        NaN         1  ...
# 7419  Computer...  Las Cruces     NM   NaN      NaN        NaN         1  ...
#
#       PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 0       0.0656         1   0.7356    0.8284   0.1049        30300
# 2       0.4536         1   0.6801    0.7795   0.8540        40100
# 43      0.0000         1   0.7857    0.9375   0.6569  PrivacyS...
# 60      0.4539         1   0.2385    0.2647   0.4386        42500
# 61      0.1481         1   0.3571    0.2857   0.4286          NaN
# ...        ...       ...      ...       ...      ...          ...
# 4561    0.2727         1   0.8923    0.0000   0.2310  PrivacyS...
# 5289    0.1846         1   0.9730    0.0000   0.2533  PrivacyS...
# 6439    0.0323         1   0.0000    0.2000   0.4000          NaN
# 7404       NaN         1      NaN       NaN      NaN        31800
# 7419       NaN         1      NaN       NaN      NaN        21300
#
#       GRAD_DEBT_MDN_SUPP
# 0           33888
# 2           23370
# 43          20992
# 60        19449.5
# 61    PrivacyS...
# ...           ...
# 4561  PrivacyS...
# 5289  PrivacyS...
# 6439  PrivacyS...
# 7404        15150
# 7419        14250
#
# [112 rows x 27 columns]

# %%
# nth 메서드를 사용하면 각 그룹의 특정 행을 선택할 수 있음 
grouped.nth([1, -1])
# Out:
#                       INSTNM         CITY  HBCU  MENONLY  WOMENONLY  SATVRMID  \
# STABBR RELAFFIL
# AK     0         Universi...    Fairbanks   0.0      0.0        0.0       NaN
#        0         Ilisagvi...       Barrow   0.0      0.0        0.0       NaN
#        1         Alaska P...    Anchorage   0.0      0.0        0.0     555.0
#        1         Alaska C...     Soldotna   0.0      0.0        0.0       NaN
# AL     0         Universi...   Birmingham   0.0      0.0        0.0     570.0
# ...                      ...          ...   ...      ...        ...       ...
# WV     0         BridgeVa...  South  C...   0.0      0.0        0.0       NaN
#        1         Appalach...   Mount Hope   0.0      0.0        0.0     514.0
#        1         West Vir...  Nutter Fort   NaN      NaN        NaN       NaN
# WY     0         Central ...     Riverton   0.0      0.0        0.0       NaN
#        0         CollegeA...     Cheyenne   0.0      0.0        0.0       NaN
#
#                  SATMTMID  ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# STABBR RELAFFIL            ...
# AK     0              NaN  ...    0.3887         1   0.2263    0.2550
#        0              NaN  ...    0.6239         1   0.1323    0.0000
#        1            503.0  ...    0.3745         1   0.3152    0.5297
#        1              NaN  ...    0.0735         1   0.8868    0.6792
# AL     0            565.0  ...    0.2607         1   0.3460    0.5214
# ...                   ...  ...       ...       ...      ...       ...
# WV     0              NaN  ...    0.3890         1      NaN       NaN
#        1            487.0  ...    0.0612         1   0.4388    0.2770
#        1              NaN  ...       NaN         1      NaN       NaN
# WY     0              NaN  ...    0.4377         1   0.1700    0.0967
#        0              NaN  ...    0.0000         1   0.8519    0.8642
#
#                  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# STABBR RELAFFIL
# AK     0          0.4519        36200            19355
#        0          0.6498        24900      PrivacyS...
#        1          0.4910        47000            23250
#        1          0.2264          NaN      PrivacyS...
# AL     0          0.2422        39700          21941.5
# ...                  ...          ...              ...
# WV     0             NaN          NaN           9429.5
#        1          0.0899        28700             9300
#        1             NaN        16700            19258
# WY     0          0.3992        25200             8757
#        0          0.7273        25600          27235.5
#
# [213 rows x 25 columns]

# %% [markdown]
# ## Filtering for states with a minority majority

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# 그룹 갯수는 STABBR의 nunique()와 같아야함
# Out:
# 59

# %%
college['STABBR'].nunique()
# Out:
# 59

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE'] # 유색 인종 비율
    total_minority = (df['UGDS'] * minority_pct).sum() # 각 기관들 학부생 중 유색인종 수의 총합
    total_ugds = df['UGDS'].sum() # 각 기관들의 학부생 수의 총합
    total_minority_pct = total_minority / total_ugds # 전체 모든 학부생들 중 유색 인종의 비율 
    return total_minority_pct > threshold

# %%
minority_pct = 1 - college['UGDS_WHITE'] # 유색 인종 비율
minority_pct
# Out:
# INSTNM
# Alabama A & M University                                  0.9667
# University of Alabama at Birmingham                       0.4078
# Amridge University                                        0.7010
# University of Alabama in Huntsville                       0.3012
# Alabama State University                                  0.9842
#                                                            ...
# SAE Institute of Technology  San Francisco                   NaN
# Rasmussen College - Overland Park                            NaN
# National Personal Training Institute of Cleveland            NaN
# Bay Area Medical Academy - San Jose Satellite Location       NaN
# Excel Learning Center-San Antonio South                      NaN
# Name: UGDS_WHITE, Length: 7535, dtype: float64

# %%
total_minority = (college['UGDS'] * minority_pct).sum() # 각 기관들 학부생 중 유색인종 수의 총합
total_minority
# Out:
# 7898501.594700001

# %%
total_ugds = college['UGDS'].sum() # 각 기관들의 학부생 수의 총합
total_ugds
# Out:
# 16200904.0

# %%
total_minority_pct = total_minority / total_ugds # 전체 모든 학부생들 중 유색 인종의 비율 
total_minority_pct
# Out:
# 0.4875346211976814

# %%
# 여기서 필터의 역할은 threshold 값을 기준으로 각 그룹을 유지할지 여부를 판별
college_filtered = grouped.filter(check_minority, threshold=.5)
college_filtered
# Out:
#                      CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Everest C...      Phoenix     AZ   0.0      0.0        0.0         1
# Collins C...      Phoenix     AZ   0.0      0.0        0.0         0
# Empire Be...      Phoenix     AZ   0.0      0.0        0.0         1
# Empire Be...       Tucson     AZ   0.0      0.0        0.0         0
# Thunderbi...     Glendale     AZ   0.0      0.0        0.0         0
# ...                   ...    ...   ...      ...        ...       ...
# WestMed C...       Merced     CA   NaN      NaN        NaN         1
# Vantage C...      El Paso     TX   NaN      NaN        NaN         1
# SAE Insti...   Emeryville     CA   NaN      NaN        NaN         1
# Bay Area ...     San Jose     CA   NaN      NaN        NaN         1
# Excel Lea...  San Antonio     TX   NaN      NaN        NaN         1
#
#               SATVRMID  ...  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM                  ...
# Everest C...       NaN  ...    0.4749         0   0.8291    0.7151   0.6700
# Collins C...       NaN  ...    0.3373         0   0.7205    0.8228   0.4764
# Empire Be...       NaN  ...    0.1600         0   0.6349    0.5873   0.4651
# Empire Be...       NaN  ...    0.2222         1   0.7962    0.6615   0.4229
# Thunderbi...       NaN  ...    1.0000         0   0.0000    0.0000   0.0000
# ...                ...  ...       ...       ...      ...       ...      ...
# WestMed C...       NaN  ...       NaN         1      NaN       NaN      NaN
# Vantage C...       NaN  ...       NaN         1      NaN       NaN      NaN
# SAE Insti...       NaN  ...       NaN         1      NaN       NaN      NaN
# Bay Area ...       NaN  ...       NaN         1      NaN       NaN      NaN
# Excel Lea...       NaN  ...       NaN         1      NaN       NaN      NaN
#
#               MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Everest C...        28600             9500
# Collins C...        25700            47000
# Empire Be...        17800             9588
# Empire Be...        18200             9833
# Thunderbi...       118900      PrivacyS...
# ...                   ...              ...
# WestMed C...          NaN          15623.5
# Vantage C...          NaN             9500
# SAE Insti...          NaN             9500
# Bay Area ...          NaN      PrivacyS...
# Excel Lea...          NaN            12125
#
# [3028 rows x 26 columns]

# %%
print('college.shape',college.shape)
print('college_filtered.shape',college_filtered.shape)
# Out:
# college.shape (7535, 26)
# college_filtered.shape (3028, 26)

# %%
college['STABBR'].nunique()
# Out:
# 59

# %%
college_filtered['STABBR'].nunique()
# Out:
# 20

# %%
college_filtered_20 = grouped.filter(check_minority, threshold=.2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %%
college_filtered_70 = grouped.filter(check_minority, threshold=.7)
college_filtered_70.shape
# Out:
# (957, 26)

# %%
college_filtered_70['STABBR'].nunique()
# Out:
# 10

# %% [markdown]
# ## Transforming through a weight loss bet

# %%
# 두 사람의 체중 감소를 추적해 승자를 결정짓는 예제
weight_loss = pd.read_csv('data/weight_loss.csv')
weight_loss.query('Month == "Jan"') # weight_loss[weight_loss.Month == 'Jan']
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
# Series 데이터의 체중 비교 함수
def percent_loss(s):
    return ((s - s.iloc[0]) / s.iloc[0]) * 100

# %%
(weight_loss
    .query('Name=="Bob" and Month=="Jan"')
    ['Weight']
    .pipe(percent_loss)
)
# Out:
# 0    0.000000
# 2   -1.030928
# 4   -2.749141
# 6   -2.749141
# Name: Weight, dtype: float64

# %%
# groupby의 transform -> 각각의 그룹에 대해 apply
# 기존 인덱스 유지
(weight_loss
    .groupby(['Name', 'Month'])
    ['Weight'] 
    .transform(percent_loss)
)
# Out:
# 0     0.000000
# 1     0.000000
# 2    -1.030928
# 3    -4.060914
# 4    -2.749141
#         ...
# 27   -3.529412
# 28   -3.065134
# 29   -3.529412
# 30   -4.214559
# 31   -5.294118
# Name: Weight, Length: 32, dtype: float64

# %%
# assign -> 열추가 -> .assign(열이름 = (Series 데이터))
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Name=="Bob" and Month in ["Jan", "Feb"]')
)
# Out:
#    Name Month    Week  Weight  percent_loss
# 0   Bob   Jan  Week 1     291          0.0
# 2   Bob   Jan  Week 2     288         -1.0
# 4   Bob   Jan  Week 3     283         -2.7
# 6   Bob   Jan  Week 4     283         -2.7
# 8   Bob   Feb  Week 1     283          0.0
# 10  Bob   Feb  Week 2     275         -2.8
# 12  Bob   Feb  Week 3     268         -5.3
# 14  Bob   Feb  Week 4     268         -5.3

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"') # 각 월에 마지막 주의 데이터만 가져옴
)
# Out:
#    Name Month    Week  Weight  percent_loss
# 6   Bob   Jan  Week 4     283         -2.7
# 7   Amy   Jan  Week 4     190         -3.6
# 14  Bob   Feb  Week 4     268         -5.3
# 15  Amy   Feb  Week 4     173         -8.9
# 22  Bob   Mar  Week 4     261         -2.6
# 23  Amy   Mar  Week 4     170         -1.7
# 30  Bob   Apr  Week 4     250         -4.2
# 31  Amy   Apr  Week 4     161         -5.3

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss') # pivot으로 데이터 테이블 형태 변경
)
# Out:
# Name   Amy  Bob
# Month
# Apr   -5.3 -4.2
# Feb   -8.9 -5.3
# Jan   -3.6 -2.7
# Mar   -1.7 -2.6

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
) # 변경한 테이블에 winner column 추가
# Out:
# Name   Amy  Bob winner
# Month
# Apr   -5.3 -4.2    Amy
# Feb   -8.9 -5.3    Amy
# Jan   -3.6 -2.7    Amy
# Mar   -1.7 -2.6    Bob

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .style.highlight_min(subset = ['Amy', 'Bob'],axis=1)
) # 최소값 강조
# Out:
# <style type="text/css">
# #T_323b3_row0_col0, #T_323b3_row1_col0, #T_323b3_row2_col0, #T_323b3_row3_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_323b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th id="T_323b3_level0_col0" class="col_heading level0 col0" >Amy</th>
#       <th id="T_323b3_level0_col1" class="col_heading level0 col1" >Bob</th>
#       <th id="T_323b3_level0_col2" class="col_heading level0 col2" >winner</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_323b3_level0_row0" class="row_heading level0 row0" >Apr</th>
#       <td id="T_323b3_row0_col0" class="data row0 col0" >-5.300000</td>
#       <td id="T_323b3_row0_col1" class="data row0 col1" >-4.200000</td>
#       <td id="T_323b3_row0_col2" class="data row0 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_323b3_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_323b3_row1_col0" class="data row1 col0" >-8.900000</td>
#       <td id="T_323b3_row1_col1" class="data row1 col1" >-5.300000</td>
#       <td id="T_323b3_row1_col2" class="data row1 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_323b3_level0_row2" class="row_heading level0 row2" >Jan</th>
#       <td id="T_323b3_row2_col0" class="data row2 col0" >-3.600000</td>
#       <td id="T_323b3_row2_col1" class="data row2 col1" >-2.700000</td>
#       <td id="T_323b3_row2_col2" class="data row2 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_323b3_level0_row3" class="row_heading level0 row3" >Mar</th>
#       <td id="T_323b3_row3_col0" class="data row3 col0" >-1.700000</td>
#       <td id="T_323b3_row3_col1" class="data row3 col1" >-2.600000</td>
#       <td id="T_323b3_row3_col2" class="data row3 col2" >Bob</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 이긴 횟수 비교
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .winner
    .value_counts()
)
# Out:
# Amy    3
# Bob    1
# Name: winner, dtype: int64

# %%
# pivot의 기능을 unstack으로 따라해본거라고 합니다.
# groupby로 이중 인덱스 만들고 unstack으로 풀어버린것
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .groupby(['Month', 'Name'])
    ['percent_loss']
    .first()
    .unstack()
)
# Out:
# Name   Amy  Bob
# Month
# Apr   -5.3 -4.2
# Feb   -8.9 -5.3
# Jan   -3.6 -2.7
# Mar   -1.7 -2.6

# %% [markdown]
# ### There's more...

# %%
# 요건 Categorical 데이터가 순서를 지정할 수 있다는 점을 이용해
# Month 열을 category로 만들어 데이터 순서를 부여하여 
# 최종 출력의 Month를 실제 월 순서로 만들어버린 예시
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)),
            Month=pd.Categorical(weight_loss.Month,
                  categories=['Jan', 'Feb', 'Mar', 'Apr'],
                  ordered=True))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
)
# Out:
# Name   Amy  Bob
# Month
# Jan   -3.6 -2.7
# Feb   -8.9 -5.3
# Mar   -1.7 -2.6
# Apr   -5.3 -4.2

# %% [markdown]
# ## Calculating weighted mean SAT scores per state with apply

# %%
# 각 그룹에 대해 계산을 수행하는 함수를 받는 4가지 메서드
# agg : 스칼라값 반환
# filter : boolean 반환
# transform : 전달된 그룹과 길이가 같은 Series, DataFrame 반환
# apply : 유연한 return 가능

# agg, transform -> 각 집계 열마다 호출
# apply 그룹당 한번만 호출 

# college 데이터셋에서 주별로 수학과 언어 SAT 점수의 가중 평균을 계산하는 예제 
# 학교별 학부생 수를 이용해 점수 가중
college = pd.read_csv('data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# 결측치 싹다 제거
# Out:
# (1184, 27)

# %%
# 사용자 정의함수 생성, 가중평균 계산
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
# 그룹(주)별로 한번씩 함수가 호출되서 하나의 값으로 출력됨
college2.groupby('STABBR').apply(weighted_math_average)
# Out:
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
#      ...
# VT    566
# WA    555
# WI    593
# WV    500
# WY    540
# Length: 53, dtype: int64

# %%
# 모든 열에 agg 적용해보면 각 집계열에 대해 값을 반환하려고 하기 때문에 오류 발생
# 저 그룹에 각 집계열은 UGDS나 SATMTMID 같은 다른 열에 접근권한을 가지고 있는게 아니기 때문에 에러
(college2
    .groupby('STABBR')
    .agg(weighted_math_average)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'UGDS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286             try:
# --> 287                 return self._python_agg_general(func, *args, **kwargs)
#     288             except KeyError:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1480                 # if this function is invalid for this dtype, we will ignore it.
# -> 1481                 result = self.grouper.agg_series(obj, f)
#    1482             except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func, preserve_dtype)
#     980         else:
# --> 981             result = self._aggregate_series_pure_python(obj, func)
#     982
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#    1004             group = group.__finalize__(obj, method="groupby")
# -> 1005             res = func(group)
#    1006             res = libreduction.extract_result(res)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1466         func = com.is_builtin_func(func)
# -> 1467         f = lambda x: func(x, *args, **kwargs)
#    1468
#
# <ipython-input-83-9baab661fb83> in weighted_math_average(df)
#       2 def weighted_math_average(df):
# ----> 3     weighted_math = df['UGDS'] * df['SATMTMID']
#       4     return int(weighted_math.sum() / df['UGDS'].sum())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     958         elif key_is_scalar:
# --> 959             return self._get_value(key)
#     960
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1069         # Similar to Index.get_value, but we do not fall back to positional
# -> 1070         loc = self.index.get_loc(label)
#    1071         return self.index._get_values_for_loc(self, loc, label)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#
# KeyError: 'UGDS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'UGDS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-e60dee68803d> in <module>
#       1 # 모든 열에 agg 적용해보면 각 집계열에 대해 값을 반환하려고 하기 때문에 오류 발생
#       2 # 저 그룹에 각 집계열은 UGDS나 SATMTMID 같은 다른 열에 접근권한을 가지고 있는게 아니기 때문에 에러
# ----> 3 (college2
#       4     .groupby('STABBR')
#       5     .agg(weighted_math_average)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     898                 gba = GroupByApply(self, [func], args=(), kwargs={})
#     899                 try:
# --> 900                     result = gba.agg()
#     901
#     902                 except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in agg(self)
#     169         elif is_list_like(arg):
#     170             # we require a list, but not a 'str'
# --> 171             return self.agg_list_like()
#     172
#     173         if callable(arg):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in agg_list_like(self)
#     373                     # See GH #43741 for more details
#     374                     with warnings.catch_warnings(record=True) as record:
# --> 375                         new_res = colg.aggregate(arg)
#     376                     if len(record) > 0:
#     377                         match = re.compile(depr_nuisance_columns_msg.format(".*"))
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     269             # but not the class list / tuple itself.
#     270             func = maybe_mangle_lambdas(func)
# --> 271             ret = self._aggregate_multiple_funcs(func)
#     272             if relabeling:
#     273                 # error: Incompatible types in assignment (expression has type
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     324
#     325             key = base.OutputKey(label=name, position=idx)
# --> 326             results[key] = self.aggregate(func)
#     327
#     328         if any(isinstance(x, DataFrame) for x in results.values()):
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     289                 # TODO: KeyError is raised in _python_agg_general,
#     290                 #  see test_groupby.test_basic
# --> 291                 result = self._aggregate_named(func, *args, **kwargs)
#     292
#     293                 # result is a dict whose keys are the elements of result_index
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     413             object.__setattr__(group, "name", name)
#     414
# --> 415             output = func(group, *args, **kwargs)
#     416             output = libreduction.extract_result(output)
#     417             if not initialized:
#
# <ipython-input-83-9baab661fb83> in weighted_math_average(df)
#       1 # 사용자 정의함수 생성, 가중평균 계산
#       2 def weighted_math_average(df):
# ----> 3     weighted_math = df['UGDS'] * df['SATMTMID']
#       4     return int(weighted_math.sum() / df['UGDS'].sum())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     957
#     958         elif key_is_scalar:
# --> 959             return self._get_value(key)
#     960
#     961         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1068
#    1069         # Similar to Index.get_value, but we do not fall back to positional
# -> 1070         loc = self.index.get_loc(label)
#    1071         return self.index._get_values_for_loc(self, loc, label)
#    1072
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'UGDS'

# %%
# 마찬가지 SATMTMID로 열을 국한해도, UGDS라는 비집계열에 대한 접근 권한이 없어 에러발생
(college2
    .groupby('STABBR')
    ['SATMTMID'] 
    .agg(weighted_math_average)
)

# %%
# apply는 유연해서 Series를 반환해 다수의 새로운 열을 만들수도 있다
def weighted_average(df):
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']
    wm_avg = weight_m.sum() / df['UGDS'].sum()
    wv_avg = weight_v.sum() / df['UGDS'].sum()
    data = {'w_math_avg': wm_avg,
           'w_verbal_avg': wv_avg,
           'math_avg': df['SATMTMID'].mean(),
           'verbal_avg': df['SATVRMID'].mean(),
           'count': len(df)
    }
    return pd.Series(data)


(college2
    .groupby('STABBR')
    .apply(weighted_average)
    .astype(int)
)
# Out:
#         w_math_avg  w_verbal_avg  math_avg  verbal_avg  count
# STABBR
# AK             503          555        503         555      1
# AL             536          533        504         508     21
# AR             529          504        515         491     16
# AZ             569          557        536         538      6
# CA             564          539        562         549     72
# ...            ...          ...        ...         ...    ...
# VT             566          564        526         527      8
# WA             555          541        551         548     18
# WI             593          556        545         516     14
# WV             500          487        481         473     17
# WY             540          535        540         535      1
#
# [53 rows x 5 columns]

# %%
(college
    .groupby('STABBR')
    .apply(weighted_average)
)
# 이 예제에서 결측치를 제거하지 않으면 가중평균계산이 중단되어 잘못된 값을 출력하게 된다.
# Out:
#         w_math_avg  w_verbal_avg    math_avg  verbal_avg  count
# STABBR
# AK        5.548091     6.121651   503.000000  555.000000   10.0
# AL      261.895658   260.550109   504.285714  508.476190   96.0
# AR      301.054792   287.264872   515.937500  491.875000   86.0
# AS        0.000000     0.000000          NaN         NaN    1.0
# AZ       61.815821    60.511712   536.666667  538.333333  133.0
# ...            ...          ...          ...         ...    ...
# VT      389.967094   388.696848   526.875000  527.500000   27.0
# WA      274.885878   267.880280   551.222222  548.333333  123.0
# WI      153.803086   144.160115   545.071429  516.857143  112.0
# WV      224.697582   218.843452   481.705882  473.411765   73.0
# WY      216.761180   214.754132   540.000000  535.000000   11.0
#
# [59 rows x 5 columns]

# %%
from scipy.stats import gmean, hmean
def calculate_means(df):
    df_means = pd.DataFrame(index=['Arithmetic', 'Weighted',
                                   'Geometric', 'Harmonic'])
    cols = ['SATMTMID', 'SATVRMID']
    for col in cols:
        arithmetic = df[col].mean()
        weighted = np.average(df[col], weights=df['UGDS'])
        geometric = gmean(df[col])
        harmonic = hmean(df[col])
        df_means[col] = [arithmetic, weighted,
                         geometric, harmonic]
    df_means['count'] = len(df)
    return df_means.astype(int)

# 평균, 가중평균, 기하평균, 조화평균에 대해 계산하는 사용자 정의함수를 
# apply를 통해 각 주별로 적용시킨 예시
(college2
    .groupby('STABBR')
    .apply(calculate_means)
)
# Out:
#                    SATMTMID  SATVRMID  count
# STABBR
# AK     Arithmetic       503       555      1
#        Weighted         503       555      1
#        Geometric        503       555      1
#        Harmonic         503       555      1
# AL     Arithmetic       504       508     21
# ...                     ...       ...    ...
# WV     Harmonic         480       472     17
# WY     Arithmetic       540       535      1
#        Weighted         540       535      1
#        Geometric        540       534      1
#        Harmonic         540       535      1
#
# [212 rows x 3 columns]

# %% [markdown]
# ## Grouping by continuous variables

# %%
# 이산(discrete) 값이 아닌 연속(continuous)한 값을 그룹화 하는 방법에 대한 예시
# 다양한 운항거리에 대한 항공사의 분포를 구하는 예시

flights = pd.read_csv('data/flights.csv')
flights
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0          94.0   590       1905       65.0         0          0
# 1         154.0  1452       1333      -13.0         0          0
# 2          85.0   641       1453       35.0         0          0
# 3         126.0  1192       1935       -7.0         0          0
# 4         166.0  1363       2225       39.0         0          0
# ...         ...   ...        ...        ...       ...        ...
# 58487     166.0  1464       1045      -19.0         0          0
# 58488      71.0   414       2050        4.0         0          0
# 58489      46.0   262       1956       -5.0         0          0
# 58490     124.0   907        855       34.0         0          0
# 58491      73.0   522       1146       -1.0         0          0
#
# [58492 rows x 14 columns]

# %%
# 거리 값을 구분하기 위한 기준 구간 값 설정
bins = [-np.inf, 200, 500, 1000, 2000, np.inf] 
# flights['DIST']를 bins에 따라 5개의 구간으로 카테고리형 변환
cuts = pd.cut(flights['DIST'], bins=bins)
cuts
# Out:
# 0        (500.0, ...
# 1        (1000.0,...
# 2        (500.0, ...
# 3        (1000.0,...
# 4        (1000.0,...
#             ...
# 58487    (1000.0,...
# 58488    (200.0, ...
# 58489    (200.0, ...
# 58490    (500.0, ...
# 58491    (500.0, ...
# Name: DIST, Length: 58492, dtype: category
# Categories (5, interval[float64, right]): [(-inf, 2... < (200.0, ... < (500.0, ... < (1000.0,... < (2000.0,...]

# %%
cuts.value_counts()
# Out:
# (500.0, 1000.0]     20659
# (200.0, 500.0]      15874
# (1000.0, 2000.0]    14186
# (2000.0, inf]        4054
# (-inf, 200.0]        3719
# Name: DIST, dtype: int64

# %%
# 각 거리 구간으로 그룹을 만들고 전체 항공편 중 항공사별 비중 계산 
(flights
    .groupby(cuts)
    ['AIRLINE']
    .value_counts(normalize=True) 
    .round(3)
)
# Out:
# DIST           AIRLINE
# (-inf, 200.0]  OO         0.326
#                EV         0.289
#                MQ         0.211
#                DL         0.086
#                AA         0.052
#                           ...
# (2000.0, inf]  WN         0.046
#                HA         0.028
#                NK         0.019
#                AS         0.012
#                F9         0.004
# Name: AIRLINE, Length: 57, dtype: float64

# %%
# 요렇게 하면 거리 그룹별  백분위별 비행시간을 찾을 수 있음 
(flights
  .groupby(cuts)
  ['AIR_TIME']
  .quantile(q=[.25, .5, .75]) 
  .div(60)
  .round(2)
)
# Out:
# DIST
# (-inf, 200.0]     0.25    0.43
#                   0.50    0.50
#                   0.75    0.57
# (200.0, 500.0]    0.25    0.77
#                   0.50    0.92
#                           ...
# (1000.0, 2000.0]  0.50    2.93
#                   0.75    3.40
# (2000.0, inf]     0.25    4.30
#                   0.50    4.70
#                   0.75    5.03
# Name: AIR_TIME, Length: 15, dtype: float64

# %%
# 예시가 맞나..? cut은 거리로 해두고 라벨은 시간으로 했는데... 
# 암튼 이렇게 구간에 라벨을 부여할수도 있음. 본예시는 unstack으로 펼치기까지 함
labels=['Under an Hour', '1 Hour', '1-2 Hours',
        '2-4 Hours', '4+ Hours']
cuts2 = pd.cut(flights['DIST'], bins=bins, labels=labels)
(flights
   .groupby(cuts2)
   ['AIRLINE']
   .value_counts(normalize=True) 
   .round(3) 
   .unstack() 
)
# Out:
# AIRLINE          AA     AS     B6     DL     EV     F9     HA     MQ     NK  \
# DIST
# Under an ...  0.052    NaN    NaN  0.086  0.289    NaN    NaN  0.211    NaN
# 1 Hour        0.071  0.001  0.007  0.189  0.156  0.005    NaN  0.100  0.012
# 1-2 Hours     0.144  0.023  0.003  0.206  0.101  0.038    NaN  0.051  0.030
# 2-4 Hours     0.264  0.016  0.003  0.165  0.016  0.031    NaN  0.003  0.045
# 4+ Hours      0.212  0.012  0.080  0.171    NaN  0.004  0.028    NaN  0.019
#
# AIRLINE          OO     UA     US     VX     WN
# DIST
# Under an ...  0.326  0.027    NaN    NaN  0.009
# 1 Hour        0.159  0.062  0.016  0.028  0.194
# 1-2 Hours     0.106  0.131  0.025  0.004  0.138
# 2-4 Hours     0.046  0.199  0.040  0.012  0.160
# 4+ Hours        NaN  0.289  0.065  0.074  0.046

# %% [markdown]
# ## Counting the total number of flights between cities

# %%
# 두 도시 사이의 총 비행횟수를 세는 예시 
flights = pd.read_csv('data/flights.csv')
flights_ct = flights.groupby(['ORG_AIR', 'DEST_AIR']).size()
# 요로코롬 출발지와 도착지에 대해 그룹화 시키고 size로 몇회인지 반환
flights_ct
# Out:
# ORG_AIR  DEST_AIR
# ATL      ABE          31
#          ABQ          16
#          ABY          19
#          ACY           6
#          AEX          40
#                     ...
# SFO      SNA         122
#          STL          20
#          SUN          10
#          TUS          20
#          XNA           2
# Length: 1130, dtype: int64

# %%
# 이렇게도 할수 있지만... 모든 항공편에 적용할수 있는 해법이 필요
flights_ct.loc[[('ATL', 'IAH'), ('IAH', 'ATL')]]
# Out:
# ORG_AIR  DEST_AIR
# ATL      IAH         121
# IAH      ATL         148
# dtype: int64

# %%
# 각 행의 출발지와 목적지 열을 알파벳 순으로 정렬
# 요렇게하면 열의 의미가 없어지고 두 열의 값이 각 행에대해 정렬되버림
f_part3 = (flights  # doctest: +SKIP
  [['ORG_AIR', 'DEST_AIR']] 
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
f_part3
# Out:
#          0    1
# 0      LAX  SLC
# 1      DEN  IAD
# 2      DFW  VPS
# 3      DCA  DFW
# 4      LAX  MCI
# ...    ...  ...
# 58487  DFW  SFO
# 58488  LAS  SFO
# 58489  SBA  SFO
# 58490  ATL  MSP
# 58491  BOI  SFO
#
# [58492 rows x 2 columns]

# %%
# 열이름 재지정해주고
# 다시 그룹화 시켜봄
rename_dict = {0:'AIR1', 1:'AIR2'}  
(flights     # doctest: +SKIP
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
)
# Out:
# AIR1  AIR2
# ABE   ATL      31
#       ORD      24
# ABI   DFW      74
# ABQ   ATL      16
#       DEN      46
#              ...
# SFO   SNA     122
#       STL      20
#       SUN      10
#       TUS      20
#       XNA       2
# Length: 1085, dtype: int64

# %%
# 
(flights     # doctest: +SKIP
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns') #
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
  .loc[('ATL', 'IAH')]
)
# Out:
# 269

# %%
# 행 별로 정렬되어있어 순서를 바꾸면 오류가 나게 된다.(해당 키가 없다고)
(flights     # doctest: +SKIP
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
  .loc[('IAH', 'ATL')]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2823                     try:
# -> 2824                         return (self._engine.get_loc(key), None)
#    2825                     except KeyError as e:
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.UInt64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.UInt64HashTable.get_item()
#
# KeyError: 29185
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-7a2a9df091a7> in <module>
#       7   .groupby(['AIR1', 'AIR2'])
#       8   .size()
# ----> 9   .loc[('IAH', 'ATL')]
#      10 )
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     915         # instead of checking it as multiindex representation (GH 13797)
#     916         if isinstance(ax0, MultiIndex) and self.name != "iloc":
# --> 917             result = self._handle_lowerdim_multi_index_axis0(tup)
#     918             if result is not None:
#     919                 return result
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in _handle_lowerdim_multi_index_axis0(self, tup)
#     887             # else IndexingError will be raised
#     888             if len(tup) <= self.obj.index.nlevels and len(tup) > self.obj.ndim:
# --> 889                 raise ek
#     890         except Exception as e1:
#     891             if isinstance(tup[0], (slice, Index)):
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in _handle_lowerdim_multi_index_axis0(self, tup)
#     879         try:
#     880             # fast path for series or for tup devoid of slices
# --> 881             return self._get_label(tup, axis=axis)
#     882         except TypeError:
#     883             # slices are unhashable
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     154             # but will fail when the index is not present
#     155             # see GH5667
# --> 156             return self.obj._xs(label, axis=axis)
#     157         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     158             raise IndexingError("no slices here, handle elsewhere")
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3733         index = self.index
#    3734         if isinstance(index, MultiIndex):
# -> 3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
#    3737             loc = self.index.get_loc(key)
#
# ~/.env/364/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2824                         return (self._engine.get_loc(key), None)
#    2825                     except KeyError as e:
# -> 2826                         raise KeyError(key) from e
#    2827                 else:
#    2828                     return partial_selection(key)
#
# KeyError: ('IAH', 'ATL')

# %% [markdown]
# ### There's more ...

# %%
# axis = 'columns'로 .apply 호출하는 것은 성능이 낮은 작업으로 더 큰데이터에서 사용은 힘듬
# Numpy sort를 사용하면 속도를 크게 올릴수 있다는 예시
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
data_sorted[:10]
# Out:
# array([['LAX', 'SLC'],
#        ['DEN', 'IAD'],
#        ['DFW', 'VPS'],
#        ['DCA', 'DFW'],
#        ['LAX', 'MCI'],
#        ['IAH', 'SAN'],
#        ['DFW', 'MSY'],
#        ['PHX', 'SFO'],
#        ['ORD', 'STL'],
#        ['IAH', 'SJC']], dtype=object)

# %%
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
flights_sort2.equals(f_part3.rename(columns={'ORG_AIR':'AIR1',
    'DEST_AIR':'AIR2'}))
# Out:
# False

# %%
# %%timeit
flights_sort = (flights   # doctest: +SKIP
    [['ORG_AIR', 'DEST_AIR']] 
   .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
# Out:
# 9.72 s ± 68.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
flights_sort2 = pd.DataFrame(data_sorted,
    columns=['AIR1', 'AIR2'])
# Out:
# 7.77 ms ± 305 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Finding the longest streak of on-time flights

# %%
# 각 출발지에서 항공사 별로 가장 긴 연속 정시 비행을 찾는 예시
#요건 짧은 예시
s = pd.Series([0, 1, 1, 0, 1, 1, 1, 0])
s
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    1
# 7    0
# dtype: int64

# %%
# .cumsum() 누적합
s1 = s.cumsum()
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    2
# 4    3
# 5    4
# 6    5
# 7    5
# dtype: int64

# %%
# 누적합과 기존데이터간의 곱
s.mul(s1)
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    3
# 5    4
# 6    5
# 7    0
# dtype: int64

# %%
# 각 인덱스간의 차이
s.mul(s1).diff()
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3   -2.0
# 4    3.0
# 5    1.0
# 6    1.0
# 7   -5.0
# dtype: float64

# %%
# 저 차이에서 음수는 연속된 1이 끝났음을 의미
# 끝난 지점 외에는 죄다 nan 처리
(s
    .mul(s.cumsum())
    .diff()
    .where(lambda x: x < 0)
)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4    NaN
# 5    NaN
# 6    NaN
# 7   -5.0
# dtype: float64

# %%
# ffill을 쓰면 아래로 값을 전파
(s
    .mul(s.cumsum())
    .diff()
    .where(lambda x: x < 0)
    .ffill()
)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4   -2.0
# 5   -2.0
# 6   -2.0
# 7   -5.0
# dtype: float64

# %%
# 전파한 값에 누적합산을 더하면 초과누적 상쇄
(s
    .mul(s.cumsum())
    .diff()
    .where(lambda x: x < 0)
    .ffill()
    .add(s.cumsum(), fill_value=0)
)
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    0.0
# 4    1.0
# 5    2.0
# 6    3.0
# 7    0.0
# dtype: float64

# %%
# 이제 본 예제 시작
flights = pd.read_csv('data/flights.csv')
(flights
    .assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
    [['AIRLINE', 'ORG_AIR', 'ON_TIME']]
)
# Out:
#       AIRLINE ORG_AIR  ON_TIME
# 0          WN     LAX        0
# 1          UA     DEN        1
# 2          MQ     DFW        0
# 3          AA     DFW        1
# 4          WN     LAX        0
# ...       ...     ...      ...
# 58487      AA     SFO        1
# 58488      F9     LAS        1
# 58489      OO     SFO        1
# 58490      WN     MSP        0
# 58491      OO     SFO        1
#
# [58492 rows x 3 columns]

# %%
# 위에서 했던 예시를 고대로 적용해서 Series의 최대 연속을 반환하는 함수를 정의

def max_streak(s):
    s1 = s.cumsum()
    return (s
       .mul(s1)
       .diff()
       .where(lambda x: x < 0) 
       .ffill()
       .add(s1, fill_value=0)
       .max()
    )

# %%
# 항공사와 출발지 공항별 정시도착비율, 비행횟수, 최대연속 정시 비행횟수 구하는 코드
(flights
    .assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
    .sort_values(['MONTH', 'DAY', 'SCHED_DEP']) 
    .groupby(['AIRLINE', 'ORG_AIR'])
    ['ON_TIME'] 
    .agg(['mean', 'size', max_streak])
    .round(2)
)
# Out:
#                  mean  size  max_streak
# AIRLINE ORG_AIR
# AA      ATL      0.82   233          15
#         DEN      0.74   219          17
#         DFW      0.78  4006          64
#         IAH      0.80   196          24
#         LAS      0.79   374          29
# ...               ...   ...         ...
# WN      LAS      0.77  2031          39
#         LAX      0.70  1135          23
#         MSP      0.84   237          32
#         PHX      0.77  1724          33
#         SFO      0.76   445          17
#
# [114 rows x 3 columns]

# %% [markdown]
# ### There's more...

# %%
# 가장 긴 연착 찾기
# Ontime 아닌거 찾아서 똑같이 돌리면 됩니다.. 
def max_delay_streak(df):
    df = df.reset_index(drop=True)
    late = 1 - df['ON_TIME']
    late_sum = late.cumsum()
    streak = (late
        .mul(late_sum)
        .diff()
        .where(lambda x: x < 0) 
        .ffill()
        .add(late_sum, fill_value=0)
    )
    last_idx = streak.idxmax()
    first_idx = last_idx - streak.max() + 1
    res = (df
        .loc[[first_idx, last_idx], ['MONTH', 'DAY']]
        .assign(streak=streak.max())
    )
    res.index = ['first', 'last']
    return res

# %%
(flights
    .assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
    .sort_values(['MONTH', 'DAY', 'SCHED_DEP']) 
    .groupby(['AIRLINE', 'ORG_AIR']) 
    .apply(max_delay_streak) 
    .sort_values('streak', ascending=False)
)
# Out:
#                        MONTH   DAY  streak
# AIRLINE ORG_AIR
# AA      DFW     first    2.0  26.0    38.0
#                 last     3.0   1.0    38.0
# MQ      ORD     last     1.0  12.0    28.0
#                 first    1.0   6.0    28.0
#         DFW     last     2.0  26.0    25.0
# ...                      ...   ...     ...
# US      LAS     last     1.0   7.0     1.0
# AS      ATL     first    5.0   4.0     1.0
# OO      LAS     first    2.0   8.0     1.0
# EV      PHX     last     8.0   1.0     0.0
#                 first    NaN   NaN     0.0
#
# [228 rows x 3 columns]
