# %%
#https://www.amazon.com/bestsellers

#위 사이트에서 appliance 카테고리의 모든 제품의 랭킹, 타이틀, 댓글수, 가격정보를 출력하시오

# %%
# pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests 
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url = 'https://www.amazon.com/bestsellers'

# %%
driver = webdriver.Chrome()

# %%
driver.get(url)

# %%
# driver.find_element_by_css_selector('#CardInstanceBhY1IjmgPcYlYyf7nhkxbA > div._p13n-zg-nav-tree-all_style_zg-browse-group__88fbz > div:nth-child(4) > a')
# appliance 클릭 

# 경로가 바뀌어서 크롤링이 안됨

# %%
driver.find_element_by_link_text('Appliances').click()  # 사이트 텍스트로 클릭
# Out:
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_2172/3386150370.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text('Appliances').click()  # 사이트 텍스트로 클릭

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.21.9-2022-01-15" lang="en-us"><!-- sp:feature:head-start --><head><script async="" crossorigin="anonymous" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics-incremental.min.js"></script><script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js"></script><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# ...

# %%
path = '#gridItemRoot > div'
tags = soup.select(path)

# %%
# 랭킹
tags[0].select('span.zg-bdg-text')
# Out:
# [<span class="zg-bdg-text">#1</span>]

# %%
tags[0].select('span.zg-bdg-text')[0].text
# Out:
# '#1'

# %%
#타이틀
tags[0].select('div._p13n-zg-list-grid-desktop_truncationStyles_p13n-sc-css-line-clamp-3__g3dy1')
# Out:
# [<div class="_p13n-zg-list-grid-desktop_truncationStyles_p13n-sc-css-line-clamp-3__g3dy1">Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel</div>]

# %%
tags[0].select('div._p13n-zg-list-grid-desktop_truncationStyles_p13n-sc-css-line-clamp-3__g3dy1')[0].text
# Out:
# 'Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel'

# %%
# 댓글수

tags[0].select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(3) > div > a > span')[0].text
# Out:
# '454'

# %%
# 가격정보

# tags[0].select("#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span > span > span")[0].text

tags[0].select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span')[0].text

# '#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span'
# Out:
# '2 offers from $89.98'

# %%
for tag in tags:
    
    print("랭킹: ", tag.select('span.zg-bdg-text')[0].text)
    print("제품명: ", tag.select('div._p13n-zg-list-grid-desktop_truncationStyles_p13n-sc-css-line-clamp-3__g3dy1')[0].text)
    print("댓글수: ", tag.select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(3) > div > a > span')[0].text)
    
    try:
        print("가격: ", tag.select("#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span > span > span")[0].text)
    except:
         print("가격: ", tag.select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span')[0].text)
            
    print("="*50)
# Out:
# 랭킹:  #1
# 제품명:  Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel
# 댓글수:  454
# 가격:  $89.98
# ...
# 랭킹:  #2
# 제품명:  AGLUCKY Ice Maker Machine for Countertop, Portable Ice Cube Makers, Make 26 lbs ice in 24 hrs,Ice Cube Rready in 6-8 Mins with Ice Scoop and Basket for Home/Office/Bar (Black)
# 댓글수:  10,757
# 가격:  $110.49
# ...
# 랭킹:  #3
# 제품명:  Frigidaire EFIC189-Silver Compact Ice Maker, 26 lb per Day, Silver
# 댓글수:  8,453
# 가격:  $129.99
# ...
# 랭킹:  #4
# 제품명:  GE Profile Opal | Countertop Nugget Ice Maker with Side Tank | Portable Ice Machine with Bluetooth Connectivity | Smart Home Kitchen Essentials | Stainless Steel Finish | Up to 24 lbs. of Ice Per Day
# 댓글수:  15,137
# 가격:  $412.49
# ...
# 랭킹:  #5
# 제품명:  2-Pack Ice Machine Cleaner and Descaler 16 fl oz, Nickel Safe Descaler | Ice Maker Cleaner Compatible with All Major Brands (Scotsman, KitchenAid, Affresh) - Made in USA by Essential Values
# 댓글수:  780
# 가격:  $19.99 - $44.99
# ...
# 랭킹:  #6
# ...

# %%
# 모든 페이지 출력(1,2 페이지 둘다 출력)

# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
# url =  https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_1?_encoding=UTF8&pg=1'
# url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_2?_encoding=UTF8&pg=2'

driver= webdriver.Chrome()
url =' https://www.amazon.com/Best-Sellers/zgbs'
driver.get(url)

# %%
driver.find_element_by_link_text('Appliances').click()  # 'Appliance'는' 그냥 보고 치는건가? 겹치면 어떡하지?
# Out:
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_2172/1461629455.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text('Appliances').click()  # 'Appliance'는' 그냥 보고 치는건가? 겹치면 어떡하지?

# %%
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

# %%
# 제품 하나 전체 박스의 경로
# path = '#zg-ordered-list > li:nth-child(1)'
path = '#zg-ordered-list > li'

tags = soup.select(path)
tags
# Out:
# [<li class="zg-item-immersion" role="gridcell"><span class="a-list-item"><div class="a-section a-spacing-none aok-relative"><div class="a-row a-spacing-none aok-inline-block"><span class="a-size-small aok-float-left zg-badge-body zg-badge-color"><span class="zg-badge-text">#1</span></span><span class="aok-float-left zg-badge-triangle zg-badge-color"></span></div><span class="aok-inline-block zg-item"><a class="a-link-normal" href="/FRIGIDAIRE-EFIC121-SS-Frigidaire-Ice-Maker/dp/B07VMBP1N5/ref=zg_bs_appliances_1?_encoding=UTF8&amp;psc=1&amp;refRID=85Z7XSMVG896WCM6YSTY"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel" height="200" src="https://images-na.ssl-images-amazon.com/images/I/71ytZOcwYqL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
#  <div aria-hidden="true" class="p13n-sc-truncated" data-rows="2">Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel</div>
#  </a>
# ...

# %%
# 랭킹
tags[0].select('#zg-ordered-list > li > span > div > div > span.a-size-small.aok-float-left.zg-badge-body.zg-badge-color > span')[0].text
# Out:
# '#1'

# %%
# 제품명
tags[0].select('#zg-ordered-list > li > span > div > span > a > div')[0].text
# Out:
# 'Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel'

# %%
# 가격 1
tags[0].select("#zg-ordered-list > li > span > div > span > a.a-link-normal.a-text-normal > span > span > span")[0].text
# Out:
# '$89.98'

# %%
# 가격(범위) 2 안나오는 이유?? 

#tags[0].select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span')[0].text

tags[0].select('#gridItemRoot > div > div.zg-grid-general-faceout > div > div:nth-child(4) > a > span')
# Out:
# []
