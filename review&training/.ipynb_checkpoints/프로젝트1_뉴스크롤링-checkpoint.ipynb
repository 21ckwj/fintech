# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
lst_title = []
lst_summary = []
lst_date = []

for i in range(400): # i =페이지, 최대 400페이지
    
    def page(i):
        page = (i+1)*10-9 # i=0부터 시작하므로
        return page
    
    search = '국제유가'
    
    #기간 끝: 2022/02/10
    
    start_date = '2018.05.11' #ex) 2017.01.01
    last_date = '2018.06.10'
    
    start_d = '20180511' #ex) 20170101
    last_d = '20180610'
    
    url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={}&sort=0&photo=0&field=0&pd=3&ds={}&de={}&cluster_rank=25&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from{}to{},a:all&start={}'.format(search, start_date, last_date, start_d, last_d, page(i))
    
   
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')
#   path = '#main_pack > section > div > div.group_news > ul>li'
    path = 'section > div > div.group_news > ul>li'
    lis = soup.select(path)
    
    for li in lis:
        # 제목
        
        title = li.select('div > div > a.news_tit')[0].text
        lst_title.append(title)
        
        # 요약
        summary = li.select('div > div.news_dsc > div > a')[0].text
        lst_summary.append(summary)      
        
        # 날짜
        cnt = len(li.select('div > div > div.news_info > div.info_group > span.info'))
        try:
            if cnt >=2:
                raise
            else:
                date=li.select('div > div > div.news_info > div.info_group > span')[0].text
        except:
            date = li.select('div > div > div.news_info > div.info_group > span:nth-child(3)')[0].text
            
        lst_date.append(date)
        
#         print(date)
#         print(title)
#         print(summary)
#         print("-"* 50)
        
        df = pd.DataFrame({'날짜':lst_date,'제목': lst_title, '요약': lst_summary})
        df.to_csv('./oilnews_data/news_{}_{}.csv'.format(start_d,last_d))

# %%
df = pd.DataFrame({'날짜':lst_date,'제목': lst_title, '요약': lst_summary})
print(len(df.values))
df
# Out:
# 3685
#                날짜                                       제목  \
# 0     2018.06.10.  충북 유가 연일 상승…ℓ당 휘발유 1611.72원·경유 1411.08원
# 1     2018.06.09.            국제유가, 美 증산 부담 속 약보합…WTI 0.3%↓
# 2     2018.06.10.                 "국제유가 오르면 소비자물가 상승 대비해야"
# 3     2018.06.10.            무역전쟁·포퓰리즘.고유가… 세계 경제 폭풍이 몰려온다
# 4     2018.06.09.         국제유가 하락했다는데…주유소 휘발유 가격, 7주 연속 상승
# ...           ...                                      ...
# 3680  2018.05.15.       [충청매일] 충북 휘발유가격 4주 연속 상승…올해 최고가 경신
# 3681  2018.05.15.       [충청매일] 충북 휘발유가격 4주 연속 상승…올해 최고가 경신
# 3682  2018.05.15.       [충청매일] 충북 휘발유가격 4주 연속 상승…올해 최고가 경신
# 3683  2018.05.15.       [충청매일] 충북 휘발유가격 4주 연속 상승…올해 최고가 경신
# 3684  2018.05.15.       [충청매일] 충북 휘발유가격 4주 연속 상승…올해 최고가 경신
#
#                                                      요약
# 0     한국석유공사 관계자는 "미 원유 생산 및 재고 증가와 석유수출국기구(OPEC) 증산...
# 1     국제유가는 8일(현지시간) 소폭 하락했다. 이날 뉴욕상업거래소(NYMEX)에서 7월...
# 2     이에 따라, 국제유가 상승이 소비자물가 상승으로 이어질 가능성에 대비해야 한다는 지...
# 3     한편 국제유가 상승세로 인도 중앙은행(RBI)이 지난주 금리인상에 나서는 등 최근 ...
# 4     한편 국제유가는 상승세를 멈추고 내림세로 돌아섰다. 우리나라가 주로 수입하는 두바이...
# ...                                                 ...
# 3680  주요 산유국인 이란과 베네수엘라의 정치 불안이 가중되면서 국제유가가 지속적으로 오르...
# 3681  주요 산유국인 이란과 베네수엘라의 정치 불안이 가중되면서 국제유가가 지속적으로 오르...
# 3682  주요 산유국인 이란과 베네수엘라의 정치 불안이 가중되면서 국제유가가 지속적으로 오르...
# 3683  주요 산유국인 이란과 베네수엘라의 정치 불안이 가중되면서 국제유가가 지속적으로 오르...
# 3684  주요 산유국인 이란과 베네수엘라의 정치 불안이 가중되면서 국제유가가 지속적으로 오르...
#
# [3685 rows x 3 columns]

# %%
#  def page(i):
#         page = (i+1)*10-9 # i=0부터 시작하므로
#         return page
    
# search = '국제유가'
    
# start_date = '2017.01.01' #ex) 2017.01.01
# last_date = '2020.12.31'
    
# start_d = '20170101' #ex) 20170101
# last_d = '20201231'
    
# url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={}&sort=0&photo=0&field=0&pd=3&ds={}&de={}&cluster_rank=25&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from{}to{},a:all&start={}'.format(search, start_date, last_date, start_d, last_d, page(i))
    
   
# res = requests.get(url)
# soup = BeautifulSoup(res.text,'html.parser')
# #   path = '#main_pack > section > div > div.group_news > ul>li'
# path = 'section > div > div.group_news > ul>li'
# lis = soup.select(path)
# # lis[0]
# date = lis[0].select('div > div > div.news_info > div.info_group > span')[0].text
# date
# # date = li.select('div > div > div.news_info > div.info_group > span:nth-child(3)')[0].text
