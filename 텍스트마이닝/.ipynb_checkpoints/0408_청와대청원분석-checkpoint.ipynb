# %% [markdown]
# # 청와대 청원 크롤링

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www1.president.go.kr/petitions/best'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="#082e59" name="theme-color"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="description">
# <meta content="청와대, 대통령비서실, 대통령, 한국, 대한민국, 대한민국 정부, president.go.kr, 靑瓦臺, 19대, 문재인" name="keywords">
# <meta content="청와대 (CHEONGWADAE)" name="author">
# <meta content="telephone=no" name="format-detection">
# <meta content="website" property="og:type"/>
# <meta content="추천순 청원 목록 1페이지 &gt;  대한민국 청와대" property="og:title"/>
# <meta content="https://www1.president.go.kr/petitions/best?page=1" property="og:url"/>
# <meta content="대한민국 청와대" property="og:site_name"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." property="og:description"/>
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" property="og:image"/>
# <meta content="https://www1.president.go.kr/petitions/best?page=1" name="twitter:url"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="twitter:description">
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" name="twitter:image"/>
# <meta content="A4YCQihzy88Col-c_8IsuKMjtJS0XM4kKQe2yq35_NI" name="google-site-verification">
# <link href="/css/favicon.ico" rel="shortcut icon"/>
# <link href="/css/favicon.png" rel="icon"/>
# <link href="/css/favicon.png" rel="apple-touch-icon"/>
# <link href="/css/sub.css?v=3" rel="stylesheet"/>
# <link href="/css/init.css?v=3" rel="stylesheet"/>
# <link href="/css/common.css" rel="stylesheet"/>
# <link href="/css/layout.css?v=20170901" rel="stylesheet"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet"/>
# <link href="/css/animate.min.css" rel="stylesheet"/>
# <link href="/css/board.css?v=20180730" rel="stylesheet"/>
# <link href="/css/header.css?ver=20171215" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/css/sub_petitions.css?v=2019" rel="stylesheet" type="text/css">
# <link href="/css/magnific-popup.css" rel="stylesheet" type="text/css">
# <link href="/css/xeicon.min.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# .board .b_list .bl_category {left:0;}
# .txt2019_1 {
# 	text-align:left;
# 	font-size:1.4em;
# 	font-weight:500;
# 	border:1px solid #CCCCCC;
# 	border-radius: 6px;
# 	padding:20px;
# 	margin-top:5px;
# 	position:relative;
# }
# .txt2019_2 {
# 	position:absolute;
# 	right:0;
# 	top:0;
# 	padding:16px;
# 	margin:2px;
# 	border-left:1px solid #CCCCCC;
# }
# .txt2019_3 {
# 	border-radius: 6px;
# 	border:1px solid #CCCCCC;
# }
# a.txt2019_4 {
# 	position:relative;
# 	display:block;
# 	padding:20px;
# 	font-size:1.4em;
# 	text-align:left;
#     color:#000000;
#     font-weight:500;
# }
#
# .txt2019_5 {
# 	position:absolute;
# 	right:0;
# 	top:0;
# 	padding:16px;
# 	margin:2px;
# }
# .txt2019_6 {
# 	border-bottom:1px solid #CCC;
# }
#
# .txt2019_7 {
# 	background:#FAFAFA;
# 	padding:20px;
# 	display:none;
# }
# .txt2019_7.active {
# 	display:block;
# }
# .txt2019_7 li {
# }
# .txt2019_8 {
#
# }
# a.txt2019_9 {
# 	position:relative;
# 	border-bottom:1px solid #e4e4e4;
# 	color:#8a8a8a;
# 	display:block;
# 	padding:10px 40px 10px 0;
# 	line-height:1.4em;
# }
# a.list-bottom {
# 	border:0;
# }
#
# a.txt2019_9 .more {
# 	position:absolute;
# 	right:0;
# 	top:50%;
# 	font-size:1.4em;
# 	margin-top:-0.4em;
# }
# ul.txt2019_10 {
# 	display:none;
# 	padding:10px 0;
# 	background:#f0f0f0;
# }
# ul.txt2019_10 li {
# 	padding:10px;
# 	line-height:1.4em;
# 	border-bottom:1px solid #CCCCCC;
# }
# ul.txt2019_10 li.bottom {
# 	border:none;
# }
# .relpy_w {
#
# }
# .wv_answer_category {left:0 !important}
# .wv_agree {color:#019eef !important}
# .wv_category {
# 	text-align:left !important;
# 	left:0 !important
# }
# .board .b_list .bl_subject {margin-right:250px;}
#
# #contents.c_sub .cs_hero.newsroom {
# 	background-image: url('/storage/images/petitions/4th/petitions_banner.png');
# }
# #contents.c_sub .cs_hero .csh_txt {
#     bottom: 70px;
# }
# .petitions_4th_btn {
# 	position: absolute;
# 	left: 220px;
# 	bottom: 20px;
# 	cursor:pointer;
# }
# .pdfview {
# 	font-size: 16px;
# 	color:#FFF;
# 	background-color :#082e59;
# 	padding: 10px 20px;
# }
# @media all and (max-width:1320px) {
# 	.petitions_4th_btn {
# 		left: 160px;
# 	}
# }
# @media all and (max-width:1024px) {
# 	.petitions_4th_btn {
# 		left: 60px;
# 	}
# 	.pdfview {
# 		font-size: 13px;
# 	}
# }
# @media screen and (max-width: 768px){
# 	#contents.c_sub .cs_hero.newsroom {
# 		background-image: url('/storage/images/petitions/4th/petitions_banner.png');
# 	}
# 	.petitions_4th_btn {
# 		left: 30px;
# 	}
# }
# @media (max-width:768px) {
# .board .b_list .bl_subject {margin-right:0px;}
# .board .b_list .bl_category {left:0px;}
# }
# @media screen and (max-width: 414px){
# 	.csp_box2 .txt25 .txt25_a {
# 		font-size:2em;
# 		line-height:1.4em;
# 		color:#252525;
# 		padding-top:40px;
# 	}
# 	.csp_box2 .txt25 .txt25_b {
# 		font-size:2.2em;
# 		line-height:1.4em;
# 		color:#252525;
# 	}
# 	.petition_box_bg {
#
# 	}
# 	#contents.c_sub .cs_hero {
# 		height:250px;
# 	}
# 	.csp_box2 .txt25 .txt25_c {
# 		font-size:1.3em;
# 		line-height:1.3em;
# 		color:#252525;
# 		padding:30px 20px;
# 		font-weight:500;
# 	}
# 	.board .b_list .bl_body .bl_no {
# 		display:none;
# 	}
# 	.ct_list .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
# 	.board .b_list .bl_body .bl_category {
# 		text-align: left;
# 	}
#
# 	.ct_list1 .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
#
# 	select#order {
# 		height:30px;
# 	}
# 	.board .b_list .bl_category {left:0px;}
# }
#
# .mfp-image-holder .mfp-content {
#     max-width: 87%;
# }
# .white-popup-block {
# 	position:relative;
# 	margin:0 auto;
# 	text-align:center;
# 	max-height:70vh;
# }
#
# .mfp-bottom-bar {
# 	margin-top: -39px;
# }
# .mfp-title {
# 	text-align:center;
# 	padding-right:0;
# }
# .mfp-title a {
# 	color:#fff;
# }
#
# .clearfix::after {
# display:block;visibility:hidden;clear:both;content:''
# }
# .event1 {
# 	width:100%;
# 	display:block;
# 	background:#043f77;
# 	color:#FFF;
# 	padding:10px 0;
# }
# .event2 {
# width:100%;
# 	display:block;
# 	background:#353535;
# 	color:#FFF;
# 	padding:10px 0;
# }
# #app_connect {
# 	margin: 10px 10px;
# 	padding: 10px 0;
# 	text-align: left;
# 	background-color: rgba(0, 0, 0, 0.7);
# 	border-radius: 10px;
# 	width: 95%;
# 	z-index: 1;
# 	position: fixed;
# 	bottom: 0;
# }
# #app_connect img {
# 	display: inline-block;
# 	vertical-align:middle;
# 	width: 38px;
# 	height: auto;
# 	padding-left: 20px;
# }
# #app_connect .app_btn {
# 	color: #fff;
# 	padding: 0 15px;
# 	height: auto;
# 	font-size: 14px;
# 	font-weight: 500;
# }
#
#
# @media  screen and (max-width: 600px){
# 	.pr_tk25 iframe{height:auto;}
# 	.ppo11{
# 		right:7%;
# 	}
# 	.ppo11 img{width:100%;}
# }
#
# .ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# .ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# .ppo{
# 	display:none;
# 	position: relative;
# }
# .ppo_area{
# 	overflow:hidden;
# 	background-color:#fff;
# 	padding:1px;
# 	border:5px solid #0b2e4c;
# }
#
# .ppo .popCont{float:left;}
# .ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# .ppo_close_today{
# 	background-color:#222;
# 	color:#fff;
# 	text-align:center;
# 	padding:10px 0;
# }
# .ppo_close_today p{font-size:14px; cursor:pointer;}
# .popopen_top button{
# 	position:absolute;
# 	right:10px;
# 	top:10px;
# 	width:50px;
# 	height:20px;
# 	color:#FFF;
# 	cursor:pointer;
# 	z-index:99;
# }
#
# .kr_pop_close {
#     position: absolute;
#     top: -22px;
#     right: 0px;
#     cursor: pointer;
#     color: #fff;
#     text-align: center;
#     padding: 0px 0px;
#     letter-spacing: 0.1em;
#     text-decoration: none !important;
#     font-size: 14px;
# }
# @media (max-width:768px) {
# 	.board .b_list .bl_subject {margin-right:0px;}
# 	}
#
# 	.ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:550px;
# 		width:100%;
# 		height:auto;
# 	}
# 	.ppo .popCont{
# 		float:left;
# 	}
# 	.ppo .popCont.popCont1{
# 		border-right:7px solid #fff;
# }
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:10px 0;
# 	}
# 	.ppo_close_today p{
# 		font-size:14px; cursor:pointer;
# 	}
# 	.popopen_top{
# 	}
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
#
# @media (max-width:414px) {
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# @media screen and (max-width: 375px){
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# .mfp-image-holder .mfp-content {
#     max-width: 87%;
# }
# .white-popup-block {
# 	position:relative;
# 	margin:0 auto;
# 	text-align:center;
# 	max-height:70vh;
# }
#
# .mfp-bottom-bar {
# 	margin-top: -39px;
# }
# .mfp-title {
# 	text-align:center;
# 	padding-right:0;
# }
# .mfp-title a {
# 	color:#fff;
# }
#
# .clearfix::after {
# display:block;visibility:hidden;clear:both;content:''
# }
# .event1 {
# 	width:100%;
# 	display:block;
# 	background:#043f77;
# 	color:#FFF;
# 	padding:10px 0;
# }
# .event2 {
# width:100%;
# 	display:block;
# 	background:#353535;
# 	color:#FFF;
# 	padding:10px 0;
# }
# #app_connect {
# 	margin: 10px 10px;
# 	padding: 10px 0;
# 	text-align: left;
# 	background-color: rgba(0, 0, 0, 0.7);
# 	border-radius: 10px;
# 	width: 95%;
# 	z-index: 1;
# 	position: fixed;
# 	bottom: 0;
# }
# #app_connect img {
# 	display: inline-block;
# 	vertical-align:middle;
# 	width: 38px;
# 	height: auto;
# 	padding-left: 20px;
# }
# #app_connect .app_btn {
# 	color: #fff;
# 	padding: 0 15px;
# 	height: auto;
# 	font-size: 14px;
# 	font-weight: 500;
# }
# .ppo_close{position:static;padding:10px; background:#0b2e4c;text-align:center; cursor:pointer;color:#FFF;}
# .petitions_counter {
# 	position:absolute;
# 	right:5%;
# 	bottom:50px;
# 	width:260px;
# 	height:276px;
# }
# .petitions_counter_box {
# 	position:relative;
# 	width:260px;
# 	height:276px;
# 	-webkit-background-size: cover;
# 	-moz-background-size: cover;
# 	-o-background-size: cover;
# 	background-size: cover;
# 	background-repeat:no-repeat;
# 	background-image:url(/storage/images/petitions/petitions_counter.png);
# }
# .total_counter {
# 	position: absolute;
#     color: #FFF;
#     font-size: 2.3em;
#     font-weight: 500;
#     letter-spacing: -1px;
#     top: 38%;
#     left: 10%;
# }
# .goal_counter {
# 	position: absolute;
#     color: #FFF;
#     font-size: 2.3em;
#     font-weight: 500;
#     letter-spacing: -1px;
#     bottom: 24%;
#     left: 10%;
# }
# .after_answer {
#     color: #aaa;
#     position: absolute;
#     left: 25px;
#     bottom: 24px;
# }
# .before_answer {
#     color: #aaa;
#     position: absolute;
#     right: 25px;
#     bottom: 24px;
# }
# .petitions_counter_box a {
# 	width: 100%;
#     height: 50px;
#     position: absolute;
#     right: 0;
#     top: 0;
# }
#
# @media screen and (max-width: 480px){
# 	.petitions_counter {
# 		position:absolute;
# 		right:2%;
# 		bottom:2px;
# 		width:160px;
# 		height:176px;
# 	}
# 	.petitions_counter_box {
# 		position:relative;
# 		width:160px;
# 		height:176px;
# 		-webkit-background-size: cover;
# 		-moz-background-size: cover;
# 		-o-background-size: cover;
# 		background-size: cover;
# 		background-repeat:no-repeat;
# 		background-image:url(/storage/images/petitions/petitions_counter.png);
# 	}
# 	.total_counter {
# 		position: absolute;
# 		color: #FFF;
# 		font-size: 1.5em;
# 		font-weight: 500;
# 		letter-spacing: -1px;
# 		top: 35%;
# 		left: 10%;
# 	}
# 	.goal_counter {
# 		position: absolute;
# 		color: #FFF;
# 		font-size: 1.5em;
# 		font-weight: 500;
# 		letter-spacing: -1px;
# 		bottom: 24%;
# 		left: 10%;
# 	}
# 	.after_answer {
# 		color: #aaa;
# 		position: absolute;
# 		left: 8px;
# 		bottom: 12px;
# 		font-size: 0.8em;
# 	}
# 	.before_answer {
# 		color: #aaa;
# 		position: absolute;
# 		right: 5px;
# 		bottom: 12px;
# 		font-size: 0.8em;
# 	}
# 	.before_answer strong {font-size:1.2em !important;}
# 	.after_answer strong {font-size:1.2em !important;}
# 	.petitions_counter_box a {
# 		width: 100%;
# 		height: 30px;
# 		position: absolute;
# 		right: 0;
# 		top: 0;
# 	}
# }
# @media screen and (max-width: 768px){
# 	.title.t1 {
# 		font-size: 30px !important;
# 	}
# }
#
#
# .mfp-arrow-right {
# 	right: 25% !important;
# }
# .mfp-arrow-left {
# 	left: 25% !important;
# }
# .mfp-arrow:after {
#     transform: scale(1.5);
# }
# .mfp-close {
# 	font-family:'Noto Sans KR';
# 	font-size: 18px;
# 	padding-bottom: 15px;
# }
# .mfp-zoom-out-cur, .mfp-zoom-out-cur .mfp-image-holder .mfp-close {
#     cursor: unset !important;
# }
# .download-btn {
#     color: #1C243E;
#     font-weight: 600;
#     position: absolute;
#     right: -25%;
#     bottom: 40px;
#     padding: 20px;
#     background-color: #FFF;
#     border-radius: 5px;
# 	border: 2px solid #1C243E;
# }
# @media (max-width: 1500px) {
# 	.mfp-arrow-right {
# 		right: 18% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 18% !important;
# 	}
# }
# @media (max-width: 1200px) {
# 	.mfp-arrow-right {
# 		right: 10% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 10% !important;
# 	}
# }
# @media (max-width: 1024px) {
# 	.mfp-image-holder .mfp-content {
# 		width: 75%;
# 	}
# 	.mfp-arrow-right {
# 		right: 3% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 3% !important;
# 	}
# 	.mfp-close {
# 		font-size: 16px;
# 	}
# 	.download-btn {
# 		right: unset;
# 		left: 50%;
# 		bottom: -30px;
# 		padding: 20px;
# 		transform: translateX(-50%);
# 	}
# }
# @media (max-width: 767px) {
# 	.mfp-arrow-right {
# 		right: -2% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: -2% !important;
# 	}
# }
# </style><script src="/js/html5.js"></script>
# <script src="/js/jquery-1.11.0.min.js"></script>
# <script src="/js/navigation.js"></script>
# <script src="/js/jquery.validate.min.js"></script>
# <script src="/js/jquery.mCustomScrollbar.js"></script>
# <script src="/js/jquery.flexslider-min.js"></script>
# <script src="/js/jquery.appear.js"></script>
# <script src="/js/moment.min.js"></script>
# <title>추천순 청원 목록 1페이지 &gt;  대한민국 청와대</title>
# </link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body><div id="accessibility">
# <strong class="blind">컨텐츠바로가기</strong>
# <ul>
# <li><a href="#cont_view" onclick="scrolltop('cont_view');"><strong>본문으로 바로가기</strong></a></li>
# <li><a href="#sitemap"><strong>하단 사이트 전체메뉴 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="wrap">
# <style>
# #header .h_gnb.on .depth1 {display:table !important;}
# </style>
# <div class="head_navi">
# <h1>
# <a href="http://www.president.go.kr/" style="display:block; text-align:center; padding:55px 0 20px 0;" title="메인페이지로 이동"><img alt="대한민국 청와대" src="/images/main/logo.png"/></a>
# </h1>
# <div class="navigator_menu">
# <ul class="menu" id="webNavi">
# <li class="ml0">
# <a href="http://www.president.go.kr/" style="position:absolute; display:block; text-align:center;" title="메인페이지로 이동">
# <img alt="대한민국 청와대" src="/images/main/logo.png"/>
# </a>
# </li>
# <li class="menu_list">
# <a href="/calendar">문재인 대통령</a>
# <ul class="menu_sub">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/c/briefings">청와대 뉴스룸</a>
# <ul class="menu_sub">
# <li><a href="/KNewDeal">한국판 뉴딜 <span style="color:#00dcff;">스페셜</span></a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/government-projects">정책정보</a>
# <ul class="menu_sub">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/petitions" title="국민소통 광장 새창열림">국민소통 광장</a>
# <ul class="menu_sub">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/about/roi">청와대 알림판</a>
# <ul class="menu_sub">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# </ul>
# </li>
# <li class="menu_list mr0">
# <a href="https://tour.president.go.kr">청와대 관람 신청</a>
# </li>
# <p class="main_search_icon">
# <a class="search_icon" href="https://www1.president.go.kr/search" style="display:block"><span class="sound_only">검색창 열기</span></a>
# </p>
# <div class="en_btn">
# <a href="http://english.president.go.kr" target="_blank" title="영문페이지로 새창열림">
# <span><img alt="영문페이지로 이동" src="/images/main/language_icon.gif"/> English</span>
# </a>
# </div>
# </ul>
# <div class="overlay overlay-slidedown">
# <button class="overlay-close" type="button">닫기</button>
# <div class="full_search">
# <form action="/search" method="post">
# <fieldset>
# <ul class="full_search_btn">
# <li class="search_box">
# <label class="hide" for="loginid">검색창</label>
# <input id="loginid" name="query" placeholder="검색어를 입력해주세요." title="검색어입력" type="text" value=""/>
# </li>
# <li class="search_btn">
# <input type="submit" value="검색"/>
# </li>
# </ul>
# </fieldset>
# </form>
# </div>
# </div>
# <script src="/js/modernizr.custom.js"></script>
# <script src="/js/classie.js"></script>
# </div>
# </div>
# <header class="" id="header">
# <div class="navigator_menu" style="display:none"></div>
# <div class="h_logo">
# <a href="/" title="메인페이지로 이동">
# <h1 class="blind">대한민국 청와대</h1>
# </a>
# </div>
# <hr/>
# <div class="h_search">
# <h2 class="blind">통합검색</h2>
# <div class="hs_btn">
# <button id="search_btn" type="button">
# <i><span class="sound_only">통합검색</span></i>
# <span class="blind">Search Btn</span>
# </button>
# </div>
# <div class="hs_wrap">
# <script>
# 				$(document).ready(function () {
# 					$('#form-search').submit(function () {
# 						var keyword = $(this).find('input[name="query"]').val();
# 						var regex = /^([a-zA-Z0-9가-힣 ]){2,}$/i;
# 						if (!regex.test(keyword)) {
# 							alert('검색어는 한글, 영문 숫자를 2글자 이상으로 입력해주세요.');
# 							return false;
# 						}
# 						return true;
# 					});
# 				});
# 			</script>
# <form action="/search" id="form-search">
# <fieldset>
# <legend>통합검색폼</legend>
# <div class="hs_group">
# <div class="hs_input">
# <label class="blind" for="hs_keyword">검색어</label>
# <input id="hs_keyword" name="query" placeholder="검색어를 입력해주세요." required="" type="text"/>
# </div>
# <button class="hs_ok" type="submit">검색</button>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <hr/>
# <div class="h_gnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="hg_btn">
# <h3>메뉴</h3>
# <button id="mainmenu_btn" type="button">
# <i><span class="sound_only">메인메뉴</span></i>
# <span class="blind">메뉴 버튼</span>
# </button>
# </div>
# <nav class="hg_wrap">
# <ul class="depth1">
# <li class="hg_president">
# <button type="button"><h3>문재인 대통령 <i><span class="sound_only">문재인 대통령</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/calendar">공개일정</a>
# </li>
# <li>
# <a href="/president-journey">걸어온길</a>
# </li>
# <li>
# <a href="/c/president-speeches">대통령의 말과 글</a>
# </li>
# <li>
# <a href="/c/first-lady-quotations">김정숙 여사 소식</a>
# </li>
# </ul>
# </li>
# <li class="hg_newsroom">
# <button type="button"><h3>청와대 뉴스룸 <i><span class="sound_only">청와대 뉴스룸</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/KNewDeal">한국판 뉴딜 <span style="color:#00dcff;">스페셜</span></a>
# </li>
# <li>
# <a href="/c/briefings">청와대가 전합니다</a>
# </li>
# <li>
# <a href="/c/blue-house-stories">청와대 이야기</a>
# </li>
# <li>
# <a href="/live-speeches">영상</a>
# </li>
# <li>
# <a href="/TodayShot">카드뉴스</a>
# </li>
# <li>
# <a href="/c/oversea-journals">세계의 시선</a>
# </li>
# <li>
# <a href="/history">청와대 일기</a>
# </li>
# </ul>
# </li>
# <li class="hg_policy">
# <button type="button"><h3>정책정보 <i><span class="sound_only">정책정보</span></i></h3></button>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="hg_community">
# <button type="button"><h3>국민소통 광장 <i><span class="sound_only">국민소통 광장</span></i></h3></button>
# <ul class="depth2">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="hg_cheongwadae">
# <button type="button"><h3>청와대 알림판 <i><span class="sound_only">청와대 알림판</span></i></h3></button>
# <ul class="depth2 hei325">
# <li>
# <a href="/about/roi">정보공개</a>
# </li>
# <li>
# <a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a>
# </li>
# <li>
# <a href="/about/organization">청와대 조직도</a>
# </li>
# <li>
# <a href="/budgets">세입·세출예산 운용상황</a>
# </li>
# <li>
# <a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a>
# </li>
# <li>
# <a href="/about/location?where=desk">오시는 길</a>
# </li>
# </ul>
# </li>
# <li><button onclick="location.href='https://tour.president.go.kr';" type="button"><h3>청와대 관람 신청<i style="background-position-x:0;background-position-y:50%"><span class="sound_only">청와대 관람 신청</span></i></h3></button></li>
# <li><button onclick="location.href='http://english.president.go.kr';" type="button"><h3>English<i aria-hidden="true" class="fa fa-globe" style="background:none; font-size:38px"><span class="sound_only">English</span></i></h3></button></li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="c_sub" id="contents">
# <!-- //contents START -->
# <section class="cs_hero newsroom">
# <div class="sound_only">국민청원</div>
# <div class="csh_txt">
# <div class="bl_title motion" data-animation="fadeInDown">
# <img alt="국민청원 4년, 국민이 세상을 바꿔 온 국민청원입니다" src="/storage/images/petitions4th/pc_txt.png?v=2" style="max-width: 100%;"/>
# </div>
# <!--
# 			<h2 class="title t1 bold cw motion" data-animation="fadeInDown">국민청원</h2>
# 			<p class="text bold big cw motion" data-animation="fadeInDown"></p>
# 			-->
# </div>
# <div class="petitions_4th_btn" style="">
# <h4 class="pdfview">
# <a href="/petitions/4th" style="color:#FFF">[스페셜 홈] 국민청원 4년, 보고드립니다 <i class="xi-mouse-pointer"></i></a>
# </h4>
# </div>
# </section>
# <section class="cs_wrap" id="cont_view">
# <div class="cs_tab">
# <div class="tab div3">
# <ul>
# <li class="motion" data-animation="fadeInLeft"><a href="/petitions">분야별 청원</a></li>
# <li class="motion" data-animation="fadeInLeft"><a class="on" href="/petitions/best" title="현재">추천순 청원</a></li>
# <li class="motion" data-animation="fadeInLeft"><a href="/petitions/answer">답변된 청원</a></li>
# </ul>
# </div>
# </div>
# <div class="cs_area">
# <div class="cs_body">
# <div class="wrap">
# <div class="ct_petitions ct_petitions_graph">
# <div class="ct_petitions">
# <div class="b_title">
# <h4 class="motion" data-animation="fadeInDown"><span class="name_point"></span>청원 작성하기</h4>
# </div>
# <div class="ct_petitions_area ct_txt1 ct_txt_left boder_sol">
# <p>청와대의 직접 소통은  국민이 물으면 정부가 답한다 는 철학을 지향합니다.</p>
# <p>국정 현안 관련, 국민들 다수의 목소리가 모여 30일 동안 20만 이상 추천 청원에 대해서는</p>
# <p><span class="ct_txt_color1">정부 및 청와대 관계자(각 부처 장관, 대통령 수석·비서관, 특별보좌관 등)</span>가 답하겠습니다.</p>
# <div class="ct_btn_area"><a class="ct_btn" href="/petitions/Step1">지금 청원하기</a></div>
# </div>
# </div><!-- ct_petitions end -->
# </div>
# <div class="csp_box txt_area25_1 add_1030_area">
# <!-- 답변대기중 -->
# <!-- // 답변대기중 -->
# </div>
# <!-- csp_box txt_area25_1 add_1030_area END -->
# <!-- 청원목록 시작 -->
# <div class="board text">
# <div class="b_title">
# <h4 class="title t3 bold cb motion" data-animation="fadeInDown">청원 목록</h4>
# <a class="fr btn t3" href="/petitions/Step1">지금 청원하기</a>
# </div>
# <div class="b_list category">
# <div aria-hidden="true" class="bl_head cb">
# <div class="bl_wrap">
# <div class="bl_category">분류</div>
# <div class="bl_subject">제목</div>
# <div class="bl_date">청원 만료일</div>
# <div class="bl_agree">참여인원</div>
# </div>
# </div>
# <div class="bl_body">
# <ul>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604660?navigation=best"><span class="sound_only">제목 </span>윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조…</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-10</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>542,911명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 외교/통일/국방</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604773?navigation=best"><span class="sound_only">제목 </span>윤석열 당선인 집무실 만들고자, 국가안전 중추인 국방부를 강압 이전하여, 국민의 혈세 수천…</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-16</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>529,551명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604735?navigation=best"><span class="sound_only">제목 </span>이명박 전 대통령 사면을 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-14</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>346,412명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 기타</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604627?navigation=best"><span class="sound_only">제목 </span>문재인 대통령님 사랑합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-09</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>286,991명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604640?navigation=best"><span class="sound_only">제목 </span>대구 동구 부정선거 및 선거관리위원회의 관리 부실로 대선 재투표를 희망합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-09</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>264,696명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 보건복지</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604699?navigation=best"><span class="sound_only">제목 </span>의료 민영화의 첫 걸음이 될 제주 영리병원을 국가가 매수해주십시오.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-13</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>211,755명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604792?navigation=best"><span class="sound_only">제목 </span>제 20대 대통령의 집무실 이전에 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-16</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>196,154명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 인권/성평등</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604677?navigation=best"><span class="sound_only">제목 </span>성범죄 피해자입니다. 여가부 폐지 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-13</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>178,821명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604818?navigation=best"><span class="sound_only">제목 </span>당선인의 대통령집무실과 공관이전을 찬성합니다. 공약이행을 반드시 해주시길 청원드립니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-17</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>175,010명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 반려동물</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604899?navigation=best"><span class="sound_only">제목 </span>폐양식장에서 취미로 고양이 해부를 즐기던 *** 학대범을 ***을 강력히 처벌해주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-21</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>133,614명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 외교/통일/국방</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604824?navigation=best"><span class="sound_only">제목 </span>국가보안법 목적수행죄 위반 윤석열 당선자를 처벌해주세요</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-20</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>128,405명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/605029?navigation=best"><span class="sound_only">제목 </span>윤석열 총장 당시 검찰 특활비 147억  공개 청원합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-30</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>127,457명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 행정</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604740?navigation=best"><span class="sound_only">제목 </span>무궁화대훈장 셀프수여 반대</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-15</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>78,882명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604763?navigation=best"><span class="sound_only">제목 </span>퇴임하기전에 검찰 수사권 기소권 분리를 끝내주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-15</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>77,197명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 인권/성평등</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604819?navigation=best"><span class="sound_only">제목 </span>제발 지하철 9호선 폭행녀를 꼭 강력 처벌을 하여 일벌백계하여 주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-17</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>73,587명
# 												</div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div style="margin-top:30px;">
# <form action="/search" class="form-control" method="POST">
# <input class="" name="searchTarget" type="hidden" value="petitions"/>
# <label class="hide" for="LIST_search">리스트 검색</label>
# <input id="LIST_search" name="query" type="text" value=""/>
# <button id="" type="submit">검색</button>
# </form>
# </div>
# <div class="paging">
# <div class="p_wrap">
# <div class="p_btn"> <a class="on" href="javascript:void(0);" title="현재 페이지"><strong>1</strong></a> <a href="?page=2">2</a> <a href="?page=3">3</a> <a href="?page=4">4</a> <a href="?page=5">5</a> <a href="?page=6">6</a> <a href="?page=7">7</a> <a href="?page=8">8</a> <a href="?page=9">9</a> <a href="?page=10">10</a> </div> <div class="p_btn next"><a href="?page=11">Next</a></div> </div>
# </div>
# </div>
# <!-- 청원목록 종료 -->
# </div>
# </div>
# </div>
# </section>
# </div>
# <!-- //contents END -->
# <script>
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
#     today.setDate(today.getDate() + expiredays);
#     document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name) {
#     var cName = name + "=";
#     var x = 0;
# 	var i = 0;
#     while ( i <= document.cookie.length ) {
#         var y = (x+cName.length);
#         if ( document.cookie.substring( x, y ) == cName ) {
#             if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
#                 endOfCookie = document.cookie.length;
#             return unescape( document.cookie.substring( y, endOfCookie ) );
#         }
#         x = document.cookie.indexOf( " ", x ) + 1;
#         if ( x == 0 )
#             break;
#     }
#     return "";
# }
# </script>
# <script>
# function closePopupNotToday(){
# 	setCookie('notToday','Y', 1);
# 	$(".ppo").hide('fade');
# }
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
#     today.setDate(today.getDate() + expiredays);
#     document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name) {
#     var cName = name + "=";
#     var x = 0;
# 	var i = 0;
#     while ( i <= document.cookie.length ) {
#         var y = (x+cName.length);
#         if ( document.cookie.substring( x, y ) == cName ) {
#             if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
#                 endOfCookie = document.cookie.length;
#             return unescape( document.cookie.substring( y, endOfCookie ) );
#         }
#         x = document.cookie.indexOf( " ", x ) + 1;
#         if ( x == 0 )
#             break;
#     }
#     return "";
# }
#
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
#
# 	$(".ppo_close").click(function(){
# 		closePopup();
# 	});
# 	$(".ppo_close_today").click(function(){
# 		closePopupNotToday();
# 	});
# 	if (getCookie("notToday") != "Y"){
# 		$('.ppo').show('fade');
# 	} else {
# 		$('.ppo').hide('fade');
# 	}
#
#
#
# </script>
# <hr/>
# <!-- <div id="app_connect">
# 		<img src="/images/main/app_icon.png"><button class="app_btn">청와대 앱으로 보기<span class="blind">버튼</span></button>
# 	</div> -->
# <div id="sitemap">
# <button class="s_btn">사이트맵 <span class="blind">버튼</span></button>
# <div class="wrap">
# <ul class="depth1">
# <li>
# <h3>문재인 대통령
#                         <a class="blind" href="/calendar">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 뉴스룸</h3>
# <ul class="depth2">
# <li><a href="/KNewDeal">한국판 뉴딜 스페셜</a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li>
# <h3>정책정보
#                         <a class="blind" href="/government-projects">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li>
# <h3>국민소통 광장
#                         <a class="blind" href="/petitions">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification">열린참여</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 알림판
#                         <a class="blind" href="/about/roi">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# <li><a href="https://tour.president.go.kr" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">청와대 관람신청</a></li>
# <li><a href="http://children.president.go.kr" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">어린이 홈페이지</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <footer id="footer">
# <div class="wrap">
# <div class="f_group">
# <div class="f_logo">
# <h2 class="blind">대한민국 청와대</h2>
# </div>
# <div class="f_sns">
# <h2 class="blind">SNS 바로가기</h2>
# <ul>
# <li>
# <a href="https://www.facebook.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="페이스북 새창열림">
# <i class="fs_icon facebook"><span class="sound_only">페이스북 바로가기 </span></i><span class="blind">Facebook</span>
# </a>
# </li>
# <li>
# <a href="https://blog.naver.com/thebluehousekr" rel="noopener noreferrer" target="_blank" title="블로그 새창열림"><i class="fs_icon blog"><span class="sound_only">블로그 바로가기 </span></i><span class="blind">blog</span></a>
# </li>
# <li>
# <a href="https://twitter.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="트위터 새창열림">
# <i class="fs_icon twitter"><span class="sound_only">트위터 바로가기 </span></i><span class="blind">Twitter</span>
# </a>
# </li>
# <li>
# <a href="https://www.instagram.com/thebluehouse_kr/" rel="noopener noreferrer" target="_blank" title="인스타그램 새창열림">
# <i class="fs_icon instagram"><span class="sound_only">인스타그램 바로가기 </span></i><span class="blind">Instagram</span>
# </a>
# </li>
# <li>
# <a href="https://www.youtube.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="유튜브 새창열림">
# <i class="fs_icon youtube"><span class="sound_only">유튜브 바로가기 </span></i><span class="blind">Youtube</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="f_wrap">
# <div class="f_info">
# <h2>CONTACT INFO</h2>
# <ul>
# <li>
# <i class="fi_icon call"><span class="sound_only">전화번호 </span></i>
# <p><a href="tel:02-730-5800">(+82) 02-730-5800</a></p>
# </li>
# <li>
# <i class="fi_icon email"><span class="sound_only">메일주소 </span></i>
# <p>담당자 메일 : <a href="mailto:webmaster@president.go.kr">메일보내기</a></p>
# </li>
# <li>
# <i class="fi_icon address"><span class="sound_only">청와대 주소</span></i>
# <p>03048 서울특별시 종로구 청와대로 1 대통령 비서실</p>
# </li>
# </ul>
# </div>
# <div class="f_menu">
# <div class="fm_wrap">
# <ul>
# <li><a href="/about/privacy">개인정보처리방침</a></li>
# <li><a href="/about/copyright">저작권 정책</a></li>
# <li><a href="/sitemap">사이트맵</a></li>
# <li><a href="/about/location">오시는 길</a></li>
# </ul>
# <ul>
# </ul>
# </div>
# <div class="fm_tip" style="line-height:20px; margin-bottom:6px;">
# 						해당 메일은 기능 장애 등 홈페이지 관련 문의만 접수합니다.<br/>
# 						청와대 및 정부에 대한 민원·제안 및 공익신고·고발 등은
# 						국민신문고(<a href="http://www.epeople.go.kr/" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">www.epeople.go.kr</a>)로
# 						접수해주시길 부탁드립니다.
# 					</div>
# <ul class="footer_mark" style="margin-top:15px;">
# <li><img alt="wa품질인증마크" src="/images/main/wa_mark.png"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="f_copyright">
# 			© Office of the President. All rights reserved.
# 		</div>
# </footer>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-112394055-1"></script>
# <script src="/js/common.js?v=1" type="text/javascript"></script>
# <script src="/js/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script>
#   $(document).ready(function () {
#
#
#
# var webNavi = $('#webNavi').superfish({});
#   });
#
#
#
# $('.txt2019_4').click( function() {
# 	$(this).nextAll('.txt2019_7').toggle();
# });
# $('.txt2019_9').click( function() {
# 	$(this).nextAll('.txt2019_10').toggle();
# });
# function youtubopen(data) {
# 	$.magnificPopup.open({
# 		items: {
# 			src:'https://www.youtube.com/watch?v='+data
# 		},
# 		type: 'iframe',
# 		mainClass: 'mfp-fade',
# 		removalDelay: 160,
# 		preloader: false,
# 		fixedContentPos: false,
# 		closeMarkup: '<button type="button" class="mfp-close tBtn">닫기</button><div class="mfp-close cBtn" aria-hidden="true"><i class="xi-close"></i></div>',
# 		autoFocusLast: true,
# 		iframe: {
# 		  markup: '<div class="mfp-iframe-scaler">'+
# 					'<div class="mfp-close"></div>'+
# 					'<iframe class="mfp-iframe" frameborder="0" title="유투브 동영상 재생" allowfullscreen></iframe>'+
# 				  '</div>',
# 		  patterns: {
# 			youtube: {
# 			  index: 'youtube.com/',
# 			  id: 'v=',
# 			  src: '//www.youtube.com/embed/%id%?autoplay=0'
# 			}
#
# 		  },
#
# 		  srcAction: 'iframe_src',
# 		}
# 	});
# }
#
# function modalpop2() {
# 	$.magnificPopup.open({
# 		items: [
# 			{src:'/storage/images/petitions4th/image0.jpeg'},
# 			{src:'/storage/images/petitions4th/image1.jpeg'},
# 			{src:'/storage/images/petitions4th/image2.jpeg'},
# 			{src:'/storage/images/petitions4th/image3.jpeg'},
# 			{src:'/storage/images/petitions4th/image4.jpeg'},
# 			{src:'/storage/images/petitions4th/image5.jpeg'},
# 			{src:'/storage/images/petitions4th/image6.jpeg'},
# 			{src:'/storage/images/petitions4th/image7.jpeg'},
# 			{src:'/storage/images/petitions4th/image8.jpeg'},
# 			{src:'/storage/images/petitions4th/image9.jpeg'},
# 			{src:'/storage/images/petitions4th/image10.jpeg'},
# 			{src:'/storage/images/petitions4th/image11.jpeg'},
# 			{src:'/storage/images/petitions4th/image12.jpeg'},
# 			{src:'/storage/images/petitions4th/image13.jpeg'},
# 			{src:'/storage/images/petitions4th/image14.jpeg'},
# 			{src:'/storage/images/petitions4th/image15.jpeg'},
# 			{src:'/storage/images/petitions4th/image16.jpeg'},
# 			{src:'/storage/images/petitions4th/image17.jpeg'},
# 			{src:'/storage/images/petitions4th/image18.jpeg'},
# 			{src:'/storage/images/petitions4th/image19.jpeg'},
# 			{src:'/storage/images/petitions4th/image20.jpeg'},
# 			{src:'/storage/images/petitions4th/image21.jpeg'},
# 			{src:'/storage/images/petitions4th/image22.jpeg'},
# 			{src:'/storage/images/petitions4th/image23.jpeg'},
# 			{src:'/storage/images/petitions4th/image24.jpeg'},
# 			{src:'/storage/images/petitions4th/image25.jpeg'},
# 			{src:'/storage/images/petitions4th/image26.jpeg'},
# 			{src:'/storage/images/petitions4th/image27.jpeg'},
# 			{src:'/storage/images/petitions4th/image29.jpeg'},
# 			{src:'/storage/images/petitions4th/image30.jpeg'},
# 			{src:'/storage/images/petitions4th/image31.jpeg'}
# 		],
# 		type: 'image',
# 		tLoading: 'Loading image #%curr%...',
# 		mainClass: 'mfp-img-mobile',
# 		gallery: {
# 			enabled: true,
# 			navigateByImgClick: true,
# 			preload: [0,1], // Will preload 0 - before current, and 1 after the current image
# 		},
# 		image: {
# 			tError: '<a href="%url%">The image #%curr%</a> could not be loaded.',
# 		},
# 		closeMarkup: '<button title="%title%" class="mfp-close" style="position: absolute; top: 0; right: -15px">닫기 <i class="xi-close"></i></button>',
# 		callbacks: {
# 			buildControls: function(){
# 				//this.content.find('figure').append('<a class="download-btn" href="/dn/611c6096c3acc">PDF 다운로드</a>');
# 			},
# 		},
# 	});
# }
#
# $(document).on('click','.mfp-img', function (e) {e.preventDefault();$.magnificPopup.close();youtubopen('46E4TFNVvJM');});
# $(document).on('click','.event2', function (e) {e.preventDefault();setCookie('notToday191111','Y', 1);$.magnificPopup.close();});
# 	function noticeopen() {
# 		$.magnificPopup.open({
# 			items: {
# 				src:'/storage/images/2019/11/ii_k2zv5l920.png',
# 				markup:'<div class="mfp-figure">'+
# 					'<div class="mfp-close"></div>'+
# 					'<div class="mfp-img"><img src="/storage/images/2019/11/ii_k2zv5l920.png"></div>'+
# 					'<div class="mfp-bottom-bar"><div class="mfp-title" style="background:#000;"></div></div></div>',
# 				title:'<table width="100%"><tr><td><a href="javascript:void(0);" class="event2">오늘 하루 열지 않음</a></td></tr></table>'
# 			},
# 			disableOn: 700,
# 			type: 'image',
# 			mainClass: 'mfp-fade',
# 			preloader: true,
# 			fixedContentPos: true,
# 			verticalFit:true
# 		});
# 	}
#
# 	if(getCookie('notToday191111') != 'Y'){
# 		//noticeopen();
# 	}
#
#
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());gtag('config', 'UA-112394055-1');
#
# 	function scrolltop(oj){
# 		var scrollPosition = $('#'+oj).offset().top;
# 		var navPosition = $('.navigator_menu').offset().top;
#
# 		$('html, body').stop().animate({scrollTop : scrollPosition-(navPosition+30)}, 300);
# 		$('#'+oj);
# 	}
# </script>
# </body>
# </html>

# %%
# 전체 경로
path = 'div.cs_area > div > div > div.board.text > div.b_list.category > div.bl_body '
tags = soup.select(path)
tags[0]
# Out:
# <div class="bl_body">
# <ul>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604660?navigation=best"><span class="sound_only">제목 </span>윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조…</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-10</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>542,911명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 외교/통일/국방</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604773?navigation=best"><span class="sound_only">제목 </span>윤석열 당선인 집무실 만들고자, 국가안전 중추인 국방부를 강압 이전하여, 국민의 혈세 수천…</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-16</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>529,551명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604735?navigation=best"><span class="sound_only">제목 </span>이명박 전 대통령 사면을 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-14</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>346,412명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 기타</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604627?navigation=best"><span class="sound_only">제목 </span>문재인 대통령님 사랑합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-09</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>286,991명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604640?navigation=best"><span class="sound_only">제목 </span>대구 동구 부정선거 및 선거관리위원회의 관리 부실로 대선 재투표를 희망합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-09</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>264,696명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 보건복지</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604699?navigation=best"><span class="sound_only">제목 </span>의료 민영화의 첫 걸음이 될 제주 영리병원을 국가가 매수해주십시오.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-13</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>211,755명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604792?navigation=best"><span class="sound_only">제목 </span>제 20대 대통령의 집무실 이전에 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-16</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>196,154명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 인권/성평등</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604677?navigation=best"><span class="sound_only">제목 </span>성범죄 피해자입니다. 여가부 폐지 반대합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-13</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>178,821명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604818?navigation=best"><span class="sound_only">제목 </span>당선인의 대통령집무실과 공관이전을 찬성합니다. 공약이행을 반드시 해주시길 청원드립니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-17</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>175,010명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 반려동물</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604899?navigation=best"><span class="sound_only">제목 </span>폐양식장에서 취미로 고양이 해부를 즐기던 *** 학대범을 ***을 강력히 처벌해주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-21</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>133,614명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 외교/통일/국방</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604824?navigation=best"><span class="sound_only">제목 </span>국가보안법 목적수행죄 위반 윤석열 당선자를 처벌해주세요</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-20</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>128,405명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/605029?navigation=best"><span class="sound_only">제목 </span>윤석열 총장 당시 검찰 특활비 147억  공개 청원합니다.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-30</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>127,457명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 행정</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604740?navigation=best"><span class="sound_only">제목 </span>무궁화대훈장 셀프수여 반대</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-15</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>78,882명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 정치개혁</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604763?navigation=best"><span class="sound_only">제목 </span>퇴임하기전에 검찰 수사권 기소권 분리를 끝내주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-15</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>77,197명
# 												</div>
# </div>
# </li>
# <li>
# <div class="bl_wrap">
# <div class="bl_category cs"><span class="sound_only">분류 </span> 인권/성평등</div>
# <div class="bl_subject">
# <a class="cb" href="/petitions/604819?navigation=best"><span class="sound_only">제목 </span>제발 지하철 9호선 폭행녀를 꼭 강력 처벌을 하여 일벌백계하여 주세요.</a>
# </div>
# <span class="sound_only">청원만료 </span><div class="bl_date light">22-04-17</div>
# <div class="bl_agree cb wv_agree">
# <span class="sound_only">참여인원 </span>73,587명
# 												</div>
# </div>
# </li>
# </ul>
# </div>

# %%
# 분류 

cate = tags[0].select('ul > li > div > div.bl_category.cs')[0].text.split(' ')[2]
cate
# Out:
# '정치개혁'

# %%
# 제목
title = tags[0].select('ul > li > div > div.bl_subject > a')[0].text
title
# Out:
# '제목 윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조…'

# %%
# 만료일

end_date = tags[0].select('ul > li > div > div.bl_date.light')[0].text
end_date
# Out:
# '22-04-10'

# %%
# 참여인원
import re
num = tags[0].select('ul > li > div > div.bl_agree.cb.wv_agree')[0].text.split(' ')[1]
num_p = re.sub('[^명1-9,]','',num)
num_p
# Out:
# '542,911명'

# %%
# main url
main_url = 'https://www1.president.go.kr'

# %%
# url_sub
url_sub = tags[0].select('ul > li > div > div.bl_subject > a')[0]['href']
print(url_sub)

#total url
total_url = main_url + url_sub
total_url

# https://www1.president.go.kr /petitions/604660?navigation=best
# Out:
# /petitions/604660?navigation=best
# 'https://www1.president.go.kr/petitions/604660?navigation=best'

# %%
# 세부내용 

res1 = requests.get(total_url)
soup1 = BeautifulSoup(res1.text, 'html.parser')
soup1
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="#082e59" name="theme-color"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="description">
# <meta content="청와대, 대통령비서실, 대통령, 한국, 대한민국, 대한민국 정부, president.go.kr, 靑瓦臺, 19대, 문재인" name="keywords">
# <meta content="청와대 (CHEONGWADAE)" name="author">
# <meta content="telephone=no" name="format-detection">
# <meta content="website" property="og:type"/>
# <meta content="윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다. &gt; 대한민국 청와대" property="og:title"/>
# <meta content="https://www1.president.go.kr/petitions/604660" property="og:url"/>
# <meta content="대한민국 청와대" property="og:site_name"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." property="og:description"/>
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" property="og:image"/>
# <meta content="https://www1.president.go.kr/petitions/604660" name="twitter:url"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="twitter:description">
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" name="twitter:image"/>
# <meta content="noarchive" name="robots"/>
# <meta content="A4YCQihzy88Col-c_8IsuKMjtJS0XM4kKQe2yq35_NI" name="google-site-verification">
# <link href="/css/favicon.ico" rel="shortcut icon"/>
# <link href="/css/favicon.png" rel="icon"/>
# <link href="/css/favicon.png" rel="apple-touch-icon"/>
# <link href="/css/sub.css?v=3" rel="stylesheet"/>
# <link href="/css/init.css?v=3" rel="stylesheet"/>
# <link href="/css/common.css" rel="stylesheet"/>
# <link href="/css/layout.css?v=20170901" rel="stylesheet"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet"/>
# <link href="/css/animate.min.css" rel="stylesheet"/>
# <link href="/css/board.css?v=20180730" rel="stylesheet"/>
# <link href="/css/header.css?ver=20171215" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/css/sub_petitions.css?v=1" rel="stylesheet" type="text/css">
# <link href="/css/magnific-popup.css" rel="stylesheet" type="text/css">
# <link href="/css/jquery.mb.YTPlayer.min.css" rel="stylesheet" type="text/css">
# <link href="/css/xeicon.min.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# .title.t1{width:100%;}
# .csh_txt .bg_pop{
# 	line-height:normal;
# 	margin-top:10px;
# 	font-size:18px;
# 	background-color:rgba(0, 0, 0, 0.6);
# 	border-radius:5px;
# 	display: inline-block;
# }
# .csh_txt .bg_pop_area{
# 	padding:10px 20px;
# 	font-weight:300;
# }
# .csh_txt .bg_pop_area p{line-height:32px;}
#
#
# #contents.c_sub .cs_hero.newsroom {
# 	background-image: url('/storage/images/petitions/4th/petitions_banner.png');
# }
# #contents.c_sub .cs_hero .csh_txt {
#     bottom: 70px;
# }
# .petitions_4th_btn {
# 	position: absolute;
# 	left: 220px;
# 	bottom: 20px;
# 	cursor:pointer;
# }
# .pdfview {
# 	font-size: 16px;
# 	color:#FFF;
# 	background-color :#082e59;
# 	padding: 10px 20px;
# }
# @media all and (max-width:1320px) {
# 	.petitions_4th_btn {
# 		left: 160px;
# 	}
# }
# @media all and (max-width:1024px) {
# 	.petitions_4th_btn {
# 		left: 60px;
# 	}
# 	.pdfview {
# 		font-size: 13px;
# 	}
# }
# @media screen and (max-width: 768px){
# 	#contents.c_sub .cs_hero.newsroom {
# 		background-image: url('/storage/images/petitions/4th/petitions_banner.png');
# 	}
# 	.petitions_4th_btn {
# 		left: 30px;
# 	}
# }
#
# @media  screen and (max-width:800px){
# 	.csh_txt .bg_pop{font-size:15px;}
# 	.csh_txt .bg_pop_area p{line-height:25px;}
# 	.csh_txt .bg_pop_area p span{display: block;}
# }
#
#
# @media  screen and (max-width:414px){
# 	.csh_txt .bg_pop{font-size:13px;}
# 	.csh_txt .bg_pop_area{padding:10px}
# 	.csh_txt .bg_pop_area p{line-height:22px;}
# 	.csh_txt .bg_pop_area p span{display: inline;}
# }
#
# .Reply_area_sns .social_page{
# 	margin:0px !important;
# 	border-bottom:0 !important;
# }
#
#
# @media  screen and (max-width: 800px){
#
# }
#
# @media  screen and (max-width: 768px){
# 	.tab.div4 li{width:25%;}
# 	#contents.c_sub  .cs_petition .csp_view .social_page{margin-bottom:0;}
# }
#
# @media  screen and (max-width: 600px){
# 	.pr_tk25 iframe{height:auto;}
# 	.ppo11{
# 		right:7%;
# 	}
# 	.ppo11 img{width:100%;}
# }
#
# @media  screen and (max-width: 414px){
# 	.pr_tk25 iframe{height:230px;}
# }
#
#
#
# .white-popup-block {
# 	max-width:720px;
# 	margin:20px auto;
#
# }
#
# .btn-r .mfp-close{
# 	color: #092e5b ! important;
# 	opacity:0.8
# }
# .background-video {
#   background-position: top center;
#   background-repeat: no-repeat;
#   bottom: 0;
#   left: 0;
#   overflow: hidden;
#   position: fixed;
#   right: 0;
#   top: 0;
# }
#
# video,
# source {
#   bottom: 0;
#   left: 0;
#   min-height: 100%;
#   min-width: 100%;
#   position: absolute;
# }
#
# .loaded .ytplayer-container {
#   display: block;
# }
#
# .loaded .placeholder-image {
#   opacity: 0;
# }
#
# .ytplayer-container {
#   bottom: 0;
#   height: 100%;
#   left: 0;
#   min-width: 100%;
#   overflow: hidden;
#   position: absolute;
#   right: 0;
#   top: 0;
#   z-index: 3;
# }
#
# .placeholder-image {
#   height: 100%;
#   left: 0;
#   min-height: 100%;
#   min-width: 100%;
#   position: fixed;
#   top: 0;
#   z-index: 1;
# }
#
# .ytplayer-shield {
#   height: 100%;
#   left: 0;
#   position: absolute;
#   top: 0;
#   width: 100%;
#   z-index: 2;
# }
#
# .ytplayer-player {
#   position: absolute;
# }
#
# .container {
#   border-radius: 6px;
#   background: rgba(255, 255, 255, .9);
#   padding: 0 30px 0 30px;
#   margin: 30px auto;
# }
#
# .videoPlay_btn {
#     position: absolute;
#     top: 41%;
#     left: 50%;
#     margin-left: -58px;
#     z-index: 999;
# }
# .video-container {position:relative;padding-top:30px;height:auto;overflow:hidden; margin-bottom:15px;}
# .video-container iframe,.video-container object,.video-container embed{position:absolute;top:0;left:0;width:100%;height:100%;}
#
# /*20180524*/
# .pop-layer .pop-container {
#   padding: 0px 25px 20px;
# }
#
# .pop-layer div.ctxt {
#   color: #666;
#   line-height: 25px;
# }
#
# .pop-layer div.wv_box1 {
# 	font-size:2em;
# 	font-weight:700;
# 	color:#212121;
# 	padding-top:30px;
# 	padding-bottom:30px;
# 	border-bottom:1px dotted #a9a9a9;
# 	text-align:center
# }
#
# .pop-layer div.wv_box2 {
# 	font-size:1.3em;
# 	font-weight:400;
# 	color:#212121;
# 	padding:30px 20px;
# 	line-height:2em;
# }
#
# .pop-layer .btn-r {
#   width: 100%;
#   padding-top: 10px;
#   text-align: right;
# }
#
# .pop-layer {
#   position: relative;
#   width: 720px;
#   height: auto;
#   background-color: #fff;
#   border: 5px solid #092e5b;
#   z-index: 10;
# }
#
# .dim-layer {
#   display: none;
#   position: fixed;
#   _position: absolute;
#   top: 0;
#   left: 0;
#   width: 100%;
#   height: 100%;
#   z-index: 100;
# }
#
# .dim-layer .dimBg {
#   position: absolute;
#   top: 0;
#   left: 0;
#   width: 100%;
#   height: 100%;
#   background: #000;
#   opacity: .5;
#   filter: alpha(opacity=50);
# }
#
# .dim-layer .pop-layer {
#   display: block;
# }
#
# a.btn-layerClose {
#   display: inline-block;
#   padding: 7px 10px;
#   border-radius:5px;
#   margin-right:20px;
#   border: 1px solid #304a8a;
#   background-color: #092e5b;
#   font-size: 13px;
#   color: #fff;
# }
#
# a.btn-layerClose:hover {
#   border: 1px solid #091940;
#   background-color: #1f326a;
#   color: #fff;
# }
#
# a.pop_openwin:visited, a.pop_openwin:active {
# 	text-decoration:none;
# 	border-bottom:1px blue dotted;
# }
#
# .pop_openwin {
# 	border-bottom:1px blue dotted;
# }
#
# .wv_clearfix::after {display:block;visibility:hidden;clear:both;content:''}
# .wv_float_left {float:left}
#
# .covidinfobox {
# 	border:1px solid #dedede;
# 	padding:23px 15px;
# 	margin-top:40px;
# 	box-sizing:content-box;
# }
#
#
#
# .covidinfobox ul {
# 	list-style:none;
# 	width:100%;
# 	height:103px
# }
# .cb {
# 	box-sizing:content-box;
# }
#
# .cb {
# 	box-sizing:content-box;
# }
# .covidinfobox li {
# 	width:33.3%;
#
# }
#
# a.covidinfoboxlink {
# 	display:table;
# 	position:relative;
# 	width:100%;
# 	height:103px;
# 	background:#f3f3f3;
# 	color:#02387b;
# 	font-size:1.1rem;
# 	font-weight:300;
# }
#
# a.covidinfoboxlink div {
# 	display:table-cell;
# 	height:103px;
# 	vertical-align:middle;
# 	margin:0 15px;
#
# }
#
# a.covidinfoboxlink span {
# 	font-weight:500;
# }
#
# .covidinfobox_txt1  {
# 	float:left;
# 	margin-left:5px;
# }
#
# .covidinfobox_txt2  {
# 	float:right;
# }
#
# @media  screen and (max-width: 800px){
# 	.pop-layer {
# 		width: 90%;
# 	}
# 	.dim-layer {position: absolute;}
#
# 	.pop-layer .pop-container{padding:0px 10px 20px;}
# 	.pop-layer div.wv_box2 img{width:100%;}
#
# 	.pop-layer div.wv_box2 {font-size:1em;}
# }
#
# .View_write {margin-bottom:50px;}
# #contents.c_sub .social_page{
# 	border-bottom:1px solid #dedede;
# 	margin-bottom:30px;
# }
# .video-container > a { color:#999  }
# .wvcontainer{
# 	width: 100%;
#     height: 500px;
#     display: table;
# }
# .wvcontents{
# 	position: relative;
#     display: table-cell;
#     vertical-align: middle;
#     width: 100%;
#     margin: 0 auto;
#     text-align: center;
# }
# .wvcontents .top_logo{
# 	width: 270px;
#     height: 140px;
#     margin: 0 auto 30px auto;
# 	background-image: url(http://www.president.go.kr/img_KR/2019/er_logo.jpg);
# 	background-repeat:no-repeat;
# 	background-position:center center;
# }
# .wvcontents h3{
# 	font-size: 42px;
# 	margin-bottom: 15px;
# 	display:block;
# }
# .wvcontents h3 span{color:#ccc;}
# .wvcontents .text{
# 	font-size: 21px;
#     color: #585858;
# 	padding-top:20px;
# }
# .wvcontents .text.txt{
# 	display: block;
#     margin-top: 25px;
# }
# .wvcontents .btn{
# 	text-align: center;
#     margin-top: 40px;
# 	border:none;
# }
#
# .wvcontents .btn:hover {
# 	background:transparent;
# }
# .wvcontents .btn a{
# 	font-size: 16px;
#     background-color: #082e59;
#     color: #fff;
#     width: 300px;
#     display: block;
#     margin: 0 auto;
#     height: 45px;
#     line-height: 42px;
#     border-radius: 5px;
# }
#
# @media screen and (max-width: 1024px){
# 	.wvcontainer {height: 350px;}
# 	.wvcontents h3 {font-size: 0px;}
# 	.wvcontents .text {font-size: 18px;}
# 	.wvcontents .top_logo {
# 		width: 220px;
# 		height: 100px;
# 		margin: 0 auto 0px auto;
# 		background-size: 150px;
# 	}
# }
#
# @media screen and (max-width: 440px){
# 	.wvcontents h3 {font-size: 20px;}
# 	.wvcontents .text {
# 		font-size: 14px;
# 		padding: 0 10px;
# 	}
# 	.wvcontents .text.txt {margin-top: 15px;}
# 	.wvcontents .btn {margin-top: 20px;}
# }
#
# @media screen and (max-width: 414px){
# 	.csp_box2 .txt25 .txt25_a {
# 		font-size:2em;
# 		line-height:1.4em;
# 		color:#252525;
# 		padding-top:40px;
# 	}
# 	.csp_box2 .txt25 .txt25_b {
# 		font-size:2.2em;
# 		line-height:1.4em;
# 		color:#252525;
# 	}
# 	.petition_box_bg {
#
# 	}
# 	#contents.c_sub .cs_hero {
# 		height:250px;
# 	}
# 	.csp_box2 .txt25 .txt25_c {
# 		font-size:1.3em;
# 		line-height:1.3em;
# 		color:#252525;
# 		padding:30px 20px;
# 		font-weight:500;
# 	}
# 	.board .b_list .bl_body .bl_no {
# 		display:none;
# 	}
# 	.ct_list .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
# 	.board .b_list .bl_body .bl_category {
# 		text-align: left;
# 	}
#
# 	.ct_list1 .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
#
# 	select#order {
# 		height:30px;
# 	}
# }
# .ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# .ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
#
# .ppo{
# 	display:none;
# 	position: relative;
# }
# .ppo_area{
# 	overflow:hidden;
# 	background-color:#fff;
# 	padding:1px;
# 	border:5px solid #0b2e4c;
# }
#
# .ppo_area img{
# 	max-width:550px;
# 	width:100%;
# 	height:auto;
# }
#
# .ppo .popCont{float:left;}
# .ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# .ppo_close_today{
# 	background-color:#222;
# 	color:#fff;
# 	text-align:center;
# 	padding:10px 0;
# }
# .ppo_close_today p{font-size:14px; cursor:pointer;}
# .popopen_top{
#
# }
#
# .popopen_top button{
# 	position:absolute;
# 	right:10px;
# 	top:10px;
# 	width:50px;
# 	height:20px;
# 	color:#FFF;
# 	cursor:pointer;
# 	z-index:99;
# }
#
# .kr_pop_close {
# 	position: absolute;
# 	top:-22px;
# 	right:0px;
# 	cursor:pointer;
# 	color:#fff;
# 	text-align:center;
# 	padding:0px 0px;
# 	letter-spacing: 0.1em;
# 	text-decoration: none !important;
# 	font-size:14px;
# }
# @media (max-width:768px) {
# 	.board .b_list .bl_subject {margin-right:0px;}
# 	}
#
# 	.ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:550px;
# 		width:100%;
# 		height:auto;
# 	}
# 	.ppo .popCont{
# 		float:left;
# 	}
# 	.ppo .popCont.popCont1{
# 		border-right:7px solid #fff;
# }
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:10px 0;
# 	}
# 	.ppo_close_today p{
# 		font-size:14px; cursor:pointer;
# 	}
# 	.popopen_top{
# 	}
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
#
# @media (max-width:414px) {
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# @media screen and (max-width: 375px){
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# .mfp-image-holder .mfp-content {
#     max-width: 87%;
# }
# .white-popup-block {
# 	position:relative;
# 	margin:0 auto;
# 	text-align:center;
# 	max-height:70vh;
# }
#
# .mfp-bottom-bar {
# 	margin-top: -39px;
# }
# .mfp-title {
# 	text-align:center;
# 	padding-right:0;
# }
# .mfp-title a {
# 	color:#fff;
# }
#
# .clearfix::after {
# display:block;visibility:hidden;clear:both;content:''
# }
# .event1 {
# 	width:100%;
# 	display:block;
# 	background:#043f77;
# 	color:#FFF;
# 	padding:10px 0;
# }
# .event2 {
# width:100%;
# 	display:block;
# 	background:#353535;
# 	color:#FFF;
# 	padding:10px 0;
# }
# #app_connect {
# 	margin: 10px 10px;
# 	padding: 10px 0;
# 	text-align: left;
# 	background-color: rgba(0, 0, 0, 0.7);
# 	border-radius: 10px;
# 	width: 95%;
# 	z-index: 1;
# 	position: fixed;
# 	bottom: 0;
# }
# #app_connect img {
# 	display: inline-block;
# 	vertical-align:middle;
# 	width: 38px;
# 	height: auto;
# 	padding-left: 20px;
# }
# #app_connect .app_btn {
# 	color: #fff;
# 	padding: 0 15px;
# 	height: auto;
# 	font-size: 14px;
# 	font-weight: 500;
# }
# #agreement_loading {display:none;}
#
# .reply-list-open a {
# 	width: 100%;
# 	display: inline-block;
# 	padding: 15px 30px;
# 	color: #333;
# 	background-color: #f3f3f3;
# 	border: 1px solid #dedede;
# 	font-size: 1.2em;
# 	letter-spacing: normal;
# 	cursor: pointer;
# }
#
# .reply-list-open a:hover {
# 	background-color:#082e59;
# 	color:#fff;
# }
# .ppo_close{position:static;padding:10px; background:#0b2e4c;text-align:center; cursor:pointer;color:#FFF;}
# .petitions_counter {
# 	position:absolute;
# 	right:5%;
# 	bottom:50px;
# 	width:260px;
# 	height:276px;
# }
# .petitions_counter_box {
# 	position:relative;
# 	width:260px;
# 	height:276px;
# 	-webkit-background-size: cover;
# 	-moz-background-size: cover;
# 	-o-background-size: cover;
# 	background-size: cover;
# 	background-repeat:no-repeat;
# 	background-image:url(/storage/images/petitions/petitions_counter.png);
# }
# .total_counter {
# 	position: absolute;
#     color: #FFF;
#     font-size: 2.3em;
#     font-weight: 500;
#     letter-spacing: -1px;
#     top: 38%;
#     left: 10%;
# }
# .goal_counter {
# 	position: absolute;
#     color: #FFF;
#     font-size: 2.3em;
#     font-weight: 500;
#     letter-spacing: -1px;
#     bottom: 24%;
#     left: 10%;
# }
# .after_answer {
#     color: #aaa;
#     position: absolute;
#     left: 25px;
#     bottom: 24px;
# }
# .before_answer {
#     color: #aaa;
#     position: absolute;
#     right: 25px;
#     bottom: 24px;
# }
# .petitions_counter_box a {
# 	width: 100%;
#     height: 50px;
#     position: absolute;
#     right: 0;
#     top: 0;
# }
#
# @media screen and (max-width: 480px){
# 	.petitions_counter {
# 		position:absolute;
# 		right:2%;
# 		bottom:2px;
# 		width:160px;
# 		height:176px;
# 	}
# 	.petitions_counter_box {
# 		position:relative;
# 		width:160px;
# 		height:176px;
# 		-webkit-background-size: cover;
# 		-moz-background-size: cover;
# 		-o-background-size: cover;
# 		background-size: cover;
# 		background-repeat:no-repeat;
# 		background-image:url(/storage/images/petitions/petitions_counter.png);
# 	}
# 	.total_counter {
# 		position: absolute;
# 		color: #FFF;
# 		font-size: 1.5em;
# 		font-weight: 500;
# 		letter-spacing: -1px;
# 		top: 35%;
# 		left: 10%;
# 	}
# 	.goal_counter {
# 		position: absolute;
# 		color: #FFF;
# 		font-size: 1.5em;
# 		font-weight: 500;
# 		letter-spacing: -1px;
# 		bottom: 24%;
# 		left: 10%;
# 	}
# 	.after_answer {
# 		color: #aaa;
# 		position: absolute;
# 		left: 8px;
# 		bottom: 12px;
# 		font-size: 0.8em;
# 	}
# 	.before_answer {
# 		color: #aaa;
# 		position: absolute;
# 		right: 5px;
# 		bottom: 12px;
# 		font-size: 0.8em;
# 	}
# 	.before_answer strong {font-size:1.2em !important;}
# 	.after_answer strong {font-size:1.2em !important;}
# 	.petitions_counter_box a {
# 		width: 100%;
# 		height: 30px;
# 		position: absolute;
# 		right: 0;
# 		top: 0;
# 	}
# }
# @media screen and (max-width: 768px){
# 	.title.t1 {
# 		font-size: 30px !important;
# 	}
# }
#
#
# .mfp-arrow-right {
# 	right: 25% !important;
# }
# .mfp-arrow-left {
# 	left: 25% !important;
# }
# .mfp-arrow:after {
#     transform: scale(1.5);
# }
# .mfp-close {
# 	font-family:'Noto Sans KR';
# 	font-size: 18px;
# 	padding-bottom: 15px;
# }
# .mfp-zoom-out-cur, .mfp-zoom-out-cur .mfp-image-holder .mfp-close {
#     cursor: unset !important;
# }
# .download-btn {
#     color: #1C243E;
#     font-weight: 600;
#     position: absolute;
#     right: -25%;
#     bottom: 40px;
#     padding: 20px;
#     background-color: #FFF;
#     border-radius: 5px;
# 	border: 2px solid #1C243E;
# }
# @media (max-width: 1500px) {
# 	.mfp-arrow-right {
# 		right: 18% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 18% !important;
# 	}
# }
# @media (max-width: 1200px) {
# 	.mfp-arrow-right {
# 		right: 10% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 10% !important;
# 	}
# }
# @media (max-width: 1024px) {
# 	.mfp-image-holder .mfp-content {
# 		width: 75%;
# 	}
# 	.mfp-arrow-right {
# 		right: 3% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: 3% !important;
# 	}
# 	.mfp-close {
# 		font-size: 16px;
# 	}
# 	.download-btn {
# 		right: unset;
# 		left: 50%;
# 		bottom: -30px;
# 		padding: 20px;
# 		transform: translateX(-50%);
# 	}
# }
# @media (max-width: 767px) {
# 	.mfp-arrow-right {
# 		right: -2% !important;
# 	}
# 	.mfp-arrow-left {
# 		left: -2% !important;
# 	}
# }
#
#
# @media screen and (max-width: 667px){
# 	.covidinfobox_txt1 {
# 		float:none;
# 	}
# 	.covidinfobox_txt1 img {
# 		width:90%;
# 		height:auto;
# 	}
# 	.covidinfobox_txt2 {
# 		display:block;
# 		float:none;
# 		margin-top:1rem;
# 		text-align:right
# 	}
#
# 	.covidinfobox ul {
# 		height:auto;
# 	}
#
# 	.covidinfobox li {
# 		float:none;
# 		width:100%;
# 		padding-top:1rem;
# 	}
# 	a.covidinfoboxlink {
# 		height:60px;
#
# 	}
# }
# </style><script src="/js/html5.js"></script>
# <script src="/js/jquery-1.11.0.min.js"></script>
# <script src="/js/navigation.js"></script>
# <script src="/js/jquery.validate.min.js"></script>
# <script src="/js/jquery.mCustomScrollbar.js"></script>
# <script src="/js/jquery.flexslider-min.js"></script>
# <script src="/js/jquery.appear.js"></script>
# <script src="/js/moment.min.js"></script>
# <title>윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다. &gt; 대한민국 청와대</title>
# </link></link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body><div id="accessibility">
# <strong class="blind">컨텐츠바로가기</strong>
# <ul>
# <li><a href="#cont_view" onclick="scrolltop('cont_view');"><strong>본문으로 바로가기</strong></a></li>
# <li><a href="#sitemap"><strong>하단 사이트 전체메뉴 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="wrap">
# <style>
# #header .h_gnb.on .depth1 {display:table !important;}
# </style>
# <div class="head_navi">
# <h1>
# <a href="http://www.president.go.kr/" style="display:block; text-align:center; padding:55px 0 20px 0;" title="메인페이지로 이동"><img alt="대한민국 청와대" src="/images/main/logo.png"/></a>
# </h1>
# <div class="navigator_menu">
# <ul class="menu" id="webNavi">
# <li class="ml0">
# <a href="http://www.president.go.kr/" style="position:absolute; display:block; text-align:center;" title="메인페이지로 이동">
# <img alt="대한민국 청와대" src="/images/main/logo.png"/>
# </a>
# </li>
# <li class="menu_list">
# <a href="/calendar">문재인 대통령</a>
# <ul class="menu_sub">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/c/briefings">청와대 뉴스룸</a>
# <ul class="menu_sub">
# <li><a href="/KNewDeal">한국판 뉴딜 <span style="color:#00dcff;">스페셜</span></a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/government-projects">정책정보</a>
# <ul class="menu_sub">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/petitions" title="국민소통 광장 새창열림">국민소통 광장</a>
# <ul class="menu_sub">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/about/roi">청와대 알림판</a>
# <ul class="menu_sub">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# </ul>
# </li>
# <li class="menu_list mr0">
# <a href="https://tour.president.go.kr">청와대 관람 신청</a>
# </li>
# <p class="main_search_icon">
# <a class="search_icon" href="https://www1.president.go.kr/search" style="display:block"><span class="sound_only">검색창 열기</span></a>
# </p>
# <div class="en_btn">
# <a href="http://english.president.go.kr" target="_blank" title="영문페이지로 새창열림">
# <span><img alt="영문페이지로 이동" src="/images/main/language_icon.gif"/> English</span>
# </a>
# </div>
# </ul>
# <div class="overlay overlay-slidedown">
# <button class="overlay-close" type="button">닫기</button>
# <div class="full_search">
# <form action="/search" method="post">
# <fieldset>
# <ul class="full_search_btn">
# <li class="search_box">
# <label class="hide" for="loginid">검색창</label>
# <input id="loginid" name="query" placeholder="검색어를 입력해주세요." title="검색어입력" type="text" value=""/>
# </li>
# <li class="search_btn">
# <input type="submit" value="검색"/>
# </li>
# </ul>
# </fieldset>
# </form>
# </div>
# </div>
# <script src="/js/modernizr.custom.js"></script>
# <script src="/js/classie.js"></script>
# </div>
# </div>
# <header class="" id="header">
# <div class="navigator_menu" style="display:none"></div>
# <div class="h_logo">
# <a href="/" title="메인페이지로 이동">
# <h1 class="blind">대한민국 청와대</h1>
# </a>
# </div>
# <hr/>
# <div class="h_search">
# <h2 class="blind">통합검색</h2>
# <div class="hs_btn">
# <button id="search_btn" type="button">
# <i><span class="sound_only">통합검색</span></i>
# <span class="blind">Search Btn</span>
# </button>
# </div>
# <div class="hs_wrap">
# <script>
# 				$(document).ready(function () {
# 					$('#form-search').submit(function () {
# 						var keyword = $(this).find('input[name="query"]').val();
# 						var regex = /^([a-zA-Z0-9가-힣 ]){2,}$/i;
# 						if (!regex.test(keyword)) {
# 							alert('검색어는 한글, 영문 숫자를 2글자 이상으로 입력해주세요.');
# 							return false;
# 						}
# 						return true;
# 					});
# 				});
# 			</script>
# <form action="/search" id="form-search">
# <fieldset>
# <legend>통합검색폼</legend>
# <div class="hs_group">
# <div class="hs_input">
# <label class="blind" for="hs_keyword">검색어</label>
# <input id="hs_keyword" name="query" placeholder="검색어를 입력해주세요." required="" type="text"/>
# </div>
# <button class="hs_ok" type="submit">검색</button>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <hr/>
# <div class="h_gnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="hg_btn">
# <h3>메뉴</h3>
# <button id="mainmenu_btn" type="button">
# <i><span class="sound_only">메인메뉴</span></i>
# <span class="blind">메뉴 버튼</span>
# </button>
# </div>
# <nav class="hg_wrap">
# <ul class="depth1">
# <li class="hg_president">
# <button type="button"><h3>문재인 대통령 <i><span class="sound_only">문재인 대통령</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/calendar">공개일정</a>
# </li>
# <li>
# <a href="/president-journey">걸어온길</a>
# </li>
# <li>
# <a href="/c/president-speeches">대통령의 말과 글</a>
# </li>
# <li>
# <a href="/c/first-lady-quotations">김정숙 여사 소식</a>
# </li>
# </ul>
# </li>
# <li class="hg_newsroom">
# <button type="button"><h3>청와대 뉴스룸 <i><span class="sound_only">청와대 뉴스룸</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/KNewDeal">한국판 뉴딜 <span style="color:#00dcff;">스페셜</span></a>
# </li>
# <li>
# <a href="/c/briefings">청와대가 전합니다</a>
# </li>
# <li>
# <a href="/c/blue-house-stories">청와대 이야기</a>
# </li>
# <li>
# <a href="/live-speeches">영상</a>
# </li>
# <li>
# <a href="/TodayShot">카드뉴스</a>
# </li>
# <li>
# <a href="/c/oversea-journals">세계의 시선</a>
# </li>
# <li>
# <a href="/history">청와대 일기</a>
# </li>
# </ul>
# </li>
# <li class="hg_policy">
# <button type="button"><h3>정책정보 <i><span class="sound_only">정책정보</span></i></h3></button>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="hg_community">
# <button type="button"><h3>국민소통 광장 <i><span class="sound_only">국민소통 광장</span></i></h3></button>
# <ul class="depth2">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="hg_cheongwadae">
# <button type="button"><h3>청와대 알림판 <i><span class="sound_only">청와대 알림판</span></i></h3></button>
# <ul class="depth2 hei325">
# <li>
# <a href="/about/roi">정보공개</a>
# </li>
# <li>
# <a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a>
# </li>
# <li>
# <a href="/about/organization">청와대 조직도</a>
# </li>
# <li>
# <a href="/budgets">세입·세출예산 운용상황</a>
# </li>
# <li>
# <a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a>
# </li>
# <li>
# <a href="/about/location?where=desk">오시는 길</a>
# </li>
# </ul>
# </li>
# <li><button onclick="location.href='https://tour.president.go.kr';" type="button"><h3>청와대 관람 신청<i style="background-position-x:0;background-position-y:50%"><span class="sound_only">청와대 관람 신청</span></i></h3></button></li>
# <li><button onclick="location.href='http://english.president.go.kr';" type="button"><h3>English<i aria-hidden="true" class="fa fa-globe" style="background:none; font-size:38px"><span class="sound_only">English</span></i></h3></button></li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="c_sub" id="contents">
# <section class="cs_hero newsroom">
# <div class="sound_only">국민청원</div>
# <div class="csh_txt">
# <div class="bl_title motion" data-animation="fadeInDown">
# <img alt="국민청원 4년, 국민이 세상을 바꿔 온 국민청원입니다" src="/storage/images/petitions4th/pc_txt.png?v=2" style="max-width: 100%;"/>
# </div>
# <!--
# 				<h2 class="title t1 bold cw motion" data-animation="fadeInDown">국민청원</h2>
# 				<p class="text bold big cw motion" data-animation="fadeInDown"></p>
# 				-->
# </div>
# <div class="petitions_4th_btn" style="">
# <h4 class="pdfview">
# <a href="/petitions/4th" style="color:#FFF">[스페셜 홈] 국민청원 4년, 보고드립니다 <i class="xi-mouse-pointer"></i></a>
# </h4>
# </div>
# </section>
# <section class="cs_wrap" id="cont_view">
# <div class="cs_tab">
# <div class="tab div3">
# <ul>
# <li class="motion" data-animation="fadeInLeft">
# <a href="/petitions">분야별 청원</a>
# </li>
# <li class="motion" data-animation="fadeInLeft">
# <a href="/petitions/best">추천순</a>
# </li>
# <li class="motion" data-animation="fadeInLeft">
# <a href="/petitions/answer">답변된 청원</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="cs_area">
# <div class="new_contents">
# <div class="petitions_contents" style="margin-top:0;">
# <!-- petitionsView_left -->
# <div class="petitionsView_left">
# <div class="petitionsView_left_pg">
# <!-- 청원 왼쪽 -->
# <div class="petitionsView_progress">
# <h4>청원진행중</h4> </div>
# <h3 class="petitionsView_title">윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다.</h3>
# <h2 class="petitionsView_count">참여인원 : [ <span class="counter">542,911</span>명 ]</h2>
# <div class="petitionsView_info">
# <ul class="petitionsView_info_list">
# <li><p>카테고리</p>정치개혁</li>
# <li><p>청원시작</p>2022-03-11</li>
# <li><p>청원마감</p>2022-04-10</li>
# <li style="margin-bottom:0;margin-right:0;"><p>청원인</p>kakao - ***</li>
# </ul>
# </div>
# <div class="petitionsView_grapy">
# <ol class="petitionsView_grapy_area">
# <li class="petitionsView_grapyName p_first">
# <div class="dot"></div>
# <h4>청원시작</h4>
# </li>
# <li class="petitionsView_grapyName p_second">
# <div class="dot petitions_point_ing">
# <div class="point_box">
# <span class="sound_only">현재 상태 </span>
# <div class="point_box_back">
# <div class="icon1"></div>
# <div class="icon2"></div>
# <div class="icon3"></div>
# </div>
# </div>
# </div>
# <h4 class="petitions_txt_ing">청원진행중</h4> </li>
# <li class="petitionsView_grapyName p_third">
# <div class="dot">
# </div>
# <h4>청원종료</h4> </li>
# <li class="petitionsView_grapyName p_fourth">
# <div class="dot">
# </div>
# <h4>답변완료</h4> </li>
# </ol>
# <div class="petitionsView_grapyLine"></div>
# </div><!-- petitionsView_grapy end -->
# <!-- 청원 본문 -->
# <div class="petitionsView_write">
# <div class="petitionsView_writeHead">
# <h4>청원내용</h4>
# <div class="writeHead_sns"></div>
# </div>
# <div class="View_write" style="word-break:break-all">
# 										20대 대통령으로 윤석열 후보가 당선되었습니다.<br/>
# <br/>
# 그러나 여전히 본인과 그부인에 대한 의혹은 좀처럼 사라지지 않고 있습니다.<br/>
# <br/>
# 대통령 후보라면 그 친가족 검증에 있어서는 먼지털 하나라도 검증대상입니다.<br/>
# <br/>
# 여전히 의혹만 있을뿐 이에 대한 검증과 수사가 제대로 이루어지지 않은 상태에서 당선인 신분이 된 것은 전혀 <br/>
# <br/>
# 납득이 안될 일입니다.<br/>
# <br/>
# 윤석열 당선인이 진정 국민과 나라를 위해 일할 지도자가 된다면 최소 이정도는 당선인 신분에도 확실한 검증이 <br/>
# <br/>
# 필요합니다.<br/>
# <br/>
# 이것이 과연 윤석열 당선인이 외쳤던 공정과 상식입니까? <br/>
# <br/>
# 도저히 국민의 한사람으로써 납득이 안될 일입니다.<br/>
# <br/>
# 물론 대장동 특검에 있어서는 여당에서 대선후에도 강력추진하겠다란 의지는 확고합니다.<br/>
# <br/>
# 그러나 여전히 이부분에 대해서 윤석열 당선인은 제대로된 답변과 언급이 없는 상태로 그냥 당선되면 없어진다.<br/>
# <br/>
# 하는 스스로의 망각된 생각을 가진 자가 20대 대통령이 된다는거 국민의 한사람으로서 도저히 납득이 안되고 이해 <br/>
# <br/>
# 불가입니다.<br/>
# <br/>
# 윤석열 당선인의 부산저축은행 부실수사 의혹과 김건희씨의 주가조작 의혹에 대해 당선인 신분에 있어서도 강력한<br/>
# <br/>
# 수사가 이루어져야 할 것이며, 필요시 이에대한 법적제재를 받는 것, 특히나 당선자 역시국민중 한사람이라는 명분 <br/>
# <br/>
# 잊어서는 안될 것입니다.<br/>
# <br/>
# 안될 것입니다.									</div>
# <ul class="View_write_link">
# </ul>
# </div>
# <!-- 청원 본문 -->
# <!-- 청원 동의 -->
# <div class="petitionsReply_area" id="petitionsReply_area">
# <div class="Reply_area_head">
# <h3 class="Reply_area_agree">청원동의 <span>542,911</span> 명</h3>
# <div class="Reply_area_sns">
# <div class="social_page motion" data-animation="fadeInUp">
# <span>SNS 공유하기</span>
# <ul>
# <li>
# <a href="javascript:void(0);" onclick="sendLink();" rel="noopener noreferrer" title="카카오톡 로그인창 바로가기(새창열림)">
# <i class="s_icon kakaotalk"><span class="sound_only">카카오톡 공유</span></i>
# <span class="blind">Kakao</span>
# </a>
# </li>
# <li>
# <a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww1.president.go.kr%2Fpetitions%2F604660" target="_blank" title="페이스북 로그인창 바로가기(새창열림)">
# <i class="s_icon facebook"><span class="sound_only">페이스북 공유</span></i>
# <span class="blind">Facebook</span>
# </a>
# </li>
# <li>
# <a href="https://twitter.com/intent/tweet?text=윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다. &gt; 대한민국 청와대&amp;url=https%3A%2F%2Fwww1.president.go.kr%2Fpetitions%2F604660" target="_blank" title="트위터 로그인창 바로가기(새창열림)">
# <i class="s_icon twitter"><span class="sound_only">트위터 공유</span></i>
# <span class="blind">Twitter</span>
# </a>
# </li>
# <li>
# <a href="https://telegram.me/share/url?url=https%3A%2F%2Fwww1.president.go.kr%2Fpetitions%2F604660&amp;text=윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다. &gt; 대한민국 청와대" target="_blank" title="텔레그램 공유하기(새창열림)">
# <i class="s_icon telegram"><span class="sound_only">텔레그램 공유</span></i>
# <span class="blind">Telegram</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="Reply_area_write">
# <div class="Reply_area_write_pg">
# <form action="/api/agreements/604660" id="form" method="post" onsubmit="return false">
# <input id="wv_token" name="agree_token" type="hidden" value=""/>
# <textarea class="petitionsReply_write" id="tw_contents" name="wv_agree_comment" onclick="loginpage();" placeholder="소셜로그인후 이용하실 수 있습니다." readonly="" required="" title="청원동의 글쓰기"></textarea>
# <button class="" onclick="loginpage();" style="background:#02387b" type="button">동의</button>
# </form>
# </div>
# </div>
# <div class="reply-list-open" style="margin-bottom:15px; margin-top: 30px; display:flex;"><a href="javascript:void(0);" onclick="agreement_list(1);">동의 내용 보기  <i class="xi-angle-down"></i></a></div>
# <div class="petitionsReply_Reply-list">
# <div class="petitionsReply_Reply" id="">
# <div id="agreement_loading" style="font-size:1.2em; font-weight:500; vertical-align:middle;"><i class="xi-spinner-5 xi-spin" style="font-size:1.3em; color:#333; font-weight:500;"></i>  데이터를 로딩중 입니다.</div>
# <ul id="agreement_list">
# </ul>
# </div>
# <div class="paging">
# <div class="p_wrap">
# <div class="p_btn">
# </div>
# </div>
# </div>
# </div>
# </div><!-- petitionsReply_area end -->
# <!-- //청원 동의 -->
# <div class="covidinfobox">
# <div class="wv_clearfix" style="padding-bottom:23px">
# <span class="covidinfobox_txt1"><img alt="코로나19 백신접종 정보 확인하기" src="/storage/images/2021/12/YKFTVJRFSG163904040816253.png"/></span>
# <span class="covidinfobox_txt2"><a href="https://ncv.kdca.go.kr" target="_blank"><img alt="질병관리청 바로가기 링크" src="/storage/images/2021/12/VRRCCDLRRV163904046796935.png"/></a></span>
# </div>
# <ul class="wv_clearfix">
# <li class="wv_float_left"><div style="padding-right:5px;"><a class="covidinfoboxlink" href="https://www.kdca.go.kr/gallery.es?mid=a20503010000&amp;bid=0002&amp;b_list=9&amp;act=view&amp;list_no=145418&amp;nPage=1&amp;vlist_no_npage=1&amp;keyField=&amp;keyWord=&amp;orderby=" target="_blank"><div><span>코로나19 백신 3차(부스터) 접종</span><br/>반드시 해야 하나요?</div></a></div></li>
# <li class="wv_float_left"><div style="padding:0 5px;"><a class="covidinfoboxlink" href="https://www.kdca.go.kr/gallery.es?mid=a20503010000&amp;bid=0002&amp;b_list=9&amp;act=view&amp;list_no=145395&amp;nPage=1&amp;vlist_no_npage=1&amp;keyField=&amp;keyWord=&amp;orderby=" target="_blank"><div>인과성불충분 환자 <br/><span>의료비 지원</span></div></a></div></li>
# <li class="wv_float_left"><div style="padding-left:5px;"><a class="covidinfoboxlink" href="https://ncv.kdca.go.kr/board.es?mid=a11802000000&amp;bid=0030" target="_blank"><div><span>뉴스&amp;팩트체크</span> <br/>직접 알려드립니다</div></a></div></li>
# </ul>
# </div>
# <!-- //청원 왼쪽 -->
# </div><!-- petitionsView_left_pg end -->
# </div>
# <!-- // petitionsView_left -->
# <!-- petitionsView_right -->
# <div class="petitionsView_right">
# <div class="petitionsView_right_pg">
# <style>
# .video-container > a { color:#999  }
#
# #petitions_video:focus {
# 	border: 1px dashed #ff0018;
# }
# </style>
# <!--<div class="petitionsView_top">
# 						<h3>한국 경제의 다양한 얼굴</h3>
# 						<div class="side_banner">
# 							<a href="/econo_num">
# 								<img src="http://www.president.go.kr/img_KR/2018/event/20180809_001.jpg?v=1" alt="숫자로 읽는 우리 경제"/>
# 							</a>
# 						</div>
# 					</div>-->
# <!-- petitionsView_top end -->
# <div class="petitionsView_top">
# <div style="padding-top:0;margin-bottom:-15px;">
# <a href="https://report.president.go.kr" style="display:block;position:relative;" target="_blank">
# <img alt="문재인 정부 국민보고 페이지" src="/storage/images/2022/03/REVVLNEHHE164774120815304.png" style="width:100%;"/>
# </a>
# </div>
# </div>
# <div class="petitionsView_top">
# <!--<h3>오늘의 청와대 LIVE</h3>-->
# <div class="video-container" id="petitions_video" style="padding-top:0;margin-bottom:-15px;" tabindex="0">
# <a href="javascript:void(0);" onclick="youtubopen2('9UFIto-U06o',this);" title="동영상 재생 팝업">
# <div class="player" data-property="{videoURL:'//youtu.be/9UFIto-U06o',containment:'body',autoPlay:true, mute:true, startAt:0, opacity:1, containment:'#video', showControls:false}" id="video" style="width:307px;height:170px;">청원답변 282, 283, 284호「동물학대 관련 국민청원 3건」</div>
# </a>
# <div style="display:none;">
# 								국민이 물으면 정부가 답한다.<br/>
# 								안녕하십니까? 방송통신위원회 상임위원 김창룡, 농림축산식품부 차관 김종훈입니다.<br/><br/>
#
# 								오늘은 방송촬영 시 동물보호 대책 마련, 고양이 학대범 강력처벌 요구, 고양이 학대갤러리 폐쇄 및 재발 방지 요구 등 동물 학대와 관련된 3건의 국민청원에 대한 답변을 드립니다.<br/><br/>
#
# 								답변에 앞서 소중한 생명을 잔인하게 살해하거나 관련 영상을 인터넷에 게시하는 등 우리 사회에서 동물 학대 범죄가 근절되지 않고 있는 현실에 대해 정부는 무거운 책임감을 느낍니다. 이러한 상황 속에 최근에는 방송 제작 과정에서까지 동물 학대가 발생하여 논란이 되었습니다.<br/><br/>
#
# 								이전과 비교하여 우리 사회가 동물권에 대한 사회적 인식이 많이 개선되었음에도 여전히 동물의 생명과 안전이 위협받는 현실에 대한 국민 여러분의 우려에 전적으로 공감합니다. 동물을 보호받을 권리를 가진 하나의 존엄한 생명체로서 대해 주기 위해서는 더 많은 관심과 노력이 필요할 것입니다. 정부는 동물보호를 위한 제도적 방안을 확대하고, 기존의 제도는 사회적 흐름에 맞게 개선해 나갈 수 있도록 노력하겠습니다.<br/><br/>
#
# 								먼저, 방송촬영 시 동물보호 대책 마련 요구 청원에 대해 답변드리겠습니다. 청원인께서는 얼마 전 논란이 되었던 KBS 드라마의 말 학대 장면을 지적하시면서 방송영상 촬영 시 KBS의 동물 안전조치 가이드라인 마련, 영상제작 관련 동물복지기준 법제화 등을 요구하였습니다. 청원에는 약 20만 명의 국민께서 동의해 주셨습니다.<br/><br/>
#
# 								KBS(한국방송공사)는 논란 발생 직후, 사과 입장문을 통해 해당 사고를 생명 윤리와 동물 복지에 대한 부족한 인식이 불러온 참사라고 판단하고 있다고 밝혔고, 제작 현장 전반에 대한 점검과 개선을 약속했습니다.<br/><br/>
#
# 								이어 2월에 ‘KBS 방송제작 가이드라인’에 동물 출연 기준을 추가하였으며, 위험한 동물 촬영 장면의 경우 최대한 CG 작업 적용, 살아 있는 동물에 인위적 해를 입하는 장면 금지 등 구체적 원칙을 담은 출연 동물 안전 보호 조항을 새롭게 신설하였습니다.<br/><br/>
#
# 								아울러 동물보호 주무 부처인 농림축산식품부는 영화, 드라마, 광고 등 영상 및 미디어에 출연하는 동물보호 가이드라인 마련을 위해 방송통신위원회 등 관계 부처와 KBS, 한국방송협회, 한국PD연합회, 동물보호단체 등 전문가 20여 명이 참석하는 민관협의체를 구성해 지난 2일 첫 회의를 열었습니다.<br/><br/>
#
# 								협의체 논의와 외국 사례 분석, 연구용역 등을 통해 촬영 현장에서 고려해야 할 기본원칙과 준수사항 등이 포함된 가이드라인을 올 상반기 내에 마련할 계획입니다.<br/><br/>
#
# 								앞으로 정부는 새로 마련되는 동물보호 가이드라인이 방송 제작 현장에서 준수되고 자리잡을 수 있도록 독려하고, 지속적인 모니터링을 해 나가겠습니다.<br/><br/>
#
# 								또한 방송사업자 및 동물보호단체와 협력하여 영상산업 전반에서 동물 복지에 대한 인식이 개선되고, 동물을 안전하게 촬영하는 제작환경이 조성되도록 노력하겠습니다. 동물과 사람을 막론하고 생명을 보다 존중하는 사회가 될 수 있도록 최선을 다하겠습니다.<br/><br/>
#
# 								다음으로, 고양이 학대범 강력처벌 청원과 고양이 학대갤러리 폐쇄 및 재발 방지 요구 청원에 대해 답변드리겠습니다.<br/><br/>
#
# 								먼저 고양이 학대범 강력처벌 요구 청원입니다. 청원인께서는 경남 창원에 있는 한 식당에서 키우던 고양이를 바닥에 내리쳐 잔인하게 죽인 사람에 대한 강력한 처벌과 함께 동물 학대 근절 대책을 요구하셨습니다. 해당 청원에는 20만여 명의 국민께서 동의해 주셨습니다.<br/><br/>
#
# 								사건이 발생한 뒤 신고를 받은 경찰은 CCTV 역추적 및 탐문을 통해 피의자를 긴급체포하였습니다. 피의자 조사를 통해 범행 사실에 대한 자백을 받았고, 피의자는 혐의가 인정되어 검찰에 불구속 송치되었습니다. 재판을 통해 동물을 잔혹하게 살해한 피의자가 강화된 동물보호법에 따라 합당한 처벌을 받게 되기를 바랍니다.<br/><br/>
#
# 								다음으로 고양이 학대갤러리 폐쇄 및 재발 방지 요구 청원에 대해 답변드리겠습니다. 청원인께서는 인터넷 커뮤니티에서 익명의 이용자들이 길고양이를 포획틀에 가두어 불을 붙이는 등 학대 행위를 하고 해당 영상을 게시판에 올리는 것에 대해 관련자 수사 및 해당 게시판 폐쇄, 재발 방지 조치 등을 촉구하셨습니다. 해당 청원에 대해 22만여 명의 국민께서 동의해 주셨습니다.<br/><br/>
#
# 								작년 7월, 해당 사이트의 한 커뮤니티에서 이루어진 학대 행위에 대한 국민청원이 있었고, 해당 게시판은 폐쇄된 바 있습니다. 하지만 같은 사이트 내에서 위치를 옮겨 범죄 행위들이 다시 이루어지고 있는 것에 대해 매우 안타깝게 생각합니다.<br/><br/>
#
# 								현재 동물권 단체가 해당 갤러리의 학대 행위를 한 성명불상의 피의자와 사이트 운영자를 고발하여 수사가 진행 중입니다. 학대 행위자는 범행 도구 추정 물품의 혈흔·유전자 감식, IP 추적 등을 통해 수사가 이루어질 예정이고, 사이트 운영자의 학대 방조 혐의에 대해서도 수사가 진행 중입니다. 동물 학대와 관련된 행위들에 대해 엄정한 수사가 이뤄질 것입니다.<br/><br/>
#
# 								지난 5년 우리 사회에서 동물보호에 대한 목소리가 꾸준히 높아져 왔습니다. 국민청원을 통해 20만 동의를 넘겨 정부가 답을 한 청원도 이번을 포함해 총 14건에 달합니다.<br/><br/>
#
# 								2018년 6월 처음으로 20만 동의를 넘은 유기견 보호소 폐지 반대 청원을 시작으로 최근에는 각종 동물 학대 행위에 대한 처벌 강화와 제도 개선을 요청하고 있습니다.<br/><br/>
#
# 								이에 정부도 2018년부터 농식품부에 ‘동물복지정책과’를 신설해 관련 정책을 총괄하게 했고, 각 지자체도 해당 업무 담당 인력을 꾸준히 충원해 왔습니다. 2020년에는 ‘동물복지 5개년 종합계획’을 수립해 체계적인 동물보호 및 복지정책 개선을 위해 노력하고 있습니다.<br/><br/>
#
# 								이와 함께 ｢동물보호법｣ 상 동물 학대 행위의 범위를 확대하고 처벌도 높여 왔습니다. ’18년부터 반려동물에게 최소한의 사육공간 제공과 같은 의무를 다하지 않는 소위 ‘애니멀 호딩’을 학대 행위에 추가하였습니다.<br/><br/>
#
# 								또 ’18년과 ’21년, 두 차례의 개정을 통해 동물을 학대해 죽게 한 경우의 처벌조항을 ‘1년 이하의 징역 또는 1천만원 이하의 벌금’에서 ‘3년 이하의 징역 또는 3천만원 이하의 벌금’으로 강화하였습니다.<br/><br/>
#
# 								‘동물’을 ‘사람과 함께하는 동반자’로서 아끼고 존중하려는 우리 사회의 노력도 중요합니다. 이를 위해 정부는 매년 공익광고를 기획·송출하고 있으며, 작년에는 일선 초등학교에서 활용할 수 있는 교육프로그램도 개발하였습니다.<br/><br/>
#
# 								방송국 차원에서 촬영현장 동물보호 가이드라인 조항이 신설되고, 정부와 민간이 함께 기본 준수사항 논의를 시작한 것은 중요한 출발점이 되리라 생각합니다.<br/><br/>
#
# 								오늘 답변드린 ‘방송촬영 시 동물보호 대책 마련’ 요구 청원은 방송 제작 현장에서의 동물권에 대해 높아진 사회적 요구사항을 다시 확인하게 되는 계기였습니다.<br/><br/>
#
# 								우리가 만드는 영상콘텐츠가 세계인이 함께 보는 ‘K-콘텐츠’로 인기를 끄는 만큼 제작현장과 영상 표현에서 동물권이 보호되도록 계속 점검해 나가겠습니다.<br/><br/>
#
# 								동물보호 관련 법, 제도 개선을 위해 지난 5년간 꾸준히 노력해 왔지만 아직 제도와 현장에서 개선해야 할 점들이 여전히 많이 남아 있음을 알고 있습니다.<br/><br/>
#
# 								정부는 앞으로도 적극적으로 동물 학대 방지 방안을 마련하여 이러한 일들이 재발되지 않도록 제도화하고, 동물보호 관련 사회적 공감대를 높여갈 수 있도록 노력하겠습니다.<br/><br/>
#
# 								국민청원에 참여해 주신 모든 분들께 깊이 감사드립니다.
# 							</div>
# </div>
# </div>
# <div class="petitionsView_top">
# <div style="padding-top:0;margin-bottom:-15px;">
# <a href="https://www.youtube.com/channel/UC5HogEz14SPRvvBoybW_0ZQ" target="_blank">
# <img alt="국민청원 유튜브 채널 이제, 유튜브 단독채널로 국민여러분을 찾아갑니다" src="/storage/images/2020/01/petitions_banner.jpg" style="width:100%;"/>
# </a>
# </div>
# </div>
# <div class="petitionsView_top">
# <h3>추천순 TOP 5</h3>
# <ul>
# <li><a href="/petitions/604660"><span>1.</span> 윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다.</a></li>
# <li><a href="/petitions/604773"><span>2.</span> 윤석열 당선인 집무실 만들고자, 국가안전 중추인 국방부를 강압 이전하여, 국민의 혈세 수천억을 날리는 것을 막아주십시요</a></li>
# <li><a href="/petitions/604735"><span>3.</span> 이명박 전 대통령 사면을 반대합니다.</a></li>
# <li><a href="/petitions/604627"><span>4.</span> 문재인 대통령님 사랑합니다.</a></li>
# <li><a href="/petitions/604640"><span>5.</span> 대구 동구 부정선거 및 선거관리위원회의 관리 부실로 대선 재투표를 희망합니다.</a></li>
# </ul>
# </div><!-- petitionsView_top end -->
# <div class="petitionsView_top">
# <h3>답변된 청원</h3>
# <ul>
# <li><a href="/petitions/603745"><span>·</span> 길고양이를 학대하는 갤러리를 폐쇄하고 엄중한 수사를 해주십시오</a></li>
# <li><a href="/petitions/603745"><span>·</span> 식당 앞에서 고양이 '두부' 를 꼬리채 들고 바닥에 내리쳐 잔혹하게 살해한 학대범을 검거하고 강력히 처벌해 주세요.</a></li>
# <li><a href="/petitions/603481"><span>·</span> 방송 촬영을 위해 안전과 생존을 위협당하는 동물의 대책 마련이 필요합니다</a></li>
# <li><a href="/petitions/603745"><span>·</span> (모녀살인범 유튜버사망사건) 가해자유튜버랑*****.****** 강력처벌을 요청합니다</a></li>
# <li><a href="/petitions/603745"><span>·</span> 여자고등학교에서 강요하는 위문 편지 금지해주세요.</a></li>
# <li><a href="/petitions/603481"><span>·</span> 저는 국민 옆에 남고 싶은 간호사입니다. 간호법 제정이 필요합니다.</a></li>
# <li><a href="/petitions/603194"><span>·</span> 드라마 설** 방영중지 청원</a></li>
# <li><a href="/petitions/602794"><span>·</span> 푸들만 19마리 입양 ! 온갖고문으로 잔혹학대 후 죽이고 불법매립한 범죄자의 강력한 처벌을 촉구하며, 신상공개 동의해주세요!!!!!</a></li>
# <li><a href="/petitions/602674"><span>·</span> 외국 국적 여중생을 묶고 6시간 가학적 집단폭행한 가해자4명 강력처벌.신상공개를촉구합니다.</a></li>
# <li><a href="/petitions/601845"><span>·</span> 신포괄수가제 항암약품 급여 폐지에 대한 반대 청원</a></li>
# </ul>
# </div><!-- petitionsView_top end -->
# <div class="petitionsView_top">
# <h3>오늘의 한장</h3>
# <div class="PW_BAN">
# <a href="/TodayShot?category=1">
# <img alt="오미크론 특성에 맞게 속도와 효율을 높여 고위험군 관리에 역점을 두고 위중증과 사망 위험을 막는 데 역량을 집중해야 할 것입니다" src="/storage/images/2022/02/d9e1f4249b26404ca736589dc4bed6fe.jpg" style="width:100%;height:auto;"><p>오미크론 특성에 맞게 속도와 효율을 높여 고위험군 관리에 역점을 두고 위중증과 사망 위험을 막는 데 역량을 집중해야 할 것입니다</p> </img></a>
# </div>
# </div>
# <script>
# 					$('#petitions_video > a').on('click', function(){
# 						//youtubopen2('9UFIto-U06o');
# 					});
# 					</script>
# <script>
# 					$('#petitions_video2 > a').on('click', function(){
# 						youtubopen('jE2BQ6Lqi5w');
# 					});
# 					</script> </div><!-- petitionsView_right_pg end -->
# </div>
# <!-- petitionsView_right -->
# </div>
# </div>
# <div class="pop-layer mfp-hide white-popup-block" id="layer2">
# <div class="pop-container">
# <div class="pop-conts">
# <!--content //-->
# <div class="ctxt wv_box1">
# 				소중한 내 청원, 청와대 답변이 궁금하세요?
# 			</div>
# <div class="ctxt wv_box2">
# 				청와대는 '국민이 물으면 정부가 답한다'는 소통 철학을 바탕으로 대통령과 수석·보좌관의 회의, 주목받는 국민청원, 외국 언론이 본 우리 정부, 해외 순방과 그 뒷얘기, 100대 국정과제와 수많은 정책 관련 소식 등 국민이 궁금해하는 내용을 홈페이지와 SNS계정을 통해 공개하고 있습니다.<br/><br/>청와대 소식을 가장 빠르고 정확하게 확인할 수 있는 '<a class="pop_openwin" href="https://www.facebook.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="청와대 공식 페이스북 새창열림">청와대 공식 페이스북</a>, <a class="pop_openwin" href="https://twitter.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="청와대 공식 트위터 새창열림">트위터</a>, <a class="pop_openwin" href="https://www.instagram.com/thebluehouse_kr/" rel="noopener noreferrer" target="_blank" title="청와대 공식 인스타그램 새창열림">인스타그램</a>, <a class="pop_openwin" href="https://www.youtube.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="청와대 공식 유튜브 새창열림">유튜브</a>, <a class="pop_openwin" href="https://pf.kakao.com/_tQbxhd" rel="noopener noreferrer" target="_blank" title="청와대 공식 카카오 플러스친구 새창열림">카카오 플러스친구 </a>'를 팔로우해주십시오.<br/>더 많은 정보와 투명하고 진솔한 소통으로 국민과 함께 하겠습니다.
# 			</div>
# <!--// content-->
# </div>
# </div>
# </div>
# <script>
# $('.btn-example').click(function(){
#         var $href = $(this).attr('href');
#         layer_popup($href);
#     });
#     function layer_popup(el){
# 		$.magnificPopup.open({
# 			type: 'inline',
# 			items:[{src:$('#layer2')}],
# 			removalDelay: 160,
# 			preloader: false,
# 			autoFocusLast: true,
# 			closeMarkup: '<div class="btn-r btn-layerClose"><button type="button" class="mfp-close tBtn">닫기</button><div class="mfp-close cBtn"><i class="fa fa-times"></i></div></div>',
# 		});
#     }
#
# </script>
# </div>
# </section>
# </div>
# <script>
# $('.petitionsReply_Reply-list').hide();
#
# function agreement_list(page, param) {
# 	$('.petitionsReply_Reply-list').show();
# 	$('.reply-list-open').hide();
# 	wv_submit = true;
# 	$("#agreement_list").empty();
# 	$("#agreement_loading").show();
# 	$('.p_btn').hide();
# 	$.ajax({
# 		type:'POST',
# 		url:'/api/agreements_list/604660',
# 		data:'page='+page,
# 		dataType : 'json',
# 		success:function(data){
# 			if (data.status == 'error')	{
# 				alter(data.message);
# 				return ;
# 			}
# 			var html = '';
#
# 			for (var i=0;i<data.item.length ;i++ ) {
# 				html += '<li class="Reply_Reply_list"><div class="Reply_Reply_contents"><div class="pv3_R_contents_head"><h4>'+data.item[i].user+'</h4></div><div class="R_R_contents_txt">'+data.item[i].agreement_comment+'</div></div></li>';
# 			}
#
# 			$("#agreement_loading").hide();
# 			$("#agreement_list").append(html);
# 			$('.p_btn').show();
# 			$('.p_btn').html(data.paging);
# 			wv_submit = false;
#
# 		},
# 		error:function(e){
# 			alert('잠시후 다시 이용해 주세요');
# 			$("#agreement_loading").hide();
# 			wv_submit = false;
# 		}
# 	});
# 	$('.p_btn').click(function(){
# 		var scrollPosition = $('.Reply_area_write_pg').offset().top;
# 		$('html, body').stop().animate({scrollTop : scrollPosition-80}, 300);
# 	});
# }
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
#     today.setDate(today.getDate() + expiredays);
#     document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name) {
#     var cName = name + "=";
#     var x = 0;
# 	var i = 0;
#     while ( i <= document.cookie.length ) {
#         var y = (x+cName.length);
#         if ( document.cookie.substring( x, y ) == cName ) {
#             if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
#                 endOfCookie = document.cookie.length;
#             return unescape( document.cookie.substring( y, endOfCookie ) );
#         }
#         x = document.cookie.indexOf( " ", x ) + 1;
#         if ( x == 0 )
#             break;
#     }
#     return "";
# }
# function closePopupNotToday(){
# 	setCookie('notToday','Y', 1);
# 	$(".ppo").hide('fade');
# }
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
#     today.setDate(today.getDate() + expiredays);
#     document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name) {
#     var cName = name + "=";
#     var x = 0;
# 	var i = 0;
#     while ( i <= document.cookie.length ) {
#         var y = (x+cName.length);
#         if ( document.cookie.substring( x, y ) == cName ) {
#             if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
#                 endOfCookie = document.cookie.length;
#             return unescape( document.cookie.substring( y, endOfCookie ) );
#         }
#         x = document.cookie.indexOf( " ", x ) + 1;
#         if ( x == 0 )
#             break;
#     }
#     return "";
# }
#
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
#
# 	$(".ppo_close").click(function(){
# 		closePopup();
# 	});
# 	$(".ppo_close_today").click(function(){
# 		closePopupNotToday();
# 	});
# 	if (getCookie("notToday") != "Y"){
# 		$('.ppo').show('fade');
# 	} else {
# 		$('.ppo').hide('fade');
# 	}
#
#
#     function sendLink() {
#       Kakao.Link.sendDefault({
#         objectType: 'feed',
#         content: {
# 				title: '윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조사 확인을 위한 청원입니다.',
# 		          description: ' > 대한민국 청와대 국민청원',
#           imageUrl: 'http://www.president.go.kr/css/favicon_400x210.png',
# 		  imageWidth:1200,
# 		  imageHeight:675,
#           link: {
# 			mobileWebUrl: 'https://www1.president.go.kr/petitions/604660',
#             webUrl: 'https://www1.president.go.kr/petitions/604660'
#           }
#         },
#         buttons: [
#           {
#             title: '자세히 보기',
#             link: {
#               mobileWebUrl: 'https://www1.president.go.kr/petitions/604660',
#               webUrl: 'https://www1.president.go.kr/petitions/604660'
#             }
#           }
#         ]
#       });
#     }
#
#
# function youtubopen2(data, oj) {
# 	var subscribe = $(oj).next().html();
# 	var videotitle = $(oj).attr('title');
#
# 	$.magnificPopup.open({
# 		items: {
# 			src:'https://www.youtube.com/watch?v='+data
# 		},
# 		disableOn: 700,
# 		type: 'iframe',
# 		mainClass: 'mfp-fade',
# 		removalDelay: 160,
# 		preloader: false,
# 		closeOnBgClick: false,
# 		fixedContentPos: true,
# 		closeMarkup: '<button type="button" class="mfp-close tBtn">닫기</button><div class="mfp-close cBtn" aria-hidden="true"><i class="xi-close"></i></div>',
# 		autoFocusLast: true,
# 		iframe: {
# 		  markup: '<div class="mfp-iframe-scaler">'+
# 					'<div class="mfp-close"></div>'+
# 					'<iframe title="'+videotitle+'도" class="mfp-iframe" frameborder="0" allowfullscreen></iframe>'+
# 				  '</div>'+
# 				  ''+
# 				  '<div  style="bottom: 0; position: relative; display: block; margin: 0 auto; text-align: left;"><div tabindex="0" style="padding: 15px 15px; color: #0b2e4c; background-color: #fff; border-radius: 5px; font-size: 14px; width:100%;max-width:870px;height:100px; display: inline-block; overflow:auto; line-height:normal;">'+ subscribe +'</div></div>', // HTML markup of popup, `mfp-close` will be replaced by the close button
# 		  patterns: {
# 			youtube: {
# 			  index: 'youtube.com/', // String that detects type of video (in this case YouTube). Simply via url.indexOf(index).
# 			  id: 'v=', // String that splits URL in a two parts, second part should be %id%
# 			  src: '//www.youtube.com/embed/%id%?autoplay=0'
# 			}
#
# 			// you may add here more sources
#
# 		  },
#
# 		  srcAction: 'iframe_src', // Templating object key. First part defines CSS selector, second attribute. "iframe_src" means: find "iframe" and set attribute "src".
# 		}
# 	});
# }
# </script>
# <hr/>
# <!-- <div id="app_connect">
# 		<img src="/images/main/app_icon.png"><button class="app_btn">청와대 앱으로 보기<span class="blind">버튼</span></button>
# 	</div> -->
# <div id="sitemap">
# <button class="s_btn">사이트맵 <span class="blind">버튼</span></button>
# <div class="wrap">
# <ul class="depth1">
# <li>
# <h3>문재인 대통령
#                         <a class="blind" href="/calendar">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 뉴스룸</h3>
# <ul class="depth2">
# <li><a href="/KNewDeal">한국판 뉴딜 스페셜</a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li>
# <h3>정책정보
#                         <a class="blind" href="/government-projects">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2021">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li>
# <h3>국민소통 광장
#                         <a class="blind" href="/petitions">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/event/4th" rel="noopener noreferrer" target="_blank" title="문재인 대통령 4주년 새창열림">문재인 대통령 4주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification">열린참여</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 알림판
#                         <a class="blind" href="/about/roi">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# <li><a href="https://tour.president.go.kr" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">청와대 관람신청</a></li>
# <li><a href="http://children.president.go.kr" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">어린이 홈페이지</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <footer id="footer">
# <div class="wrap">
# <div class="f_group">
# <div class="f_logo">
# <h2 class="blind">대한민국 청와대</h2>
# </div>
# <div class="f_sns">
# <h2 class="blind">SNS 바로가기</h2>
# <ul>
# <li>
# <a href="https://www.facebook.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="페이스북 새창열림">
# <i class="fs_icon facebook"><span class="sound_only">페이스북 바로가기 </span></i><span class="blind">Facebook</span>
# </a>
# </li>
# <li>
# <a href="https://blog.naver.com/thebluehousekr" rel="noopener noreferrer" target="_blank" title="블로그 새창열림"><i class="fs_icon blog"><span class="sound_only">블로그 바로가기 </span></i><span class="blind">blog</span></a>
# </li>
# <li>
# <a href="https://twitter.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="트위터 새창열림">
# <i class="fs_icon twitter"><span class="sound_only">트위터 바로가기 </span></i><span class="blind">Twitter</span>
# </a>
# </li>
# <li>
# <a href="https://www.instagram.com/thebluehouse_kr/" rel="noopener noreferrer" target="_blank" title="인스타그램 새창열림">
# <i class="fs_icon instagram"><span class="sound_only">인스타그램 바로가기 </span></i><span class="blind">Instagram</span>
# </a>
# </li>
# <li>
# <a href="https://www.youtube.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="유튜브 새창열림">
# <i class="fs_icon youtube"><span class="sound_only">유튜브 바로가기 </span></i><span class="blind">Youtube</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="f_wrap">
# <div class="f_info">
# <h2>CONTACT INFO</h2>
# <ul>
# <li>
# <i class="fi_icon call"><span class="sound_only">전화번호 </span></i>
# <p><a href="tel:02-730-5800">(+82) 02-730-5800</a></p>
# </li>
# <li>
# <i class="fi_icon email"><span class="sound_only">메일주소 </span></i>
# <p>담당자 메일 : <a href="mailto:webmaster@president.go.kr">메일보내기</a></p>
# </li>
# <li>
# <i class="fi_icon address"><span class="sound_only">청와대 주소</span></i>
# <p>03048 서울특별시 종로구 청와대로 1 대통령 비서실</p>
# </li>
# </ul>
# </div>
# <div class="f_menu">
# <div class="fm_wrap">
# <ul>
# <li><a href="/about/privacy">개인정보처리방침</a></li>
# <li><a href="/about/copyright">저작권 정책</a></li>
# <li><a href="/sitemap">사이트맵</a></li>
# <li><a href="/about/location">오시는 길</a></li>
# </ul>
# <ul>
# </ul>
# </div>
# <div class="fm_tip" style="line-height:20px; margin-bottom:6px;">
# 						해당 메일은 기능 장애 등 홈페이지 관련 문의만 접수합니다.<br/>
# 						청와대 및 정부에 대한 민원·제안 및 공익신고·고발 등은
# 						국민신문고(<a href="http://www.epeople.go.kr/" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">www.epeople.go.kr</a>)로
# 						접수해주시길 부탁드립니다.
# 					</div>
# <ul class="footer_mark" style="margin-top:15px;">
# <li><img alt="wa품질인증마크" src="/images/main/wa_mark.png"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="f_copyright">
# 			© Office of the President. All rights reserved.
# 		</div>
# </footer>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-112394055-1"></script>
# <script src="/js/common.js" type="text/javascript"></script>
# <script src="/js/jquery.waypoints.min.js" type="text/javascript"></script>
# <script src="/js/jquery.countup.js" type="text/javascript"></script>
# <script src="/js/jquery.form.min.js" type="text/javascript"></script>
# <script src="/js/jquery.mb.YTPlayer.min.js" type="text/javascript"></script>
# <script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script>
# <script src="/js/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script>
#   $(document).ready(function () {
#
#
#
# var webNavi = $('#webNavi').superfish({});
# $('#video').YTPlayer();
# $('#video2').YTPlayer();
# $('.counter').countUp({
# 	delay: 5,
# 	time: 600
# });
#   });
#
# function loginpage(){
# 	location.href = '/login?reurl=%2Fpetitions%2F604660';
# }
#
# Kakao.init('13b6f0aa4163fefd4e2883ff8a536553');
# function KakaoSendLink() {
# 	Kakao.Link.sendScrap({
# 		requestUrl: 'https://www1.president.go.kr/petitions/604660'
# 	});
# }
#
# function youtubopen(data) {
# 	$.magnificPopup.open({
# 		items: {
# 			src:'https://www.youtube.com/watch?v='+data
# 		},
# 		type: 'iframe',
# 		mainClass: 'mfp-fade',
# 		removalDelay: 160,
# 		preloader: false,
# 		fixedContentPos: false,
# 		closeMarkup: '<button type="button" class="mfp-close tBtn">닫기</button><div class="mfp-close cBtn" aria-hidden="true"><i class="xi-close"></i></div>',
# 		autoFocusLast: true,
# 		iframe: {
# 		  markup: '<div class="mfp-iframe-scaler">'+
# 					'<div class="mfp-close"></div>'+
# 					'<iframe class="mfp-iframe" frameborder="0" title="유투브 동영상 재생" allowfullscreen></iframe>'+
# 				  '</div>',
# 		  patterns: {
# 			youtube: {
# 			  index: 'youtube.com/',
# 			  id: 'v=',
# 			  src: '//www.youtube.com/embed/%id%?autoplay=0'
# 			}
#
# 		  },
#
# 		  srcAction: 'iframe_src',
# 		}
# 	});
# }
#
#
# function modalpop2() {
# 	$.magnificPopup.open({
# 		items: [
# 			{src:'/storage/images/petitions4th/image0.jpeg'},
# 			{src:'/storage/images/petitions4th/image1.jpeg'},
# 			{src:'/storage/images/petitions4th/image2.jpeg'},
# 			{src:'/storage/images/petitions4th/image3.jpeg'},
# 			{src:'/storage/images/petitions4th/image4.jpeg'},
# 			{src:'/storage/images/petitions4th/image5.jpeg'},
# 			{src:'/storage/images/petitions4th/image6.jpeg'},
# 			{src:'/storage/images/petitions4th/image7.jpeg'},
# 			{src:'/storage/images/petitions4th/image8.jpeg'},
# 			{src:'/storage/images/petitions4th/image9.jpeg'},
# 			{src:'/storage/images/petitions4th/image10.jpeg'},
# 			{src:'/storage/images/petitions4th/image11.jpeg'},
# 			{src:'/storage/images/petitions4th/image12.jpeg'},
# 			{src:'/storage/images/petitions4th/image13.jpeg'},
# 			{src:'/storage/images/petitions4th/image14.jpeg'},
# 			{src:'/storage/images/petitions4th/image15.jpeg'},
# 			{src:'/storage/images/petitions4th/image16.jpeg'},
# 			{src:'/storage/images/petitions4th/image17.jpeg'},
# 			{src:'/storage/images/petitions4th/image18.jpeg'},
# 			{src:'/storage/images/petitions4th/image19.jpeg'},
# 			{src:'/storage/images/petitions4th/image20.jpeg'},
# 			{src:'/storage/images/petitions4th/image21.jpeg'},
# 			{src:'/storage/images/petitions4th/image22.jpeg'},
# 			{src:'/storage/images/petitions4th/image23.jpeg'},
# 			{src:'/storage/images/petitions4th/image24.jpeg'},
# 			{src:'/storage/images/petitions4th/image25.jpeg'},
# 			{src:'/storage/images/petitions4th/image26.jpeg'},
# 			{src:'/storage/images/petitions4th/image27.jpeg'},
# 			{src:'/storage/images/petitions4th/image29.jpeg'},
# 			{src:'/storage/images/petitions4th/image30.jpeg'},
# 			{src:'/storage/images/petitions4th/image31.jpeg'}
# 		],
# 		type: 'image',
# 		tLoading: 'Loading image #%curr%...',
# 		mainClass: 'mfp-img-mobile',
# 		gallery: {
# 			enabled: true,
# 			navigateByImgClick: true,
# 			preload: [0,1], // Will preload 0 - before current, and 1 after the current image
# 		},
# 		image: {
# 			tError: '<a href="%url%">The image #%curr%</a> could not be loaded.',
# 		},
# 		closeMarkup: '<button title="%title%" class="mfp-close" style="position: absolute; top: 0; right: -15px">닫기 <i class="xi-close"></i></button>',
# 		callbacks: {
# 			buildControls: function(){
# 				//this.content.find('figure').append('<a class="download-btn" href="/dn/611c6096c3acc">PDF 다운로드</a>');
# 			},
# 		},
# 	});
# }
#
# $(document).on('click','.mfp-img', function (e) {e.preventDefault();$.magnificPopup.close();youtubopen('46E4TFNVvJM');});
# $(document).on('click','.event2', function (e) {e.preventDefault();setCookie('notToday191111','Y', 1);$.magnificPopup.close();});
# 	function noticeopen() {
# 		$.magnificPopup.open({
# 			items: {
# 				src:'/storage/images/2019/11/ii_k2zv5l920.png',
# 				markup:'<div class="mfp-figure">'+
# 					'<div class="mfp-close"></div>'+
# 					'<div class="mfp-img"><img src="/storage/images/2019/11/ii_k2zv5l920.png"></div>'+
# 					'<div class="mfp-bottom-bar"><div class="mfp-title" style="background:#000;"></div></div></div>',
# 				title:'<table width="100%"><tr><td><a href="javascript:void(0);" class="event2">오늘 하루 열지 않음</a></td></tr></table>'
# 			},
# 			disableOn: 700,
# 			type: 'image',
# 			mainClass: 'mfp-fade',
# 			preloader: true,
# 			fixedContentPos: true,
# 			verticalFit:true
# 		});
# 	}
#
# 	if(getCookie('notToday191111') != 'Y'){
# 		//noticeopen();
# 	}
#
#
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());gtag('config', 'UA-112394055-1');
#
# 	function scrolltop(oj){
# 		var scrollPosition = $('#'+oj).offset().top;
# 		var navPosition = $('.navigator_menu').offset().top;
#
# 		$('html, body').stop().animate({scrollTop : scrollPosition-(navPosition+30)}, 300);
# 		$('#'+oj);
# 	}
# </script>
# </body>
# </html>

# %%
## request가 막혀 미리 받아놓은 csv파일로 분석

# %% [markdown]
# # csv파일로 감정분석

# %%
pet = pd.read_csv('./data/petition.csv')
pet
# Out:
#         article_id       start         end  answered  votes  category  \
# 0               21  2017-08-19  2017-11-17         0      9     안전/환경
# 1               22  2017-08-19  2017-11-17         0     17        기타
# 2               23  2017-08-19  2017-09-03         0      0        미래
# 3               24  2017-08-19  2017-08-26         0     53       일자리
# 4               25  2017-08-19  2017-09-03         0      0        미래
# ...            ...         ...         ...       ...    ...       ...
# 377751      492039  2019-01-09  2019-02-08         0     48    인권/성평등
# 377752      492040  2019-01-09  2019-02-08         0      5      정치개혁
# 377753      492041  2019-01-09  2019-02-08         0      1  외교/통일/국방
# 377754      492042  2019-01-09  2019-02-08         0      4      정치개혁
# 377755      492043  2019-01-09  2019-02-08         0      1        행정
#
#                                                     title  \
# 0                                     스텔라 데이지호에 대한 제안입니다.
# 1                                          비리제보처를 만들어주세요.
# 2                                                제2의 개성공단
# 3                                공공기관 무조건적인 정규직전환을 반대합니다.
# 4                                                제2의 개성공단
# ...                                                   ...
# 377751                      박종철 의원. 폭행구속수사 및 의원직 박탈 청원합니다
# 377752  각 정상들은 들으시요 국회의원을 학력과 무관한 양심 및  윤리가 있는  서민이 되어...
# 377753                                   남한땅에 옥류관을 오픈해주세요
# 377754                                   임종석실장님 수고많으셨습니다.
# 377755         예천군과 환경부를 규탄합니다. 어불성설인 가축사육 관련 법규를 개정해주세요!
#
#                                                   content
# 0       스텔라 데이지호에 대한 제안입니다.\n3월31일 스텔라 데이지호가 침몰하고 5달째가...
# 1       현 정부에 국민들이 가장 원하는 것은 부패척결입니다.  우리 사회에 각종 비리들이 ...
# 2       만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...
# 3       현정부에서 정규직 일자리를 늘리는 것에 찬성합니다. 그런데 공공기관 비정규직들은 인...
# 4       만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...
# ...                                                   ...
# 377751  나라돈으로 해외연수가서 현지 동반 가이드를 때려 안경 파편이 얼굴이 꽂혔답니다. C...
# 377752  각 정당은 현재 국회의원 개개인을 심사하면 지탄받은 사람이 국\n회를 장악하고 있습...
# 377753  말그대로 옥류관을 여기서 열면 진짜 재미있고 신나는 일이 일어날것 같은 느낌이 듭니...
# 377754  범죄정권이후 많은 어려움을 갖고 시작한 국민의정부.\n저급한 자칭 보수단체와 한국당...
# 377755  해당 사건이 발생한 곳은 요즘은 매체에서 매일 나오는 곳으로 '군의원의 외유성 해외...
#
# [377756 rows x 8 columns]

# %% [markdown]
# ## csv파일 전처리

# %%
pet = pet.sample(frac=0.1).copy()
pet.head()
# Out:
#         article_id       start         end  answered  votes category  \
# 84218        95001  2018-01-14  2018-02-13         0      2       미래
# 375338      488888  2019-01-06  2019-02-05         0      0       미래
# 33109        34437  2017-11-11  2017-12-11         0      0     정치개혁
# 207813      268592  2018-06-11  2018-07-11         0      1       기타
# 362573      471751  2018-12-17  2019-01-16         0      0       미래
#
#                      title                                            content
# 84218                 가상화퍠  가상화폐는 브럭체인 기반으로 미래의 성장동력 임에도 불구하고  폐쇄 운운 하늗것은 ...
# 375338  이나라애서  살기  힘들  장애인  안.녕하세요 대통령님   저는  장애인  조혜순이라고합니다  제  나이는   38살...
# 33109           이명박출국금지 구속  아집과 독선으로 국토를 절단내고 국고를 탕진한 자다. 온갖 협잡과 거짓으로 국민을 ...
# 207813    국가 공휴일에 학원을 가요!!  6월 13일에 안산 학원에  나옵니다. 국가 지정 임시 공휴일에 학원을 왜 나와야 ...
# 362573       백종원대표를 국회의원으로  어려운말말고 그냥 결론만 얘기하자면\n방송의힘도 있지만 그 가게만 잘되는게 아닌 상...

# %%
pet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37776 entries, 84218 to 90531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   article_id  37776 non-null  int64
#  1   start       37776 non-null  datetime64[ns]
#  2   end         37776 non-null  datetime64[ns]
#  3   answered    37776 non-null  int64
#  4   votes       37776 non-null  int64
#  5   category    37776 non-null  object
#  6   title       37776 non-null  object
#  7   content     37776 non-null  object
#  8   duration    37776 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(3), object(3), timedelta64[ns](1)
# memory usage: 2.9+ MB

# %%
pet['start'] = pd.to_datetime(pet['start'])
pet['end'] = pd.to_datetime(pet['end'])

# %%
pet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37776 entries, 84218 to 90531
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   article_id  37776 non-null  int64
#  1   start       37776 non-null  datetime64[ns]
#  2   end         37776 non-null  datetime64[ns]
#  3   answered    37776 non-null  int64
#  4   votes       37776 non-null  int64
#  5   category    37776 non-null  object
#  6   title       37776 non-null  object
#  7   content     37776 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(3)
# memory usage: 2.6+ MB

# %%
pet['duration'] = pet['end'] - pet['start']

# %%
pet.head()
# Out:
#         article_id      start        end  answered  votes category  \
# 84218        95001 2018-01-14 2018-02-13         0      2       미래
# 375338      488888 2019-01-06 2019-02-05         0      0       미래
# 33109        34437 2017-11-11 2017-12-11         0      0     정치개혁
# 207813      268592 2018-06-11 2018-07-11         0      1       기타
# 362573      471751 2018-12-17 2019-01-16         0      0       미래
#
#                      title                                            content  \
# 84218                 가상화퍠  가상화폐는 브럭체인 기반으로 미래의 성장동력 임에도 불구하고  폐쇄 운운 하늗것은 ...
# 375338  이나라애서  살기  힘들  장애인  안.녕하세요 대통령님   저는  장애인  조혜순이라고합니다  제  나이는   38살...
# 33109           이명박출국금지 구속  아집과 독선으로 국토를 절단내고 국고를 탕진한 자다. 온갖 협잡과 거짓으로 국민을 ...
# 207813    국가 공휴일에 학원을 가요!!  6월 13일에 안산 학원에  나옵니다. 국가 지정 임시 공휴일에 학원을 왜 나와야 ...
# 362573       백종원대표를 국회의원으로  어려운말말고 그냥 결론만 얘기하자면\n방송의힘도 있지만 그 가게만 잘되는게 아닌 상...
#
#        duration
# 84218   30 days
# 375338  30 days
# 33109   30 days
# 207813  30 days
# 362573  30 days

# %%
# 30일 이상 게시가 되고, answer을 받은 청원목록

# %%
pet.info() # duration의 데이터타입 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37776 entries, 84218 to 90531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   article_id  37776 non-null  int64
#  1   start       37776 non-null  datetime64[ns]
#  2   end         37776 non-null  datetime64[ns]
#  3   answered    37776 non-null  int64
#  4   votes       37776 non-null  int64
#  5   category    37776 non-null  object
#  6   title       37776 non-null  object
#  7   content     37776 non-null  object
#  8   duration    37776 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(3), object(3), timedelta64[ns](1)
# memory usage: 2.9+ MB

# %%
pet[(pet['duration'] >= '30 days') & (pet['answered']==1)]
# Out:
#         article_id      start        end  answered   votes     category  \
# 131327      157046 2018-03-03 2018-04-02         1  222770       인권/성평등
# 43992        45581 2017-11-17 2017-12-17         1  281985         보건복지
# 209715      270921 2018-06-14 2018-07-14         1  219987  문화/예술/체육/언론
# 84324        95138 2018-01-14 2018-02-13         1  219395     교통/건축/국토
#
#                                            title  \
# 131327               단역배우 자매 자살 사건 제발 재조사를 해주세여.
# 43992      권역외상센터 (이국종 교수님) 추가적, 제도적, 환경적, 인력 지원
# 209715    대구 동성로/서울 시청광장   퀴어행사(동성애축제)개최를 반대합니다.
# 84324   대전 아파트 단지내 횡단보도 교통사고..가해자의 만행과 도로교통법의 허점
#
#                                                   content duration
# 131327  http://news.naver.com/main/read.nhn?mode=LSD&m...  30 days
# 43992   청원사항)\n중증외상분야의 추가적, 제도적, 환경적, 인력 지원 방안마련\n현 의료...  30 days
# 209715  서울 시청/대구 동성로  퀴어행사(동성애축제)개최를 반대합니다.\n대구 6월 23일...  30 days
# 84324   1. 2017년 10월 16일 19시10분경 대전 맑은 아침 아파트 단지 내 횡단보...  30 days

# %%
# 분야별 청원
pet['category'].value_counts()
# Out:
# 정치개혁           5868
# 기타             4633
# 인권/성평등         3424
# 안전/환경          2922
# 교통/건축/국토       2693
# 외교/통일/국방       2581
# 육아/교육          2515
# 보건복지           2288
# 일자리            2192
# 행정             1919
# 문화/예술/체육/언론    1742
# 미래             1736
# 경제민주화          1642
# 성장동력            700
# 반려동물            393
# 저출산/고령화대책       362
# 농산어촌            166
# Name: category, dtype: int64

# %%
pet['category'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53685 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48169 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48124 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52293 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54785 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 53440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54872 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 53685 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48169 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50977 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48124 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52293 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\21ckw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52492 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## pet_by_moon 데이터프레임 설정

# %%
pet_by_moon = pet.sort_values('start')
pet_by_moon
# Out:
#         article_id      start        end  answered  votes     category  \
# 27              49 2017-08-19 2017-11-17         0     27          일자리
# 32              54 2017-08-19 2017-08-26         0    144          일자리
# 35              58 2017-08-19 2017-11-17         0     21          일자리
# 41              64 2017-08-20 2017-09-04         0      1        육아/교육
# 66              89 2017-08-20 2017-11-18         0   1101          일자리
# ...            ...        ...        ...       ...    ...          ...
# 376805      490873 2019-01-09 2019-02-08         0      7         보건복지
# 377425      491616 2019-01-09 2019-02-08         0      1  문화/예술/체육/언론
# 377159      491317 2019-01-09 2019-02-08         0     61       인권/성평등
# 377548      491786 2019-01-09 2019-02-08         0      2         성장동력
# 377072      491213 2019-01-09 2019-02-08         0     15          일자리
#
#                                                  title  \
# 27                           공정한사회 절차가 바른사회가 되기를 원합니다.
# 32                                  공정한 기회 균등이 보장되는 사회
# 35      국토교통부와 한국주택협회가 행한 부당한 행위와 권력남용에 대한 내용을 청원드립니다.
# 41                               대한민국 학원에대한 법을 신설하여주십쇼
# 66                    고용노동부 일반상담원 처우개선을 위한 예산편성 촉구 청원서
# ...                                                ...
# 376805                                    전 아들만 둘 있습니다
# 377425                             도쿄올림픽 불참 보이콧 청원합니다.
# 377159                  예천군 박종철 의윈 물러나세요. 거짓말장이 폭행범입니다
# 377548         30명 40명 규모 미니의대,약대,치대 정원 100명 이상 으로 늘려야
# 377072                         교사도 9호봉이 아니라 1호봉부터 시작해야
#
#                                                   content duration
# 27      문재인대통령과 교육부장관님!\n교사 정규직은 임용고시라는 제도를 통해 정교사가 될 ...  90 days
# 32      안녕하십니까.저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다. ...   7 days
# 35      안녕하세요? 존경하고 지지하는 문재인 대통령님!\n저는 성남시 분당구 정자동 주택전...  90 days
# 41      안녕하십니까!\n저는 대구에거주하고 중학교3학년인 학생입니다.... 저는 다름이 아...  15 days
# 66      문재인정부 출범 100일을 맞이하는 기자회견이 8월17일 청와대에서 열리고 지지율은...  90 days
# ...                                                   ...      ...
# 376805  전 아들만 둘 있습니다\n둘다\n이왕이면\n이웃을 살피고\n누구가를 도우면 사는것도...  30 days
# 377425  일본의 군국주의 부활을 위한 몸짓이 갈수록 심화되고 있습니다.\n우방국간 상호 과실...  30 days
# 377159  국민을 함부로 대하는 의원은 자격이 없으며 물러남이 마땅합 니다.  거짓말장이. 폭...  30 days
# 377548  30명\n40명 규모의\n미니 약대\n미니 의대\n미니 치대\n미니 한의대 등을\n...  30 days
# 377072  이제 십중팔구는 대학가는 시대입니다.\n형편이 어려우면 정부에서 대학교육까지 등록금...  30 days
#
# [37776 rows x 9 columns]

# %% [markdown]
# ## 월별 등장빈도가 가장 많은 상위 5개 단어를 출력

# %%
# 년+월 열 만들어주기
pet_by_moon['yearmonth'] = pet_by_moon['start'].astype('str').apply(lambda x : x[:7])
pet_by_moon.head()
# Out:
#     article_id      start        end  answered  votes category  \
# 27          49 2017-08-19 2017-11-17         0     27      일자리
# 32          54 2017-08-19 2017-08-26         0    144      일자리
# 35          58 2017-08-19 2017-11-17         0     21      일자리
# 41          64 2017-08-20 2017-09-04         0      1    육아/교육
# 66          89 2017-08-20 2017-11-18         0   1101      일자리
#
#                                              title  \
# 27                       공정한사회 절차가 바른사회가 되기를 원합니다.
# 32                              공정한 기회 균등이 보장되는 사회
# 35  국토교통부와 한국주택협회가 행한 부당한 행위와 권력남용에 대한 내용을 청원드립니다.
# 41                           대한민국 학원에대한 법을 신설하여주십쇼
# 66                고용노동부 일반상담원 처우개선을 위한 예산편성 촉구 청원서
#
#                                               content duration yearmonth
# 27  문재인대통령과 교육부장관님!\n교사 정규직은 임용고시라는 제도를 통해 정교사가 될 ...  90 days   2017-08
# 32  안녕하십니까.저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다. ...   7 days   2017-08
# 35  안녕하세요? 존경하고 지지하는 문재인 대통령님!\n저는 성남시 분당구 정자동 주택전...  90 days   2017-08
# 41  안녕하십니까!\n저는 대구에거주하고 중학교3학년인 학생입니다.... 저는 다름이 아...  15 days   2017-08
# 66  문재인정부 출범 100일을 맞이하는 기자회견이 8월17일 청와대에서 열리고 지지율은...  90 days   2017-08

# %% [markdown]
# ## 자연어 전처리

# %%
# konlpy 작동확인
from konlpy.tag import Komoran
kor = Komoran()

# %%
kor.nouns('가슴 아파도 나 이렇게 웃어요')
# Out:
# ['가슴']

# %% [markdown]
# #### 한글+공백 만 남기기

# %%
import re
def text_clean(doc):
    doc = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ ]','',doc)
    doc = re.sub('\s+',' ',doc)
    return doc

# %%
# 제거 후 공백이 한칸 남음 -> 빈값 처리해줘야함
te = 'a nnndfsdf; erwk3      dkf;  '
text_clean(te)
# Out:
# ' '

# %%
pet_by_moon['clean_content'] = pet_by_moon['content'].apply(text_clean)

# %%
pet_by_moon.head()
# Out:
#     article_id      start        end  answered  votes category  \
# 27          49 2017-08-19 2017-11-17         0     27      일자리
# 32          54 2017-08-19 2017-08-26         0    144      일자리
# 35          58 2017-08-19 2017-11-17         0     21      일자리
# 41          64 2017-08-20 2017-09-04         0      1    육아/교육
# 66          89 2017-08-20 2017-11-18         0   1101      일자리
#
#                                              title  \
# 27                       공정한사회 절차가 바른사회가 되기를 원합니다.
# 32                              공정한 기회 균등이 보장되는 사회
# 35  국토교통부와 한국주택협회가 행한 부당한 행위와 권력남용에 대한 내용을 청원드립니다.
# 41                           대한민국 학원에대한 법을 신설하여주십쇼
# 66                고용노동부 일반상담원 처우개선을 위한 예산편성 촉구 청원서
#
#                                               content duration yearmonth  \
# 27  문재인대통령과 교육부장관님!\n교사 정규직은 임용고시라는 제도를 통해 정교사가 될 ...  90 days   2017-08
# 32  안녕하십니까.저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다. ...   7 days   2017-08
# 35  안녕하세요? 존경하고 지지하는 문재인 대통령님!\n저는 성남시 분당구 정자동 주택전...  90 days   2017-08
# 41  안녕하십니까!\n저는 대구에거주하고 중학교3학년인 학생입니다.... 저는 다름이 아...  15 days   2017-08
# 66  문재인정부 출범 100일을 맞이하는 기자회견이 8월17일 청와대에서 열리고 지지율은...  90 days   2017-08
#
#                                         clean_content
# 27  문재인대통령과 교육부장관님교사 정규직은 임용고시라는 제도를 통해 정교사가 될 수 있...
# 32  안녕하십니까저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다 타시...
# 35  안녕하세요 존경하고 지지하는 문재인 대통령님저는 성남시 분당구 정자동 주택전시관 입...
# 41  안녕하십니까저는 대구에거주하고 중학교학년인 학생입니다 저는 다름이 아니라 어느 학생...
# 66  문재인정부 출범 일을 맞이하는 기자회견이 월일 청와대에서 열리고 지지율은 여전히 에...

# %%
pet_by_moon.shape
# Out:
# (37776, 11)

# %%
pet_by_moon[pet_by_moon['clean_content']==np.NaN]
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content]
# Index: []

# %%
pet_by_moon[pet_by_moon['clean_content'].isnull()]
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content]
# Index: []

# %% [markdown]
# #### 빈값처리

# %%
# 빈값 확인
pet_by_moon[pet_by_moon['clean_content']== '']
# Out:
#         article_id      start        end  answered  votes     category  \
# 5073          5114 2017-09-05 2017-12-04         0      1        안전/환경
# 9143          9196 2017-09-05 2017-12-04         0      0        안전/환경
# 6459          6504 2017-09-05 2017-10-05         0      0           미래
# 3784          3825 2017-09-05 2017-09-12         0      0         정치개혁
# 6443          6488 2017-09-05 2017-12-04         0      0        육아/교육
# 11380        11435 2017-09-06 2017-12-05         0      0        안전/환경
# 10173        10227 2017-09-06 2017-09-13         0      0         정치개혁
# 12996        13057 2017-09-09 2017-12-08         0      1       인권/성평등
# 13508        13575 2017-09-12 2017-09-19         0      0           미래
# 14434        14519 2017-09-18 2017-10-18         0      0     외교/통일/국방
# 14722        14828 2017-09-19 2017-10-19         0      1        육아/교육
# 15546        15659 2017-09-21 2017-10-21         0      0          일자리
# 25239        26291 2017-11-05 2017-12-05         0      3  문화/예술/체육/언론
# 38034        39393 2017-11-11 2017-12-11         0      4         정치개혁
# 37505        38850 2017-11-11 2017-12-11         0      1         정치개혁
# 33323        34651 2017-11-11 2017-12-11         0      0         정치개혁
# 33954        35283 2017-11-11 2017-12-11         0      0         정치개혁
# 40665        42124 2017-11-12 2017-12-12         0      0         정치개혁
# 43471        45030 2017-11-16 2017-12-16         0      0         정치개혁
# 58788        61767 2017-12-08 2018-01-07         0      0         정치개혁
# 61914        65454 2017-12-13 2018-01-12         0      0         정치개혁
# 61541        65018 2017-12-13 2018-01-12         0      0         보건복지
# 62047        65602 2017-12-14 2018-01-13         0      2         정치개혁
# 62051        65606 2017-12-14 2018-01-13         0      1         정치개혁
# 64400        68331 2017-12-17 2018-01-16         0      0         보건복지
# 64330        68254 2017-12-17 2018-01-16         0      0     외교/통일/국방
# 66887        71264 2017-12-22 2018-01-21         0      0         성장동력
# 68140        72585 2017-12-24 2018-01-23         0      0       인권/성평등
# 77341        84612 2018-01-11 2018-02-10         0      0         성장동력
# 87602        99376 2018-01-17 2018-02-16         0      0         정치개혁
# 109367      131081 2018-02-06 2018-03-08         0     22         정치개혁
# 112239      134685 2018-02-08 2018-03-10         0      2           기타
# 112676      135219 2018-02-09 2018-03-11         0      0           기타
# 116906      140104 2018-02-15 2018-03-17         0      0           기타
# 117422      140734 2018-02-16 2018-03-18         0      0           기타
# 122515      146638 2018-02-22 2018-03-24         0      2           기타
# 128017      153150 2018-02-27 2018-03-29         0     81     외교/통일/국방
# 144299      173470 2018-03-23 2018-04-22         0      6         정치개혁
# 145790      175506 2018-03-26 2018-04-25         0      7        육아/교육
# 154996      187655 2018-04-06 2018-05-06         0      1         정치개혁
# 154993      187649 2018-04-06 2018-05-06         0      0         정치개혁
# 197859      253878 2018-05-30 2018-06-29         0      0  문화/예술/체육/언론
# 202801      261931 2018-06-04 2018-07-04         0      0           기타
# 240611      311677 2018-07-19 2018-08-18         0      1         성장동력
# 242950      314557 2018-07-22 2018-08-21         0     27           기타
# 253185      328257 2018-08-03 2018-09-02         0      1        안전/환경
# 274055      355750 2018-08-26 2018-09-25         0      5     외교/통일/국방
# 276407      358869 2018-08-29 2018-09-28         0     25           미래
# 324079      422121 2018-10-27 2018-11-26         0      0        육아/교육
# 329101      428406 2018-11-01 2018-12-01         0     10     외교/통일/국방
# 329625      429055 2018-11-02 2018-12-02         0     22         정치개혁
# 339651      441618 2018-11-14 2018-12-14         0     51        육아/교육
# 351097      456548 2018-11-30 2018-12-30         0      0         정치개혁
# 352467      458531 2018-12-02 2019-01-01         0      0        육아/교육
# 356023      463146 2018-12-07 2019-01-06         0      0       인권/성평등
# 371866      484189 2019-01-01 2019-01-31         0      6           미래
# 375934      489669 2019-01-07 2019-02-06         0      4           기타
#
#                                                     title  \
# 5073                                           청소년 보호법 폐지
# 9143                                          천소년법 폐지해주십쇼
# 6459                                             청소년 법 폐지
# 3784                                       청소년법 폐지 찬성합니다.
# 6443                                       미래를 쉬게 할 수 없어요
# 11380                                          청소년법폐지해주세요
# 10173                                           소년법 폐지 동의
# 12996                                           청소년보호법 폐지
# 13508                                                   .
# 14434                                            fwqfwqfe
# 14722   http://www1.president.go.kr/petitions/13618?na...
# 15546   성과연봉제  폐지해주시기 바랍니다.이미 2년전부터 성과연봉제 실행중인 금융기관이 있습니다
# 25239                  피피온라인4 저사양도 렉없이 게임 할 수 있었으면 좋겠습니다.
# 38034             개별청원 하지마시고 위 추천순 2번째가셔서 동의하셔야 힘이 합쳐집니다.
# 37505                                        이명박 대통령 출국금지
# 33323                                           이명박 출국 금지
# 33954                                      이명박 출국 금지 및 구속
# 40665                                             이명박출국금지
# 43471   http://m.dcinside.com/view.php?id=stock_new2&n...
# 58788                      피해자의 돈으로 로비하고, 그 돈을 받는 정관계 인사들
# 61914                          지금이 몇년도 인데 신분제를 운영하고 있어 ㅡㅡ
# 61541                                                  ss
# 62047                              내가 공무원 해봤는데 공무원 일안하던데?
# 62051                        비트코인을 규제하려고 하지말고 이해하려고 노력해라.
# 64400                                           노인 장기요양보험
# 64330                                                   d
# 66887                                               동의합니다
# 68140                                       호ㅗㅗㅗㅗㅗㅗㅗㅗㅗㅗㅗㅗ
# 77341                  청원신청 하지 마시고 가상화폐 폐지 청원 공식링크에 동의하세요
# 87602                         가난한 서민들은 일확천금으로 돈벌면 안됩니~꽈?~
# 109367                    정형식  동의 11만명..여기에서 동의글 올려주세여...
# 112239                              세타2 엔진 동의 부탁드립니다 20만명
# 112676                         세타2 엔진 동의 부탁드립니다 제발...링크있음
# 116906                         세타2 엔진 동의 부탁드립니다 제발...링크있음
# 117422                         세타2 엔진 동의 부탁드립니다 제발...링크있음
# 122515                                     세타2 엔진 청원 링크있음
# 128017  천안함 재조사 동의 한곳으로 모아주세요.:https://www1.president....
# 144299                                       헌법에 군인권 보장하라
# 145790                       고3분들! 청원20만넘을려면 밑에 주소로 가야되요!
# 154996                            사법부는 무슨 배쨩으로 청원게시판 안만드나
# 154993                             국회는 무슨 배짱으로 청원게시판 안만드나
# 197859                           리그오브레전드 아시안게임으로 채택부탁드립니다
# 202801                      적폐청산에는 잘못된 정책의 청산도 포함되어야 합니다.
# 240611                                                  ㆍ
# 242950  SBS가 한국당을 손잡고 이재명 안좋은 프로그램을 증거도 없이 내보내는지 검찰은 확...
# 253185                                        뉴스 보고 느끼세요.
# 274055                           나라를 위해 희생한 자들에게 거짓말을 맙시다
# 276407                              우리나라는 공무원만 행복한 나라 같아요
# 324079                                                 jj
# 329101  국방의무 와 예비군 의무 한사람들에게 군가산점 부활해주시고 공무원 및 각종취업에 우...
# 329625                             문재인 탄핵시키고 홍준표 대통령 만듭시다
# 339651                                  예비신부 살인마 얼굴공개해주세요
# 351097      https://www1.president.go.kr/petitions/452618
# 352467                                도와주세요. 성적조작을 막아주세요.
# 356023  이 방 송 좀 청 취 해 주 시 고 공 감 좀 요"https://www.youtub...
# 371866                                     태어나면서한살 폐지해주세요
# 375934                            ***은 과천투기 했는지 여기다 답글달아라
#
#                                                   content duration yearmonth  \
# 5073                                                    .  90 days   2017-09
# 9143                                                    .  90 days   2017-09
# 6459                                                    ㆍ  30 days   2017-09
# 3784                                                    .   7 days   2017-09
# 6443                                                  123  90 days   2017-09
# 11380                                                  ..  90 days   2017-09
# 10173                                                   .   7 days   2017-09
# 12996   http://www1.president.go.kr/petitions/1785?nav...  90 days   2017-09
# 13508                                                   -   7 days   2017-09
# 14434                                            fwqfwqef  30 days   2017-09
# 14722   http://www1.president.go.kr/petitions/13618?na...  30 days   2017-09
# 15546                                                   .  30 days   2017-09
# 25239                                                   ,  30 days   2017-11
# 38034                                                   ㆍ  30 days   2017-11
# 37505                                                  ..  30 days   2017-11
# 33323                                    2017.11.11~12.11  30 days   2017-11
# 33954                                              please  30 days   2017-11
# 40665                                                   .  30 days   2017-11
# 43471   http://m.dcinside.com/view.php?id=stock_new2&n...  30 days   2017-11
# 58788   http://www1.president.go.kr/petitions/61619?na...  30 days   2017-12
# 61914                                                   .  30 days   2017-12
# 61541                                                  ss  30 days   2017-12
# 62047                                                   ?  30 days   2017-12
# 62051                                                   .  30 days   2017-12
# 64400                                                ....  30 days   2017-12
# 64330                                                   d  30 days   2017-12
# 66887                                                   2  30 days   2017-12
# 68140                           kkhhhhhhhhhhhhhhhhhhhhhhh  30 days   2017-12
# 77341   https://www1.president.go.kr/petitions/76020?n...  30 days   2018-01
# 87602                                                 ...  30 days   2018-01
# 109367      https://www1.president.go.kr/petitions/127921  30 days   2018-02
# 112239      https://www1.president.go.kr/petitions/130578  30 days   2018-02
# 112676      https://www1.president.go.kr/petitions/130578  30 days   2018-02
# 116906      https://www1.president.go.kr/petitions/130578  30 days   2018-02
# 117422      https://www1.president.go.kr/petitions/130578  30 days   2018-02
# 122515      https://www1.president.go.kr/petitions/130578  30 days   2018-02
# 128017  https://www1.president.go.kr/petitions/147762\...  30 days   2018-02
# 144299                                                  .  30 days   2018-03
# 145790  https://www1.president.go.kr/petitions/175020?...  30 days   2018-03
# 154996                                                  '  30 days   2018-04
# 154993                                                  -  30 days   2018-04
# 197859                                                  .  30 days   2018-05
# 202801  https://www1.president.go.kr/petitions/261889?...  30 days   2018-06
# 240611                                                  ㆍ  30 days   2018-07
# 242950                                                  ㆍ  30 days   2018-07
# 253185        https://news.v.daum.net/v/20180802194748807  30 days   2018-08
# 274055               http://www.insight.co.kr/news/174451  30 days   2018-08
# 276407                                                  .  30 days   2018-08
# 324079                                                hjh  30 days   2018-10
# 329101                                                  .  30 days   2018-11
# 329625                                                  ㆍ  30 days   2018-11
# 339651   https://news.v.daum.net/v/20181114050153154?f=m,  30 days   2018-11
# 351097      https://www1.president.go.kr/petitions/452618  30 days   2018-11
# 352467   https://m.blog.naver.com/coffeerang/221410847630  30 days   2018-12
# 356023        "https://www.youtube.com/embed/jQQFyZc4fFo"  30 days   2018-12
# 371866  https://www1.president.go.kr/petitions/484158?...  30 days   2019-01
# 375934                                                  .  30 days   2019-01
#
#        clean_content
# 5073
# 9143
# 6459
# 3784
# 6443
# 11380
# 10173
# 12996
# 13508
# 14434
# 14722
# 15546
# 25239
# 38034
# 37505
# 33323
# 33954
# 40665
# 43471
# 58788
# 61914
# 61541
# 62047
# 62051
# 64400
# 64330
# 66887
# 68140
# 77341
# 87602
# 109367
# 112239
# 112676
# 116906
# 117422
# 122515
# 128017
# 144299
# 145790
# 154996
# 154993
# 197859
# 202801
# 240611
# 242950
# 253185
# 274055
# 276407
# 324079
# 329101
# 329625
# 339651
# 351097
# 352467
# 356023
# 371866
# 375934

# %%
# pet_by_moon[pet_by_moon['clean_content'].apply(bool) == False]

# %%
# len(pet_by_moon[pet_by_moon['clean_content'].apply(bool) == False])
# Out:
# 57

# %%
len(pet_by_moon[pet_by_moon['clean_content']== ''])
# Out:
# 57

# %%
pet_by_moon[pet_by_moon['clean_content']== ' ']
# Out:
#         article_id      start        end  answered  votes     category  \
# 54381        56545 2017-12-02 2018-01-01         0      9           기타
# 54721        56952 2017-12-02 2018-01-01         0      2           기타
# 54400        56564 2017-12-02 2018-01-01         0      2  문화/예술/체육/언론
# 198092      254553 2018-05-30 2018-06-29         0      1     외교/통일/국방
#
#                                title  \
# 54381   DELETE AND CLOSE MAMA (MNET)
# 54721            đề nghị xóa bỏ mama
# 54400                     close mnet
# 198092         Hello mr. Moon Jae-in
#
#                                                   content duration yearmonth  \
# 54381   I want the MAMA (MNET) event to be immediately...  30 days   2017-12
# 54721   đề nghị xóa bỏ mama bởi vì quá vô lí EXO chúng...  30 days   2017-12
# 54400                                          close mnet  30 days   2017-12
# 198092  I'm very poor country's president.\nI hope kor...  30 days   2018-05
#
#        clean_content
# 54381
# 54721
# 54400
# 198092

# %%
# 빈값 제거
pet_by_moon = pet_by_moon[pet_by_moon['clean_content']!= '']

# %%
# 제거확인
pet_by_moon[pet_by_moon['clean_content']== '']
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content]
# Index: []

# %%
pet_by_moon.shape
# Out:
# (37719, 11)

# %%
# ' ' 빈값 없애주기
pet_by_moon[pet_by_moon['clean_content']== ' ']
# Out:
#         article_id      start        end  answered  votes     category  \
# 54381        56545 2017-12-02 2018-01-01         0      9           기타
# 54721        56952 2017-12-02 2018-01-01         0      2           기타
# 54400        56564 2017-12-02 2018-01-01         0      2  문화/예술/체육/언론
# 198092      254553 2018-05-30 2018-06-29         0      1     외교/통일/국방
#
#                                title  \
# 54381   DELETE AND CLOSE MAMA (MNET)
# 54721            đề nghị xóa bỏ mama
# 54400                     close mnet
# 198092         Hello mr. Moon Jae-in
#
#                                                   content duration yearmonth  \
# 54381   I want the MAMA (MNET) event to be immediately...  30 days   2017-12
# 54721   đề nghị xóa bỏ mama bởi vì quá vô lí EXO chúng...  30 days   2017-12
# 54400                                          close mnet  30 days   2017-12
# 198092  I'm very poor country's president.\nI hope kor...  30 days   2018-05
#
#        clean_content
# 54381
# 54721
# 54400
# 198092

# %%
# 빈값 제거
pet_by_moon = pet_by_moon[pet_by_moon['clean_content']!= ' ']

# %%
# 제거 확인
pet_by_moon[pet_by_moon['clean_content']== ' ']
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content]
# Index: []

# %% [markdown]
# #### 토큰화

# %%
# 빈값 처리를 안해주면 Java오류가 남!
# 7분 시간 소요 왜 mecab을 쓰려고 하는 지 알 것 같다

clean_tokens = []
for w in pet_by_moon['clean_content']:
    token = kor.nouns(w)
    clean_tokens.append(token)
    
pet_by_moon['clean_tokens']= clean_tokens

# %%
pet_by_moon.head()
# Out:
#      article_id      start        end  answered  votes  category  \
# 17           38 2017-08-19 2017-08-26         0      0  외교/통일/국방
# 36           59 2017-08-19 2017-10-18         0      2      반려동물
# 1            22 2017-08-19 2017-11-17         0     17        기타
# 5            26 2017-08-19 2017-08-26         0      2      보건복지
# 122         146 2017-08-20 2017-09-04         0     15  교통/건축/국토
#
#                                                  title  \
# 17                              한중관계 사드 갈등 해소방법 찾았습니다.
# 36    유기동물 재발방지를 위한 반려동물 번식업, 반려동물 판매업, 반려동물 등록법 개정 요구
# 1                                       비리제보처를 만들어주세요.
# 5    보건복지부 부령 제339호중 “특수의료장비 운영에 관한 규칙” 중  불합리한 행정제...
# 122                     8.2 부동산 대책 중 재개발/재건축 관련 청원입니다.
#
#                                                content duration yearmonth  \
# 17   문재인 대통령님 한중관계 사드 갈등 해소방법 찾았습니다.\n시진핑 주석 한테 이렇게...   7 days   2017-08
# 36   안녕하세요.\n사람과 동물과 자연을 소중하게 생각하는 국민으로서 청원합니다.\n우리...  60 days   2017-08
# 1    현 정부에 국민들이 가장 원하는 것은 부패척결입니다.  우리 사회에 각종 비리들이 ...  90 days   2017-08
# 5    청원인  왕 기 운\n서울 도봉구 창동 삼성아파트 101-1103호\n청원취지\n보...   7 days   2017-08
# 122  안녕하세요. 요즘 참 바람잘 날 없는 대한민국입니다. 대외와 대내가 모두 많은 위협...  15 days   2017-08
#
#                                          clean_content  \
# 17   문재인 대통령님 한중관계 사드 갈등 해소방법 찾았습니다시진핑 주석 한테 이렇게 말해...
# 36   안녕하세요사람과 동물과 자연을 소중하게 생각하는 국민으로서 청원합니다우리나라는 매년...
# 1    현 정부에 국민들이 가장 원하는 것은 부패척결입니다 우리 사회에 각종 비리들이 많은...
# 5    청원인 왕 기 운서울 도봉구 창동 삼성아파트 호청원취지보건복지부 부령 제호중 특수의...
# 122  안녕하세요 요즘 참 바람잘 날 없는 대한민국입니다 대외와 대내가 모두 많은 위협과 ...
#
#                                           clean_tokens
# 17   [문재인, 대통령, 중, 관계, 사드, 갈등, 해소, 방법, 습, 니다, 시진핑, ...
# 36   [안녕하세요, 사람과, 동물, 자연, 생각, 국민, 청원, 합, 니다, 우리나라, ...
# 1    [정부, 국민, 것, 부패, 척결, 사회, 각종, 비리, 내부, 고발, 내부고발자,...
# 5    [청원, 왕, 기, 서울, 도봉구, 창동, 삼성, 아파트, 호, 청원, 취지, 보건...
# 122  [안녕하세요, 요즘, 바람, 날, 대한민국, 대외, 대내, 위협, 도전, 직면, 와...

# %% [markdown]
# #### 빈값처리

# %%
pet_by_moon[pet_by_moon['clean_tokens'] == '' ]
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content, clean_tokens]
# Index: []

# %%
# 빈 리스트 찾기
pet_by_moon[pet_by_moon['clean_tokens'].apply(bool) == False]
# Out:
#         article_id      start        end  answered  votes  category  \
# 1538          1568 2017-09-02 2017-12-01         0      0      보건복지
# 2598          2637 2017-09-04 2017-09-19         0      0     안전/환경
# 3385          3426 2017-09-04 2017-12-03         0      0    인권/성평등
# 3487          3528 2017-09-05 2017-12-04         0      0    인권/성평등
# 9123          9176 2017-09-05 2017-09-12         0      0  외교/통일/국방
# ...            ...        ...        ...       ...    ...       ...
# 367109      477780 2018-12-24 2019-01-23         0      1     안전/환경
# 368255      479311 2018-12-26 2019-01-25         0      3  외교/통일/국방
# 372135      484553 2019-01-01 2019-01-31         0      1      정치개혁
# 375574      489198 2019-01-07 2019-02-06         0      4      보건복지
# 376283      490167 2019-01-08 2019-02-07         0      0        미래
#
#                                            title  \
# 1538                                           ㄷ
# 2598                           청소년 보호법 폐지해주세요 제발
# 3385                         소년법 폐지 또는 개안을 원합니다.
# 3487                         소년법 폐지 또는 개안을 원합니다.
# 9123                                          나라
# ...                                          ...
# 367109  핸드폰  해킹범 및 사주범을    사형수  사형범으로 취급하여  주십시요
# 368255                                       모병제
# 372135                                        정치
# 375574                                   세상살기싫어요
# 376283          한국 학부모님들 제발 학생들 일본으로 유학 보내지말아주세요
#
#                                                   content duration yearmonth  \
# 1538                                                   ㄱㄴ  90 days   2017-09
# 2598                                                  제발요  15 days   2017-09
# 3385                                             제발 들어주세요  90 days   2017-09
# 3487                                             제발 들어주세요  90 days   2017-09
# 9123                                                    ㅇ   7 days   2017-09
# ...                                                   ...      ...       ...
# 367109                                                ㅡ ㅡ  30 days   2018-12
# 368255  우리나라도모병제를시행해야됩니다\n20대꽃다운청춘들이무슨죄로군이란감옥으로끌려가야되나요...  30 days   2018-12
# 372135                                                이것참  30 days   2019-01
# 375574  병신돼니모든것포기하고싶네요생활보호대상자돼서지원금나온것쓸데너무없고늙어서이혼후홀로남았는...  30 days   2019-01
# 376283                                          왜그러십니까 정말  30 days   2019-01
#
#                                             clean_content clean_tokens
# 1538                                                   ㄱㄴ           []
# 2598                                                  제발요           []
# 3385                                             제발 들어주세요           []
# 3487                                             제발 들어주세요           []
# 9123                                                    ㅇ           []
# ...                                                   ...          ...
# 367109                                                ㅡ ㅡ           []
# 368255  우리나라도모병제를시행해야됩니다대꽃다운청춘들이무슨죄로군이란감옥으로끌려가야되나요푼돈주면...           []
# 372135                                                이것참           []
# 375574  병신돼니모든것포기하고싶네요생활보호대상자돼서지원금나온것쓸데너무없고늙어서이혼후홀로남았는...           []
# 376283                                          왜그러십니까 정말           []
#
# [196 rows x 12 columns]

# %%
# 빈값 제거
pet_by_moon = pet_by_moon[pet_by_moon['clean_tokens'].apply(bool) == True]

# %%
# 제거 확인
pet_by_moon[pet_by_moon['clean_tokens'].apply(bool) == False]
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content, clean_tokens]
# Index: []

# %% [markdown]
# #### stopword 제외시키기

# %%
st_df = pd.read_csv('./data/stopwords-ko.txt',header = None)
st_list = st_df[0].tolist()

def remove_stwords(doc):
    doc = [w for w in doc if w not in st_list]
    doc = ' '.join(doc)
    return doc

# %%
pet_by_moon['remove_clean_tokens'] = pet_by_moon['clean_tokens'].apply(remove_stwords)
# Out:
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_17412/3851306810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_by_moon['remove_clean_tokens'] = pet_by_moon['clean_tokens'].apply(remove_stwords)

# %%
pet_by_moon.head()
# Out:
#     article_id      start        end  answered  votes category  \
# 27          49 2017-08-19 2017-11-17         0     27      일자리
# 32          54 2017-08-19 2017-08-26         0    144      일자리
# 35          58 2017-08-19 2017-11-17         0     21      일자리
# 41          64 2017-08-20 2017-09-04         0      1    육아/교육
# 66          89 2017-08-20 2017-11-18         0   1101      일자리
#
#                                              title  \
# 27                       공정한사회 절차가 바른사회가 되기를 원합니다.
# 32                              공정한 기회 균등이 보장되는 사회
# 35  국토교통부와 한국주택협회가 행한 부당한 행위와 권력남용에 대한 내용을 청원드립니다.
# 41                           대한민국 학원에대한 법을 신설하여주십쇼
# 66                고용노동부 일반상담원 처우개선을 위한 예산편성 촉구 청원서
#
#                                               content duration yearmonth  \
# 27  문재인대통령과 교육부장관님!\n교사 정규직은 임용고시라는 제도를 통해 정교사가 될 ...  90 days   2017-08
# 32  안녕하십니까.저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다. ...   7 days   2017-08
# 35  안녕하세요? 존경하고 지지하는 문재인 대통령님!\n저는 성남시 분당구 정자동 주택전...  90 days   2017-08
# 41  안녕하십니까!\n저는 대구에거주하고 중학교3학년인 학생입니다.... 저는 다름이 아...  15 days   2017-08
# 66  문재인정부 출범 100일을 맞이하는 기자회견이 8월17일 청와대에서 열리고 지지율은...  90 days   2017-08
#
#                                         clean_content  \
# 27  문재인대통령과 교육부장관님교사 정규직은 임용고시라는 제도를 통해 정교사가 될 수 있...
# 32  안녕하십니까저는 인천에서 지방으로 전출을 희망하는 별거 부부이자 중등교사입니다 타시...
# 35  안녕하세요 존경하고 지지하는 문재인 대통령님저는 성남시 분당구 정자동 주택전시관 입...
# 41  안녕하십니까저는 대구에거주하고 중학교학년인 학생입니다 저는 다름이 아니라 어느 학생...
# 66  문재인정부 출범 일을 맞이하는 기자회견이 월일 청와대에서 열리고 지지율은 여전히 에...
#
#                                          clean_tokens  \
# 27  [문재인, 대통령, 교육부, 장관, 교사, 정규, 직, 임용, 고시, 제도, 정교,...
# 32  [안녕하십니까, 인천, 지방, 전출, 희망, 별거, 부부, 중등, 교사, 시도, 전...
# 35  [안녕하세요, 존경, 지지, 문재인, 대통령, 성남시, 분당구, 정자동, 주택, 전...
# 41  [안녕하십니까, 대구, 거주, 중학교, 학년, 학생, 학생, 학원, 학원, 이란, ...
# 66  [문재인, 정부, 출범, 일, 기자회견, 월, 청와대, 지지, 고공, 행진, 있다,...
#
#                                   remove_clean_tokens
# 27  문재인 대통령 교육부 장관 교사 정규 직 임용 고시 제도 정교 사가 수 기간 교사 ...
# 32  안녕하십니까 인천 지방 전출 희망 별거 부부 중등 교사 시도 전출 성공 하루 가족 ...
# 35  안녕하세요 존경 지지 문재인 대통령 성남시 분당구 정자동 주택 전시관 입 점 업체 ...
# 41  안녕하십니까 대구 거주 중학교 학년 학생 학생 학원 학원 이란 자체 학생 공부 밑 ...
# 66  문재인 정부 출범 기자회견 청와대 지지 고공 행진 그간 사회 만연 적 폐 청산 소통...

# %%
# 전처리하는 중 빈리스트값들이 들어가 있는것을 확인

pet_by_moon[pet_by_moon['clean_tokens'].apply(bool) == False]
# Out:
#         article_id      start        end  answered  votes category  \
# 2817          2858 2017-09-04 2017-09-11         0      0    안전/환경
# 3387          3428 2017-09-04 2017-12-03         0      0   인권/성평등
# 2827          2868 2017-09-04 2017-09-11         0      0    안전/환경
# 3389          3430 2017-09-04 2017-12-03         0      0   인권/성평등
# 2308          2346 2017-09-04 2017-09-11         0      0   인권/성평등
# ...            ...        ...        ...       ...    ...      ...
# 371856      484175 2019-01-01 2019-01-31         0      4     정치개혁
# 372943      485561 2019-01-02 2019-02-01         0     45     보건복지
# 372950      485569 2019-01-02 2019-02-01         0      0       기타
# 374341      487418 2019-01-04 2019-02-03         0     14     정치개혁
# 374433      487549 2019-01-04 2019-02-03         0     10      일자리
#
#                                                     title  \
# 2817                               부산청소년폭행 강력하게 처벌을 청원합니다
# 3387                                  소년법 폐지 또는 개안을 원합니다.
# 2827                               부산청소년폭행 강력하게 처벌을 청원합니다
# 3389                                  소년법 폐지 또는 개안을 원합니다.
# 2308                                      청소년 보호법 폐지해주세요~
# ...                                                   ...
# 371856                                               국회법안
# 372943                 강북 삼성병원 의료진 사망사건에 관련 한 의료안정성을 위한청윈
# 372950                               어중간한 자영업자 죽이는 정부 대책?
# 374341                                            시의원.군의원
# 374433  대한민국은 근로자,노동자만 사는 나라가 아닙니다 자영업자 법인회사 경영자도 대한민국...
#
#                                                   content duration yearmonth  \
# 2817                                             너무하네요 진짜   7 days   2017-09
# 3387                                             제발 들어주세요  90 days   2017-09
# 2827                                             너무하네요 진짜   7 days   2017-09
# 3389                                             제발 들어주세요  90 days   2017-09
# 2308                                              페지해주세요!   7 days   2017-09
# ...                                                   ...      ...       ...
# 371856  법안처리가당리당약에의해\n처리가되지않의무로\n일정기간지나면자동상정되어\n대표국민표결...  30 days   2019-01
# 372943                                              동일합니다  30 days   2019-01
# 372950                                                 ㅜㅜ  30 days   2019-01
# 374341  예천에서일어난,군의원추태사건\n정말나라망신아닌지요.\n군믽시민들세금의로연수란명목으로...  30 days   2019-01
# 374433                                               ㄷㄷㄷㄷ  30 days   2019-01
#
#                                             clean_content clean_tokens  \
# 2817                                             너무하네요 진짜           []
# 3387                                             제발 들어주세요           []
# 2827                                             너무하네요 진짜           []
# 3389                                             제발 들어주세요           []
# 2308                                               페지해주세요           []
# ...                                                   ...          ...
# 371856  법안처리가당리당약에의해처리가되지않의무로일정기간지나면자동상정되어대표국민표결로과반수통과...           []
# 372943                                              동일합니다           []
# 372950                                                 ㅜㅜ           []
# 374341  예천에서일어난군의원추태사건정말나라망신아닌지요군믽시민들세금의로연수란명목으로여행가면서접...           []
# 374433                                               ㄷㄷㄷㄷ           []
#
#        remove_clean_tokens
# 2817
# 3387
# 2827
# 3389
# 2308
# ...                    ...
# 371856
# 372943
# 372950
# 374341
# 374433
#
# [200 rows x 13 columns]

# %% [markdown]
# #### 빈값처리

# %%
# 빈값 확인
pet_by_moon[pet_by_moon['remove_clean_tokens']== '']
# Out:
#         article_id      start        end  answered  votes  category  \
# 1393          1422 2017-09-02 2017-12-01         0      1        미래
# 2506          2545 2017-09-04 2017-12-03         0      0    인권/성평등
# 30031        31337 2017-11-10 2017-12-10         0      1    인권/성평등
# 30150        31466 2017-11-11 2017-12-11         0      1       일자리
# 112487      134992 2018-02-09 2018-03-11         0      6      반려동물
# 364140      473742 2018-12-19 2019-01-18         0      1  교통/건축/국토
#
#                                                    title  \
# 1393                                              가식은 그만
# 2506    제 아이에게 "맞고 다니지말아라. 청소년 보호법이 있단다"라고 가르치고 싶지 않습니다.
# 30031                                               학교폭력
# 30150                             한국전력공사 부산 전체 구조조정 해주십쇼
# 112487                            문재인은 모하냐  김여정 영접하러 안가고
# 364140                                               설거지
#
#                        content duration yearmonth           clean_content  \
# 1393         100일 넘도록 한게 모 있죠?  90 days   2017-09           일 넘도록 한게 모 있죠
# 2506                    이상입니다.  90 days   2017-09                   이상입니다
# 30031                        하  30 days   2017-11                       하
# 30150       솔직히 다 날로먹는것을 아닙니까?  30 days   2017-11       솔직히 다 날로먹는것을 아닙니까
# 112487             직접 안가고 모하냐.  30 days   2018-02              직접 안가고 모하냐
# 364140  어질러놓은것부터 치우고 다른일보셔야지 요  30 days   2018-12  어질러놓은것부터 치우고 다른일보셔야지 요
#
#        clean_tokens remove_clean_tokens
# 1393            [일]
# 2506           [이상]
# 30031           [하]
# 30150           [것]
# 112487          [모]
# 364140       [것, 일]

# %%
# 빈값 확인
pet_by_moon[pet_by_moon['remove_clean_tokens']== ' '] # 없음
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content, clean_tokens, remove_clean_tokens]
# Index: []

# %%
# 빈값 확인
pet_by_moon[pet_by_moon['remove_clean_tokens'].apply(bool)== False] # ''과 결과 같음
# Out:
#         article_id      start        end  answered  votes  category  \
# 1393          1422 2017-09-02 2017-12-01         0      1        미래
# 2506          2545 2017-09-04 2017-12-03         0      0    인권/성평등
# 30031        31337 2017-11-10 2017-12-10         0      1    인권/성평등
# 30150        31466 2017-11-11 2017-12-11         0      1       일자리
# 112487      134992 2018-02-09 2018-03-11         0      6      반려동물
# 364140      473742 2018-12-19 2019-01-18         0      1  교통/건축/국토
#
#                                                    title  \
# 1393                                              가식은 그만
# 2506    제 아이에게 "맞고 다니지말아라. 청소년 보호법이 있단다"라고 가르치고 싶지 않습니다.
# 30031                                               학교폭력
# 30150                             한국전력공사 부산 전체 구조조정 해주십쇼
# 112487                            문재인은 모하냐  김여정 영접하러 안가고
# 364140                                               설거지
#
#                        content duration yearmonth           clean_content  \
# 1393         100일 넘도록 한게 모 있죠?  90 days   2017-09           일 넘도록 한게 모 있죠
# 2506                    이상입니다.  90 days   2017-09                   이상입니다
# 30031                        하  30 days   2017-11                       하
# 30150       솔직히 다 날로먹는것을 아닙니까?  30 days   2017-11       솔직히 다 날로먹는것을 아닙니까
# 112487             직접 안가고 모하냐.  30 days   2018-02              직접 안가고 모하냐
# 364140  어질러놓은것부터 치우고 다른일보셔야지 요  30 days   2018-12  어질러놓은것부터 치우고 다른일보셔야지 요
#
#        clean_tokens remove_clean_tokens
# 1393            [일]
# 2506           [이상]
# 30031           [하]
# 30150           [것]
# 112487          [모]
# 364140       [것, 일]

# %%
# 빈값 제거

pet_by_moon = pet_by_moon[pet_by_moon['remove_clean_tokens']!= '']

# %%
# 제거 확인
pet_by_moon[pet_by_moon['remove_clean_tokens']== '']
# Out:
# Empty DataFrame
# Columns: [article_id, start, end, answered, votes, category, title, content, duration, yearmonth, clean_content, clean_tokens, remove_clean_tokens]
# Index: []
