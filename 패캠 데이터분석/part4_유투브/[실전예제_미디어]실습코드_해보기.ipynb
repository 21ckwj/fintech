# %% [markdown]
# #[실전예제-미디어] - 유튜브 인기 채널 및 영상 분석

# %% [markdown]
# # 인기 채널 순위 시각화 - 환경 설정 (라이브러리, 폰트, 데이터)

# %% [markdown]
# ###1. 한글 폰트 설치 및 적용

# %% [markdown]
# ###2. 한글 폰트 설치 테스트

# %% [markdown]
# ###3. Warning 출력 무시

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###4. 라이브러리 import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###5. 데이터 가져오기 Drag & Drop

# %%
# kaggle trending youtube video statistics

# %% [markdown]
# # 인기 채널 순위 시각화 - 데이터 구조 파악 및 정리

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ###1. pandas로 데이터 불러오기 (engine="python", error_bad_lines="false")

# %%
pip install chardet
# Out:
# Requirement already satisfied: chardet in c:\users\21ckw\anaconda3\lib\site-packages (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import chardet
import os

# %%
df = pd.read_csv('KRvideos1.csv', error_bad_lines=False,encoding='utf-8',delim_whitespace='\t')

encoding = chardet.detect(df)
encoding
# usecols=['trending_date','title','channel_title','category_id','publish_time']
# Out:
# b'Skipping line 3: expected 32 fields, saw 46\nSkipping line 6: expected 32 fields, saw 60\nSkipping line 7: expected 32 fields, saw 39\nSkipping line 9: expected 32 fields, saw 33\nSkipping line 10: expected 32 fields, saw 50\nSkipping line 13: expected 32 fields, saw 185\nSkipping line 14: expected 32 fields, saw 37\nSkipping line 16: expected 32 fields, saw 34\nSkipping line 17: expected 32 fields, saw 37\nSkipping line 19: expected 32 fields, saw 91\nSkipping line 21: expected 32 fields, saw 76\nSkipping line 22: expected 32 fields, saw 33\nSkipping line 23: expected 32 fields, saw 35\nSkipping line 27: expected 32 fields, saw 100\nSkipping line 31: expected 32 fields, saw 82\nSkipping line 37: expected 32 fields, saw 36\nSkipping line 40: expected 32 fields, saw 37\nSkipping line 42: expected 32 fields, saw 34\nSkipping line 44: expected 32 fields, saw 53\nSkipping line 45: expected 32 fields, saw 70\nSkipping line 46: expected 32 fields, saw 116\nSkipping line 47: expected 32 fields, saw 115\nSkipping line 48: expected 32 fields, saw 139\nSkipping line 49: expected 32 fields, saw 186\nSkipping line 51: expected 32 fields, saw 227\nSkipping line 54: expected 32 fields, saw 44\nSkipping line 55: expected 32 fields, saw 52\nSkipping line 58: expected 32 fields, saw 253\nSkipping line 61: expected 32 fields, saw 37\nSkipping line 63: expected 32 fields, saw 33\nSkipping line 64: expected 32 fields, saw 162\nSkipping line 65: expected 32 fields, saw 106\nSkipping line 66: expected 32 fields, saw 163\nSkipping line 67: expected 32 fields, saw 34\nSkipping line 69: expected 32 fields, saw 71\nSkipping line 70: expected 32 fields, saw 33\nSkipping line 71: expected 32 fields, saw 69\nSkipping line 72: expected 32 fields, saw 107\nSkipping line 73: expected 32 fields, saw 348\nSkipping line 74: expected 32 fields, saw 40\nSkipping line 75: expected 32 fields, saw 209\nSkipping line 76: expected 32 fields, saw 58\nSkipping line 77: expected 32 fields, saw 111\nSkipping line 79: expected 32 fields, saw 38\nSkipping line 80: expected 32 fields, saw 191\nSkipping line 82: expected 32 fields, saw 95\nSkipping line 83: expected 32 fields, saw 35\nSkipping line 84: expected 32 fields, saw 355\nSkipping line 85: expected 32 fields, saw 35\nSkipping line 86: expected 32 fields, saw 44\nSkipping line 87: expected 32 fields, saw 41\nSkipping line 105: expected 32 fields, saw 88\nSkipping line 109: expected 32 fields, saw 54\nSkipping line 110: expected 32 fields, saw 139\nSkipping line 111: expected 32 fields, saw 40\nSkipping line 113: expected 32 fields, saw 33\nSkipping line 114: expected 32 fields, saw 39\nSkipping line 118: expected 32 fields, saw 120\nSkipping line 120: expected 32 fields, saw 34\nSkipping line 121: expected 32 fields, saw 65\nSkipping line 122: expected 32 fields, saw 54\nSkipping line 125: expected 32 fields, saw 121\nSkipping line 127: expected 32 fields, saw 55\nSkipping line 128: expected 32 fields, saw 33\nSkipping line 130: expected 32 fields, saw 120\nSkipping line 131: expected 32 fields, saw 124\nSkipping line 132: expected 32 fields, saw 81\nSkipping line 133: expected 32 fields, saw 248\nSkipping line 135: expected 32 fields, saw 149\nSkipping line 136: expected 32 fields, saw 65\nSkipping line 138: expected 32 fields, saw 81\nSkipping line 142: expected 32 fields, saw 104\nSkipping line 143: expected 32 fields, saw 64\nSkipping line 144: expected 32 fields, saw 55\nSkipping line 145: expected 32 fields, saw 68\nSkipping line 146: expected 32 fields, saw 214\nSkipping line 148: expected 32 fields, saw 207\nSkipping line 150: expected 32 fields, saw 94\nSkipping line 151: expected 32 fields, saw 115\nSkipping line 152: expected 32 fields, saw 168\nSkipping line 153: expected 32 fields, saw 44\nSkipping line 154: expected 32 fields, saw 36\nSkipping line 156: expected 32 fields, saw 76\nSkipping line 157: expected 32 fields, saw 221\nSkipping line 158: expected 32 fields, saw 38\nSkipping line 159: expected  ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23168/1991325877.py in <module>
#       1 df = pd.read_csv('KRvideos1.csv', error_bad_lines=False,encoding='utf-8',delim_whitespace='\t')
#       2
# ----> 3 encoding = chardet.detect(df)
#       4 encoding
#       5 # usecols=['trending_date','title','channel_title','category_id','publish_time']
#
# ~\anaconda3\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      34     if not isinstance(byte_str, bytearray):
#      35         if not isinstance(byte_str, bytes):
# ---> 36             raise TypeError('Expected object of type bytes or bytearray, got: '
#      37                             '{}'.format(type(byte_str)))
#      38         else:
#
# TypeError: Expected object of type bytes or bytearray, got: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## 데이터 구조 파악하기

# %% [markdown]
# ###1. row, column 수 파악하기

# %% [markdown]
# ###2. 결측 값 확인

# %% [markdown]
# ###3. 전체 데이터 구조 파악하기

# %% [markdown]
# ## 데이터 정리하기

# %% [markdown]
# ###1. 필요한 칼럼만 추리기

# %% [markdown]
# ###2. view 내림차순 정렬 하기

# %% [markdown]
# ###3. 중복 제거 (MAX만 남김)

# %% [markdown]
# ###4. 중복된 row는 몇개였을까?

# %% [markdown]
# ###5. 중복 제거된 것 확인하기

# %% [markdown]
# # 인기 채널 순위 시각화 - seaborn을 활용한 데이터 시각화

# %% [markdown]
# ##1. 조회수 기준 TOP 100 채널 순위 조회

# %% [markdown]
# ####채널별 조회수 합계

# %% [markdown]
# ####정렬

# %% [markdown]
# ###TOP 100만 뽑기

# %% [markdown]
# ###reset_index()

# %% [markdown]
# ##2. seaborn barplot 사용하여 TOP 100 채널 데이터 시각화

# %% [markdown]
# ##3. 사이즈 (20*100) 및 축 조정

# %% [markdown]
# # 인기 영상 키워드 분석하기 - 제목 추출 및 정제하기

# %% [markdown]
# ###1. 데이터 조회

# %% [markdown]
# ###2. 제목, 뷰만 가져오고 뷰 많은 순으로 정렬 후 중복 제거

# %% [markdown]
# ###3. 제목 Array로 조회

# %% [markdown]
# ###4. 정규표현식(re)로 한글 데이터만 남기기 (한글,띄어쓰기 포함)

# %% [markdown]
# ###5. 공백만 있는 row는 삭제

# %% [markdown]
# # 인기 영상 키워드 분석하기 - 제목 단어 추출 및 빈도 수 구하기

# %% [markdown]
# ###1. soynlp 설치

# %% [markdown]
# ###2. WordExtractor로 단어 점수 학습

# %% [markdown]
# ###3. LTokenizer로 L-R 분리

# %% [markdown]
# ###4. 제목 데이터 중 L만 남기기

# %% [markdown]
# # 인기 영상 키워드 분석하기 - 단어 빈도 수 구하기

# %% [markdown]
# ###1. 인기 영상 (50만 조회수 이상)

# %% [markdown]
# ###2. tokenized 단어 한 배열에 담기

# %% [markdown]
# ### Counter로 words 빈도 수 파악하기

# %% [markdown]
# # 인기 영상 키워드 분석하기 - 워드 클라우드 그리기

# %% [markdown]
# ### wordcloud 폰트 설정 및 생성하기

# %% [markdown]
# ### StopWord 설정 후 다시 보기
