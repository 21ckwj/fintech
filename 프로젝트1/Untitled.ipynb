# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
url = 'http://www.kesis.net/sub/sub_0001_02.jsp'
# 경로
#form1 > article.content > section > table

res =requests.get(url)
res.text
# Out:
# '<!doctype html>\r\n<html lang="ko" xmlns="http://www.w3.org/1999/xhtml">\r\n\r\n  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="http://www.kesis.net:80/etr/jquery/jquery-ui/js/jquery-1.8.2.min.js"></script> \r\n<script type="text/javascript" src="http://www.kesis.net:80/etr/jquery/jquery-ui/js/jquery-ui-1.8.24.custom.min.js"></script> \r\n<link rel="stylesheet" href="http://www.kesis.net:80/etr/jquery/jquery-ui/css/ui-lightness/jquery-ui-1.8.24.custom.css" type="text/css"/>\r\n<script type="text/javascript" src="/etr/script/common.js;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" ></script>\r\n\r\n\r\n<head>\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\r\n<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no"/>\r\n<link rel="canonical" href="http://www.kesis.net"/>\r\n<!-- <link rel="canonical" href="http://www.kesis.net"> -->\r\n<title>KESIS 국가에너지통계종합정보시스템</title>\r\n<meta name="description" content="KESIS는 에너지 정보·통계 포털사이트로서 에너지통계연보 및 월보, 지역에너지통계연보, 에너지밸런스, 에너지수급동향, 에너지수요전망, 에너지총조사, 가구에너지패널조사 데이터 등을 제공합니다.">\r\n<link rel="stylesheet" href="/etr/css/common.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/reset.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/default.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/header.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/main_d.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/main_t.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/main_m.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/> \r\n<link rel="stylesheet" href="/etr/css/sub_d.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/sub_t.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/sub_m.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/newCss.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<link rel="stylesheet" href="/etr/css/newMain.css;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2" type="text/css"/>\r\n<script type="text/javascript" src="/etr/jquery/function.js;jsessionid=jfwctMkthAijb7BQ01L1YqaIexA8Tbu4ZzUo16WKvAyShEy97ySKQQ5GoFC1rlxz.kwas1_servlet_engine2"></script>\r\n\r\n</head>\r\n\r\n<script type="text/javascript">\r\n\tvar domainName="http://www.kesis.net:80";\r\n\tvar nowDt="";\r\n</script>\r\n\r\n\r\n\r\n<style type="text/css">\r\n\t\t.bbs_tbl_list .bbs_img{width:30%;}\r\n\t\t.bbs_tbl_list .bbs_content{width:70% !important; padding-left: 0.5%;padding-right: 0.5%;}\r\n\t\t.bbs_tbl_list .bbs_a{width:100% !important;}\r\n\t\t.bbs_tbl_list .bbs_file{position:relative;display:none;} \r\n\t\t/* 이부분 있어야된다면 아래와같이\r\n\t\t.bbs_tbl_list .bbs_content{width:40% !important;}\r\n\t\t.bbs_tbl_list .bbs_file{position:relative;width:10%;} \r\n\t\t*/\r\n\t ...
