# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 15, 'display.max_rows', 500, 'display.max_colwidth', 12)

# %%
df= pd.read_csv('KESIS_키워드_top_500.csv', index_col=0)
df
# Out:
#          index     0
# 0           배럴  2907
# 1           전주  2284
# 2           미국  2061
# 3           기록  1400
# 4           증가  1378
# 5           기준  1346
# 6           감소  1280
# 7           대비  1124
# 8           만b   860
# 9           원유   732
# 10        원유생산   688
# 11          상승   649
# 12          발표   570
# 13          하락   489
# 14          자금   473
# 15         투기성   469
# 16          감산   420
# 17         포지션   389
# 18          주간   380
# 19        원유시추   367
# 20        원유재고   320
# 21        스프레드   319
# 22         원월물   302
# 23        석유재고   298
# 24         순매수   280
# 25        선물거래   279
# 26   상품선물거래위원회   277
# 27         사우디   271
# 28         지난주   258
# 29        선물가격   254
# 30         휘발유   251
# 31        선물유가   249
# 32          가치   241
# 33         유로화   234
# 34          환율   223
# 35         백만b   222
# 36         러시아   213
# 37        중간유분   213
# 38          생산   206
# 39        국제유가   205
# 40          매수   197
# 41          유가   191
# ...

# %%
#키워드 선별

# 상승 하강 을 골라놓고 최대한 많이

# 아닌거는 중립 비중 높은거로 

# 키워드분석
# 1. 보면서 유가의 방향성을 단어선출
# 2. 중립 -> 검색키워드

# 주별 리포트 키워드선출 이 주에 유가가어떻게 변동했는지 감정사전 

#뉴스크롤링기사 유가에 어떤 상관관계가 있는지

#감정 사전 뉴스 ,선행지수, 유가상관관계를 구할예정
