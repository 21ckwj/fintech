# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('./data_pj2/서울특별시 공공자전거 이용정보(시간대별)_21.01.csv', encoding='cp949')
# Out:
#               대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  \
# 0       2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  NaN  ~10대
# 1       2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  NaN  ~10대
# 2       2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  NaN  ~10대
# 3       2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  NaN  ~10대
# 4       2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  NaN  ~10대
# ...            ...   ...    ...                      ...    ...  ...   ...
# 718852  2021-01-31    23    207        207. 여의나루역 1번출구 앞    단체권  NaN  ~10대
# 718853  2021-01-31    23   3549             3549.건영아파트 앞    단체권  NaN   20대
# 718854  2021-01-31    23    248             248. 초원아파트 앞    단체권  NaN   20대
# 718855  2021-01-31    23    131                131. 증산2교    단체권  NaN   20대
# 718856  2021-01-31    23    247         247. 당산역 10번출구 앞    단체권    M   40대
#
#         이용건수     운동량   탄소량      이동거리  사용시간
# ...

# %%
pd.read_csv('./data_pj2/서울시 공공자전거 고장신고 내역_21.7-21.12 (1).csv', encoding='cp949')
# Out:
#            자전거번호        등록일시 고장구분
# 0      SPB-48144  2021-07-01  기타
# 1      SPB-53580  2021-07-01  기타
# 2      SPB-32012  2021-07-01  기타
# 3      SPB-51473  2021-07-01  기타
# 4      SPB-53296  2021-07-01  기타
# ...          ...         ...  ...
# 95684  SPB-52362  2021-12-30   안장
# 95685  SPB-34353  2021-12-30  기타
# 95686  SPB-31667  2021-12-30  기타
# 95687  SPB-43563  2021-12-30   체인
# 95688  SPB-43563  2021-12-30  기타
#
# [95689 rows x 3 columns]

# %%
pd.read_csv('./data_pj2/공공자전거 대여이력 정보_2112.csv', encoding='cp949')
# Out:
#              자전거번호                 대여일시  대여 대여소번호  대여 대여소명  대여거치대  \
# 0        SPB-53035  2021-12-01 09:45:56         3     중랑센터      0
# 1        SPB-40999  2021-12-05 16:02:31         3     중랑센터      0
# 2        SPB-55934  2021-12-10 22:01:39         3     중랑센터      0
# 3        SPB-50913  2021-12-11 07:01:32         3     중랑센터      0
# 4        SPB-31324  2021-12-15 16:02:04         3     중랑센터      0
# ...            ...                  ...       ...      ...    ...
# 1704292  SPB-51882  2021-12-30 09:39:45      9999     상담센터      0
# 1704293  SPB-51134  2021-12-30 18:55:31      9999     상담센터      0
# 1704294  SPB-37732  2021-12-30 21:12:40      9999     상담센터      0
# 1704295  SPB-51854  2021-12-22 09:46:16     88888     영남배송      0
# 1704296  SPB-53564  2021-12-22 14:38:04     99999  영남단말기정비      0
#
#                         반납일시  반납대여소번호             반납대여소명  반납거치대  이용시간     이용거리
# 0        2021-12-01 09:58:57      646  장한평역 1번출구 (국민은행앞)      0    13     0.00
# ...

# %%
pd.read_csv('./data_pj2/공공자전거 대여소 정보(21.12월 기준).csv', encoding='cp949',header=2)
# Out:
#       Unnamed: 0                  Unnamed: 1  자치구  \
# 0            NaN                         NaN  NaN
# 1            NaN                         NaN  NaN
# 2          102.0                  망원역 1번출구 앞  마포구
# 3          103.0                  망원역 2번출구 앞  마포구
# 4          104.0                  합정역 1번출구 앞  마포구
# ...          ...                         ...  ...
# 2583      5070.0  마곡13단지힐스테이트마스터 후문(1320동 앞)  강서구
# 2584      5072.0                  김포공항입구 교통섬  강서구
# 2585      5073.0                우장산역 헤링턴타워 앞  강서구
# 2586      5074.0                 마곡동 주니어마곡점앞  강서구
# 2587      5075.0                      템퍼 목동점  강서구
#
#                                         상세주소         위도          경도  \
# 0                                        NaN        NaN         NaN
# 1                                        NaN        NaN         NaN
# 2                          서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 3                          서울특별시 마포구 월드컵로 79  37.554951  126.910835
# ...
