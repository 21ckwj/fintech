# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/조류인플루엔자 발생현황.csv')
df
# Out:
#       Unnamed: 0            0      1                    2  \
# 0              0  고병원성조류인플루엔자  다산1농장     전라북도 부안군 진서면 진서리
# 1              1  고병원성조류인플루엔자   영광농장      세종특별자치시 부강면 등곡리
# 2              2  고병원성조류인플루엔자   현대농장     전라남도 영암군 시종면 신학리
# 3              3  고병원성조류인플루엔자   지원농장      경기도 파주시 광탄면 발랑리
# 4              4  고병원성조류인플루엔자  보성3농장      세종특별자치시 연동면 문주리
# ...          ...          ...    ...                  ...
# 1077           7  고병원성조류인플루엔자    박병준  충청남도 천안시 동남구 북면 운용리
# 1078           8  고병원성조류인플루엔자  가나안농장     전라남도 나주시 산포면 매성리
# 1079           9  고병원성조류인플루엔자    서기환     충청북도 음성군 삼성면 용성리
# 1080           0  고병원성조류인플루엔자    김학면     충청북도 음성군 삼성면 덕정리
# 1081           1  고병원성조류인플루엔자    박덕규     충청북도 음성군 삼성면 용성리
#
#                             3        4  5             6    7
# 0     2021-12-27 (2021-12-28)   오리-종오리  -  조류인플루엔자연구진단과  NaN
# 1     2021-12-23 (2021-12-24)    닭-산란계  -  조류인플루엔자연구진단과  NaN
# 2     2021-12-20 (2021-12-22)     닭-육계  -  조류인플루엔자연구진단과  NaN
# ...

# %%
# 날짜 처리

# %%
df['날짜'] = df['3'].apply(lambda x : x.split(' ')[0])
df['날짜']
# Out:
# 0       2021-12-27
# 1       2021-12-23
# 2       2021-12-20
# 3       2021-12-17
# 4       2021-12-16
#            ...
# 1077    2003-12-24
# 1078    2003-12-21
# 1079    2003-12-19
# 1080    2003-12-17
# 1081    2003-12-12
# Name: 날짜, Length: 1082, dtype: object
