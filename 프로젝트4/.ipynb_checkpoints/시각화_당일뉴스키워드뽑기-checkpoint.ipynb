# %% [markdown]
# # 당일뉴스 키워드 뽑기

# %%
import pandas as pd
import numpy as np
import os
from keybert import KeyBERT

# %%
df_today = pd.read_csv('./data/당일뉴스/0422_news.csv',index_col=0)
df_today
# Out:
#               company                                              title  \
# 0          By Reuters  Global energy crisis, Russia invasion eclipse ...
# 1          By Reuters  Oil edges higher on concerns over Russia, Liby...
# 2    By Investing.com  Oil Snaps 2-Day Slide as Supply Issues Back in...
# 3        By Bloomberg  Gasoline Imports Flowing to U.S. West Coast at...
# 4          By Reuters  U.S. companies can help rebuild Ukraine, head ...
# ..                ...                                                ...
# 252        By Reuters  Johnny Depp says ex-wife Heard beat him, cost ...
# 253        By Reuters  G7 finance ministers pledge more than $24 bill...
# 254        By Reuters  South Carolina court halts first firing-squad ...
# 255        By Reuters  Biden hosts military chiefs as Ukraine crisis ...
# 256        By Reuters  Ukraine seeks Mariupol evacuation talks after ...
#
#                                                content        Date
# 0    As a candidate, Joe Biden made climate change ...  2022-04-22
# 1    By David Gaffen\nNEW YORK (Reuters) -Oil price...  2022-04-22
# 2    By Barani Krishnan\nInvesting.com -- Oil price...  2022-04-22
# 3    (Bloomberg) -- The U.S. West Coast is importin...  2022-04-22
# 4    U.S. companies can help rebuild Ukraine with d...  2022-04-22
# ..                                                 ...         ...
# 252                                 suddenly in my 50s  2022-04-22
# 253  G7 finance ministers said they have provided a...  2022-04-22
# 254  By Jonathan Allen\n(Reuters) -South Carolina's...  2022-04-22
# 255  President Joe Biden convened U.S. military lea...  2022-04-22
# 256  Ukraine proposed talks with Moscow over evacua...  2022-04-22
#
# [257 rows x 4 columns]

# %%
# 파일 하나일 경우

df = pd.read_csv('./data/당일뉴스/0422_news.csv',index_col=0)
df.dropna(inplace=True)
df.reset_index(drop=True)
        
kw_model = KeyBERT()

date_list = []
kw_list = []
kw_list_only = []

# df의 모든 행에 대해
for n in range(len(df)):

    # 날짜 
    date_list.append(df['Date'].iloc[n])

    # diversity 0.4, 키워드 50개 추출
    keywords_list = kw_model.extract_keywords(df['content'].iloc[n], keyphrase_ngram_range=(1,1),
                                     use_mmr=True,diversity=0.4, nr_candidates=50, top_n=50)

    # (키워드 +유사성) 유사성 높은순으로 정렬
    keywords_sorted = sorted(keywords_list, key= lambda keywords_list: keywords_list[1], reverse=True)
    kw_list.append(keywords_sorted)

    # 키워드만 모으기
    temp_list = []
    for idx in range(len(keywords_sorted)):
        temp_list.append(keywords_sorted[idx][0])

    kw_list_only.append(temp_list)


df_kw = pd.DataFrame({'Date':date_list, 'keywords,similarity': kw_list, "keywords": kw_list_only})
df_kw.to_csv('./data/당일키워드/keyword_0422.csv')

# %%
# 폴더별로 데이터 들어올경우

topics = ['stock-market-news', 'commodities-news', 'forex-news', 'economy', 'economic-indicators','politics','world-news']

# 당일 뉴스 데이터 경로
path = './data/'
result_path = './data/keyword_result/'

for topic in topics[2:4]:
    path_topic = os.path.join(path,topic)
    path_result = os.path.join(result_path,topic)
    file_list = os.listdir(path_topic)
    file_num = len(os.listdir(path_topic))
    
    # 저장폴더 만들기
    if not os.path.exists(path_result):
        os.makedirs(path_result)
    else:
        pass

    for i in range(file_num):  # 원래는 file_num
        
        df = pd.read_csv(path_topic + '/' + file_list[i])
        df.dropna(inplace=True)
        df.reset_index(drop=True)
        
        kw_model = KeyBERT()
        
        date_list = []
        kw_list = []
        kw_list_only = []
        
        # df의 모든 행에 대해
        for n in range(len(df)):
            
            # 날짜 
            date_list.append(df['date'].iloc[n])
            
            # diversity 0.4, 키워드 50개 추출
            keywords_list = kw_model.extract_keywords(df['content'].iloc[n], keyphrase_ngram_range=(1,1),
                                             use_mmr=True,diversity=0.4, nr_candidates=50, top_n=50)
            
            # (키워드 +유사성) 유사성 높은순으로 정렬
            keywords_sorted = sorted(keywords_list, key= lambda keywords_list: keywords_list[1], reverse=True)
            kw_list.append(keywords_sorted)
            
            # 키워드만 모으기
            temp_list = []
            for idx in range(len(keywords_sorted)):
                temp_list.append(keywords_sorted[idx][0])
                
            kw_list_only.append(temp_list)

        
        df_kw = pd.DataFrame({'Date':date_list, 'keywords,similarity': kw_list, "keywords": kw_list_only})
        df_kw.to_csv('./data/keyword_result/{}/keyword_{}_{}.csv'.format(topic, topic,i))

# %% [markdown]
# # 뽑은 키워드 전처리

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from PIL import Image

# %%
df_kw = pd.read_csv('./data/당일키워드/keyword_0422.csv',index_col=0)
df_kw.head()
# Out:
#          Date                                keywords,similarity  \
# 0  2022-04-22  [('biden', 0.4685), ('fuels', 0.3992), ('oil',...
# 1  2022-04-22  [('futures', 0.4365), ('brent', 0.4083), ('oil...
# 2  2022-04-22  [('oil', 0.378), ('crude', 0.3364), ('brent', ...
# 3  2022-04-22  [('refinery', 0.5331), ('chevron', 0.3951), ('...
# 4  2022-04-22  [('ukraine', 0.4884), ('ukrainian', 0.425), ('...
#
#                                             keywords
# 0  ['biden', 'fuels', 'oil', 'warming', 'demand',...
# 1  ['futures', 'brent', 'oil', 'petroleum', 'crud...
# 2  ['oil', 'crude', 'brent', 'wti', 'opec', 'pric...
# 3  ['refinery', 'chevron', 'gasoline', 'refinerie...
# 4  ['ukraine', 'ukrainian', 'funding', 'shevchenk...

# %%
df_kw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 256
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 257 non-null    object
#  1   keywords,similarity  257 non-null    object
#  2   keywords             257 non-null    object
# dtypes: object(3)
# memory usage: 8.0+ KB

# %%
words = df_kw['keywords'][0]
words
# Out:
# "['biden', 'fuels', 'oil', 'warming', 'demand', 'energy', 'geopolitical', 'drilling', 'campaign', 'candidate', 'climate', 'conservatives', 'reserves', 'president', 'pump', 'prices', 'inflation', 'economist', 'joe', 'forecast', 'strategic', 'policy', 'war', 'decades', 'reform', 'promising', 'pay', 'progressives', 'gain', 'prioritize', 'short', 'leading', 'decarbonize', 'keeping', 'headwinds', 'end', 'fossil', 'reality', 'november', 'ed', 'forced', 'jarring', 'urge', 'hirs', 'difficulties', 'rampant', 'sure', 'fellow', 'instead', 'curb']"

# %%
import re
kw_list = re.sub('[^A-Za-z ]',"",words).split()
kw_list
# Out:
# ['biden',
#  'fuels',
#  'oil',
#  'warming',
#  'demand',
#  'energy',
#  'geopolitical',
#  'drilling',
#  'campaign',
#  'candidate',
#  'climate',
#  'conservatives',
#  'reserves',
#  'president',
#  'pump',
#  'prices',
#  'inflation',
#  'economist',
#  'joe',
#  'forecast',
#  'strategic',
#  'policy',
#  'war',
#  'decades',
#  'reform',
#  'promising',
#  'pay',
#  'progressives',
#  'gain',
#  'prioritize',
#  'short',
#  'leading',
#  'decarbonize',
#  'keeping',
#  'headwinds',
#  'end',
#  'fossil',
#  'reality',
#  'november',
#  'ed',
#  'forced',
#  'jarring',
#  'urge',
#  'hirs',
#  'difficulties',
#  'rampant',
#  'sure',
#  'fellow',
#  'instead',
#  'curb']

# %% [markdown]
# ## 상위 10개 단어만 모으는 함수 적용

# %%
def kw_tolist(words):
    num = 10
    kw_list = re.sub('[^A-Za-z ]',"",words).split()
    return kw_list[:num]

# %%
df_kw['kw_list'] = df_kw['keywords'].apply(kw_tolist)

# %%
df_kw['kw_list'][0]
# Out:
# ['biden',
#  'fuels',
#  'oil',
#  'warming',
#  'demand',
#  'energy',
#  'geopolitical',
#  'drilling',
#  'campaign',
#  'candidate']

# %% [markdown]
# # 당일 키워드 합치기

# %%
today_kw =  df_kw['kw_list'].sum()
today_kw
# Out:
# ['biden',
#  'fuels',
#  'oil',
#  'warming',
#  'demand',
#  'energy',
#  'geopolitical',
#  'drilling',
#  'campaign',
#  'candidate',
#  'futures',
#  'brent',
#  'oil',
#  'petroleum',
#  'crude',
#  'fuels',
#  'opec',
#  'barrels',
#  'traders',
#  'prices',
#  'oil',
#  'crude',
#  'brent',
#  'wti',
#  'opec',
#  'prices',
#  'barrels',
#  'traders',
#  'investing',
#  'bullish',
#  'refinery',
#  'chevron',
#  'gasoline',
#  'refineries',
#  'coast',
#  'oil',
#  'cvx',
#  'barrels',
#  'maintenance',
#  'exports',
#  'ukraine',
#  'ukrainian',
#  'funding',
#  'shevchenko',
#  'banking',
#  'financing',
#  'aid',
#  'finances',
#  'fund',
#  'infrastructure',
#  'corn',
#  'agriculture',
#  'grain',
#  'forecasts',
#  'futures',
#  'crop',
#  'planting',
#  'produce',
#  'commodity',
#  'production',
#  'exxon',
#  'petroleum',
#  'emissions',
#  'co',
#  'carbon',
#  'renewable',
#  'fuel',
#  'gm',
#  'mobil',
#  'pipeline',
#  'nyse',
#  'nasdaq',
#  'boeing',
#  'bp',
#  'apple',
#  'aapl',
#  'rdsa',
#  'ba',
#  'shell',
#  'equinor',
#  'opec',
#  'oil',
#  'prices',
#  'imfc',
#  'sanctions',
#  'brent',
#  'inflation',
#  'imf',
#  'reuters',
#  'commodity',
#  'petroleum',
#  'oilfields',
#  'venezuela',
#  'sanctions',
#  'oil',
#  'halliburton',
#  'refiners',
#  'drilling',
#  'caracas',
#  'exports',
#  'alekperov',
#  'oilfield',
#  'bpd',
#  'shares',
#  'qatar',
#  'qurna',
#  'owned',
#  'chairman',
#  'oil',
#  'company',
#  'oil',
#  'petroleum',
#  'moscow',
#  'ukraine',
#  'russian',
#  'opec',
#  'crude',
#  'futures',
#  'gasoline',
#  'barrels',
#  'inflation',
#  'commodity',
#  'investors',
#  'gold',
#  'market',
#  'funds',
#  'holdings',
#  'declining',
#  'yields',
#  'reserve',
#  'eu',
#  'euros',
#  'boiler',
#  'heating',
#  'fuels',
#  'energy',
#  'thermostat',
#  'climate',
#  'europeans',
#  'saving',
#  'ferries',
#  'ferry',
#  'fuel',
#  'tankers',
#  'boat',
#  'harbor',
#  'shipyard',
#  'maritime',
#  'seas',
#  'propulsion',
#  'stock',
#  'markets',
#  'pop',
#  'china',
#  'day',
#  'featured',
#  'contrast',
#  'sharp',
#  'treasury',
#  'gold',
#  'goldsilver',
#  'fed',
#  'futures',
#  'yields',
#  'dollar',
#  'bank',
#  'inflation',
#  'bond',
#  'oil',
#  'petroleum',
#  'opec',
#  'futures',
#  'forecasts',
#  'fuel',
#  'markets',
#  'commodities',
#  'libya',
#  'news',
#  'oil',
#  'russia',
#  'libya',
#  'ukraine',
#  'traders',
#  'russian',
#  'crude',
#  'imports',
#  'reserves',
#  'china',
#  'futures',
#  'brent',
#  'settle',
#  'crude',
#  'oil',
#  'prices',
#  'settled',
#  'cents',
#  'contract',
#  'barrel',
#  'renewables',
#  'fuels',
#  'investment',
#  'energy',
#  'demand',
#  'growth',
#  'economies',
#  'oil',
#  'trillion',
#  'infrastructure',
#  'exports',
#  'customs',
#  'imports',
#  'sanctions',
#  'import',
#  'logistical',
#  'russian',
#  'exporter',
#  'russia',
#  'kremlin',
#  'earnings',
#  'growth',
#  'strong',
#  'average',
#  'months',
#  'recent',
#  'reflected',
#  'exports',
#  'sanctions',
#  'euros',
#  'export',
#  'germany',
#  'russia',
#  'ukraine',
#  'german',
#  'russian',
#  'economic',
#  'inflation',
#  'cpi',
#  'rates',
#  'zealand',
#  'recession',
#  'pace',
#  'rising',
#  'economists',
#  'wellington',
#  'prices',
#  'exports',
#  'korea',
#  'korean',
#  'economy',
#  'export',
#  'shipments',
#  'imports',
#  'china',
#  'commerce',
#  'goods',
#  'exports',
#  'customs',
#  'imports',
#  'sanctions',
#  'import',
#  'logistical',
#  'russian',
#  'exporter',
#  'russia',
#  'kremlin',
#  'earnings',
#  'growth',
#  'strong',
#  'average',
#  'months',
#  'recent',
#  'reflected',
#  'exports',
#  'sanctions',
#  'euros',
#  'export',
#  'germany',
#  'russia',
#  'ukraine',
#  'german',
#  'russian',
#  'economic',
#  'inflation',
#  'cpi',
#  'rates',
#  'zealand',
#  'recession',
#  'pace',
#  'rising',
#  'economists',
#  'wellington',
#  'prices',
#  'exports',
#  'korea',
#  'korean',
#  'economy',
#  'export',
#  'shipments',
#  'imports',
#  'china',
#  'commerce',
#  'goods',
#  'defrauded',
#  'fines',
#  'chairman',
#  'investors',
#  'claims',
#  'regulator',
#  'securities',
#  'car',
#  'forced',
#  'company',
#  'ukraine',
#  'putin',
#  'g',
#  'sanctions',
#  'moscow',
#  'appeasement',
#  'ministers',
#  'finance',
#  'imf',
#  'reuters',
#  'tariffs',
#  'inflation',
#  'subsidies',
#  'biden',
#  'sanctions',
#  'goods',
#  'supply',
#  'treasury',
#  'economic',
#  'leverage',
#  'nyse',
#  'buyout',
#  'drugstore',
#  'market',
#  'shareholders',
#  'financing',
#  'shares',
#  'valuing',
#  'valuation',
#  'equity',
#  'zambia',
#  'debt',
#  'creditors',
#  'creditor',
#  'lender',
#  'bank',
#  'finance',
#  'pandemic',
#  'yi',
#  'restructuring',
#  'costs',
#  'ukraine',
#  'damage',
#  'billion',
#  'war',
#  'malpass',
#  'estimate',
#  'infrastructure',
#  'economic',
#  'invasion',
#  'housing',
#  'investors',
#  'markets',
#  'inflation',
#  'homes',
#  'speculative',
#  'rents',
#  'buyers',
#  'canadians',
#  'estate',
#  'humana',
#  'kindred',
#  'nyse',
#  'hospice',
#  'goldman',
#  'insurer',
#  'buybacks',
#  'financial',
#  'ownership',
#  'securities',
#  'treasury',
#  'crises',
#  'finance',
#  'administration',
#  'governance',
#  'putin',
#  'ministers',
#  'bloomberg',
#  'briefing',
#  'leaders',
#  'solomon',
#  'islands',
#  'campbell',
#  'pacific',
#  'arrive',
#  'island',
#  'delegation',
#  'talks',
#  'briefing',
#  'department',
#  'russia',
#  'ukraine',
#  'g',
#  'russian',
#  'allies',
#  'treasury',
#  'finance',
#  'powell',
#  'yellen',
#  'fund',
#  'bank',
#  'monetary',
#  'mexico',
#  'currency',
#  'peso',
#  'inflation',
#  'banked',
#  'financial',
#  'digital',
#  'unbanked',
#  'inflation',
#  'fed',
#  'pace',
#  'basis',
#  'powell',
#  'rate',
#  'monetary',
#  'march',
#  'hike',
#  'points',
#  'aid',
#  'ukraine',
#  'fund',
#  'humanitarian',
#  'treasury',
#  'plan',
#  'financing',
#  'biden',
#  'budget',
#  'million',
#  'multilateralism',
#  'sanctions',
#  'ukraine',
#  'committee',
#  'imfc',
#  'consensus',
#  'reuters',
#  'imf',
#  'chaired',
#  'nadia',
#  'russia',
#  'currency',
#  'banking',
#  'bitcoin',
#  'digital',
#  'cryptocurrencies',
#  'rouble',
#  'russian',
#  'payments',
#  'technologies',
#  'rouble',
#  'banking',
#  'nabiullina',
#  'lender',
#  'monetary',
#  'sanctions',
#  'debt',
#  'payments',
#  'russian',
#  'inflation',
#  'banks',
#  'fed',
#  'policymakers',
#  'federal',
#  'governors',
#  'monetary',
#  'recession',
#  'presidents',
#  'senate',
#  'inflation',
#  'tesla',
#  'demand',
#  'companies',
#  'maker',
#  'consumers',
#  'profitability',
#  'retailers',
#  'products',
#  'prices',
#  'fares',
#  'fed',
#  'evans',
#  'bank',
#  'federal',
#  'bloomberg',
#  'reserve',
#  'presidents',
#  'chicago',
#  'executive',
#  'president',
#  'inflation',
#  'peaked',
#  'peak',
#  'march',
#  'prices',
#  'economists',
#  'high',
#  'canada',
#  'escalation',
#  'rocketing',
#  'antitrust',
#  'lawsuit',
#  'apple',
#  'monopoly',
#  'nasdaq',
#  'appealed',
#  'netflix',
#  'case',
#  'dispute',
#  'moscow',
#  'brexit',
#  'prize',
#  'seen',
#  'great',
#  'inflation',
#  'easing',
#  'fed',
#  'fiscal',
#  'rates',
#  'federal',
#  'borrowing',
#  'daly',
#  'raising',
#  'neutral',
#  'puerto',
#  'rican',
#  'ssi',
#  'rico',
#  'sotomayor',
#  'kavanaugh',
#  'federal',
#  'vaello',
#  'guam',
#  'discrimination',
#  'assets',
#  'ukraine',
#  'treasury',
#  'russian',
#  'russia',
#  'sequestered',
#  'rebuilding',
#  'yellen',
#  'confiscated',
#  'costs',
#  'tai',
#  'travel',
#  'talks',
#  'met',
#  'britain',
#  'trade',
#  'atlantic',
#  'british',
#  'katherine',
#  'uk',
#  'sanctions',
#  'treasury',
#  'putin',
#  'sanctioning',
#  'ukraine',
#  'moscow',
#  'kremlin',
#  'belarus',
#  'oligarch',
#  'currency',
#  'unemployment',
#  'recession',
#  'labor',
#  'shortage',
#  'layoffs',
#  'inflation',
#  'payrolls',
#  'demand',
#  'economists',
#  'treasury',
#  'ukraine',
#  'globalisation',
#  'sanctions',
#  'war',
#  'moscow',
#  'regimes',
#  'alliances',
#  'durch',
#  'economic',
#  'invasion',
#  'nabiullina',
#  'vladimir',
#  'monetary',
#  'putin',
#  'inflation',
#  'banks',
#  'tatiana',
#  'debt',
#  'economist',
#  'sanctions',
#  'facebook',
#  'vietnamese',
#  'censorship',
#  'twitter',
#  'enforced',
#  'media',
#  'livestreams',
#  'minh',
#  'communist',
#  'restrict',
#  'sanctions',
#  'tariffs',
#  'commodities',
#  'goods',
#  'bans',
#  'russia',
#  'products',
#  'restrictions',
#  'russian',
#  'ukraine',
#  'carlsberg',
#  'copenhagen',
#  'depreciation',
#  'euros',
#  'revenue',
#  'danish',
#  'sell',
#  'pedersen',
#  'heineken',
#  'breweries',
#  'bundesbank',
#  'ecb',
#  'inflation',
#  'stimulus',
#  'forecast',
#  'future',
#  'early',
#  'euro',
#  'july',
#  'bonds',
#  'earnings',
#  'nyse',
#  'nasdaq',
#  'financial',
#  'bloomberg',
#  'analysts',
#  'quarterly',
#  'tesla',
#  'stocks',
#  'forecasts',
#  'retirement',
#  'employment',
#  'labor',
#  'jobs',
#  'workers',
#  'march',
#  'return',
#  'report',
#  'older',
#  'month',
#  'fed',
#  'inflation',
#  'monetary',
#  'powell',
#  'policymakers',
#  'recession',
#  'bankers',
#  'daly',
#  'evans',
#  'march',
#  'economic',
#  'maximum',
#  'value',
#  'government',
#  'conditions',
#  'adjust',
#  'dictate',
#  'investors',
#  'hong',
#  'securities',
#  'stocks',
#  'finance',
#  'exchanges',
#  'chinese',
#  'connect',
#  'market',
#  'channel',
#  'india',
#  'russia',
#  'boris',
#  'gujarat',
#  'ukraine',
#  'reliance',
#  'oil',
#  'foreign',
#  'countries',
#  'modi',
#  'inflation',
#  'economy',
#  'consumers',
#  'holiday',
#  'spending',
#  'retailers',
#  'london',
#  'easter',
#  'weekend',
#  'bookings',
#  'covid',
#  'shanghai',
#  'reopening',
#  'quarantine',
#  'funeral',
#  'carmaker',
#  'resuming',
#  'tesla',
#  'investigating',
#  'factories',
#  'inflation',
#  'euro',
#  'eurostat',
#  'prices',
#  'march',
#  'rate',
#  'percentage',
#  'eu',
#  'increase',
#  'energy',
#  'forex',
#  'fx',
#  'currency',
#  'russia',
#  'exchange',
#  'rouble',
#  'adjustments',
#  'controls',
#  'importers',
#  'foreign',
#  'beijing',
#  'boao',
#  'china',
#  'macroeconomic',
#  'economy',
#  'gdp',
#  'forecasts',
#  'investments',
#  'policy',
#  'spillovers',
#  'consumption',
#  'economy',
#  'spending',
#  'pandemic',
#  'covid',
#  'coronavirus',
#  'consumer',
#  'inflationary',
#  'holiday',
#  'energy',
#  'gdp',
#  'tourism',
#  'pandemic',
#  'travel',
#  'trillion',
#  'covid',
#  'growth',
#  'china',
#  'industry',
#  'coronavirus',
#  'yen',
#  'currency',
#  'japan',
#  'markets',
#  'economic',
#  'inflation',
#  'bank',
#  'declines',
#  'reuters',
#  'rates',
#  'g',
#  'sanctions',
#  'ukraine',
#  'briefing',
#  'moscow',
#  'indrawati',
#  'meeting',
#  'cooperation',
#  'global',
#  'reuters',
#  'insurance',
#  'premium',
#  'premiums',
#  'insurers',
#  'pricing',
#  'inflation',
#  'cost',
#  'policy',
#  'increase',
#  'motorists',
#  'inflation',
#  'macroeconomic',
#  'monetary',
#  'economists',
#  'brazilian',
#  'suspended',
#  'interruption',
#  'policymakers',
#  'monitoring',
#  'rates',
#  'inflation',
#  'mexico',
#  'mexican',
#  'forecast',
#  'monetary',
#  'rate',
#  'prices',
#  'april',
#  'march',
#  'percentage',
#  'fed',
#  'dollar',
#  'rates',
#  'futures',
#  'euro',
#  'bets',
#  'treasuries',
#  'prices',
#  'funds',
#  'pace',
#  'fed',
#  'dollar',
#  'rates',
#  'futures',
#  'euro',
#  'bets',
#  'treasuries',
#  'prices',
#  'funds',
#  'pace',
#  'treasury',
#  'usd',
#  'yen',
#  'currencies',
#  'yields',
#  'fed',
#  'fx',
#  'inflation',
#  'slowdown',
#  'low',
#  'euro',
#  'eurozone',
#  'bundesbank',
#  'currency',
#  'monetary',
#  'joachim',
#  'bank',
#  'belgian',
#  'inflation',
#  'rates',
#  'currency',
#  'g',
#  'suzuki',
#  'yen',
#  'treasury',
#  'japan',
#  'finance',
#  'markets',
#  'reuters',
#  'bank',
#  'yen',
#  'fx',
#  'japan',
#  'currency',
#  'frx',
#  'markets',
#  'investors',
#  'market',
#  'fingfx',
#  'exchange',
#  'yuan',
#  'inflation',
#  'currencies',
#  'monetary',
#  'asia',
#  'malaysian',
#  'thai',
#  'chinese',
#  'banks',
#  'bets',
#  'yen',
#  'currency',
#  'markets',
#  'boj',
#  'intervention',
#  'speculative',
#  'balance',
#  'depreciation',
#  'japan',
#  'threatening',
#  'trump',
#  'fundraising',
#  'wall',
#  'bannon',
#  'campaign',
#  'presidential',
#  'guilty',
#  'prosecutors',
#  'kolfage',
#  'pleaded',
#  'funding',
#  'biden',
#  'aid',
#  'ukraine',
#  'artillery',
#  'howitzers',
#  'million',
#  'pledged',
#  'campaign',
#  'war',
#  'prosecutor',
#  'agency',
#  'director',
#  'bureau',
#  'gun',
#  'dettelbach',
#  'attorney',
#  'biden',
#  'firearms',
#  'deputy',
#  'trump',
#  'fundraising',
#  'wall',
#  'bannon',
#  'campaign',
#  'presidential',
#  'guilty',
#  'prosecutors',
#  'kolfage',
#  'pleaded',
#  'funding',
#  'biden',
#  'aid',
#  'ukraine',
#  'artillery',
#  'howitzers',
#  'million',
#  'pledged',
#  'campaign',
#  'war',
#  'prosecutor',
#  'agency',
#  'director',
#  'bureau',
#  'gun',
#  'dettelbach',
#  'attorney',
#  'biden',
#  'firearms',
#  'deputy',
#  'gap',
#  'nyse',
#  'shares',
#  'sales',
#  'trading',
#  'company',
#  'brand',
#  'navy',
#  'promotional',
#  'ceo',
#  'earnings',
#  'beer',
#  'nyse',
#  'shares',
#  'adams',
#  'revenue',
#  'boston',
#  'brands',
#  'sam',
#  'tea',
#  'pesos',
#  'financiero',
#  'mexico',
#  'income',
#  'revenue',
#  'forecast',
#  'loan',
#  'profit',
#  'banorte',
#  'billion',
#  'marta',
#  'hall',
#  'chairman',
#  'resigned',
#  'founder',
#  'lidar',
#  'sensor',
#  ...]

# %%
# 당일 키워드 개수
len(today_kw)
# Out:
# 2524

# %% [markdown]
# # 워드클라우드 만들기

# %%
c = Counter(today_kw)
c
# Out:
# Counter({'biden': 15,
#          'fuels': 4,
#          'oil': 17,
#          'warming': 1,
#          'demand': 9,
#          'energy': 5,
#          'geopolitical': 1,
#          'drilling': 3,
#          'campaign': 6,
#          'candidate': 1,
#          'futures': 12,
#          'brent': 4,
#          'petroleum': 5,
#          'crude': 6,
#          'opec': 7,
#          'barrels': 4,
#          'traders': 3,
#          'prices': 18,
#          'wti': 1,
#          'investing': 27,
#          'bullish': 1,
#          'refinery': 1,
#          'chevron': 2,
#          'gasoline': 2,
#          'refineries': 1,
#          'coast': 1,
#          'cvx': 1,
#          'maintenance': 1,
#          'exports': 9,
#          'ukraine': 33,
#          'ukrainian': 1,
#          'funding': 5,
#          'shevchenko': 1,
#          'banking': 4,
#          'financing': 6,
#          'aid': 6,
#          'finances': 1,
#          'fund': 8,
#          'infrastructure': 3,
#          'corn': 1,
#          'agriculture': 1,
#          'grain': 1,
#          'forecasts': 16,
#          'crop': 1,
#          'planting': 1,
#          'produce': 2,
#          'commodity': 5,
#          'production': 4,
#          'exxon': 2,
#          'emissions': 1,
#          'co': 1,
#          'carbon': 1,
#          'renewable': 1,
#          'fuel': 4,
#          'gm': 2,
#          'mobil': 2,
#          'pipeline': 1,
#          'nyse': 48,
#          'nasdaq': 43,
#          'boeing': 2,
#          'bp': 1,
#          'apple': 4,
#          'aapl': 1,
#          'rdsa': 1,
#          'ba': 1,
#          'shell': 1,
#          'equinor': 1,
#          'imfc': 2,
#          'sanctions': 19,
#          'inflation': 34,
#          'imf': 3,
#          'reuters': 18,
#          'oilfields': 1,
#          'venezuela': 1,
#          'halliburton': 1,
#          'refiners': 1,
#          'caracas': 1,
#          'alekperov': 1,
#          'oilfield': 1,
#          'bpd': 1,
#          'shares': 40,
#          'qatar': 1,
#          'qurna': 1,
#          'owned': 1,
#          'chairman': 4,
#          'company': 12,
#          'moscow': 9,
#          'russian': 18,
#          'investors': 23,
#          'gold': 2,
#          'market': 23,
#          'funds': 3,
#          'holdings': 5,
#          'declining': 1,
#          'yields': 5,
#          'reserve': 2,
#          'eu': 2,
#          'euros': 9,
#          'boiler': 1,
#          'heating': 1,
#          'thermostat': 1,
#          'climate': 1,
#          'europeans': 1,
#          'saving': 1,
#          'ferries': 1,
#          'ferry': 1,
#          'tankers': 1,
#          'boat': 1,
#          'harbor': 1,
#          'shipyard': 1,
#          'maritime': 1,
#          'seas': 1,
#          'propulsion': 1,
#          'stock': 33,
#          'markets': 12,
#          'pop': 1,
#          'china': 11,
#          'day': 1,
#          'featured': 1,
#          'contrast': 1,
#          'sharp': 1,
#          'treasury': 13,
#          'goldsilver': 1,
#          'fed': 16,
#          'dollar': 3,
#          'bank': 9,
#          'bond': 2,
#          'commodities': 4,
#          'libya': 2,
#          'news': 2,
#          'russia': 14,
#          'imports': 6,
#          'reserves': 1,
#          'settle': 1,
#          'settled': 1,
#          'cents': 1,
#          'contract': 1,
#          'barrel': 1,
#          'renewables': 1,
#          'investment': 2,
#          'growth': 8,
#          'economies': 1,
#          'trillion': 2,
#          'customs': 2,
#          'import': 2,
#          'logistical': 2,
#          'exporter': 2,
#          'kremlin': 3,
#          'earnings': 35,
#          'strong': 2,
#          'average': 2,
#          'months': 2,
#          'recent': 2,
#          'reflected': 2,
#          'export': 4,
#          'germany': 2,
#          'german': 2,
#          'economic': 8,
#          'cpi': 2,
#          'rates': 8,
#          'zealand': 2,
#          'recession': 7,
#          'pace': 5,
#          'rising': 2,
#          'economists': 5,
#          'wellington': 2,
#          'korea': 3,
#          'korean': 3,
#          'economy': 7,
#          'shipments': 3,
#          'commerce': 3,
#          'goods': 4,
#          'defrauded': 2,
#          'fines': 1,
#          'claims': 1,
#          'regulator': 1,
#          'securities': 7,
#          'car': 2,
#          'forced': 1,
#          'putin': 9,
#          'g': 7,
#          'appeasement': 1,
#          'ministers': 3,
#          'finance': 8,
#          'tariffs': 2,
#          'subsidies': 1,
#          'supply': 4,
#          'leverage': 2,
#          'buyout': 1,
#          'drugstore': 1,
#          'shareholders': 9,
#          'valuing': 1,
#          'valuation': 1,
#          'equity': 3,
#          'zambia': 1,
#          'debt': 5,
#          'creditors': 1,
#          'creditor': 1,
#          'lender': 2,
#          'pandemic': 4,
#          'yi': 1,
#          'restructuring': 1,
#          'costs': 3,
#          'damage': 1,
#          'billion': 5,
#          'war': 6,
#          'malpass': 1,
#          'estimate': 2,
#          'invasion': 3,
#          'housing': 1,
#          'homes': 1,
#          'speculative': 2,
#          'rents': 1,
#          'buyers': 1,
#          'canadians': 1,
#          'estate': 2,
#          'humana': 1,
#          'kindred': 1,
#          'hospice': 1,
#          'goldman': 3,
#          'insurer': 3,
#          'buybacks': 1,
#          'financial': 8,
#          'ownership': 1,
#          'crises': 1,
#          'administration': 1,
#          'governance': 1,
#          'bloomberg': 6,
#          'briefing': 3,
#          'leaders': 1,
#          'solomon': 1,
#          'islands': 1,
#          'campbell': 1,
#          'pacific': 3,
#          'arrive': 1,
#          'island': 1,
#          'delegation': 1,
#          'talks': 2,
#          'department': 1,
#          'allies': 3,
#          'powell': 5,
#          'yellen': 2,
#          'monetary': 11,
#          'mexico': 3,
#          'currency': 10,
#          'peso': 2,
#          'banked': 1,
#          'digital': 3,
#          'unbanked': 1,
#          'basis': 1,
#          'rate': 3,
#          'march': 7,
#          'hike': 1,
#          'points': 1,
#          'humanitarian': 3,
#          'plan': 2,
#          'budget': 1,
#          'million': 7,
#          'multilateralism': 1,
#          'committee': 1,
#          'consensus': 1,
#          'chaired': 1,
#          'nadia': 1,
#          'bitcoin': 1,
#          'cryptocurrencies': 1,
#          'rouble': 3,
#          'payments': 5,
#          'technologies': 1,
#          'nabiullina': 2,
#          'banks': 5,
#          'policymakers': 3,
#          'federal': 6,
#          'governors': 1,
#          'presidents': 2,
#          'senate': 2,
#          'tesla': 11,
#          'companies': 6,
#          'maker': 1,
#          'consumers': 4,
#          'profitability': 6,
#          'retailers': 2,
#          'products': 3,
#          'fares': 1,
#          'evans': 2,
#          'chicago': 1,
#          'executive': 2,
#          'president': 3,
#          'peaked': 1,
#          'peak': 1,
#          'high': 1,
#          'canada': 1,
#          'escalation': 1,
#          'rocketing': 1,
#          'antitrust': 1,
#          'lawsuit': 3,
#          'monopoly': 1,
#          'appealed': 2,
#          'netflix': 6,
#          'case': 1,
#          'dispute': 1,
#          'brexit': 1,
#          'prize': 1,
#          'seen': 1,
#          'great': 1,
#          'easing': 2,
#          'fiscal': 1,
#          'borrowing': 1,
#          'daly': 2,
#          'raising': 1,
#          'neutral': 1,
#          'puerto': 1,
#          'rican': 1,
#          'ssi': 1,
#          'rico': 1,
#          'sotomayor': 1,
#          'kavanaugh': 1,
#          'vaello': 1,
#          'guam': 1,
#          'discrimination': 1,
#          'assets': 2,
#          'sequestered': 1,
#          'rebuilding': 1,
#          'confiscated': 1,
#          'tai': 1,
#          'travel': 3,
#          'met': 1,
#          'britain': 1,
#          'trade': 2,
#          'atlantic': 1,
#          'british': 1,
#          'katherine': 1,
#          'uk': 1,
#          'sanctioning': 1,
#          'belarus': 1,
#          'oligarch': 1,
#          'unemployment': 1,
#          'labor': 2,
#          'shortage': 1,
#          'layoffs': 1,
#          'payrolls': 1,
#          'globalisation': 1,
#          'regimes': 1,
#          'alliances': 1,
#          'durch': 1,
#          'vladimir': 2,
#          'tatiana': 1,
#          'economist': 1,
#          'facebook': 2,
#          'vietnamese': 1,
#          'censorship': 1,
#          'twitter': 5,
#          'enforced': 1,
#          'media': 2,
#          'livestreams': 1,
#          'minh': 1,
#          'communist': 1,
#          'restrict': 1,
#          'bans': 1,
#          'restrictions': 1,
#          'carlsberg': 1,
#          'copenhagen': 2,
#          'depreciation': 3,
#          'revenue': 28,
#          'danish': 1,
#          'sell': 1,
#          'pedersen': 1,
#          'heineken': 2,
#          'breweries': 1,
#          'bundesbank': 2,
#          'ecb': 2,
#          'stimulus': 1,
#          'forecast': 9,
#          'future': 2,
#          'early': 2,
#          'euro': 5,
#          'july': 1,
#          'bonds': 2,
#          'analysts': 26,
#          'quarterly': 5,
#          'stocks': 26,
#          'retirement': 1,
#          'employment': 1,
#          'jobs': 1,
#          'workers': 2,
#          'return': 1,
#          'report': 2,
#          'older': 1,
#          'month': 1,
#          'bankers': 1,
#          'maximum': 1,
#          'value': 1,
#          'government': 1,
#          'conditions': 1,
#          'adjust': 1,
#          'dictate': 1,
#          'hong': 3,
#          'exchanges': 1,
#          'chinese': 4,
#          'connect': 1,
#          'channel': 2,
#          'india': 1,
#          'boris': 1,
#          'gujarat': 1,
#          'reliance': 1,
#          'foreign': 4,
#          'countries': 1,
#          'modi': 1,
#          'holiday': 2,
#          'spending': 3,
#          'london': 1,
#          'easter': 1,
#          'weekend': 1,
#          'bookings': 1,
#          'covid': 7,
#          'shanghai': 3,
#          'reopening': 1,
#          'quarantine': 1,
#          'funeral': 1,
#          'carmaker': 2,
#          'resuming': 2,
#          'investigating': 1,
#          'factories': 1,
#          'eurostat': 1,
#          'percentage': 2,
#          'increase': 2,
#          'forex': 1,
#          'fx': 3,
#          'exchange': 4,
#          'adjustments': 1,
#          'controls': 1,
#          'importers': 1,
#          'beijing': 2,
#          'boao': 1,
#          'macroeconomic': 2,
#          'gdp': 2,
#          'investments': 4,
#          'policy': 3,
#          'spillovers': 1,
#          'consumption': 1,
#          'coronavirus': 3,
#          'consumer': 2,
#          'inflationary': 3,
#          'tourism': 2,
#          'industry': 1,
#          'yen': 5,
#          'japan': 5,
#          'declines': 1,
#          'indrawati': 1,
#          'meeting': 1,
#          'cooperation': 1,
#          'global': 1,
#          'insurance': 1,
#          'premium': 1,
#          'premiums': 1,
#          'insurers': 1,
#          'pricing': 1,
#          'cost': 2,
#          'motorists': 1,
#          'brazilian': 2,
#          'suspended': 1,
#          'interruption': 1,
#          'monitoring': 1,
#          'mexican': 1,
#          'april': 2,
#          'bets': 3,
#          'treasuries': 2,
#          'usd': 1,
#          'currencies': 3,
#          'slowdown': 1,
#          'low': 1,
#          'eurozone': 2,
#          'joachim': 1,
#          'belgian': 1,
#          'suzuki': 1,
#          'frx': 1,
#          'fingfx': 1,
#          'yuan': 4,
#          'asia': 2,
#          'malaysian': 1,
#          'thai': 1,
#          'boj': 1,
#          'intervention': 1,
#          'balance': 1,
#          'threatening': 1,
#          'trump': 3,
#          'fundraising': 2,
#          'wall': 2,
#          'bannon': 2,
#          'presidential': 3,
#          'guilty': 2,
#          'prosecutors': 2,
#          'kolfage': 2,
#          'pleaded': 2,
#          'artillery': 3,
#          'howitzers': 2,
#          'pledged': 3,
#          'prosecutor': 2,
#          'agency': 2,
#          'director': 2,
#          'bureau': 4,
#          'gun': 2,
#          'dettelbach': 2,
#          'attorney': 3,
#          'firearms': 2,
#          'deputy': 2,
#          'gap': 1,
#          'sales': 15,
#          'trading': 21,
#          'brand': 1,
#          'navy': 1,
#          'promotional': 1,
#          'ceo': 7,
#          'beer': 1,
#          'adams': 1,
#          'boston': 1,
#          'brands': 2,
#          'sam': 1,
#          'tea': 1,
#          'pesos': 2,
#          'financiero': 1,
#          'income': 3,
#          'loan': 2,
#          'profit': 9,
#          'banorte': 1,
#          'marta': 1,
#          'hall': 1,
#          'resigned': 1,
#          'founder': 1,
#          'lidar': 1,
#          'sensor': 1,
#          'velodyne': 1,
#          'david': 1,
#          'musk': 7,
#          'takeover': 4,
#          'twtr': 3,
#          'thoma': 1,
#          'compliance': 1,
#          'anchorage': 1,
#          'laundering': 1,
#          'charter': 1,
#          'crypto': 1,
#          'sioux': 1,
#          'comptroller': 1,
#          'bhp': 2,
#          'miners': 2,
#          'copper': 3,
#          'chile': 2,
#          'escondida': 1,
#          'concerns': 1,
#          'ore': 2,
#          'tonnes': 2,
#          'snap': 2,
#          'selling': 1,
#          'business': 5,
#          'dow': 12,
#          'losses': 4,
#          'moneygram': 1,
#          'remittance': 1,
#          'refunds': 1,
#          'transfers': 1,
#          'electronically': 1,
#          'complaint': 1,
#          'transaction': 1,
#          'melvin': 2,
#          'betting': 1,
#          'capital': 2,
#          'gamestop': 1,
#          'snapchat': 1,
#          'surgical': 2,
#          'innovation': 1,
#          'vinci': 1,
#          'ibm': 1,
#          'ppg': 1,
#          'industries': 2,
#          'coatings': 1,
#          'eps': 3,
#          'tomorrow': 1,
#          'congress': 1,
#          'expectations': 1,
#          'upcoming': 3,
#          'gucci': 1,
#          'citi': 1,
#          'shareholder': 5,
#          'investor': 5,
#          'southwest': 1,
#          'buyer': 1,
#          'icahn': 1,
#          'acquisition': 2,
#          'iphone': 1,
#          'ipad': 1,
#          'forecasting': 2,
#          'trend': 1,
#          'yield': 1,
#          'peru': 1,
#          'cuajone': 1,
#          'mining': 2,
#          'protests': 1,
#          'mineral': 2,
#          'emergency': 1,
#          'pedro': 1,
#          'castillo': 1,
#          'mobilizing': 1,
#          'argos': 1,
#          'grupo': 1,
#          'nutresa': 1,
#          'participate': 1,
#          'conglomerate': 1,
#          'refused': 1,
#          'colombian': 1,
#          'verizon': 1,
#          'vz': 1,
#          'communications': 2,
#          'marathon': 1,
#          'refiner': 1,
#          'houston': 1,
#          'operates': 1,
#          'chemotherapy': 1,
#          'refining': 1,
#          'leading': 1,
#          'dividend': 1,
#          'vmi': 1,
#          'valmont': 1,
#          'earning': 1,
#          'nordex': 1,
#          'etr': 1,
#          'siemens': 1,
#          'dax': 1,
#          'ag': 1,
#          'eurofins': 1,
#          'eufi': 1,
#          'saf': 1,
#          'france': 2,
#          'carrefour': 2,
#          'cac': 1,
#          'airline': 2,
#          'carrier': 2,
#          'alitalia': 1,
#          'ita': 1,
#          'airways': 1,
#          'equita': 1,
#          'privatisation': 2,
#          'mp': 1,
#          'magnet': 1,
#          'alloy': 1,
#          'manufacturing': 1,
#          'materials': 1,
#          'fort': 1,
#          'dividends': 1,
#          'revenues': 1,
#          'blackstone': 1,
#          'nflx': 3,
#          'airlines': 8,
#          'grave': 1,
#          'cemetery': 1,
#          'graves': 1,
#          'maxar': 1,
#          'maxr': 1,
#          'mariupol': 2,
#          'expansion': 1,
#          'kilometers': 1,
#          'near': 1,
#          'dealerships': 1,
#          'auto': 1,
#          'autonation': 1,
#          'trends': 2,
#          'retailer': 6,
#          'fidelity': 1,
#          'brokerage': 1,
#          'metaverse': 1,
#          'building': 1,
#          'virtual': 1,
#          'opened': 1,
#          'education': 1,
#          'retail': 1,
#          'cse': 1,
#          'nordisk': 1,
#          'feedstocks': 1,
#          'chemicals': 1,
#          'gains': 2,
#          'sandberg': 1,
#          'kotick': 1,
#          'published': 1,
#          'mail': 1,
#          'story': 1,
#          'wsj': 1,
#          'warned': 1,
#          'told': 1,
#          'denied': 1,
#          'prospects': 1,
#          'automaker': 2,
#          'hypermarkets': 1,
#          'purchasing': 2,
#          'carvana': 1,
#          'cvna': 1,
#          'strategics': 1,
#          'share': 4,
#          'saudi': 1,
#          'tadawul': 1,
#          'xom': 1,
#          'xerox': 1,
#          'xrx': 1,
#          'loss': 1,
#          'firm': 2,
#          'telecommunications': 1,
#          'hbo': 1,
#          'estimated': 3,
#          'net': 1,
#          'aal': 1,
#          'miles': 1,
#          'passenger': 1,
#          'acquire': 2,
#          'spear': 1,
#          'price': 2,
#          'lam': 2,
#          'estimates': 1,
#          'margins': 1,
#          'premarket': 3,
#          'fq': 1,
#          'supplier': 1,
#          'minivans': 1,
#          'minivan': 1,
#          'citroen': 1,
#          'sedan': 1,
#          'c': 1,
#          'suvs': 1,
#          'cx': 1,
#          'stellantis': 1,
#          'grand': 1,
#          'morris': 3,
#          'philip': 3,
#          'corporate': 1,
#          'meat': 2,
#          'foods': 1,
#          'upside': 1,
#          'cultivated': 1,
#          'nestle': 3,
#          'organic': 1,
#          'conservative': 1,
#          'margin': 1,
#          'guidance': 1,
#          'increased': 1,
#          'tobacco': 1,
#          'international': 1,
#          'longtime': 1,
#          'associate': 1,
#          'pm': 1,
#          'alcoa': 1,
#          'alumina': 1,
#          'aluminum': 1,
#          'ebitda': 1,
#          'selloff': 1,
#          'aa': 1,
#          'hedge': 2,
#          'invested': 2,
#          'plotkin': 1,
#          'reinvest': 1,
#          'returns': 1,
#          'didi': 1,
#          'delaying': 1,
#          'railroads': 1,
#          'railroad': 1,
#          'corp': 2,
#          'chain': 1,
#          'zlotys': 1,
#          'inventory': 1,
#          'poland': 1,
#          'merchandise': 1,
#          'surplus': 1,
#          'lutkiewicz': 1,
#          'italia': 1,
#          'milan': 1,
#          'credit': 1,
#          'guarantee': 1,
#          'sace': 1,
#          'luxury': 2,
#          'lvmh': 2,
#          'vuitton': 1,
#          'hotels': 2,
#          'union': 1,
#          'csx': 1,
#          'focus': 1,
#          'updates': 1,
#          'nurse': 1,
#          'st': 1,
#          'thursday': 1,
#          'generali': 2,
#          'gasi': 2,
#          'francesco': 2,
#          'billionaires': 1,
#          'gaetano': 1,
#          'donnet': 2,
#          'assicurazioni': 1,
#          'nextera': 1,
#          'food': 1,
#          'dairy': 1,
#          'toshiba': 1,
#          'otc': 2,
#          'tosyy': 1,
#          'strategic': 4,
#          'approved': 1,
#          'evaluation': 1,
#          'alternatives': 1,
#          'lockheed': 1,
#          'flying': 1,
#          'jetblue': 1,
#          'richest': 3,
#          'pemex': 1,
#          'eurobond': 1,
#          'andres': 1,
#          'repayments': 1,
#          'cash': 1,
#          'sba': 1,
#          'trustee': 1,
#          'costco': 1,
#          'deliveries': 1,
#          'delays': 1,
#          'planemaker': 1,
#          'plans': 2,
#          'wbd': 1,
#          'warnermedia': 1,
#          'merger': 1,
#          'warner': 1,
#          'discovery': 1,
#          'unit': 1,
#          'new': 1,
#          'automotive': 1,
#          'evs': 1,
#          'driven': 1,
#          'tata': 1,
#          'nse': 1,
#          'sensex': 1,
#          'maruti': 1,
#          'bse': 1,
#          'hitachi': 1,
#          'kkr': 1,
#          'kohlberg': 1,
#          'nikkei': 2,
#          'roberts': 1,
#          'logistics': 1,
#          'reports': 2,
#          'invest': 1,
#          'billionaire': 3,
#          'liquefied': 1,
#          'lng': 1,
#          'offshore': 2,
#          'wns': 1,
#          'buywithprime': 1,
#          'prime': 1,
#          'ecommerce': 1,
#          'shopping': 1,
#          'amazon': 2,
#          'bigcommerce': 1,
#          'deals': 1,
#          'checkout': 1,
#          'delivery': 1,
#          'polled': 1,
#          'outperforming': 1,
#          'danaher': 1,
#          'dhr': 1,
#          'paris': 1,
#          'boutiques': 1,
#          'employees': 1,
#          'bompard': 1,
#          'tard': 1,
#          'alexandre': 1,
#          'asset': 1,
#          'unveil': 1,
#          'roles': 1,
#          'technical': 1,
#          'operations': 1,
#          'creative': 1,
#          'thg': 1,
#          'indicative': 1,
#          'tentative': 1,
#          'gmt': 1,
#          'speculation': 1,
#          'moulding': 1,
#          'retaining': 1,
#          'sued': 1,
#          'litigation': 1,
#          'carmakers': 1,
#          'mandate': 3,
#          'masking': 1,
#          'mandates': 1,
#          'masks': 1,
#          'requiring': 1,
#          'enforce': 2,
#          'moratorium': 1,
#          'ruling': 2,
#          'pepco': 1,
#          'discount': 1,
#          'shoppers': 1,
#          'customers': 4,
#          'macron': 3,
#          'asx': 1,
#          'bxb': 1,
#          'sydney': 1,
#          'cgf': 1,
#          'fujikura': 1,
#          'tokyo': 1,
#          'unionpay': 1,
#          'russians': 1,
#          'debit': 1,
#          'hsbc': 1,
#          'lenders': 1,
#          'abb': 1,
#          'deloitte': 1,
#          'auditing': 1,
#          'audit': 1,
#          'charlton': 1,
#          'mitie': 1,
#          'fined': 1,
#          'goodwill': 1,
#          'breaches': 1,
#          'dishonest': 1,
#          'ftse': 1,
#          'eurostar': 1,
#          'traffic': 1,
#          'freight': 1,
#          'tunnel': 1,
#          'getlink': 1,
#          'trains': 1,
#          'rail': 1,
#          'sachs': 1,
#          'hotel': 1,
#          'radisson': 1,
#          'booking': 1,
#          'worldwide': 1,
#          'cnooc': 2,
#          'cny': 1,
#          'shenzhen': 2,
#          'hyundai': 1,
#          'kia': 1,
#          'cars': 1,
#          'factory': 1,
#          'spacex': 2,
#          'ventures': 1,
#          'rocket': 1,
#          'hyperloop': 1,
#          'elon': 1,
#          'slump': 2,
#          'lending': 1,
#          'rebound': 1,
#          'lockdowns': 2,
#          'lost': 1,
#          'said': 1,
#          'ackman': 1,
#          'delta': 1,
#          'mask': 2,
#          'enforcement': 1,
#          'violations': 1,
#          'comply': 1,
#          'barred': 1,
#          'passengers': 1,
#          'withdraw': 1,
#          'pension': 1,
#          'proposal': 1,
#          'review': 1,
#          'amzn': 1,
#          'agreement': 1,
#          'kohl': 1,
#          'bidders': 1,
#          'bidding': 1,
#          'llc': 1,
#          'macellum': 1,
#          'sale': 1,
#          'mainland': 1,
#          'abpa': 1,
#          'xingang': 1,
#          'owns': 1,
#          'ventas': 1,
#          'firms': 1,
#          'stake': 1,
#          'buildings': 1,
#          'iron': 1,
#          'suppliers': 1,
#          'gillette': 1,
#          'competitors': 1,
#          'starbucks': 1,
#          'sbux': 1,
#          'unions': 1,
#          'complaints': 1,
#          'cafe': 1,
#          'forbes': 1,
#          'salary': 1,
#          'compensation': 1,
#          'satellite': 1,
#          'network': 1,
#          'nasa': 1,
#          'starlink': 1,
#          'broadband': 1,
#          'spacecraft': 1,
#          'internet': 1,
#          'streaming': 2,
#          'roku': 1,
#          'decline': 1,
#          'advertisement': 1,
#          'executives': 1,
#          'subscribers': 1,
#          'accounts': 1,
#          ...})

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/Malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

c = Counter(today_kw)
wc = WordCloud(font_path='malgun', width=800, height=800, max_font_size=250, colormap='Dark2',scale=2.0,font_step=4,
               background_color='whitesmoke', prefer_horizontal = True, max_words=50, random_state=1)
gen = wc.generate_from_frequencies(c)
plt.figure(figsize=(15,15))

plt.title("키워드로 보는 미국시장", size = 20)
plt.axis('off') # 그래프 축 제거
plt.imshow(gen)

# %%
# colormap 종류

# plot_color_gradients('Sequential',
#                      ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
#                       'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
#                       'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'])

# plot_color_gradients('Sequential (2)',
#                      ['binary', 'gist_yarg', 'gist_gray', 'gray', 'bone',
#                       'pink', 'spring', 'summer', 'autumn', 'winter', 'cool',
#                       'Wistia', 'hot', 'afmhot', 'gist_heat', 'copper'])

                     
# plot_color_gradients('Qualitative',
#                      ['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2',
#                       'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b',
#                       'tab20c'])

# %% [markdown]
# # 워드클라우드 작동코드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from PIL import Image

# 파일경로 설정해줘야 함
df_kw = pd.read_csv('./data/당일키워드/keyword_0422.csv',index_col=0)

# 기사당 키워드 10개 뽑는 함수
def kw_tolist(words):
    num = 10
    kw_list = re.sub('[^A-Za-z ]',"",words).split()
    return kw_list[:num] 

df_kw['kw_list'] = df_kw['keywords'].apply(kw_tolist)

#당일 키워드 전체
today_kw =  df_kw['kw_list'].sum()

# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/Malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

c = Counter(today_kw)
wc = WordCloud(font_path='malgun', width=800, height=800, max_font_size=250, colormap='Dark2',scale=2.0,font_step=4,
               background_color='whitesmoke', prefer_horizontal = True, max_words=50, random_state=1)
gen = wc.generate_from_frequencies(c)
plt.figure(figsize=(15,15))

plt.title("키워드로 보는 미국시장", size = 30)
plt.axis('off') # 그래프 축 제거
plt.imshow(gen)

# %% [markdown]
# # 단어빈도수 bar chart

# %%
# 빈도수 기준으로 내림차순 정렬
c1 = sorted(c.items(),reverse=True, key=lambda x: x[1])
c1[:5]
# Out:
# [('oil', 814),
#  ('futures', 567),
#  ('crude', 494),
#  ('opec', 416),
#  ('prices', 410)]

# %%
c1[0][0]
# Out:
# 'oil'

# %%
# 상위 50개 단어만 리스트에 담기
num = 50
words = []
counts = []
for i in range(num):
    words.append(c1[i][0])
    counts.append(c1[i][1])

# %%
print(words[:5])
print(counts[:5])
# Out:
# ['oil', 'futures', 'crude', 'opec', 'prices']
# [814, 567, 494, 416, 410]

# %%
words_r = reversed(words)
list(words_r)
# Out:
# ['energy',
#  'forecast',
#  'saudi',
#  'yields',
#  'reserves',
#  'supply',
#  'omicron',
#  'refinery',
#  'stockpiles',
#  'trading',
#  'nyse',
#  'diesel',
#  'forecasts',
#  'traders',
#  'market',
#  'emissions',
#  'biden',
#  'russia',
#  'putin',
#  'bloomberg',
#  'commodity',
#  'dollar',
#  'wti',
#  'treasury',
#  'fuels',
#  'gas',
#  'stocks',
#  'fed',
#  'commodities',
#  'moscow',
#  'investing',
#  'gasoline',
#  'fuel',
#  'russian',
#  'reuters',
#  'exports',
#  'ukraine',
#  'gold',
#  'demand',
#  'markets',
#  'inflation',
#  'brent',
#  'barrels',
#  'sanctions',
#  'petroleum',
#  'prices',
#  'opec',
#  'crude',
#  'futures',
#  'oil']

# %%
counts_r = list(reversed(counts))
counts_r
# Out:
# [70,
#  70,
#  71,
#  72,
#  73,
#  74,
#  76,
#  76,
#  85,
#  85,
#  86,
#  89,
#  90,
#  95,
#  96,
#  100,
#  100,
#  103,
#  104,
#  105,
#  105,
#  106,
#  110,
#  111,
#  111,
#  114,
#  118,
#  121,
#  125,
#  135,
#  141,
#  143,
#  160,
#  160,
#  161,
#  190,
#  208,
#  210,
#  216,
#  223,
#  235,
#  255,
#  331,
#  355,
#  398,
#  410,
#  416,
#  494,
#  567,
#  814]

# %% [markdown]
# # barchart 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

# c 는 워드클라우드 코드에서 받아옴

# 빈도수 기준으로 내림차순 정렬
c1 = sorted(c.items(),reverse=True, key=lambda x: x[1])

# 상위 50개 단어만 리스트에 담기
num = 50
words = []
counts = []
for i in range(num):
    words.append(c1[i][0])
    counts.append(c1[i][1])


words_r = list(reversed(words))
counts_r = list(reversed(counts))

y = np.arange(50)
plt.figure(figsize=(10,10))
title_font = {
    'fontsize': 30,
    'fontweight': 'bold'}
plt.title('키워드 빈도수', fontdict=title_font, pad=20)
plt.barh(y,counts_r)
plt.yticks(y,words_r)

plt.show()
