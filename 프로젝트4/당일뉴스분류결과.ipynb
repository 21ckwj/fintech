# %% [markdown]
# # 당일 뉴스 분류 결과

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

#데이터프레임의 모든 column의 폭 최대화
pd.set_option('display.max_colwidth', -1)

#데이터프레임의 row 500(물론 column 값도 지정가능합니다)
pd.set_option('display.max_row', 500)
# Out:
# C:\Users\21ckw\AppData\Local\Temp/ipykernel_22064/807685918.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('./data/당일뉴스/당일뉴스분류_0422.csv',index_col=0)
df
# Out:
#            date                                           news_oil  news_ship  \
# 0    2022-04-22  As a candidate, Joe Biden made climate change ...        NaN
# 1    2022-04-22  By David Gaffen\nNEW YORK (Reuters) -Oil price...        NaN
# 2    2022-04-22  By Barani Krishnan\nInvesting.com -- Oil price...        NaN
# 3    2022-04-22                                                NaN        NaN
# 4    2022-04-22  U.S. companies can help rebuild Ukraine with d...        NaN
# ..          ...                                                ...        ...
# 243  2022-04-22                                                NaN        NaN
# 244  2022-04-22  G7 finance ministers said they have provided a...        NaN
# 245  2022-04-22                                                NaN        NaN
# 246  2022-04-22  President Joe Biden convened U.S. military lea...        NaN
# 247  2022-04-22  Ukraine proposed talks with Moscow over evacua...        NaN
#
# ...

# %% [markdown]
# ## 석유와 가스부분

# %%
df_oil = df.dropna(subset='news_oil')[['date','news_oil']]

# %%
len(df_oil)
# Out:
# 61

# %%
df_oil.reset_index(drop=True)
# Out:
#           date  \
# 0   2022-04-22
# 1   2022-04-22
# 2   2022-04-22
# 3   2022-04-22
# 4   2022-04-22
# 5   2022-04-22
# 6   2022-04-22
# 7   2022-04-22
# 8   2022-04-22
# 9   2022-04-22
# 10  2022-04-22
# 11  2022-04-22
# 12  2022-04-22
# 13  2022-04-22
# 14  2022-04-22
# 15  2022-04-22
# 16  2022-04-22
# 17  2022-04-22
# 18  2022-04-22
# 19  2022-04-22
# 20  2022-04-22
# 21  2022-04-22
# 22  2022-04-22
# 23  2022-04-22
# 24  2022-04-22
# 25  2022-04-22
# 26  2022-04-22
# 27  2022-04-22
# 28  2022-04-22
# 29  2022-04-22
# 30  2022-04-22
# 31  2022-04-22
# 32  2022-04-22
# 33  2022-04-22
# 34  2022-04-22
# 35  2022-04-22
# 36  2022-04-22
# 37  2022-04-22
# 38  2022-04-22
# 39  2022-04-22
# 40  2022-04-22
# 41  2022-04-22
# 42  2022-04-22
# 43  2022-04-22
# 44  2022-04-22
# 45  2022-04-22
# 46  2022-04-22
# 47  2022-04-22
# 48  2022-04-22
# 49  2022-04-22
# 50  2022-04-22
# 51  2022-04-22
# 52  2022-04-22
# 53  2022-04-22
# 54  2022-04-22
# 55  2022-04-22
# 56  2022-04-22
# ...

# %% [markdown]
# ## 자동차 부분

# %%
df_vh = df.dropna(subset='news_vh')[['date','news_vh']]

# %%
len(df_vh)
# Out:
# 11

# %%
df_vh
# Out:
#            date  \
# 93   2022-04-22
# 103  2022-04-22
# 120  2022-04-22
# 124  2022-04-22
# 129  2022-04-22
# 163  2022-04-22
# 165  2022-04-22
# 170  2022-04-22
# 184  2022-04-22
# 200  2022-04-22
# 215  2022-04-22
#
# ...

# %% [markdown]
# ## 반도체 부분

# %%
df_sc = df.dropna(subset='news_sc')[['date','news_sc']]

# %%
df_sc
# Out:
#            date  \
# 47   2022-04-22
# 110  2022-04-22
#
# ...

# %% [markdown]
# ## 철강 부분

# %%
df_steel = df.dropna(subset='news_steel')[['date','news_steel']]
df_steel
# Out:
# Empty DataFrame
# Columns: [date, news_steel]
# Index: []

# %% [markdown]
# ## 조선

# %%
df_ship = df.dropna(subset='news_ship')[['date','news_ship']]
df_ship
# Out:
# Empty DataFrame
# Columns: [date, news_ship]
# Index: []

# %% [markdown]
# ## 기타 뉴스

# %%
df_others = df.dropna(subset='news_others')[['date','news_others']]
df_others
# Out:
#            date  \
# 3    2022-04-22
# 5    2022-04-22
# 6    2022-04-22
# 7    2022-04-22
# 8    2022-04-22
# 9    2022-04-22
# 10   2022-04-22
# 11   2022-04-22
# 12   2022-04-22
# 13   2022-04-22
# 15   2022-04-22
# 16   2022-04-22
# 17   2022-04-22
# 18   2022-04-22
# 19   2022-04-22
# 20   2022-04-22
# 22   2022-04-22
# 24   2022-04-22
# 25   2022-04-22
# 26   2022-04-22
# 28   2022-04-22
# 29   2022-04-22
# 30   2022-04-22
# 32   2022-04-22
# 33   2022-04-22
# 35   2022-04-22
# 37   2022-04-22
# 38   2022-04-22
# 43   2022-04-22
# 44   2022-04-22
# 45   2022-04-22
# 46   2022-04-22
# 48   2022-04-22
# 49   2022-04-22
# 50   2022-04-22
# 52   2022-04-22
# 54   2022-04-22
# 57   2022-04-22
# 60   2022-04-22
# 61   2022-04-22
# 62   2022-04-22
# 63   2022-04-22
# 64   2022-04-22
# 65   2022-04-22
# 67   2022-04-22
# 69   2022-04-22
# 71   2022-04-22
# 72   2022-04-22
# 74   2022-04-22
# 76   2022-04-22
# 77   2022-04-22
# 78   2022-04-22
# 79   2022-04-22
# 80   2022-04-22
# ...
