# %%
import pandas as pd
import numpy as np
import re
import os

# %%
import FinanceDataReader as fdr

# %%
lst1 = []
file_list1 = os.listdir('./data/개별기업뉴스_자연어처리/')
for file in file_list1:
    corp = file[:-4]
    lst1.append(corp)

# %%
df1 = pd.Series(lst1).to_frame()
print(len(df1))
df1.head()
# Out:
# 474
#         0
# 0  AJ네트웍스
# 1   AK홀딩스
# 2     BGF
# 3     BYC
# 4  CJ CGV

# %%
df1[df1[0].str.contains('삼화')]
# Out:
#         0
# 230  삼화전기

# %% [markdown]
# # 누락 40기업 회사이름이 다름

# %%
file_list2 = pd.read_csv('./data/개별기업명_511.csv')
lst_511 = pd.Series(file_list2['회사이름'])

# %%
x_list = lst_511[~lst_511.isin(lst1)]
x_list
# Out:
# 13           삼화페인트
# 50            DI동일
# 59           삼화콘덴서
# 68          한국수출포장
# 80            아모레G
# 101          쌍용C&E
# 105            IHQ
# 107            쌍용차
# 109           삼영화학
# 118           한국석유
# 119           태양금속
# 123            NPC
# 148           롯데칠성
# 151            현대차
# 156           삼영전자
# 159         대림B&Co
# 169           화승인더
# 198         F&F홀딩스
# 209           KCTC
# 224          무림P&P
# 230          한국프랜지
# 231    LS ELECTRIC
# 247           삼화전자
# 253           한신기계
# 255           금호석유
# 275           계룡건설
# 291           한국전력
# 301           서울가스
# 304         현대엘리베이
# 331         SJM홀딩스
# 332           한국단자
# 346             KT
# 358           KT&G
# 389          동원F&B
# 394         스카이라이프
# 405        세이브존I&C
# 409         TKG휴켐스
# 450          효성ITX
# 476            SJM
# 510       엘브이엠씨홀딩스
# Name: 회사이름, dtype: object

# %%
len(lst_511[~lst_511.isin(lst1)])
# Out:
# 40

# %%
x_list.to_frame().to_csv('./data/누락기업40.csv')

# %%
x_list.to_frame()
# Out:
#             회사이름
# 13         삼화페인트
# 50          DI동일
# 59         삼화콘덴서
# 68        한국수출포장
# 80          아모레G
# 101        쌍용C&E
# 105          IHQ
# 107          쌍용차
# 109         삼영화학
# 118         한국석유
# 119         태양금속
# 123          NPC
# 148         롯데칠성
# 151          현대차
# 156         삼영전자
# 159       대림B&Co
# 169         화승인더
# 198       F&F홀딩스
# 209         KCTC
# 224        무림P&P
# 230        한국프랜지
# 231  LS ELECTRIC
# 247         삼화전자
# 253         한신기계
# 255         금호석유
# 275         계룡건설
# 291         한국전력
# 301         서울가스
# 304       현대엘리베이
# 331       SJM홀딩스
# 332         한국단자
# 346           KT
# 358         KT&G
# 389        동원F&B
# 394       스카이라이프
# 405      세이브존I&C
# 409       TKG휴켐스
# 450        효성ITX
# 476          SJM
# 510     엘브이엠씨홀딩스

# %%
df_kospi =fdr.StockListing('KRX')
df_kospi.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df_kospi[df_kospi['Name'].str.contains('삼화')]
# Out:
#       Symbol  Market    Name                     Sector  \
# 4448  046390  KOSDAQ  삼화네트웍스  영화, 비디오물, 방송프로그램 제작 및 배급업
# 4449  004450   KOSPI    삼화왕관             기타 금속 가공제품 제조업
# 4450  009470   KOSPI    삼화전기                   전자부품 제조업
# 4451  011230   KOSPI    삼화전자              영상 및 음향기기 제조업
# 4452  001820   KOSPI   삼화콘덴서                   전자부품 제조업
# 4453  000390   KOSPI   삼화페인트                기타 화학제품 제조업
#
#                                              Industry ListingDate SettleMonth  \
# 4448                             시스템통합(SI), 시스템유지(SM)  2001-01-11         12월
# 4449              납세용 일반병마개,알루미늄캡,플라스틱캡 제조,판매,금속인쇄,수출  1976-05-28         12월
# 4450                                        콘덴서 제조,판매  1986-11-24         12월
# 4451  전자부품(페라이트 코어,SMPS,편향요크(DY),고압변성기(FBT)용코어) 제조,판매  1987-05-25         12월
# 4452                                      콘덴서(축전기) 제조  1976-06-26         12월
# 4453                          건축용페인트,공업용페인트,분체도료 등 제조  1993-09-10         12월
#
# ...

# %%
ja = os.listdir('./data/개별기업뉴스_자연어처리/')
ja
# Out:
# ['AJ네트웍스.csv',
#  'AK홀딩스.csv',
#  'BGF.csv',
#  'BYC.csv',
#  'CJ CGV.csv',
#  'CJ.csv',
#  'CJ대한통운.csv',
#  'CJ제일제당.csv',
#  'CS홀딩스.csv',
#  'DB.csv',
#  'DB하이텍.csv',
#  'DL.csv',
#  'DRB동일.csv',
#  'DSR.csv',
#  'E1.csv',
#  'GS건설.csv',
#  'GS글로벌.csv',
#  'GS리테일.csv',
#  'HDC.csv',
#  'HDC랩스.csv',
#  'HDC현대EP.csv',
#  'HJ중공업.csv',
#  'HMM.csv',
#  'HSD엔진.csv',
#  'JW중외제약.csv',
#  'JW홀딩스.csv',
#  'KC그린홀딩스.csv',
#  'KC코트렐.csv',
#  'KEC.csv',
#  'KG스틸.csv',
#  'KG케미칼.csv',
#  'KH 필룩스.csv',
#  'KISCO홀딩스.csv',
#  'KPX케미칼.csv',
#  'KPX홀딩스.csv',
#  'KR모터스.csv',
#  'KSS해운.csv',
#  'KTcs.csv',
#  'LF.csv',
#  'LG.csv',
#  'LG디스플레이.csv',
#  'LG생활건강.csv',
#  'LG유플러스.csv',
#  'LG이노텍.csv',
#  'LG전자.csv',
#  'LG화학.csv',
#  'LIG넥스원.csv',
#  'LS.csv',
#  'LS네트웍스.csv',
#  'LX인터내셔널.csv',
#  'LX하우시스.csv',
#  'MH에탄올.csv',
#  'NAVER.csv',
#  'NICE.csv',
#  'OCI.csv',
#  'POSCO홀딩스.csv',
#  'S-Oil.csv',
#  'SBS.csv',
#  'SGC에너지.csv',
#  'SG글로벌.csv',
#  'SG세계물산.csv',
#  'SIMPAC.csv',
#  'SK.csv',
# ...

# %%
## 다시 크롤링 할 기업
# 경방, 광전자, 국동, 남성, 대동, 대창, 덕성, 동방, 동서, 만도

# %%
re_lst = []
for i in range(len(ja)):
    if len(ja[i])<=6:
        re_lst.append(ja[i])
re_lst
# Out:
# ['CJ.csv',
#  'DB.csv',
#  'DL.csv',
#  'E1.csv',
#  'LF.csv',
#  'LG.csv',
#  'LS.csv',
#  'SK.csv',
#  '경농.csv',
#  '경방.csv',
#  '국동.csv',
#  '금양.csv',
#  '기아.csv',
#  '남성.csv',
#  '넥센.csv',
#  '농심.csv',
#  '대교.csv',
#  '대동.csv',
#  '대웅.csv',
#  '대창.csv',
#  '덕성.csv',
#  '동방.csv',
#  '동서.csv',
#  '동양.csv',
#  '두산.csv',
#  '만도.csv',
#  '무학.csv',
#  '백산.csv',
#  '벽산.csv',
#  '보령.csv',
#  '샘표.csv',
#  '서연.csv',
#  '서원.csv',
#  '서흥.csv',
#  '선진.csv',
#  '성안.csv',
#  '세방.csv',
#  '신원.csv',
#  '신흥.csv',
#  '영풍.csv',
#  '영흥.csv',
#  '우성.csv',
#  '우진.csv',
#  '웅진.csv',
#  '원림.csv',
#  '인팩.csv',
#  '전방.csv',
#  '진도.csv',
#  '한독.csv',
#  '한섬.csv',
#  '한진.csv',
#  '한화.csv',
#  '혜인.csv',
#  '화신.csv',
#  '효성.csv',
#  '후성.csv']

# %%
ja[0]
# Out:
# 'AJ네트웍스.csv'

# %% [markdown]
# # 뉴스 검색 안되는 기업: 두글자 기업명에서 직접 선출

# %%
# 네이버 증권에서 2021년 6월까지만 크롤링
ns_list = ['광전자',
 'DB',
 '경농',
 '경방',
 '국동',
 '금양',
 '남성',
 '대교',
 '대동',
 '대창',
 '덕성',
 '동방',
 '동서',
 '동양',
 '만도',
 '무학',
 '백산',
 '벽산',
 '보령',
 '서연',
 '서원',
 '서흥',
 '선진',
 '성안',
 '세방',
 '신원',
 '신흥',
 '영흥',
 '우성',
 '원림',
 '전방',
 '진도',
 '혜인',
 '화신']
