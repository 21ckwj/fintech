# %%
import pandas as pd
import numpy as np

import json
import requests

# %%
# pblntf_ty A B C D E F G

# %%
key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
# corp_code= '00656021'
st_date = '20200101'
end_date = '20200130'
rpt_type = 'B'

url = 'https://opendart.fss.or.kr/api/list.json?crtfc_key='+key+'&bgn_de='\
+st_date+ '&end_de='+ end_date+'&pblntf_ty='+rpt_type+'&corp_cls=Y&page_no=1&page_count=10'

# https://opendart.fss.or.kr/api/list.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&bgn_de=20200117&end_de=20200117&pblntf_ty=B&corp_cls=Y&page_no=1&page_count=10

# %%
res = requests.get(url)
content = res.content.decode('utf-8')
data = json.loads(content)
data
# Out:
# {'status': '000',
#  'message': '정상',
#  'page_no': 1,
#  'page_count': 10,
#  'total_count': 86,
#  'total_page': 9,
#  'list': [{'corp_code': '00139889',
#    'corp_name': 'SKC',
#    'stock_code': '011790',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(타법인주식및출자증권양도결정)',
#    'rcept_no': '20200130000452',
#    'flr_nm': 'SKC',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식처분결정)',
#    'rcept_no': '20200130000420',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00112332',
#    'corp_name': '미래에셋생명',
#    'stock_code': '085620',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식취득결정)',
#    'rcept_no': '20200130000417',
#    'flr_nm': '미래에셋생명',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00134723',
#    'corp_name': '페이퍼코리아',
#    'stock_code': '001020',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(감자결정)',
#    'rcept_no': '20200130000427',
#    'flr_nm': '페이퍼코리아',
#    'rcept_dt': '20200130',
#    'rm': '정'},
#   {'corp_code': '01350869',
#    'corp_name': '우리금융지주',
#    'stock_code': '316140',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(상각형조건부자본증권발행결정)',
#    'rcept_no': '20200130000410',
#    'flr_nm': '우리금융지주',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00159102',
#    'corp_name': 'DB손해보험',
#    'stock_code': '005830',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식취득결정)',
#    'rcept_no': '20200130000309',
#    'flr_nm': 'DB손해보험',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00266961',
#    'corp_name': 'NAVER',
#    'stock_code': '035420',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(자기주식취득결정)',
#    'rcept_no': '20200130000006',
#    'flr_nm': 'NAVER',
#    'rcept_dt': '20200130',
#    'rm': ''},
#   {'corp_code': '00266961',
#    'corp_name': 'NAVER',
#    'stock_code': '035420',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식취득결정)',
#    'rcept_no': '20200130000001',
#    'flr_nm': 'NAVER',
#    'rcept_dt': '20200130',
#    'rm': '정'},
#   {'corp_code': '00108065',
#    'corp_name': '쎌마테라퓨틱스',
#    'stock_code': '015540',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(전환사채권발행결정)',
#    'rcept_no': '20200129000483',
#    'flr_nm': '쎌마테라퓨틱스',
#    'rcept_dt': '20200129',
#    'rm': '정'},
#   {'corp_code': '01310269',
#    'corp_name': 'HDC현대산업개발',
#    'stock_code': '294870',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(유상증자결정)',
#    'rcept_no': '20200129000449',
#    'flr_nm': 'HDC현대산업개발',
#    'rcept_dt': '20200129',
#    'rm': '정'}]}

# %%
 pd.DataFrame(data['list'])
# Out:
#   corp_code  corp_name stock_code corp_cls                      report_nm  \
# 0  00139889        SKC     011790        Y  [기재정정]주요사항보고서(타법인주식및출자증권양도결정)
# 1  00111722     미래에셋증권     006800        Y              주요사항보고서(자기주식처분결정)
# 2  00112332     미래에셋생명     085620        Y              주요사항보고서(자기주식취득결정)
# 3  00134723     페이퍼코리아     001020        Y            [기재정정]주요사항보고서(감자결정)
# 4  01350869     우리금융지주     316140        Y  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 5  00159102     DB손해보험     005830        Y              주요사항보고서(자기주식취득결정)
# 6  00266961      NAVER     035420        Y        [기재정정]주요사항보고서(자기주식취득결정)
# 7  00266961      NAVER     035420        Y              주요사항보고서(자기주식취득결정)
# 8  00108065    쎌마테라퓨틱스     015540        Y       [기재정정]주요사항보고서(전환사채권발행결정)
# 9  01310269  HDC현대산업개발     294870        Y          [기재정정]주요사항보고서(유상증자결정)
#
#          rcept_no     flr_nm  rcept_dt rm
# 0  20200130000452        SKC  20200130
# 1  20200130000420     미래에셋증권  20200130
# 2  20200130000417     미래에셋생명  20200130
# 3  20200130000427     페이퍼코리아  20200130  정
# 4  20200130000410     우리금융지주  20200130
# 5  20200130000309     DB손해보험  20200130
# 6  20200130000006      NAVER  20200130
# 7  20200130000001      NAVER  20200130  정
# 8  20200129000483    쎌마테라퓨틱스  20200129  정
# 9  20200129000449  HDC현대산업개발  20200129  정

# %%
# 공시원본서류

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as et
from io import BytesIO
from zipfile import ZipFile

# %%
api_key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
url1 = 'https://opendart.fss.or.kr/api/document.xml?crtfc_key='+api_key

# %%
res = requests.get(url1)
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><result><status>100</status><message>필수값(rcept_no)이 누락되었습니다.</message></result>'

# %%
# u = requests.get(url1, params={'crtfc_key':api_key})
# zipfile_bytes = u.content # 처음 받았을때 bytes타입

# # BytesIO함수를 통해 bytes -> ZipFile로 변환
# zipfile_obj = ZipFile(BytesIO(zipfile_bytes)) 

# # 압축을 풀어서 XML File을 string으로 담기
# xmlfile_objs = {name: zipfile_obj.read(name) for name in zipfile_obj.namelist()}
# xml_str = xmlfile_objs['CORPCODE.xml'].decode('utf-8')

# # XML String을 가져와서 DataFrame에 담기
# xroot = et.fromstring(xml_str)

# %%
# pblntf_ty A B C D E F G

# %%
import dart_fss as dart
api_key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
dart.set_api_key(api_key=api_key)
reports = dart.filings.search(corp_code='00139889', 
                        bgn_de='20110101', 
                        end_de='20211231', 
                        last_reprt_at='N', 
                        pblntf_ty='B', 
#                         pblntf_detail_ty=None, 
#                         corp_cls=None, 
                        page_no=1, 
                        page_count=100)

# %%
reports
# Out:
# {'page_count': 100,
#  'page_no': 1,
#  'report_list': [{'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20211221',
#                   'rcp_no': '20211221000438',
#                   'report_nm': '주요사항보고서(자기주식처분결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20210929',
#                   'rcp_no': '20210929000562',
#                   'report_nm': '주요사항보고서(자기주식처분결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20200908',
#                   'rcp_no': '20200908000213',
#                   'report_nm': '[기재정정]주요사항보고서(주식교환ㆍ이전결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20200812',
#                   'rcp_no': '20200812000001',
#                   'report_nm': '[첨부추가]주요사항보고서(주식교환ㆍ이전결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20200203',
#                   'rcp_no': '20200203000321',
#                   'report_nm': '[첨부정정]주요사항보고서(회사분할결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20200130',
#                   'rcp_no': '20200130000452',
#                   'report_nm': '[기재정정]주요사항보고서(타법인주식및출자증권양도결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20191224',
#                   'rcp_no': '20191224000188',
#                   'report_nm': '[기재정정]주요사항보고서(회사분할결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20191216',
#                   'rcp_no': '20191216000337',
#                   'report_nm': '[첨부정정]주요사항보고서(타법인주식및출자증권양도결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20191202',
#                   'rcp_no': '20191202000489',
#                   'report_nm': '[첨부추가]주요사항보고서(타법인주식및출자증권양도결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20190807',
#                   'rcp_no': '20190807000322',
#                   'report_nm': '[첨부추가]주요사항보고서(타법인주식및출자증권양도결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20190807',
#                   'rcp_no': '20190807000317',
#                   'report_nm': '주요사항보고서(회사분할결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20190613',
#                   'rcp_no': '20190613000054',
#                   'report_nm': '[첨부추가]주요사항보고서(타법인주식및출자증권양수결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20161111',
#                   'rcp_no': '20161111000481',
#                   'report_nm': '주요사항보고서(자기주식취득결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20161027',
#                   'rcp_no': '20161027000363',
#                   'report_nm': '주요사항보고서(자기주식처분결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20151218',
#                   'rcp_no': '20151218000371',
#                   'report_nm': '주요사항보고서(회사합병결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20150306',
#                   'rcp_no': '20150306000450',
#                   'report_nm': '[기재정정]주요사항보고서(중요한영업양수도결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20150205',
#                   'rcp_no': '20150205000245',
#                   'report_nm': '[기재정정]주요사항보고서(중요한영업양수도결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20141224',
#                   'rcp_no': '20141224000575',
#                   'report_nm': '[기재정정]주요사항보고서(중요한영업양수도결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20141222',
#                   'rcp_no': '20141222000418',
#                   'report_nm': '주요사항보고서(중요한영업양수도결정)',
#                   'rm': '정',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20130627',
#                   'rcp_no': '20130627000411',
#                   'report_nm': '주요사항보고서(신주인수권부사채권발행결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20111006',
#                   'rcp_no': '20111006000256',
#                   'report_nm': '주요사항보고서(자기주식처분결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20110707',
#                   'rcp_no': '20110707000417',
#                   'report_nm': '주요사항보고서(전환사채권발행결정)',
#                   'rm': '',
#                   'stock_code': '011790'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00139889',
#                   'corp_name': 'SKC',
#                   'flr_nm': 'SKC',
#                   'rcept_dt': '20110707',
#                   'rcp_no': '20110707000419',
#                   'report_nm': '주요사항보고서(신주인수권부사채권발행결정)',
#                   'rm': '',
#                   'stock_code': '011790'}],
#  'total_count': 23,
#  'total_page': 1}

# %% [markdown]
# # 회사 고유번호 : crp_df

# %%
crp_api = dart_fss.api.filings.get_corp_code()
crp_api
# Out:
# Output()
# [OrderedDict([('corp_code', '00434003'),
#               ('corp_name', '다코'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434456'),
#               ('corp_name', '일산약품'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430964'),
#               ('corp_name', '굿앤엘에스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432403'),
#               ('corp_name', '한라판지'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00388953'),
#               ('corp_name', '크레디피아제이십오차유동화전문회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00179984'),
#               ('corp_name', '연방건설산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00420143'),
#               ('corp_name', '브룩스피알아이오토메이션잉크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00401111'),
#               ('corp_name', '매경아이비아이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435534'),
#               ('corp_name', '캐드뱅크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430186'),
#               ('corp_name', '엠와이오피삼차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430201'),
#               ('corp_name', '엠와이오피이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430210'),
#               ('corp_name', '엠와이오피일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430229'),
#               ('corp_name', '포스미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00140432'),
#               ('corp_name', '축복할렐루야'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00426208'),
#               ('corp_name', '한국전자화학'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433262'),
#               ('corp_name', 'ConnachtCapitalMarketInvestmentLtd.'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433749'),
#               ('corp_name', '선진아이티'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433785'),
#               ('corp_name', '팀스코리아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00196079'),
#               ('corp_name', '에넥스하이테크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435048'),
#               ('corp_name', '세이스텝바이스텝혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435057'),
#               ('corp_name', '유리알파헷지채권혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00108843'),
#               ('corp_name', '한기술정보통신'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00443232'),
#               ('corp_name', '다움종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00248293'),
#               ('corp_name', '한국애치슨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00455662'),
#               ('corp_name', '고은상사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00149318'),
#               ('corp_name', '조흥종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00451347'),
#               ('corp_name', '유니즈유통'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00415105'),
#               ('corp_name', '창대화장품'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00420824'),
#               ('corp_name', '문화종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00389439'),
#               ('corp_name', '한국종합미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00454016'),
#               ('corp_name', '아이펜텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00452072'),
#               ('corp_name', '대홍염공'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00437602'),
#               ('corp_name', '지오항공여행사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00365518'),
#               ('corp_name', '헤이아니타코리아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00246967'),
#               ('corp_name', '태산산업개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445559'),
#               ('corp_name', '군포종합시장'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00444657'),
#               ('corp_name', '기우'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00448936'),
#               ('corp_name', '라시도'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00405658'),
#               ('corp_name', '예전미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00410818'),
#               ('corp_name', '세미가'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00416061'),
#               ('corp_name', '대닉스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00448909'),
#               ('corp_name', '인포핸드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445407'),
#               ('corp_name', '지현개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421647'),
#               ('corp_name', '한국부동산신탁제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421425'),
#               ('corp_name', 'ISCCaymanLtd.'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423265'),
#               ('corp_name', '연산'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423292'),
#               ('corp_name', '씨케이알유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00420602'),
#               ('corp_name', '디에스피'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00307505'),
#               ('corp_name', 'LOMBARDKOREAILIMITED'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00218229'),
#               ('corp_name', '승진씨앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00241397'),
#               ('corp_name', '우신투자자문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421896'),
#               ('corp_name', '외환카드제오차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00365712'),
#               ('corp_name', '태연'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00388616'),
#               ('corp_name', '글로벌금강제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00230407'),
#               ('corp_name', '글로벌렌탈'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423566'),
#               ('corp_name', '뤼미에르에셋'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423274'),
#               ('corp_name', '바사라엔터테인먼트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00419688'),
#               ('corp_name', '대백유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00419712'),
#               ('corp_name', '아이키키'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00414665'),
#               ('corp_name', '진명씨앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421869'),
#               ('corp_name', '한경핫벤처'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421957'),
#               ('corp_name', '우리부동산제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00255442'),
#               ('corp_name', '영진상운'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00427517'),
#               ('corp_name', '한국토지신탁제오차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00376152'),
#               ('corp_name', '다드림커뮤니케이션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00382241'),
#               ('corp_name', 'ARISAIGASIANSMALLCOMPANIESFUND(L)BHD'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431501'),
#               ('corp_name', '싱가포르개발은행서울지점'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434270'),
#               ('corp_name', '삼성인덱스프리미엄30혼합형뮤추얼펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434289'),
#               ('corp_name', 'KTB혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434298'),
#               ('corp_name', 'KTB플러스찬스혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434313'),
#               ('corp_name', 'KTB포트폴리오스타혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434322'),
#               ('corp_name', 'KTB에버스타혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429463'),
#               ('corp_name', '나노이앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429515'),
#               ('corp_name', '지산엔터프라이즈'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432175'),
#               ('corp_name', '유아이에스코리아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00387033'),
#               ('corp_name', '트리플에스유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00384045'),
#               ('corp_name', '크레디피아제이십일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431608'),
#               ('corp_name', '싱가포르개발은행'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431705'),
#               ('corp_name', '엘지팩토링제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430256'),
#               ('corp_name', '이피에스뱅크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431167'),
#               ('corp_name', '이라이프네트워크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432315'),
#               ('corp_name', '덕성'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00413134'),
#               ('corp_name', '타오건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435376'),
#               ('corp_name', '장원코리아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00110909'),
#               ('corp_name', '대신통상'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00245995'),
#               ('corp_name', '삼광제지공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00220695'),
#               ('corp_name', '서울교육'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00211794'),
#               ('corp_name', '보성패션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00454496'),
#               ('corp_name', '넥스탑'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00455592'),
#               ('corp_name', '마니빌'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00370796'),
#               ('corp_name', '제이엘코프'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00199401'),
#               ('corp_name', '컴마을'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00369596'),
#               ('corp_name', '삼신크리에이션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00210078'),
#               ('corp_name', '호한통상'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00363398'),
#               ('corp_name', '케이엠티'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00110042'),
#               ('corp_name', '대백가구'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00364324'),
#               ('corp_name', '청빛산업개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00248017'),
#               ('corp_name', '삼양전자'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00452179'),
#               ('corp_name', '숭민코리아유통'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00413754'),
#               ('corp_name', '유오티앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00343163'),
#               ('corp_name', '한라스페코중공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00452513'),
#               ('corp_name', '알본'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435978'),
#               ('corp_name', '상일디지털'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00368153'),
#               ('corp_name', '서전어패럴'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00455149'),
#               ('corp_name', '웰비스트랜스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00249946'),
#               ('corp_name', '한국키엔스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00110839'),
#               ('corp_name', '대신생명보험'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00293798'),
#               ('corp_name', '대성메디테크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00113119'),
#               ('corp_name', '대한알루미늄공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424389'),
#               ('corp_name', '남성엠케이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424486'),
#               ('corp_name', '씨엠액텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00224734'),
#               ('corp_name', '한국부동산신탁'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00197713'),
#               ('corp_name', '주은산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421948'),
#               ('corp_name', '신엘지프라이머리제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00422381'),
#               ('corp_name', '데코제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00350446'),
#               ('corp_name', '뉴스테이트삼차모기지유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00396642'),
#               ('corp_name', '엘지수퍼센터'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425449'),
#               ('corp_name', '아이클릭세븐'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425458'),
#               ('corp_name', '월드인코레스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425333'),
#               ('corp_name', '코리아픽시컴'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424617'),
#               ('corp_name', '산은부동산제사차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424006'),
#               ('corp_name', '글로벌자이언트시스템'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424051'),
#               ('corp_name', '신클레어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00403599'),
#               ('corp_name', '에이에스피기업구조조정전문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425519'),
#               ('corp_name', 'Marubeni-ItochuSteelInc.'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00224585'),
#               ('corp_name', '신한'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429524'),
#               ('corp_name', '우리모아제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429533'),
#               ('corp_name', '글로벌사모안정혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432722'),
#               ('corp_name', '파워외환카드제팔차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432786'),
#               ('corp_name', '파워외환카드제오차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429728'),
#               ('corp_name', '영퓨처'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00428668'),
#               ('corp_name', '코로볼틴펀드리미티드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430751'),
#               ('corp_name', '대창크랑크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00385372'),
#               ('corp_name', '허츠제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431680'),
#               ('corp_name', '새암교육'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00386308'),
#               ('corp_name', '반지종합상가'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00256450'),
#               ('corp_name', '동서산업건설(가칭)'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00290816'),
#               ('corp_name', '대우종합기계(가칭)'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00291532'),
#               ('corp_name', '대우조선공업(가칭)'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00127990'),
#               ('corp_name', '삼일상호저축은행'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431565'),
#               ('corp_name', '케이디에스에스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00399959'),
#               ('corp_name', '비젼케이파트너스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00430238'),
#               ('corp_name', '리버랜드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00263034'),
#               ('corp_name', '동양선재'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00205298'),
#               ('corp_name', '춘천미도파'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00431042'),
#               ('corp_name', '거버너스M&A사모펀드3호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00348715'),
#               ('corp_name', '아이앤비골드문브이에이치'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00447964'),
#               ('corp_name', '체리미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00448361'),
#               ('corp_name', '경원하이텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00185851'),
#               ('corp_name', '중원화학'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445735'),
#               ('corp_name', '나크나인'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00385770'),
#               ('corp_name', '동남해상관광호텔'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00319245'),
#               ('corp_name', '한성선박'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00126502'),
#               ('corp_name', '삼성콘크리트공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00363440'),
#               ('corp_name', '엠알더블유테크노로지'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445522'),
#               ('corp_name', '제이에이치홀딩스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00320302'),
#               ('corp_name', '동연산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00444958'),
#               ('corp_name', '우양주택건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00441836'),
#               ('corp_name', '해진하우징'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445203'),
#               ('corp_name', '대림전자'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00445629'),
#               ('corp_name', '효헌산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00454052'),
#               ('corp_name', '우림산업개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00454414'),
#               ('corp_name', '에이스하이테크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00196857'),
#               ('corp_name', '해표푸드서비스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00413383'),
#               ('corp_name', '에프씨산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00225098'),
#               ('corp_name', '극동뉴메릭'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00410304'),
#               ('corp_name', '서울드림랜드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00310998'),
#               ('corp_name', '한국미라이공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00415114'),
#               ('corp_name', '21세기화장품'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00451000'),
#               ('corp_name', '광명산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00369985'),
#               ('corp_name', '다음솔루션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00199809'),
#               ('corp_name', '이성화학'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00371670'),
#               ('corp_name', '정우조명'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00401430'),
#               ('corp_name', '모바일웰컴'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00247027'),
#               ('corp_name', '푸른건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00144058'),
#               ('corp_name', '월다크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00416867'),
#               ('corp_name', '길도건업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00456263'),
#               ('corp_name', '원일스포지움'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436339'),
#               ('corp_name', '용인자원'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00120748'),
#               ('corp_name', '마산강관'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00386724'),
#               ('corp_name', '세창철강공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00255390'),
#               ('corp_name', '재무와정보'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00455547'),
#               ('corp_name', '대양중공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00233398'),
#               ('corp_name', '이에이지씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00405065'),
#               ('corp_name', '페타코페트로륨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425537'),
#               ('corp_name', 'MarubeniCorporation'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424158'),
#               ('corp_name', '캐피탈라인'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00100920'),
#               ('corp_name', '건설증권'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00370167'),
#               ('corp_name', '일진전자통신'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00409131'),
#               ('corp_name', '오픈솔루션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424194'),
#               ('corp_name', 'AMERICAORIENTALGROUP'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00364713'),
#               ('corp_name', 'mvp창업투자'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00408901'),
#               ('corp_name', '라이져'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00161170'),
#               ('corp_name', '한라시멘트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423557'),
#               ('corp_name', '한국알리안츠화재해상보험'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00307444'),
#               ('corp_name', '코리아벌처투자'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00370468'),
#               ('corp_name', '티에스케이지'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424547'),
#               ('corp_name', '메리츠투자자문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424219'),
#               ('corp_name', '텔레닉스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424185'),
#               ('corp_name', '유니텍워터시스템즈'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424556'),
#               ('corp_name', '거륜씨앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00121631'),
#               ('corp_name', '문화'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424866'),
#               ('corp_name', '모비도미'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424884'),
#               ('corp_name', '에이치케이인베스트먼트유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424927'),
#               ('corp_name', 'LiquidmetalTechnologies'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423797'),
#               ('corp_name', '모멘타(케이만)'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433350'),
#               ('corp_name', 'KTB프라임8호혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433369'),
#               ('corp_name', '유리명품장기채권형사모펀드3호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433378'),
#               ('corp_name', '유리유니콘채권혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433387'),
#               ('corp_name', '맥쿼리아이엠엠프라임7호채권형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433420'),
#               ('corp_name', '마이에셋애국성장형이호펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433457'),
#               ('corp_name', '채권플러스알파2호펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433466'),
#               ('corp_name', '마이다스사모프라임안정형2호펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00376073'),
#               ('corp_name', '테크포인트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00234306'),
#               ('corp_name', '부국개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429418'),
#               ('corp_name', '세닥에듀케이션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429977'),
#               ('corp_name', '에이치엘홀딩스에스에이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00340786'),
#               ('corp_name', '크레디리요네증권'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00218928'),
#               ('corp_name', '케이티인더스트리'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00106793'),
#               ('corp_name', '김천상호저축은행'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00378886'),
#               ('corp_name', '이화홀딩스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433484'),
#               ('corp_name', '미래에셋유니온사모혼합형펀드2호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433493'),
#               ('corp_name', '맥쿼리아이엠엠액티브채권형사모펀드3호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433509'),
#               ('corp_name', '맥쿼리아이엠엠프라임6호혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433518'),
#               ('corp_name', '유리명품장기채권형사모펀드2호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00406596'),
#               ('corp_name', '신우쉬핑'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00443001'),
#               ('corp_name', '동흥컨설팅'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00363741'),
#               ('corp_name', '디조콤'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436375'),
#               ('corp_name', '맘모스산업개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00222277'),
#               ('corp_name', '아성'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00446284'),
#               ('corp_name', '디토정보기술'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00446682'),
#               ('corp_name', '오우디앤씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00139995'),
#               ('corp_name', '에어웨이엑스프레스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00444602'),
#               ('corp_name', '탑월드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00446433'),
#               ('corp_name', '옥시큐어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00150314'),
#               ('corp_name', '진로종합유통'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00231840'),
#               ('corp_name', '케이에프텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00236243'),
#               ('corp_name', '나토상사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00309479'),
#               ('corp_name', '지오이네트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00447034'),
#               ('corp_name', '이십일세기종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00447496'),
#               ('corp_name', '일현건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00300928'),
#               ('corp_name', '삼영기공'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00317566'),
#               ('corp_name', '삼능주택'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00412001'),
#               ('corp_name', '동해'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00155407'),
#               ('corp_name', '풍광직물'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00443542'),
#               ('corp_name', '기성텍스타일'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00179726'),
#               ('corp_name', '제텍스바론'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00300982'),
#               ('corp_name', '국제개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00298818'),
#               ('corp_name', '유유후마킬라'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424644'),
#               ('corp_name', '피앤씨미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00350570'),
#               ('corp_name', '비앤에프투자자문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424316'),
#               ('corp_name', '한국부동산신탁제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00368551'),
#               ('corp_name', '에이텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424307'),
#               ('corp_name', '덕경종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425078'),
#               ('corp_name', '글로벌스페셜혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00154499'),
#               ('corp_name', '태화'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424653'),
#               ('corp_name', '씨앤앰유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00414522'),
#               ('corp_name', '온누리방송'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425120'),
#               ('corp_name', '케이티엠'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00356723'),
#               ('corp_name', '아이앤비골드문컨설팅'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00375506'),
#               ('corp_name', '동국제강제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00424769'),
#               ('corp_name', '밸류노믹스기업구조조정전문회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00223300'),
#               ('corp_name', '조창'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00378178'),
#               ('corp_name', '테크노켐'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00360294'),
#               ('corp_name', '영지통상'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00425209'),
#               ('corp_name', 'RosewellConsulting&InvestmentLtd.'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433527'),
#               ('corp_name', '유리시티즌장기채권형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433536'),
#               ('corp_name', 'KTB장기채권형사모펀드3호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433545'),
#               ('corp_name', 'KTB장기채권형사모펀드4호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433554'),
#               ('corp_name', '맥쿼리아이엠엠포세이돈채권형사모펀드4호'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00433563'),
#               ('corp_name', '마이에셋애국안정형1호펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434702'),
#               ('corp_name', '노보스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434711'),
#               ('corp_name', '세이유니온채권혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434720'),
#               ('corp_name', 'LG드림혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434739'),
#               ('corp_name', '알파그로스주식형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434748'),
#               ('corp_name', '유리알파헷지채권혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434757'),
#               ('corp_name', '알파헷지이기욱혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434775'),
#               ('corp_name', '맥쿼리IMM홀인원채권형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434793'),
#               ('corp_name', '유리시장중립채권형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434809'),
#               ('corp_name', '유리알파30채권혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432573'),
#               ('corp_name', '파워외환카드제사차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432607'),
#               ('corp_name', '파워외환카드제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432643'),
#               ('corp_name', '케드제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00323390'),
#               ('corp_name', '굿윌경영자문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00412861'),
#               ('corp_name', '국제금속산업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00443913'),
#               ('corp_name', '덕정무역'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00315179'),
#               ('corp_name', '삼성코닝마이크로옵틱스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00165264'),
#               ('corp_name', '혜성건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00368171'),
#               ('corp_name', '코스모에쿼티파트너스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00369480'),
#               ('corp_name', '경빈'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00446196'),
#               ('corp_name', '내외시스템'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00108311'),
#               ('corp_name', '태승어패럴'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00105615'),
#               ('corp_name', '금동조명'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00360197'),
#               ('corp_name', '태광정밀공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
# ...
#               ('corp_name', '유리크레디트채권혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434544'),
#               ('corp_name', 'KTB프리미엄찬스혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434553'),
#               ('corp_name', 'KTB에이스찬스혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00432050'),
#               ('corp_name', '다린정보'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00344843'),
#               ('corp_name', '기보캐피탈제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00371908'),
#               ('corp_name', '엘에스에프프로퍼티투유동화전문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00339090'),
#               ('corp_name', '온디지털테크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00337986'),
#               ('corp_name', '캐피탈그룹인터내셔널인코포레이티드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00206136'),
#               ('corp_name', '세림아이텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00440411'),
#               ('corp_name', '코스유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00422309'),
#               ('corp_name', '뉴밀레니엄하나유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00439257'),
#               ('corp_name', '동양정보통신M&A'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00439284'),
#               ('corp_name', '하이페리온제삼차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00439424'),
#               ('corp_name', '코머스에셋'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435011'),
#               ('corp_name', '경동실업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00428525'),
#               ('corp_name', '에스티엑스제이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00427128'),
#               ('corp_name', '오일뱅크제삼차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00428677'),
#               ('corp_name', '케이지브이제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436560'),
#               ('corp_name', '인성어패럴'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00440697'),
#               ('corp_name', '소프티안'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00439734'),
#               ('corp_name', '동양알미늄'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00327387'),
#               ('corp_name', '소모페스트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00437611'),
#               ('corp_name', '젤존항공여행사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00321064'),
#               ('corp_name', '바이오엔비텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00362557'),
#               ('corp_name', '세원반도체'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00224105'),
#               ('corp_name', '두원그린피아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00447654'),
#               ('corp_name', '미도핸드백'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00453169'),
#               ('corp_name', '대영테크'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00371388'),
#               ('corp_name', '아이비젠'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00144340'),
#               ('corp_name', '한화포리마'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00437204'),
#               ('corp_name', '신케이에스유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00443302'),
#               ('corp_name', '프라임유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436463'),
#               ('corp_name', '우영제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00452692'),
#               ('corp_name', '한컴리눅스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00441739'),
#               ('corp_name', '두산건설제육유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00441669'),
#               ('corp_name', '산은부동산제팔차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436940'),
#               ('corp_name', '오토피아제칠차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00436959'),
#               ('corp_name', '외환카드제팔차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00427526'),
#               ('corp_name', '삼성신한아하론일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00264705'),
#               ('corp_name', '현대유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00387714'),
#               ('corp_name', '칼제일차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00300946'),
#               ('corp_name', '백두건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00402086'),
#               ('corp_name', '리엔텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00452461'),
#               ('corp_name', '대양건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00100948'),
#               ('corp_name', '건양콘크리트'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00365572'),
#               ('corp_name', '맥스미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00400486'),
#               ('corp_name', '루넷'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00417909'),
#               ('corp_name', '충일아스콘'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00153816'),
#               ('corp_name', '태양연와공업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00414586'),
#               ('corp_name', '제동'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00187637'),
#               ('corp_name', '농협축산유통'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00415035'),
#               ('corp_name', '동서D&S'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00235864'),
#               ('corp_name', '에스앤제이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00416043'),
#               ('corp_name', '창영물산'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00174280'),
#               ('corp_name', '태화건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00417352'),
#               ('corp_name', '동방코리아'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00238223'),
#               ('corp_name', '영텍스타일'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00248530'),
#               ('corp_name', '미진시스템'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00234740'),
#               ('corp_name', '고려소재개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00417565'),
#               ('corp_name', '아이앤알코리아기업구조조정전문'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00192958'),
#               ('corp_name', '건륭실업'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00387459'),
#               ('corp_name', '충주공용버스터미널'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00415761'),
#               ('corp_name', '푸른도시개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00404011'),
#               ('corp_name', '로고스이넷'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00168553'),
#               ('corp_name', '대광종합건설'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00309804'),
#               ('corp_name', '굿윌씨앤아이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00408600'),
#               ('corp_name', '아라아이디시'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00418731'),
#               ('corp_name', '디엠아이디'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00363121'),
#               ('corp_name', '웅보개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00230577'),
#               ('corp_name', '광복산업개발'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00295671'),
#               ('corp_name', '리빙티브이'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00418759'),
#               ('corp_name', '산은부동산제삼차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00211448'),
#               ('corp_name', '신라'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00406170'),
#               ('corp_name', '글로만'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00301060'),
#               ('corp_name', '서림개스실린더'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00242350'),
#               ('corp_name', '파인에셋홀딩스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00134352'),
#               ('corp_name', '세일'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00420569'),
#               ('corp_name', '한일밀라노.존'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00422141'),
#               ('corp_name', '첼린저이차유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00422178'),
#               ('corp_name', '휴민텍'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00419891'),
#               ('corp_name', '템플턴스트래티직이머징마켓츠펀드엘디씨'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00419907'),
#               ('corp_name', '신한파이낸스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00310989'),
#               ('corp_name', '코오롱모터스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00420976'),
#               ('corp_name', '큐마트솔루션'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421072'),
#               ('corp_name', '나은미디어'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00423706'),
#               ('corp_name', 'BystronicLaserAG'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00384425'),
#               ('corp_name', '코브코유동화전문유한회사'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00350297'),
#               ('corp_name', '칼스버그에이에스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00421124'),
#               ('corp_name', '아이엠씨마케팅'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434632'),
#               ('corp_name', '글로벌채권프리미엄혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434650'),
#               ('corp_name', 'KTB밸류코스닥혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434669'),
#               ('corp_name', 'KTB밸류코리아혼합형사모펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434678'),
#               ('corp_name', '삼성팀파워90주식형뮤추얼펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00429658'),
#               ('corp_name', '스톰홀딩스'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00118831'),
#               ('corp_name', '아이넥스테크놀로지'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00205483'),
#               ('corp_name', '세종토건'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00434492'),
#               ('corp_name', '부평유선방송'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  OrderedDict([('corp_code', '00435622'),
#               ('corp_name', 'KTB온누리혼합형펀드'),
#               ('stock_code', None),
#               ('modify_date', '20170630')]),
#  ...]

# %%
crp_df = pd.DataFrame(crp_api)
crp_df.head()
# Out:
#   corp_code          corp_name stock_code modify_date
# 0  00434003                 다코       None    20170630
# 1  00434456               일산약품       None    20170630
# 2  00430964              굿앤엘에스       None    20170630
# 3  00432403               한라판지       None    20170630
# 4  00388953  크레디피아제이십오차유동화전문회사       None    20170630

# %%
crp_code = crp_df['corp_code']
crp_code
# Out:
# 0        00434003
# 1        00434456
# 2        00430964
# 3        00432403
# 4        00388953
#            ...
# 94144    00913768
# 94145    00110857
# 94146    01364808
# 94147    01497522
# 94148    01494136
# Name: corp_code, Length: 94149, dtype: object

# %%
crp_code[0]
# Out:
# '00434003'

# %% [markdown]
# # 기업 공시자료 리스트

# %%
# 증권 코드를 이용한 찾기
corp_list = dart_fss.corp.get_corp_list()
samsung = corp_list.find_by_stock_code('005930')
reports = samsung.search_filings( bgn_de='20190301', end_de='20190531')

# %%
reports
# Out:
# {'page_count': 100,
#  'page_no': 1,
#  'report_list': [{'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130002065',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130002048',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130002045',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130002040',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130002030',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211130',
#                   'rcp_no': '20211130000246',
#                   'report_nm': '대규모기업집단현황공시[분기별공시(대표회사용)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211115',
#                   'rcp_no': '20211115001818',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211115',
#                   'rcp_no': '20211115001798',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211115',
#                   'rcp_no': '20211115001782',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211115',
#                   'rcp_no': '20211115001759',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211028',
#                   'rcp_no': '20211028000016',
#                   'report_nm': '특수관계인에대한출자',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20211028',
#                   'rcp_no': '20211028000015',
#                   'report_nm': '특수관계인에대한출자',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210831',
#                   'rcp_no': '20210831000203',
#                   'report_nm': '대규모기업집단현황공시[분기별공시(대표회사용)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210813',
#                   'rcp_no': '20210813000487',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210813',
#                   'rcp_no': '20210813000473',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210729',
#                   'rcp_no': '20210729000326',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210531',
#                   'rcp_no': '20210531000161',
#                   'report_nm': '대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001495',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001483',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001477',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000804',
#                   'report_nm': '특수관계인에대한출자',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000733',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000726',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000717',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210317',
#                   'rcp_no': '20210317000939',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210302',
#                   'rcp_no': '20210302000645',
#                   'report_nm': '대규모기업집단현황공시[분기별공시(대표회사용)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216000713',
#                   'report_nm': '특수관계인과의내부거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216000704',
#                   'report_nm': '특수관계인과의내부거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210215',
#                   'rcp_no': '20210215001257',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'}],
#  'total_count': 29,
#  'total_page': 1}

# %%
reports = dart.filings.search(bgn_de='20190101', end_de='20190331')
reports.report_list
# Out:
# [{'corp_cls': 'N',
#   'corp_code': '01109122',
#   'corp_name': '스템랩',
#   'flr_nm': '스템랩',
#   'rcept_dt': '20190314',
#   'rcp_no': '20190314000797',
#   'report_nm': '[첨부추가]주요사항보고서(전환사채권발행결정)',
#   'rm': '정',
#   'stock_code': '258540'},
#  {'corp_cls': 'K',
#   'corp_code': '00363510',
#   'corp_name': '소니드',
#   'flr_nm': '소니드',
#   'rcept_dt': '20190228',
#   'rcp_no': '20190228901313',
#   'report_nm': '[첨부추가]증권발행결과(자율공시)(제19회차 CB)',
#   'rm': '코',
#   'stock_code': '060230'},
#  {'corp_cls': 'Y',
#   'corp_code': '00872984',
#   'corp_name': '이마트',
#   'flr_nm': '이마트',
#   'rcept_dt': '20190315',
#   'rcp_no': '20190315000687',
#   'report_nm': '[첨부추가]주요사항보고서(풋백옵션등계약체결결정)',
#   'rm': '정',
#   'stock_code': '139480'},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000051',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi우량채권형증권자투자신탁[채권])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000055',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi글로벌회사채증권자투자신탁(UH)[채권-재간접형])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000057',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi인디아포르테증권자투자신탁[주식])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000063',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi글로벌회사채증권자투자신탁(H)[채권-재간접형])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000067',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi성장중소형주10증권자투자신탁[채권혼합])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'E',
#   'corp_code': '00453804',
#   'corp_name': '엔에이치아문디자산운용',
#   'flr_nm': '엔에이치아문디자산운용',
#   'rcept_dt': '20190328',
#   'rcp_no': '20190328000070',
#   'report_nm': '증권발행실적보고서(집합투자증권)(NH-Amundi퇴직연금중소형주증권자(子)투자신탁1호[채권혼합])',
#   'rm': '',
#   'stock_code': ''},
#  {'corp_cls': 'K',
#   'corp_code': '00352499',
#   'corp_name': '링네트',
#   'flr_nm': '링네트',
#   'rcept_dt': '20190313',
#   'rcp_no': '20190313000347',
#   'report_nm': '[첨부추가]주요사항보고서(자기주식취득신탁계약체결결정)',
#   'rm': '정',
#   'stock_code': '042500'}]

# %%
len(reports.report_list)
# Out:
# 10

# %%
# 검색된 10개중 첫번째 데이터

# 보고서이름
reports.report_list[0].report_nm
# Out:
# '[첨부추가]주요사항보고서(전환사채권발행결정)'

# %%
# 보고서 번호
reports.report_list[0].rcp_no
# Out:
# '20190314000797'

# %%
# 회사명
reports.report_list[0].corp_name
# Out:
# '스템랩'

# %%
# 공시일
reports.report_list[0].rcept_dt
# Out:
# '20211130'

# %% [markdown]
# # 공시서류원본파일 다운로드

# %%
import requests
import zipfile
import os

# %%
api_key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
url1 = 'https://opendart.fss.or.kr/api/document.xml'
recept_no = '20211221000404'
params = {
    'crtfc_key':api_key,
    'rcept_no': recept_no
}

doc_zip_path = os.path.abspath('./data/공시원문/document.zip')

if not os.path.isfile(doc_zip_path):
    response = requests.get(url1, params= params)
    with open(doc_zip_path, 'wb') as fp:
        fp.write(response.content)
        
zf = zipfile.ZipFile(doc_zip_path)
zf.extractall()

# %%
zf = zipfile.ZipFile(doc_zip_path)
zf
# Out:
# <zipfile.ZipFile filename='C:\\KDT4\\ML,DL\\프로젝트6\\data\\공시원문\\document.zip' mode='r'>

# %%
zipinfo = zf.infolist()
zipinfo
# Out:
# [<ZipInfo filename='20211221000404.xml' compress_type=deflate file_size=5623 compress_size=1544>]

# %%
filenames = [x.filename for x in zipinfo]
filename = filenames[0]
zf.extract(filename)
zf.close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='C:\\KDT4\\ML,DL\\프로젝트6\\data\\공시원문\\document.zip' mode='r'>>

# %%
# encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩
with open(f'./{filename}', 'r', encoding='euc-kr') as fp:
    lines = fp.readlines()
with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

# %%
# zipfile 압축푼 파일 encoding 문제 해결

with open(f'./data/공시원문/document/{filename}','r', encoding='euc-kr') as fp:
    lines = fp.readlines()

# %%
# &cr; 문자열 대체

lines = [x.replace('&cr', '&#13;') for x in lines]

with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('./data/공시원문/temp.xml')
root = tree.getroot()
body = root.find('BODY')
insertion = body.find('INSERTION')

# %%
body.attrib
# Out:
# {}

# %% [markdown]
# ## dart_fss 사용

# %%
rcept_no = df_list['rcept_no']
rcept_no[0]
# Out:
# '20211221000404'

# %%
import dart_fss
dart_fss.api.filings.download_document('./data/공시원문/', rcept_no[0])
# Out:
# Output()
# './data/공시원문/20211221000404.zip'

# %%
with open(doc_zip_path, 'wb') as fp:
        fp.write(response.content)

doc_zip_path = os.path.abspath('./data/공시원문/document.zip')
zf = zipfile.ZipFile(doc_zip_path)
zf.extractall()
zipinfo = zf.infolist()
zipinfo
# Out:
# [<ZipInfo filename='20211221000404.xml' compress_type=deflate file_size=5623 compress_size=1544>]

# %%
filenames = [x.filename for x in zipinfo]
filename = filenames[0]
zf.extract(filename)
zf.close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='C:\\KDT4\\ML,DL\\프로젝트6\\data\\공시원문\\document.zip' mode='r'>>

# %%
# encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩 후 temp.xml로 저장
with open(f'./{filename}', 'r', encoding='euc-kr') as fp:
    lines = fp.readlines()
with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

# %%
# &cr; 문자열 대체
lines = [x.replace('&cr', '&#13;') for x in lines]

with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

# %%
lines
# Out:
# ['<?xml version="1.0" encoding="utf-8"?>\n',
#  '\n',
#  '\n',
#  '<DOCUMENT xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="dart3.xsd">\n',
#  '\n',
#  '<DOCUMENT-NAME ACODE="80727">특수관계인으로부터부동산임차</DOCUMENT-NAME>\n',
#  '<FORMULA-VERSION SUBVER="1" ADATE="20120401">1.1</FORMULA-VERSION>\n',
#  '<COMPANY-NAME AREGCIK="01133217">카카오뱅크</COMPANY-NAME>\n',
#  '\n',
#  '\n',
#  '<BODY>\n',
#  '\n',
#  '<SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">\n',
#  '<TITLE ATOC="Y" AASSOCNOTE="D-0-1-0-0">특수관계인으로부터 부동산임차</TITLE>\n',
#  '<P></P>\n',
#  '\n',
#  '<TABLE ACLASS="NORMAL" WIDTH="739" BORDER="1">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="84"></COL>\n',
#  '<COL WIDTH="54"></COL>\n',
#  '<COL WIDTH="54"></COL>\n',
#  '<COL WIDTH="111"></COL>\n',
#  '<COL WIDTH="69"></COL>\n',
#  '<COL WIDTH="83"></COL>\n',
#  '<COL WIDTH="69"></COL>\n',
#  '<COL WIDTH="143"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY ALIGN="LEFT" VALIGN="TOP">\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="93" HEIGHT="30">기업집단명</TD>\n',
#  '<TD VALIGN="MIDDLE" WIDTH="63" HEIGHT="30" ALIGN="CENTER">카카오</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="63" HEIGHT="30">회사명</TD>\n',
#  '<TD VALIGN="MIDDLE" WIDTH="120" HEIGHT="30" ALIGN="CENTER">(주)카카오뱅크</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30">공시일자</TD>\n',
#  '<TD VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ALIGN="CENTER">2021.12.21</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30">관련법규</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="152" HEIGHT="30">공정거래법 11조의2</TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '<P></P>\n',
#  '\n',
#  '<TABLE ACLASS="NORMAL" AFIXTABLE="N" WIDTH="738" BORDER="0">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="729"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="738" HEIGHT="30">(단위 : 백만원)</TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '\n',
#  '<TABLE BORDER="1" WIDTH="738" ACLASS="NORMAL">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="184"></COL>\n',
#  '<COL WIDTH="103"></COL>\n',
#  '<COL WIDTH="93"></COL>\n',
#  '<COL WIDTH="111"></COL>\n',
#  '<COL WIDTH="202"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="30">1. 거래상대방</TD>\n',
#  '<TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="214" HEIGHT="30">(주)카카오</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="120" HEIGHT="30">회사와의 관계</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="211" HEIGHT="30">계열회사</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="7" VALIGN="MIDDLE" WIDTH="193" HEIGHT="210">2. 부동산 임차내역</TD>\n',
#  '<TD VALIGN="MIDDLE" WIDTH="112" HEIGHT="30">가. 임차일자</TD>\n',
#  '<TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="433" HEIGHT="30">2022.05.01</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="112" HEIGHT="30">나. 임차목적물</TD>\n',
#  '<TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="433" HEIGHT="30">건물 (면적 27,566.04㎡)</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="112" HEIGHT="30">다. 소재지</TD>\n',
#  '<TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="433" HEIGHT="30">경기도 성남시 분당구 백현동</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="4" VALIGN="MIDDLE" WIDTH="112" HEIGHT="120">라. 거래내역</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="102" HEIGHT="30">임차기간</TD>\n',
#  '<TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="331" HEIGHT="30">2022.05.01 ~ 2032.04.30</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="102" HEIGHT="30">거래금액</TD>\n',
#  '<TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="331" HEIGHT="30">8,793</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="102" HEIGHT="30">- 보증금</TD>\n',
#  '<TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="331" HEIGHT="30">7,255</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="102" HEIGHT="30">- 연간임차료</TD>\n',
#  '<TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="331" HEIGHT="30">8,706</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="30">3. 거래의 목적</TD>\n',
#  '<TD COLSPAN="4" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="545" HEIGHT="30">사무공간 전대차 거래</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="30">4. 이사회 의결일</TD>\n',
#  '<TD COLSPAN="4" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="545" HEIGHT="30">2021.12.21</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="193" HEIGHT="60">- 사외이사 참석여부</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="112" HEIGHT="30">참석(명)</TD>\n',
#  '<TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="433" HEIGHT="30">6</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="112" HEIGHT="30">불참(명)</TD>\n',
#  '<TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="433" HEIGHT="30">-</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="30">- 감사(감사위원)참석여부</TD>\n',
#  '<TD COLSPAN="4" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="545" HEIGHT="30">참석</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="237">5. 기타</TD>\n',
#  '<TD COLSPAN="4" VALIGN="MIDDLE" WIDTH="545" HEIGHT="237">- 상기 \'2. 라. 거래내역\'중 \'거래금액\'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.&#13;;&#13;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.&#13;;&#13;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD VALIGN="MIDDLE" WIDTH="193" HEIGHT="30">※ 관련공시일</TD>\n',
#  '<TD COLSPAN="4" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="545" HEIGHT="30">-</TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '</SECTION-1>\n',
#  '</BODY>\n',
#  '</DOCUMENT>']

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('./data/공시원문/temp.xml')
root = tree.getroot()

# %%
root[0].text
# Out:
# '특수관계인으로부터부동산임차'

# %%
len(root)
# Out:
# 4

# %%
root[3].text
# Out:
# '\n\n'

# %%
import xml.etree.ElementTree
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            print(td.text)
# Out:
# 기업집단명
# 카카오
# 회사명
# (주)카카오뱅크
# 공시일자
# 2021.12.21
# 관련법규
# 공정거래법 11조의2
# (단위 : 백만원)
# 1. 거래상대방
# (주)카카오
# 회사와의 관계
# 계열회사
# 2. 부동산 임차내역
# 가. 임차일자
# 2022.05.01
# 나. 임차목적물
# 건물 (면적 27,566.04㎡)
# 다. 소재지
# 경기도 성남시 분당구 백현동
# 라. 거래내역
# 임차기간
# 2022.05.01 ~ 2032.04.30
# 거래금액
# 8,793
# - 보증금
# 7,255
# - 연간임차료
# 8,706
# 3. 거래의 목적
# 사무공간 전대차 거래
# 4. 이사회 의결일
# 2021.12.21
# - 사외이사 참석여부
# 참석(명)
# 6
# 불참(명)
# -
# - 감사(감사위원)참석여부
# 참석
# 5. 기타
# ;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.
# ※ 관련공시일
# -

# %%
import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
lis
# Out:
# ['기업집단명',
#  '카카오',
#  '회사명',
#  '(주)카카오뱅크',
#  '공시일자',
#  '2021.12.21',
#  '관련법규',
#  '공정거래법 11조의2',
#  '(단위 : 백만원)',
#  '1. 거래상대방',
#  '(주)카카오',
#  '회사와의 관계',
#  '계열회사',
#  '2. 부동산 임차내역',
#  '가. 임차일자',
#  '2022.05.01',
#  '나. 임차목적물',
#  '건물 (면적 27,566.04㎡)',
#  '다. 소재지',
#  '경기도 성남시 분당구 백현동',
#  '라. 거래내역',
#  '임차기간',
#  '2022.05.01 ~ 2032.04.30',
#  '거래금액',
#  '8,793',
#  '- 보증금',
#  '7,255',
#  '- 연간임차료',
#  '8,706',
#  '3. 거래의 목적',
#  '사무공간 전대차 거래',
#  '4. 이사회 의결일',
#  '2021.12.21',
#  '- 사외이사 참석여부',
#  '참석(명)',
#  '6',
#  '불참(명)',
#  '-',
#  '- 감사(감사위원)참석여부',
#  '참석',
#  '5. 기타',
#  "- 상기 '2. 라. 거래내역'중 '거래금액'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.",
#  '※ 관련공시일',
#  '-']

# %%
import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
lis1 = []
lis2 = []
for tbody in root.iter('TBODY'):
    lis.append(re.sub('\r','',tbody.text))
    for tr in tbody.iter('TR'):
        lis1.append(re.sub('\r','',tr.text))
        for td in tr.findall('TD'):
            lis2.append(re.sub('\r','',td.text))

# %%
lis
# Out:
# ['\n\n', '\n\n', '\n\n']

# %%
lis1
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n']

# %%
lis2
# Out:
# ['기업집단명',
#  '카카오',
#  '회사명',
#  '(주)카카오뱅크',
#  '공시일자',
#  '2021.12.21',
#  '관련법규',
#  '공정거래법 11조의2',
#  '(단위 : 백만원)',
#  '1. 거래상대방',
#  '(주)카카오',
#  '회사와의 관계',
#  '계열회사',
#  '2. 부동산 임차내역',
#  '가. 임차일자',
#  '2022.05.01',
#  '나. 임차목적물',
#  '건물 (면적 27,566.04㎡)',
#  '다. 소재지',
#  '경기도 성남시 분당구 백현동',
#  '라. 거래내역',
#  '임차기간',
#  '2022.05.01 ~ 2032.04.30',
#  '거래금액',
#  '8,793',
#  '- 보증금',
#  '7,255',
#  '- 연간임차료',
#  '8,706',
#  '3. 거래의 목적',
#  '사무공간 전대차 거래',
#  '4. 이사회 의결일',
#  '2021.12.21',
#  '- 사외이사 참석여부',
#  '참석(명)',
#  '6',
#  '불참(명)',
#  '-',
#  '- 감사(감사위원)참석여부',
#  '참석',
#  '5. 기타',
#  "- 상기 '2. 라. 거래내역'중 '거래금액'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.",
#  '※ 관련공시일',
#  '-']

# %%
import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        print('title',tr.findall('TD')[0].text)
        for td in tr.findall('TD')[1:]:
            lis.append(re.sub('\r','',td.text))
            print(td.text)
        print('-'*50)
lis
# Out:
# title 기업집단명
# 카카오
# 회사명
# (주)카카오뱅크
# 공시일자
# 2021.12.21
# 관련법규
# 공정거래법 11조의2
# --------------------------------------------------
# title (단위 : 백만원)
# --------------------------------------------------
# title 1. 거래상대방
# (주)카카오
# 회사와의 관계
# 계열회사
# --------------------------------------------------
# title 2. 부동산 임차내역
# 가. 임차일자
# 2022.05.01
# --------------------------------------------------
# title 나. 임차목적물
# 건물 (면적 27,566.04㎡)
# --------------------------------------------------
# title 다. 소재지
# 경기도 성남시 분당구 백현동
# --------------------------------------------------
# title 라. 거래내역
# 임차기간
# 2022.05.01 ~ 2032.04.30
# --------------------------------------------------
# title 거래금액
# 8,793
# --------------------------------------------------
# title - 보증금
# 7,255
# --------------------------------------------------
# title - 연간임차료
# 8,706
# --------------------------------------------------
# title 3. 거래의 목적
# 사무공간 전대차 거래
# --------------------------------------------------
# title 4. 이사회 의결일
# 2021.12.21
# --------------------------------------------------
# title - 사외이사 참석여부
# 참석(명)
# 6
# --------------------------------------------------
# title 불참(명)
# -
# --------------------------------------------------
# title - 감사(감사위원)참석여부
# 참석
# --------------------------------------------------
# title 5. 기타
# ;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.
# --------------------------------------------------
# title ※ 관련공시일
# -
# --------------------------------------------------
# ['카카오',
#  '회사명',
#  '(주)카카오뱅크',
#  '공시일자',
#  '2021.12.21',
#  '관련법규',
#  '공정거래법 11조의2',
#  '(주)카카오',
#  '회사와의 관계',
#  '계열회사',
#  '가. 임차일자',
#  '2022.05.01',
#  '건물 (면적 27,566.04㎡)',
#  '경기도 성남시 분당구 백현동',
#  '임차기간',
#  '2022.05.01 ~ 2032.04.30',
#  '8,793',
#  '7,255',
#  '8,706',
#  '사무공간 전대차 거래',
#  '2021.12.21',
#  '참석(명)',
#  '6',
#  '-',
#  '참석',
#  "- 상기 '2. 라. 거래내역'중 '거래금액'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.",
#  '-']

# %%
# encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩 후 temp.xml로 저장
with open(f'./{filename}', 'r', encoding='euc-kr') as fp:
    lines = fp.readlines()
with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)
    
# &cr; 문자열 대체
lines = [x.replace('&cr', '&#13;') for x in lines]

with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
lis

# %% [markdown]
#  # 합친코드: 회사코드-> 회사공시목록:리포트넘버 -> 원문 다운

# %% [markdown]
# ## 다트 회사 코드

# %%
# 다트회사 코드
crp_api = dart_fss.api.filings.get_corp_code()
crp_df = pd.DataFrame(crp_api)
crp_df.head()
# Out:
# Output()
#   corp_code          corp_name stock_code modify_date
# 0  00434003                 다코       None    20170630
# 1  00434456               일산약품       None    20170630
# 2  00430964              굿앤엘에스       None    20170630
# 3  00432403               한라판지       None    20170630
# 4  00388953  크레디피아제이십오차유동화전문회사       None    20170630

# %% [markdown]
# ## fdr 주가 코드

# %%
# 증권코드
import FinanceDataReader as fdr
crp_df = fdr.StockListing('KRX')
df_KOSPI = crp_df[crp_df['Market'] == 'KOSPI']
df_KOSPI.head()
# Out:
#    Symbol Market               Name           Sector             Industry  \
# 1  095570  KOSPI             AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2  006840  KOSPI              AK홀딩스           기타 금융업                 지주사업
# 6  152100  KOSPI        ARIRANG 200              NaN                  NaN
# 7  295820  KOSPI    ARIRANG 200동일가중              NaN                  NaN
# 8  253150  KOSPI  ARIRANG 200선물레버리지              NaN                  NaN
#
#   ListingDate SettleMonth     Representative                       HomePage  \
# 1  2015-08-21         12월           박대현, 손삼달         http://www.ajnet.co.kr
# 2  1999-08-11         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr
# 6         NaT         NaN                NaN                            NaN
# 7         NaT         NaN                NaN                            NaN
# 8         NaT         NaN                NaN                            NaN
#
#   Region
# 1  서울특별시
# 2  서울특별시
# 6    NaN
# 7    NaN
# 8    NaN

# %%
df_KOSPI[df_KOSPI['Symbol']=='095570']['Name'].iloc[0]
# Out:
# 'AJ네트웍스'

# %%
df_KOSPI[~df_KOSPI['ListingDate'].isnull() ]
# Out:
#       Symbol Market     Name           Sector  \
# 1     095570  KOSPI   AJ네트웍스  산업용 기계 및 장비 임대업
# 2     006840  KOSPI    AK홀딩스           기타 금융업
# 53    027410  KOSPI      BGF           기타 금융업
# 54    282330  KOSPI   BGF리테일           종합 소매업
# 56    138930  KOSPI  BNK금융지주           기타 금융업
# ...      ...    ...      ...              ...
# 7989  005870  KOSPI      휴니드   통신 및 방송 장비 제조업
# 7998  079980  KOSPI      휴비스         화학섬유 제조업
# 8001  005010  KOSPI      휴스틸        1차 철강 제조업
# 8009  000540  KOSPI     흥국화재              보험업
# 8012  003280  KOSPI     흥아해운           해상 운송업
#
#                                            Industry ListingDate SettleMonth  \
# 1                               렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                                              지주사업  1999-08-11         12월
# 53                                             지주회사  2014-05-19         12월
# 54                                          체인화 편의점  2017-12-08         12월
# 56                                           금융지주회사  2011-03-30         12월
# ...                                             ...         ...         ...
# 7989                       무선통신기기,군납용무전기,위성방송수신기 제조  1991-09-03         12월
# 7998  합성섬유(폴리에스테르원사,원면),재생섬유,폴리에스텔 원사,원면,고상칩 제조,도소매  2012-02-23         12월
# 8001                          강관(배관용,구조용,유정용) 제조,도매  1973-06-29         12월
# 8009                                           손해보험  1974-12-05         12월
# 8012                                 외항화물운송업(케미컬탱커)  1976-06-29         12월
#
#          Representative                       HomePage Region
# 1              박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2     채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 53                  홍정국           http://www.bgf.co.kr  서울특별시
# 54                  이건준       http://www.bgfretail.com  서울특별시
# 56                  김지완           http://www.bnkfg.com  부산광역시
# ...                 ...                            ...    ...
# 7989                신종석          http://www.huneed.com  인천광역시
# 7998                신유동           http://www.huvis.com  서울특별시
# 8001                 박훈         http://www.husteel.com  서울특별시
# 8009                임규준     http://www.insurance.co.kr  서울특별시
# 8012                이환구         http://www.heung-a.com  서울특별시
#
# [820 rows x 10 columns]

# %% [markdown]
# ## 회사 공시목록

# %%
# A : 정기공시
# B : 주요사항보고
# C : 발행공시
# D : 지분공시
# E : 기타공시
# F : 외부감사관련
# G : 펀드공시
# H : 자산유동화
# I : 거래소공시
# j : 공정위공시

rpt_type = ['A','B','C','D','E','F','G','H','I','J']

# %%
# 증권 코드를 이용한 찾기
corp_list = dart_fss.corp.get_corp_list()
samsung = corp_list.find_by_stock_code('005930')
reports = samsung.search_filings(bgn_de='20210101', end_de='20211231',page_count=100,page_no=2)#, pblntf_ty='J')

# %%
print(samsung)
# Out:
# [00126380]삼성전자

# %%
len(reports.report_list)
# Out:
# 100

# %%
reports
# Out:
# {'page_count': 100,
#  'page_no': 2,
#  'report_list': [{'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210729',
#                   'rcp_no': '20210729800060',
#                   'report_nm': '현금ㆍ현물배당결정',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210729',
#                   'rcp_no': '20210729800057',
#                   'report_nm': '연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210729',
#                   'rcp_no': '20210729800054',
#                   'report_nm': '[기재정정]연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김강수',
#                   'rcept_dt': '20210723',
#                   'rcp_no': '20210723000157',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210707',
#                   'rcp_no': '20210707800054',
#                   'report_nm': '기업설명회(IR)개최(안내공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210707',
#                   'rcp_no': '20210707800050',
#                   'report_nm': '연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유정',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210706',
#                   'rcp_no': '20210706800475',
#                   'report_nm': '지속가능경영보고서등관련사항(자율공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210705',
#                   'rcp_no': '20210705800437',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '안규리',
#                   'rcept_dt': '20210629',
#                   'rcp_no': '20210629000190',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '박창진',
#                   'rcept_dt': '20210629',
#                   'rcp_no': '20210629000122',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '최주호',
#                   'rcept_dt': '20210624',
#                   'rcp_no': '20210624000396',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210608',
#                   'rcp_no': '20210608800487',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김강수',
#                   'rcept_dt': '20210603',
#                   'rcp_no': '20210603000241',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210531',
#                   'rcp_no': '20210531800741',
#                   'report_nm': '기업지배구조보고서공시',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '우경구',
#                   'rcept_dt': '20210531',
#                   'rcp_no': '20210531001381',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '안규리',
#                   'rcept_dt': '20210531',
#                   'rcp_no': '20210531000761',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210531',
#                   'rcp_no': '20210531000161',
#                   'report_nm': '대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김태영',
#                   'rcept_dt': '20210524',
#                   'rcp_no': '20210524000002',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '이승욱',
#                   'rcept_dt': '20210521',
#                   'rcp_no': '20210521000249',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': 'Ha Hyesung',
#                   'rcept_dt': '20210518',
#                   'rcp_no': '20210518000199',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '이길호',
#                   'rcept_dt': '20210518',
#                   'rcp_no': '20210518000155',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김재성',
#                   'rcept_dt': '20210518',
#                   'rcp_no': '20210518000089',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '반효동',
#                   'rcept_dt': '20210518',
#                   'rcp_no': '20210518000081',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '정인호',
#                   'rcept_dt': '20210518',
#                   'rcp_no': '20210518000017',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김태영',
#                   'rcept_dt': '20210517',
#                   'rcp_no': '20210517001888',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김태영',
#                   'rcept_dt': '20210517',
#                   'rcp_no': '20210517001580',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210517',
#                   'rcp_no': '20210517001185',
#                   'report_nm': '분기보고서 (2021.03)',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김형재',
#                   'rcept_dt': '20210517',
#                   'rcp_no': '20210517000438',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001495',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001483',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514001477',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김용관',
#                   'rcept_dt': '20210514',
#                   'rcp_no': '20210514000624',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김태영',
#                   'rcept_dt': '20210512',
#                   'rcp_no': '20210512000475',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '고재필',
#                   'rcept_dt': '20210511',
#                   'rcp_no': '20210511000205',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '조필주',
#                   'rcept_dt': '20210511',
#                   'rcp_no': '20210510000900',
#                   'report_nm': '[기재정정]임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '노태문',
#                   'rcept_dt': '20210507',
#                   'rcp_no': '20210507000833',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210507',
#                   'rcp_no': '20210507800674',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성물산',
#                   'rcept_dt': '20210507',
#                   'rcp_no': '20210507000809',
#                   'report_nm': '주식등의대량보유상황보고서(일반)',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '최윤호',
#                   'rcept_dt': '20210507',
#                   'rcp_no': '20210507000808',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '조필주',
#                   'rcept_dt': '20210507',
#                   'rcp_no': '20210507000026',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '정',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '오문욱',
#                   'rcept_dt': '20210504',
#                   'rcp_no': '20210504000590',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '국민연금공단',
#                   'rcept_dt': '20210504',
#                   'rcp_no': '20210504000163',
#                   'report_nm': '주식등의대량보유상황보고서(약식)',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '이재용',
#                   'rcept_dt': '20210503',
#                   'rcp_no': '20210503000533',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '이건희',
#                   'rcept_dt': '20210503',
#                   'rcp_no': '20210503000523',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성물산',
#                   'rcept_dt': '20210503',
#                   'rcp_no': '20210503000505',
#                   'report_nm': '주식등의대량보유상황보고서(일반)',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김승일',
#                   'rcept_dt': '20210430',
#                   'rcp_no': '20210430001364',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210430',
#                   'rcp_no': '20210430800706',
#                   'report_nm': '최대주주등소유주식변동신고서(최대주주변경시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210430',
#                   'rcp_no': '20210430800602',
#                   'report_nm': '최대주주변경',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210430',
#                   'rcp_no': '20210430800591',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '안규리',
#                   'rcept_dt': '20210430',
#                   'rcp_no': '20210430000481',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429800664',
#                   'report_nm': '기타경영사항(자율공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429800649',
#                   'report_nm': '기타경영사항(자율공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000804',
#                   'report_nm': '특수관계인에대한출자',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000733',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000726',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429000717',
#                   'report_nm': '특수관계인에대한증여',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429800081',
#                   'report_nm': '현금ㆍ현물배당결정',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429800072',
#                   'report_nm': '연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210429',
#                   'rcp_no': '20210429800068',
#                   'report_nm': '[기재정정]연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '우경구',
#                   'rcept_dt': '20210428',
#                   'rcp_no': '20210427000593',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김기남',
#                   'rcept_dt': '20210423',
#                   'rcp_no': '20210423000610',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210408',
#                   'rcp_no': '20210408800717',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210407',
#                   'rcp_no': '20210407800510',
#                   'report_nm': '기업설명회(IR)개최(안내공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210407',
#                   'rcp_no': '20210407800054',
#                   'report_nm': '연결재무제표기준영업(잠정)실적(공정공시)',
#                   'rm': '유정',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '안규리',
#                   'rcept_dt': '20210402',
#                   'rcp_no': '20210402001357',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '반효동',
#                   'rcept_dt': '20210325',
#                   'rcp_no': '20210325000651',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '정지은',
#                   'rcept_dt': '20210322',
#                   'rcp_no': '20210322000015',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '반효동',
#                   'rcept_dt': '20210319',
#                   'rcp_no': '20210319000132',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210317',
#                   'rcp_no': '20210317000939',
#                   'report_nm': '특수관계인과의보험거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210317',
#                   'rcp_no': '20210317000926',
#                   'report_nm': '사외이사의선임ㆍ해임또는중도퇴임에관한신고',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210317',
#                   'rcp_no': '20210317800897',
#                   'report_nm': '정기주주총회결과',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '반효동',
#                   'rcept_dt': '20210316',
#                   'rcp_no': '20210316000067',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210309',
#                   'rcp_no': '20210309000744',
#                   'report_nm': '사업보고서 (2020.12)',
#                   'rm': '연',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '국민연금공단',
#                   'rcept_dt': '20210309',
#                   'rcp_no': '20210309000549',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210308',
#                   'rcp_no': '20210308800940',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '국민연금공단',
#                   'rcept_dt': '20210305',
#                   'rcp_no': '20210305000674',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '박찬훈',
#                   'rcept_dt': '20210303',
#                   'rcp_no': '20210303000376',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210302',
#                   'rcp_no': '20210302000645',
#                   'report_nm': '대규모기업집단현황공시[분기별공시(대표회사용)]',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '정진민',
#                   'rcept_dt': '20210223',
#                   'rcp_no': '20210223000189',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210218',
#                   'rcp_no': '20210218800417',
#                   'report_nm': '감사보고서제출',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '김현주',
#                   'rcept_dt': '20210218',
#                   'rcp_no': '20210218000576',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216001434',
#                   'report_nm': '의결권대리행사권유참고서류',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216001189',
#                   'report_nm': '주주총회소집공고',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216000713',
#                   'report_nm': '특수관계인과의내부거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216000704',
#                   'report_nm': '특수관계인과의내부거래',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216800359',
#                   'report_nm': '기타경영사항(자율공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210216',
#                   'rcp_no': '20210216800151',
#                   'report_nm': '주주총회소집결의',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210215',
#                   'rcp_no': '20210215001257',
#                   'report_nm': '동일인등출자계열회사와의상품ㆍ용역거래변경',
#                   'rm': '공',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '오문욱',
#                   'rcept_dt': '20210209',
#                   'rcp_no': '20210209000001',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210208',
#                   'rcp_no': '20210208801055',
#                   'report_nm': '최대주주등소유주식변동신고서',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '장세연',
#                   'rcept_dt': '20210208',
#                   'rcp_no': '20210208000166',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '조필주',
#                   'rcept_dt': '20210208',
#                   'rcp_no': '20210208000100',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '최호규',
#                   'rcept_dt': '20210208',
#                   'rcp_no': '20210208000022',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '안규리',
#                   'rcept_dt': '20210203',
#                   'rcp_no': '20210203000461',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '국민연금공단',
#                   'rcept_dt': '20210203',
#                   'rcp_no': '20210203000324',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '정진민',
#                   'rcept_dt': '20210202',
#                   'rcp_no': '20210202000037',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '이창수',
#                   'rcept_dt': '20210128',
#                   'rcp_no': '20210128000335',
#                   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#                   'rm': '',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210128',
#                   'rcp_no': '20210128800077',
#                   'report_nm': '매출액또는손익구조30%(대규모법인은15%)이상변경',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210128',
#                   'rcp_no': '20210128800075',
#                   'report_nm': '수시공시의무관련사항(공정공시)',
#                   'rm': '유',
#                   'stock_code': '005930'},
#                  {'corp_cls': 'Y',
#                   'corp_code': '00126380',
#                   'corp_name': '삼성전자',
#                   'flr_nm': '삼성전자',
#                   'rcept_dt': '20210128',
#                   'rcp_no': '20210128800069',
#                   'report_nm': '현금ㆍ현물배당결정',
#                   'rm': '유',
#                   'stock_code': '005930'}],
#  'total_count': 211,
#  'total_page': 3}

# %% [markdown]
# ## 보고서번호

# %%
reports.report_list[0].rcp_no
# Out:
# '20190531000190'

# %%
re

# %% [markdown]
# ## 보고서 원문 다운(저장위치, 보고서번호)

# %%
import dart_fss
dart_fss.api.filings.download_document('./data/공시원문/삼성전자_20211130001512', rcept_no[1])
# Out:
# Output()
# './data/공시원문/삼성전자_20211130001512\\20211130001512.zip'

# %% [markdown]
# ## 보고서 원문 압축풀고 인코딩해결

# %%
doc_zip_path = os.path.abspath('./data/공시원문/document.zip')
zf = zipfile.ZipFile(doc_zip_path)
zf.extractall()
zipinfo = zf.infolist()
zipinfo

# %%
# 첫번째 압축풀기
zf = zipfile.ZipFile('./data/공시원문/삼성전자_20211130001512/20211130001512.zip').extractall('./data/공시원문_압축해제')
# zf.extractall()

# %%
zf
# Out:
# 'C:\\KDT4\\ML,DL\\프로젝트6\\20211130001512.xml'

# %%
# encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩 후 temp.xml로 저장
with open(f'./{filename}', 'r', encoding='euc-kr') as fp:
    lines = fp.readlines()
with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

# %%
# &cr; 문자열 대체
lines = [x.replace('&cr', '&#13;') for x in lines]

with open('./data/공시원문/temp.xml', 'w', encoding='utf-8') as fp:
    fp.writelines(lines)

import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
lis

# %%
import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
lis
# Out:
# ['기업집단명',
#  '카카오',
#  '회사명',
#  '(주)카카오뱅크',
#  '공시일자',
#  '2021.12.21',
#  '관련법규',
#  '공정거래법 11조의2',
#  '(단위 : 백만원)',
#  '1. 거래상대방',
#  '(주)카카오',
#  '회사와의 관계',
#  '계열회사',
#  '2. 부동산 임차내역',
#  '가. 임차일자',
#  '2022.05.01',
#  '나. 임차목적물',
#  '건물 (면적 27,566.04㎡)',
#  '다. 소재지',
#  '경기도 성남시 분당구 백현동',
#  '라. 거래내역',
#  '임차기간',
#  '2022.05.01 ~ 2032.04.30',
#  '거래금액',
#  '8,793',
#  '- 보증금',
#  '7,255',
#  '- 연간임차료',
#  '8,706',
#  '3. 거래의 목적',
#  '사무공간 전대차 거래',
#  '4. 이사회 의결일',
#  '2021.12.21',
#  '- 사외이사 참석여부',
#  '참석(명)',
#  '6',
#  '불참(명)',
#  '-',
#  '- 감사(감사위원)참석여부',
#  '참석',
#  '5. 기타',
#  "- 상기 '2. 라. 거래내역'중 '거래금액'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.",
#  '※ 관련공시일',
#  '-']

# %%
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
# Out:
# ['기업집단명',
#  '카카오',
#  '회사명',
#  '(주)카카오뱅크',
#  '공시일자',
#  '2021.12.21',
#  '관련법규',
#  '공정거래법 11조의2',
#  '(단위 : 백만원)',
#  '1. 거래상대방',
#  '(주)카카오',
#  '회사와의 관계',
#  '계열회사',
#  '2. 부동산 임차내역',
#  '가. 임차일자',
#  '2022.05.01',
#  '나. 임차목적물',
#  '건물 (면적 27,566.04㎡)',
#  '다. 소재지',
#  '경기도 성남시 분당구 백현동',
#  '라. 거래내역',
#  '임차기간',
#  '2022.05.01 ~ 2032.04.30',
#  '거래금액',
#  '8,793',
#  '- 보증금',
#  '7,255',
#  '- 연간임차료',
#  '8,706',
#  '3. 거래의 목적',
#  '사무공간 전대차 거래',
#  '4. 이사회 의결일',
#  '2021.12.21',
#  '- 사외이사 참석여부',
#  '참석(명)',
#  '6',
#  '불참(명)',
#  '-',
#  '- 감사(감사위원)참석여부',
#  '참석',
#  '5. 기타',
#  "- 상기 '2. 라. 거래내역'중 '거래금액'은 연간임차료와 보증금에 대한 환산 연간임차료(부가가치세법 시행규칙 제47조의 이자율 연 1.2%적용)의 합계금액입니다.;;- 상기 연간임차료는 전대차 개시일로부터 1년간의 전차료이며, 이후 전차료는 본 계약 및 물가상승에 따라 변동될 수 있습니다.;;- 상기 사항은 진행절차 및 관계법령, 거래상대방 등과의 합의 등에 의거 변동될 수 있으며, 본 거래와 관련된 계약서의 체결 및 변경, 본건 거래의 실행은 대표이사 및 그가 지정하는 자에게 위임합니다.",
#  '※ 관련공시일',
#  '-']

# %%
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        print(re.sub('\r','',tr.text))

# %% [markdown]
# ## 합치기

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import zipfile
import os
import xml.etree.ElementTree
import re
import dart_fss

# %%
api_key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
dart_fss.set_api_key(api_key=api_key)

# 기업개수 820개 확인
crp_df = fdr.StockListing('KRX')
df_KOSPI = crp_df[crp_df['Market'] == 'KOSPI']
df_KOSPI = df_KOSPI[~df_KOSPI['ListingDate'].isnull() ]
code_lst = df_KOSPI1['Symbol']
corp_list = dart_fss.corp.get_corp_list()

# 증권 코드를 이용한 찾기.
code = code_lst
rpt_type = ['B','C','D','E','F','G','H','J','I'] 
bgn = '20120101'
end = '20220531'

x_corp_name = []
x_rpt_name = []
x_rpt_date= []
x_rpt_no= []


for code in code_lst:
    
    # 회사이름
    name = df_KOSPI[df_KOSPI['Symbol']==code]['Name'].iloc[0]
    corp = corp_list.find_by_stock_code(code)
    
    for rpt in rpt_type:
        
        try:
            reports = corp.search_filings(bgn_de= bgn, end_de= end, page_count= 100, pblntf_ty= rpt)

            for page in range(1,reports.total_page+1):

                for i in range(len(reports.report_list)):
                    # 공시일
                    date = reports.report_list[i].rcept_dt

                    # 리포트 숫자명
                    rcp_no = reports.report_list[i].rcp_no

                    #리포트 이름
                    rpt_name = reports.report_list[i].report_nm

                    try:
                        # zip파일 다운받기
                        dart_fss.api.filings.download_document('./data/공시원문/{}_{}'.format(name,rcp_no),rcp_no)

                        # 회사이름+ 리포트타입 파일
                        path = os.getcwd()
                        path1 = os.path.join(path,'data','공시원문_xml파일',name,rpt)

                        if not os.path.exists(path1):
                            os.makedirs(path1)


                        # 첫번째 압축풀기
                        zf = zipfile.ZipFile('./data/공시원문/{}_{}/{}.zip'.format(name,rcp_no,rcp_no)).extractall('./data/공시원문_압축해제/{}'.format(rcp_no))
                        # encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩 후 temp.xml로 저장
                        with open('./data/공시원문_압축해제/{}/{}.xml'.format(rcp_no,rcp_no), 'r', encoding='euc-kr') as fp:
                            lines = fp.readlines()
                        # &cr; 문자열 대체
                        lines = [x.replace('&cr', '&#13;') for x in lines]
                        lines = [x.replace('<주', '&lt;주') for x in lines]
                        lines = [x.replace('M&A', 'M&amp;A') for x in lines]
                        lines = [x.replace('R&D', 'R&amp;A') for x in lines]

                        with open('./data/공시원문_xml파일/{}/{}/{}_{}_{}_{}.xml'.format(name,rpt,name,rpt,rpt_name,rcp_no), 'w', encoding='utf-8') as fp:
                            fp.writelines(lines)

                    except:
                        x_corp_name.append(name)
                        x_rpt_name.append(rpt_name)
                        x_rpt_date.append(date)
                        x_rpt_no.append(rcp_no)
                        print('회사이름: ',name)
                        print('리포트이름: ',rpt_name)
                        print('리포트번호: ',rcp_no)
                        print('공시일: ',date)
                        print('-'*50)
                        
        except:
            print('보고서타입 :', rpt)
            

            
            
#             # 원문 저장
#             tree = xml.etree.ElementTree.parse('./data/공시원문/{}_{}_{}.xml'.format(name,rpt_name,date))
# Out:
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]주요사항보고서(회사분할결정)
# 공시일:  20210108
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(타법인주식및출자증권양도결정)
# 공시일:  20190102
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(타법인주식및출자증권양도결정)
# 공시일:  20181228
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20200120
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20200115
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20200115
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190723
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190718
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190718
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190528
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190528
# --------------------------------------------------
# 리포트이름:  [첨부정정]증권신고서(채무증권)
# 공시일:  20190523
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190523
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190523
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20181016
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20181011
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20181011
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180119
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180116
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20180116
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  증권발행실적보고서
# 공시일:  20170802
# --------------------------------------------------
# Output()
# 리포트이름:  투자설명서
# 공시일:  20170802
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20170801
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20170727
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20170727
# --------------------------------------------------
# Output()
# 리포트이름:  증권신고서(채무증권)
# 공시일:  20170721
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20161021
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20161017
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20161017
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20160504
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20160428
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20160428
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20160127
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20160125
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20160121
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]투자설명서
# 공시일:  20150807
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(지분증권)
# 공시일:  20150807
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권신고서(지분증권)
# 공시일:  20150729
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]증권신고서(채무증권)
# 공시일:  20121210
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]의결권대리행사권유참고서류
# 공시일:  20220318
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20200304
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171228
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171228
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171016
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170927
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170804
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170512
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170412
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170412
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170412
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170412
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170331
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170331
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170615
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170316
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20160325
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 보고서타입 : F
# 보고서타입 : G
# 보고서타입 : H
# 보고서타입 : J
# 리포트이름:  [기재정정]주요사항보고서(자기주식처분결정)
# 공시일:  20180412
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]주요사항보고서(유상증자결정)
# 공시일:  20121022
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20190419
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171109
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171012
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170905
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170823
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170719
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170706
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170418
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170331
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20170329
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170125
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20150302
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20190419
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171109
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171012
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170905
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170823
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170719
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170706
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170418
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170331
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20170329
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170125
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20150302
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식매수선택권부여에관한신고
# 공시일:  20170324
# --------------------------------------------------
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20170316
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170309
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20160317
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20150326
# --------------------------------------------------
# 리포트이름:  [기재정정]사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20150326
# --------------------------------------------------
# 리포트이름:  [기재정정]사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20150326
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20150312
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 보고서타입 : F
# 보고서타입 : G
# 보고서타입 : H
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20210531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20200529
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20190531
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(주식교환ㆍ이전결정)
# 공시일:  20190417
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20180306
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20180212
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(회사분할결정)
# 공시일:  20170807
# --------------------------------------------------
# Output()
# 리포트이름:  주요사항보고서(회사분할결정)
# 공시일:  20170608
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(주식의포괄적교환ㆍ이전결정)
# 공시일:  20150615
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(주식의포괄적교환ㆍ이전결정)
# 공시일:  20150610
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(주식의포괄적교환ㆍ이전결정)
# 공시일:  20150601
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(주식의포괄적교환ㆍ이전)
# 공시일:  20190417
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(주식의포괄적교환ㆍ이전)
# 공시일:  20190408
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]투자설명서
# 공시일:  20180212
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(지분증권)
# 공시일:  20180212
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권신고서(지분증권)
# 공시일:  20180129
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권발행실적보고서(합병등)
# 공시일:  20171128
# --------------------------------------------------
# Output()
# 리포트이름:  증권발행실적보고서(합병등)
# 공시일:  20171101
# --------------------------------------------------
# Output()
# 리포트이름:  투자설명서
# 공시일:  20170905
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(분할)
# 공시일:  20170824
# --------------------------------------------------
# Output()
# 리포트이름:  증권신고서(분할)
# 공시일:  20170814
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(주식의포괄적교환ㆍ이전)
# 공시일:  20150615
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(주식의포괄적교환ㆍ이전)
# 공시일:  20150610
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20200225
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20200225
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20190312
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20180123
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171222
# --------------------------------------------------
# 리포트이름:  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# 리포트이름:  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171113
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170925
# --------------------------------------------------
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20170913
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20170913
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170821
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170814
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170711
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170703
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170703
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170623
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170622
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170612
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170602
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170523
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170519
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170517
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170517
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170511
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170424
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170411
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170407
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170323
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170215
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170102
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20200225
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20200225
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20190312
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20180123
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171222
# --------------------------------------------------
# 리포트이름:  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# 리포트이름:  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# 리포트이름:  [기재정정]주식등의대량보유상황보고서(일반)
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171113
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20171108
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170925
# --------------------------------------------------
# 리포트이름:  [기재정정]의결권대리행사권유참고서류
# 공시일:  20170913
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20170913
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170821
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170814
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170711
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170703
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170703
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170623
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170622
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170612
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170602
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170523
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170519
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170517
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170517
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170511
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170424
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170411
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170407
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20170323
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170215
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170102
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170102
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20190312
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20171101
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170928
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170913
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170612
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170309
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  연결감사보고서 (2013.12)
# 공시일:  20140319
# --------------------------------------------------
# Output()
# 리포트이름:  감사보고서 (2013.12)
# 공시일:  20140319
# --------------------------------------------------
# Output()
# 리포트이름:  감사보고서 (2012.12)
# 공시일:  20130329
# --------------------------------------------------
# Output()
# 리포트이름:  감사보고서 (2011.12)
# 공시일:  20120305
# --------------------------------------------------
# 보고서타입 : G
# 보고서타입 : H
# 보고서타입 : J
# 보고서타입 : B
# 보고서타입 : C
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20200305
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]공개매수설명서
# 공시일:  20180212
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수신고서
# 공시일:  20180212
# --------------------------------------------------
# 리포트이름:  [첨부정정]공개매수신고서
# 공시일:  20180130
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수설명서
# 공시일:  20180129
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수신고서
# 공시일:  20180129
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171215
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20200305
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]공개매수설명서
# 공시일:  20180212
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수신고서
# 공시일:  20180212
# --------------------------------------------------
# 리포트이름:  [첨부정정]공개매수신고서
# 공시일:  20180130
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수설명서
# 공시일:  20180129
# --------------------------------------------------
# 리포트이름:  [기재정정]공개매수신고서
# 공시일:  20180129
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171215
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(약식)
# 공시일:  20171214
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171213
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20200306
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 보고서타입 : F
# 보고서타입 : G
# 보고서타입 : H
# 보고서타입 : J
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주요사항보고서(자기주식취득신탁계약체결결정)
# 공시일:  20200303
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20200212
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20200206
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20190821
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20190816
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20190213
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20190207
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20180223
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20180219
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20180213
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20180208
# --------------------------------------------------
# Output()
# 리포트이름:  주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20160108
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20151202
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20150824
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20150819
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20150617
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20150612
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(상각형조건부자본증권발행결정)
# 공시일:  20150522
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(주식의포괄적교환ㆍ이전결정)
# 공시일:  20150409
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]일괄신고서
# 공시일:  20201127
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  증권발행실적보고서
# 공시일:  20200219
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20191031
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190401
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190214
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190213
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181226
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181114
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180403
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171117
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]일괄신고서
# 공시일:  20201127
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  증권발행실적보고서
# 공시일:  20200219
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20191031
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190401
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190214
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190213
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181226
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181114
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180403
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171117
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]일괄신고서
# 공시일:  20201127
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  증권발행실적보고서
# 공시일:  20200219
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20200212
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20191031
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190821
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20190401
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20190214
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20190213
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181226
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20181114
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180814
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180515
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20180403
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180223
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]일괄신고서
# 공시일:  20171117
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20200305
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200221
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20200305
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200221
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200306
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20200305
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200221
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20200305
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20190312
# --------------------------------------------------
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20190311
# --------------------------------------------------
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20190307
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170912
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170309
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 보고서타입 : F
# 보고서타입 : G
# 보고서타입 : H
# 보고서타입 : J
# 보고서타입 : B
# 보고서타입 : C
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200304
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20200304
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20200305
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20171128
# --------------------------------------------------
# 리포트이름:  [기재정정]주주총회소집공고
# 공시일:  20170309
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170302
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  연결감사보고서 (2012.12)
# 공시일:  20130329
# --------------------------------------------------
# Output()
# 리포트이름:  감사보고서 (2012.12)
# 공시일:  20130329
# --------------------------------------------------
# 보고서타입 : G
# 보고서타입 : H
# 보고서타입 : J
# 리포트이름:  [기재정정]주요사항보고서(주식교환ㆍ이전결정)
# 공시일:  20191209
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(자기주식처분결정)
# 공시일:  20191209
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(주식교환ㆍ이전결정)
# 공시일:  20190814
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]주요사항보고서(자기주식처분결정)
# 공시일:  20190516
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(주식교환ㆍ이전결정)
# 공시일:  20190516
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20160826
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20160401
# --------------------------------------------------
# 리포트이름:  [첨부정정]주요사항보고서(유상증자결정)
# 공시일:  20160204
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20160126
# --------------------------------------------------
# 리포트이름:  [첨부정정]주요사항보고서(유상증자결정)
# 공시일:  20160125
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(유상증자결정)
# 공시일:  20160122
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180410
# --------------------------------------------------
# 리포트이름:  [기재정정]증권신고서(채무증권)
# 공시일:  20180406
# --------------------------------------------------
# 리포트이름:  [발행조건확정]증권신고서(채무증권)
# 공시일:  20180404
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20171201
# --------------------------------------------------
# Output()
# 리포트이름:  임원ㆍ주요주주특정증권등소유상황보고서
# 공시일:  20170720
# --------------------------------------------------
# Output()
# 리포트이름:  의결권대리행사권유참고서류
# 공시일:  20170308
# --------------------------------------------------
# Output()
# 리포트이름:  주식등의대량보유상황보고서(일반)
# 공시일:  20170125
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 공시일:  20170324
# --------------------------------------------------
# Output()
# 리포트이름:  주주총회소집공고
# 공시일:  20170308
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 보고서타입 : F
# 보고서타입 : G
# 보고서타입 : H
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20210531
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20210531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20201027
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20200529
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20200528
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20191209
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20191209
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20191129
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20190610
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20190531
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20181220
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20181220
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20180531
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인으로부터주식의취득
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20171130
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20170831
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170623
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170623
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170531
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20170228
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20160614
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20160531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20151214
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20151214
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20150601
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20150601
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20210531
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20210531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20201027
# --------------------------------------------------
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20200529
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20200528
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20200227
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20191209
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20191209
# --------------------------------------------------
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20191129
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20190610
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20190531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20181220
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20180531
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  특수관계인으로부터주식의취득
# 공시일:  20171219
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20171130
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20170831
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170623
# --------------------------------------------------
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170623
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20170531
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[분기별공시(대표회사용)]
# 공시일:  20170228
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20160614
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20160531
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20151214
# --------------------------------------------------
# 리포트이름:  [기재정정]특수관계인과의내부거래
# 공시일:  20151214
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20150601
# --------------------------------------------------
# Output()
# 리포트이름:  대규모기업집단현황공시[연1회공시및1/4분기용(대표회사)]
# 공시일:  20150601
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]주요사항보고서(회사합병결정)
# 공시일:  20211018
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]주요사항보고서(유상증자결정)
# 공시일:  20200515
# --------------------------------------------------
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(타법인주식및출자증권양수결정)
# 공시일:  20160524
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()

# %%
df_x = pd.DataFrame({'회사이름':x_corp_name, '공시제목':x_rpt_name , '공시날짜':x_rpt_date, '공시숫자명': x_rpt_no})

# %%
pd.read_csv('./data/공시원문_xml파일/AJ네트웍스/B/AJ네트웍스_B_[기재정정]주요사항보고서(유상증자결정)_20140715000087.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14132/3570773888.py in <module>
# ----> 1 pd.read_csv('./data/공시원문_xml파일/AJ네트웍스/B/AJ네트웍스_B_[기재정정]주요사항보고서(유상증자결정)_20140715000087.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 128, saw 2

# %%
lines
# Out:
# ['<?xml version="1.0" encoding="utf-8"?>\n',
#  '\n',
#  '\n',
#  '<DOCUMENT xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="dart3.xsd">\n',
#  '\n',
#  '<DOCUMENT-HEADER AEXT-CLASS="Y">\n',
#  '<DOCUMENT-NAME ACODE="11306">주요사항보고서(유상증자결정)</DOCUMENT-NAME>\n',
#  '<FORMULA-VERSION ADATE="20130701">1.3</FORMULA-VERSION>\n',
#  '<COMPANY-NAME AREGCIK="00365387">아주렌탈 주식회사</COMPANY-NAME>\n',
#  '</DOCUMENT-HEADER>\n',
#  '\n',
#  '<BODY>\n',
#  '\n',
#  '<INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">\n',
#  '<COMMENT>◆click◆ 정정문서 작성시 『정오표』 삽입</COMMENT>\n',
#  '<LIBRARYLIST>정정신고(보고).LCommon</LIBRARYLIST>\n',
#  '</INSERTION>\n',
#  '\n',
#  '<INSERTION ABASISNUMBER="E1" AFREQUENCY="1" ADUPLICATION="N">\n',
#  '<COMMENT>◆click◆ 『표지』삽입</COMMENT>\n',
#  '<LIBRARYLIST>표지-주요사항보고서.LCommon:표지-주요사항보고서／거래소신고의무사항.LCommon</LIBRARYLIST>\n',
#  '\n',
#  '<LIBRARY>\n',
#  '<FILENAME ATYPE="LCommon">표지-주요사항보고서／거래소신고의무사항</FILENAME>\n',
#  '\n',
#  '<SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">\n',
#  '<TITLE ATOC="Y" AASSOCNOTE="D-0-0-0-0">주요사항보고서 / 거래소 신고의무 사항</TITLE>\n',
#  '\n',
#  '<TABLE ACLASS="NORMAL" AFIXTABLE="Y" WIDTH="600" BORDER="0">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="132"></COL>\n',
#  '<COL WIDTH="174"></COL>\n',
#  '<COL WIDTH="267"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="30"></TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="53">&cr;</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="324" HEIGHT="30">금융위원회 / 한국거래소 귀중</TD>\n',
#  '<TD ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="276" HEIGHT="30">2013  년   8  월   30  일</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="53">&cr;</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30">회     사     명  :</TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">아주렌탈주식회사</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30">대  표   이  사  :</TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">안 진 수</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30">본 점  소 재 지 :</TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">서울시 구로구 구로동 235-2 에이스하이엔드타워 9층</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30"></TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">(전  화) 02-6363-9999</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30"></TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">(홈페이지) http://www.ajurental.com</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30"></TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30"></TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="30"></TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="30"></TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30">작 성 책 임 자 :</TD>\n',
#  '<TD WIDTH="183" HEIGHT="30">(직 책) 경영지원본부장  </TD>\n',
#  '<TD WIDTH="276" HEIGHT="30">(성 명) 채의석</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="141" HEIGHT="30"></TD>\n',
#  '<TD COLSPAN="2" WIDTH="459" HEIGHT="30">(전 화) 02-6240-0802</TD>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="3" WIDTH="600" HEIGHT="30"></TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '<P></P>\n',
#  '<PGBRK></PGBRK>\n',
#  '</SECTION-1>\n',
#  '</LIBRARY>\n',
#  '</INSERTION>\n',
#  '\n',
#  '<SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">\n',
#  '<TITLE ATOC="Y" AASSOCNOTE="D-0-1-0-0">유상증자 결정</TITLE>\n',
#  '<P></P>\n',
#  '\n',
#  '<TABLE-GROUP ACLASS="CST_CNT" ADELETETABLE="N">\n',
#  '\n',
#  '<TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="1">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="151"></COL>\n',
#  '<COL WIDTH="163"></COL>\n',
#  '<COL WIDTH="259"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="160" HEIGHT="60" AUPDATECONT="N">1. 신주의 종류와 수</TD>\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">보통주 (주)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="CST_CNT">38,000</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">우선주 (주)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="PST_CNT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="332" HEIGHT="30" AUPDATECONT="N">2. 1주당 액면가액 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="FVAL">5,000</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="160" HEIGHT="60" AUPDATECONT="N">3. 증자전 &cr;    발행주식총수 (주)</TD>\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">보통주 (주)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="BFR_CST_CNT">2,481,434 </TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">우선주 (주)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="BFR_PST_CNT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="4" VALIGN="MIDDLE" WIDTH="160" HEIGHT="143" AUPDATECONT="N">4. 자금조달의 목적</TD>\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">시설자금 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="FND_USE1">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="172" HEIGHT="30" AUPDATECONT="N">운영자금 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="FND_USE2">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="172" HEIGHT="53" AUPDATECONT="N">타법인 증권&cr;취득자금 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="268" HEIGHT="53" ACODE="ANC_ACQ_AMT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" WIDTH="172" HEIGHT="30" AUPDATECONT="N">기타자금 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="268" HEIGHT="30" ACODE="FND_USE3">810,730,000</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="332" HEIGHT="30" AUPDATECONT="N">5. 증자방식</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="268" HEIGHT="30" AUNIT="CI_MTH" AUNITVALUE="6">제3자배정증자</TU>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '</TABLE-GROUP>\n',
#  '\n',
#  '<INSERTION ABASISNUMBER="E1" AFREQUENCY="1" ADUPLICATION="N">\n',
#  '<COMMENT>◆click◆ 『증자방식별 세부내역』 삽입</COMMENT>\n',
#  '<LIBRARYLIST>11306#*증자의경우.dsl</LIBRARYLIST>\n',
#  '\n',
#  '<LIBRARY>\n',
#  '<FILENAME ATYPE="dsl">04_제3자배정증자의경우</FILENAME>\n',
#  '\n',
#  '<TABLE-GROUP ACLASS="THD_ASN_INC" ADELETETABLE="N">\n',
#  '\n',
#  '<TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="599" BORDER="1">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="140"></COL>\n',
#  '<COL WIDTH="191"></COL>\n',
#  '<COL WIDTH="241"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="149" HEIGHT="60" AUPDATECONT="N">6. 신주 발행가액</TD>\n',
#  '<TD ALIGN="CENTER" WIDTH="200" HEIGHT="30" AUPDATECONT="N">보통주 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="250" HEIGHT="30" ACODE="CST_ISS_VAL">21,335</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" WIDTH="200" HEIGHT="30" AUPDATECONT="N">우선주 (원)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="250" HEIGHT="30" ACODE="PST_ISS_VAL">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">7. 기준주가에 대한 할인율 또는 할증율 (%)</TD>\n',
#  '<TE ALIGN="RIGHT" WIDTH="250" HEIGHT="30" ACODE="DC_RATE">해당사항 없음</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">8. 제3자배정에 대한 정관의 근거</TD>\n',
#  '<TE WIDTH="250" HEIGHT="30" ACODE="ART_BAS" ALIGN="CENTER">정관 제10조 2항 제11호 규정</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">9. 납입일</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="PYM_DT" AUNITVALUE="20130830">2013년 08월 30일</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">10. 신주의 배당기산일</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="DV_ST_DT" AUNITVALUE="20130101">2013년 01월 01일</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">11. 신주권교부예정일</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="NST_GV_DT" AUNITVALUE="20130830">2013년 08월 30일</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">12. 신주의 상장 예정일</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="LST_PLN_DT" AUNITVALUE="-">-</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="30" AUPDATECONT="N">13. 현물출자로 인한 우회상장 해당여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="PIN_BL_YN" AUNITVALUE="N">아니오</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="30" AUPDATECONT="N">   - 현물출자가 있는지 여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="PIN_EXT_YN" AUNITVALUE="N">아니오</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="53" AUPDATECONT="N">   - 현물출자 재산 중 주권비상장법인주식이 &cr;      있는지 여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="53" AUNIT="PIN_SLC_YN" AUNITVALUE="N">아니오</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="149" HEIGHT="83" AUPDATECONT="N">   - 납입예정 주식의&cr;      현물출자 가액</TD>\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="200" HEIGHT="30" AUPDATECONT="N">현물출자가액(원)</TD>\n',
#  '<TE ALIGN="CENTER" WIDTH="250" HEIGHT="30" ACODE="PIN_VAL">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="200" HEIGHT="53" AUPDATECONT="N">당사 최근사업연도 &cr;자산총액 대비(%)</TD>\n',
#  '<TE ALIGN="CENTER" WIDTH="250" HEIGHT="53" ACODE="PIN_AST_RT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="30" AUPDATECONT="N">   - 납입예정 주식수</TD>\n',
#  '<TE ALIGN="CENTER" WIDTH="250" HEIGHT="30" ACODE="PAY_EXP_CNT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="30" AUPDATECONT="N">14. 우회상장 요건 충족여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="BL_CON_YN" AUNITVALUE="N">아니오</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="349" HEIGHT="30" AUPDATECONT="N">15. 이사회결의일(결정일)</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="DRC_DT" AUNITVALUE="20130828">2013년 08월 28일</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ROWSPAN="2" VALIGN="MIDDLE" WIDTH="149" HEIGHT="60" AUPDATECONT="N">   - 사외이사&cr;      참석여부</TD>\n',
#  '<TD ALIGN="CENTER" WIDTH="200" HEIGHT="30" AUPDATECONT="N">참석 (명)</TD>\n',
#  '<TE ALIGN="CENTER" WIDTH="250" HEIGHT="30" ACODE="ATD_CNT">3</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD ALIGN="CENTER" WIDTH="200" HEIGHT="30" AUPDATECONT="N">불참 (명)</TD>\n',
#  '<TE ALIGN="CENTER" WIDTH="250" HEIGHT="30" ACODE="NATD_CNT">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">   - 감사(감사위원) 참석여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="ADT_ATD_YN" AUNITVALUE="Y">참석</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">16. 증권신고서 제출대상 여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="RPT_SM_YN" AUNITVALUE="N">아니오</TU>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">17. 제출을 면제받은 경우 그 사유</TD>\n',
#  '<TE WIDTH="250" HEIGHT="30" ACODE="RPT_SBM" ALIGN="CENTER">소액공모</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD COLSPAN="2" WIDTH="349" HEIGHT="30" AUPDATECONT="N">18. 공정거래위원회 신고대상 여부</TD>\n',
#  '<TU ALIGN="CENTER" WIDTH="250" HEIGHT="30" AUNIT="TRD_YN" AUNITVALUE="N">미해당</TU>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '</TABLE-GROUP>\n',
#  '<P>&cr;19. 기타 투자판단에 참고할 사항</P>\n',
#  '\n',
#  '<INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">\n',
#  '<COMMENT>◆click◆ 자회사에 관한 공시의 경우 『자회사명』삽입</COMMENT>\n',
#  '<LIBRARYLIST>주요사항보고서-자회사에관한공시(거래소신고의무사항).LCommon</LIBRARYLIST>\n',
#  '</INSERTION>\n',
#  '<P>가. 신주의발행가액 산정 근거 :&cr; - 상속세 및 증여세법에 의하여 주식가치를 평가하여 발행가액을 산정하였습니다.&cr;나. 기타 신주 발행에 관한 필요한 절차사항은 대표이사에게 일임합니다.&cr;</P>\n',
#  '\n',
#  '<TABLE-GROUP ACLASS="THD_ASN_OBJ" ADELETETABLE="N">\n',
#  '\n',
#  '<TABLE ACLASS="NORMAL" AFIXTABLE="Y" WIDTH="600" BORDER="0">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="591"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="600" HEIGHT="30" AUPDATECONT="N">【제3자배정 근거, 목적 등】</TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '\n',
#  '<TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="600" BORDER="1">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="291"></COL>\n',
#  '<COL WIDTH="291"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<THEAD>\n',
#  '\n',
#  '<TR ACOPY="N" ADELETE="N">\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="300" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">제3자배정 근거가 되는 정관규정</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="300" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">제3자배정 증자의 목적</TH>\n',
#  '</TR>\n',
#  '</THEAD>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="N">\n',
#  '\n',
#  '<TE WIDTH="300" HEIGHT="1603" ACODE="RULE">\n',
#  '<P>제 10 조【신주인수권】</P>\n',
#  '<P>1.    본 회사의 주주는 신주발행에 있어서 그가 소유한 주식수에 비례하여 신주의 배정을 받을 권리를 가진다.</P>\n',
#  '<P>2.    1항의 규정에 불구하고 다음 각 호의 경우에는 주주 외의자에게 신주를 배정할 수 있다.</P>\n',
#  '<P>1)   자본시장과금융투자업에관한법률 제9조 규정에 의하여 신주를 모집하거나 인수인에게 인수하게 하는 경우</P>\n',
#  '<P>2)   자본시장과금융투자업에관한법률 제165조의6의 규정에 의하여 이사회의 결의로 일반 공모증자방식으로 신주를 발행하는 경우 </P>\n',
#  '<P>3)   우리사주 조합원에게 신주를 우선 배정하는 경우</P>\n',
#  '<P>4)   주식매수선택권의 행사로 인하여 신주를 발행하는 경우</P>\n',
#  '<P>5)   자본시장과금융투자업에관한법률 제165조의16의 규정에 의하여 주식예탁증서(DR) 발행에 따라 신주를 발행하는 경우회사가 경영상 필요로 외국인투자촉진법에 의한 외국인투자를 위하여 신주를 발행하는 경우</P>\n',
#  '<P>6)   회사가 경영상 필요로 외국인투자촉진법에 의한 외국인투자를 위하여 신주를 발행하는 경우</P>\n',
#  '<P>7)   회사가 경영상 필요에 의하여 신규영업의 진출 및 사업목적의 확대 등을 위한 자금조달을 위하여 국내외 개인 또는 법인투자자에게 신주를 발행하는 경우</P>\n',
#  '<P>8)   중소기업창업지원법에 의한 중소기업 창업투자회사에 총 발행주식의 30%까지 배정하는 경우</P>\n',
#  '<P>9)   회사가 경영상 또는 기술도입을 필요로 국내 외 합작 또는 제휴법인,개인 투자자에게 신주를 발행하는 경우</P>\n',
#  '<P>10)   회사가 긴급한 자금의 조달을 위하여 국내외 금융기관 또는 개인투자자에게 신주를 발행하는 경우</P>\n',
#  '<P>11)   긴급한 자금 조달, 재무구조 개선, 인수합병, 사내복지 등 경영상의 목적을 달성하기 위하여 국내외 금융기관, 일반법인 및 국내외 개인에게 신주를 배정하는 경우</P>\n',
#  '<P>12)   근로자복지기본법 제 39조의 규정에 의하여 우리사주매수선택권 행사로 인하여 신주를 발행하는 경우</P>\n',
#  '<P>3.    제2항에 따라 주주외의 자에게 신주를 배정하는 경우 상법 제416조제1호,제2호, 제2호의 2,제3호,제4호에서 정하는 사항을 그 납입기일의 2주 전까지 주주에게 통지하거나 공고하여야 한다.</P>\n',
#  '<P>4.    주주가 신주인수권을 포기 또는 상실하거나 신주배정에서 단주가 발생하는 경우에 그 처리방법은 이사회의 결의로 정한다.</P>\n',
#  '</TE>\n',
#  '<TE WIDTH="300" HEIGHT="1603" ACODE="OBJ"> - 사업규모 팽창에 따른 자본증가 필요</TE>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '</TABLE-GROUP>\n',
#  '<P></P>\n',
#  '\n',
#  '<TABLE-GROUP ACLASS="THD_ASN_LST" ADELETETABLE="N">\n',
#  '\n',
#  '<TABLE ACLASS="NORMAL" AFIXTABLE="Y" WIDTH="600" BORDER="0">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="591"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TD WIDTH="600" HEIGHT="30" AUPDATECONT="N">【제3자배정 대상자별 선정경위, 거래내역, 배정내역 등】</TD>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '\n',
#  '<TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="637" BORDER="1">\n',
#  '\n',
#  '<COLGROUP>\n',
#  '<COL WIDTH="68"></COL>\n',
#  '<COL WIDTH="133"></COL>\n',
#  '<COL WIDTH="172"></COL>\n',
#  '<COL WIDTH="96"></COL>\n',
#  '<COL WIDTH="78"></COL>\n',
#  '<COL WIDTH="36"></COL>\n',
#  '</COLGROUP>\n',
#  '\n',
#  '<THEAD>\n',
#  '\n',
#  '<TR ACOPY="N" ADELETE="N">\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="77" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">제3자배정 대상자</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="142" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">회사 또는&cr;최대주주와의 관계</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="181" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">선정경위</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="105" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">증자결정 전후 6월이내 거래내역 및 계획</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="87" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">배정주식수 (주)</TH>\n',
#  '<TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="45" HEIGHT="76" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비 고</TH>\n',
#  '</TR>\n',
#  '</THEAD>\n',
#  '\n',
#  '<TBODY>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="N">\n',
#  '<TE WIDTH="77" HEIGHT="53" ACODE="PART" VALIGN="MIDDLE" ALIGN="CENTER">안진수</TE>\n',
#  '<TE WIDTH="142" HEIGHT="53" ACODE="RLT" VALIGN="MIDDLE" ALIGN="CENTER">등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="53" ACODE="SLT_JDG" VALIGN="MIDDLE" ALIGN="CENTER">경영상 목적달성을 위해 &cr;당사 정관에 의거 선정 </TE>\n',
#  '<TE WIDTH="105" HEIGHT="53" ACODE="MNTH" VALIGN="MIDDLE" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="53" ACODE="ALL_CNT" VALIGN="MIDDLE">10,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="53" ACODE="ETC" VALIGN="MIDDLE" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">조현만</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">8,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">손삼달</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">미등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">6,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">조성찬</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">미등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">5,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">채의석</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">경영지원본부장</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">3,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">윤규선</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">관계사 등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">3,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '\n',
#  '<TR ACOPY="Y" ADELETE="Y">\n',
#  '<TE WIDTH="77" HEIGHT="30" ACODE="PART" ALIGN="CENTER">이광재</TE>\n',
#  '<TE WIDTH="142" HEIGHT="30" ACODE="RLT" ALIGN="CENTER">관계사 등기임원</TE>\n',
#  '<TE WIDTH="181" HEIGHT="30" ACODE="SLT_JDG" ALIGN="CENTER">상동</TE>\n',
#  '<TE WIDTH="105" HEIGHT="30" ACODE="MNTH" ALIGN="CENTER">-</TE>\n',
#  '<TE ALIGN="RIGHT" WIDTH="87" HEIGHT="30" ACODE="ALL_CNT">3,000 </TE>\n',
#  '<TE WIDTH="45" HEIGHT="30" ACODE="ETC" ALIGN="CENTER">-</TE>\n',
#  '</TR>\n',
#  '</TBODY>\n',
#  '</TABLE>\n',
#  '</TABLE-GROUP>\n',
#  '</LIBRARY>\n',
#  '</INSERTION>\n',
#  '</SECTION-1>\n',
#  '</BODY>\n',
#  '</DOCUMENT>']

# %%
import xml.etree.ElementTree
import re
tree = xml.etree.ElementTree.parse('./data/공시원문/temp.xml')
root=tree.getroot()
lis = []
for tbody in root.iter('TBODY'):
    for tr in tbody.iter('TR'):
        for td in tr.findall('TD'):
            lis.append(re.sub('\r','',td.text))
lis

# %%
path = os.getcwd()
name = df_KOSPI[df_KOSPI['Symbol']=='005930']['Name'].iloc[0]
rpt_name = 'B'

path1 = os.path.join(path,'data','공시원문_xml파일',name,rpt_name)

if not os.path.exists(path1):
    os.makedirs(path1)

# %%
api_key = '27676a3402dacfa13da58c1b44a0d723cae77a1e'
dart_fss.set_api_key(api_key=api_key)

# 기업개수 820개 확인
crp_df = fdr.StockListing('KRX')
df_KOSPI = crp_df[crp_df['Market'] == 'KOSPI']
df_KOSPI1 = df_KOSPI[~df_KOSPI['ListingDate'].isnull() ]
code_lst = df_KOSPI1['Symbol']
corp_list = dart_fss.corp.get_corp_list()

# 증권 코드를 이용한 찾기.
code = code_lst
rpt_type = ['B','C','D','E','F','G','H','J']  # I 수정필요
bgn = '20120101'
end = '20220531'

x_corp_name = []
x_rpt_name = []
x_rpt_date= []
x_rpt_no= []


for code in code_lst[:1]:
    
    # 회사이름
    name = df_KOSPI1[df_KOSPI1['Symbol']==code]['Name'].iloc[0]
    corp = corp_list.find_by_stock_code(code)
    
    for rpt in rpt_type[:1]:
        
        try:
            reports = corp.search_filings(bgn_de= bgn, end_de= end, page_count= 100, pblntf_ty= rpt)

            for page in range(1,reports.total_page+1):

                for i in range(len(reports.report_list)):
                    # 공시일
                    date = reports.report_list[i].rcept_dt

                    # 리포트 숫자명
                    rcp_no = reports.report_list[i].rcp_no

                    #리포트 이름
                    rpt_name = reports.report_list[i].report_nm

                    try:
                        # zip파일 다운받기
                        dart_fss.api.filings.download_document('./data/공시원문/{}_{}'.format(name,rcp_no),rcp_no)

                        # 회사이름+ 리포트타입 파일
                        path = os.getcwd()
                        path1 = os.path.join(path,'data','공시원문_xml파일',name,rpt)

                        if not os.path.exists(path1):
                            os.makedirs(path1)


                        # 첫번째 압축풀기
                        zf = zipfile.ZipFile('./data/공시원문/{}_{}/{}.zip'.format(name,rcp_no,rcp_no)).extractall('./data/공시원문_압축해제/{}'.format(rcp_no))
                        
#                         # encoding 깨짐 문제 : euc-kr로 읽고 utf-8로 인코딩 후 temp.xml로 저장
#                         with open('./data/공시원문_압축해제/{}/{}.xml'.format(rcp_no,rcp_no), 'r', encoding='euc-kr') as fp:
#                             lines = fp.readlines()
#                         # &cr; 문자열 대체
#                         lines = [x.replace('&cr', '&#13;') for x in lines]
#                         lines = [x.replace('<주', '&lt;주') for x in lines]
#                         lines = [x.replace('M&A', 'M&amp;A') for x in lines]
#                         lines = [x.replace('R&D', 'R&amp;A') for x in lines]

#                         with open('./data/공시원문_xml파일/{}/{}/{}_{}_{}_{}.xml'.format(name,rpt,name,rpt,rpt_name,rcp_no), 'w', encoding='utf-8') as fp:
#                             fp.writelines(lines)

                    except:
                        x_corp_name.append(name)
                        x_rpt_name.append(rpt_name)
                        x_rpt_date.append(date)
                        x_rpt_no.append(rcp_no)
                        print('리포트이름: ',rpt_name)
                        print('공시일: ',date)
                        print('-'*50)
                        
        except:
            print('보고서타입 :', rpt)
# Out:
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [첨부정정]주요사항보고서(회사분할결정)
# 공시일:  20210108
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# 리포트이름:  [기재정정]주요사항보고서(타법인주식및출자증권양도결정)
# 공시일:  20190102
# --------------------------------------------------
# 리포트이름:  [기재정정]주요사항보고서(타법인주식및출자증권양도결정)
# 공시일:  20181228
# --------------------------------------------------
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()

# %%
# zip파일 다운받기
dart_fss.api.filings.download_document('./data/공시원문/{}_{}'.format(name,rcp_no),rcp_no)

# # 회사이름+ 리포트타입 파일
# path = os.getcwd()
# path1 = os.path.join(path,'data','공시원문_xml파일',name,rpt)

# if not os.path.exists(path1):
# os.makedirs(path1)


# 첫번째 압축풀기
zf = zipfile.ZipFile('./data/공시원문/{}_{}/{}.zip'.format(name,rcp_no,rcp_no)).extractall('./data/공시원문_압축해제/{}'.format(rcp_no))

# %%
pd.read_xml('./data/공시원문_압축해제/20120308000497/20120308000497.xml')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_824/2477681591.py in <module>
# ----> 1 pd.read_xml('./data/공시원문_압축해제/20120308000497/20120308000497.xml')
#
# ~\anaconda3\lib\site-packages\pandas\io\xml.py in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, encoding, parser, stylesheet, compression, storage_options)
#     925     """
#     926
# --> 927     return _parse(
#     928         path_or_buffer=path_or_buffer,
#     929         xpath=xpath,
#
# ~\anaconda3\lib\site-packages\pandas\io\xml.py in _parse(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, encoding, parser, stylesheet, compression, storage_options, **kwargs)
#     726         raise ValueError("Values for parser can only be lxml or etree.")
#     727
# --> 728     data_dicts = p.parse_data()
#     729
#     730     return _data_to_frame(data=data_dicts, **kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\io\xml.py in parse_data(self)
#     389         from lxml.etree import XML
#     390
# --> 391         self.xml_doc = XML(self._parse_doc(self.path_or_buffer))
#     392
#     393         if self.stylesheet is not None:
#
# ~\anaconda3\lib\site-packages\pandas\io\xml.py in _parse_doc(self, raw_doc)
#     540         )
#     541
# --> 542         handle_data = get_data_from_filepath(
#     543             filepath_or_buffer=raw_doc,
#     544             encoding=self.encoding,
#
# ~\anaconda3\lib\site-packages\pandas\io\xml.py in get_data_from_filepath(filepath_or_buffer, encoding, compression, storage_options)
#     611         ) as handle_obj:
#     612             filepath_or_buffer = (
# --> 613                 handle_obj.handle.read()
#     614                 if hasattr(handle_obj.handle, "read")
#     615                 else handle_obj.handle
#
# ~\anaconda3\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 214: invalid start byte
